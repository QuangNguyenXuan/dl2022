# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# To: /content/FER-2013.zip
# 100% 63.3M/63.3M [00:01<00:00, 43.6MB/s]

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/FER-2013.zip"

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng image_dataset_from_directory

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
tf.keras.utils.set_random_seed(1)
tf.config.experimental.enable_op_determinism()

# %%
batch_size = 256
img_height = 48
img_width = 48
train_dir = "/content/train" 
test_dir = "/content/test"

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  color_mode="grayscale")
# Out:
# Found 28709 files belonging to 7 classes.
# Using 22968 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  color_mode="grayscale")
# Out:
# Found 28709 files belonging to 7 classes.
# Using 5741 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(np.squeeze(images[i].numpy()).astype("uint8"), cmap="gray")
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
normalized_train_ds = train_ds.map(lambda x, y: (tf.subtract(tf.divide(x, 127.5),1), y))
normalized_val_ds = val_ds.map(lambda x, y: (tf.subtract(tf.divide(x, 127.5),1), y))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(buffer_size=512).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

normalized_train_ds = normalized_train_ds.cache().shuffle(buffer_size=512).prefetch(buffer_size=AUTOTUNE)
normalized_val_ds = normalized_val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %% [markdown]
# ##### Softmax Regression Norm

# %%
num_class = 7

######################### YOUR CODE HERE #########################
# Sử dụng tf.keras.Sequential để thiết kế model theo yêu cầu đề  bài 
FER_SRN_model = tf.keras.Sequential([
    # Flaten layer: input shape = (48,48,1)

    # Dense layer: 7 nodes (num_class)

])

FER_SRN_model.summary()
#
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
opt = tf.keras.optimizers.SGD(learning_rate=0.006)
# metric = tf.keras.metrics.SparseCategoricalAccuracy()
FER_SRN_model.compile(optimizer=opt,loss=loss, metrics=['accuracy'])

#
FER_SRN_history = FER_SRN_model.fit(normalized_train_ds, validation_data=normalized_val_ds, epochs=100)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_1 (Dense)             (None, 7)                 16135
#
# =================================================================
# Total params: 16,135
# Trainable params: 16,135
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 90/90 [==============================] - 6s 19ms/step - loss: 1.9033 - accuracy: 0.2264 - val_loss: 1.8417 - val_accuracy: 0.2519
# Epoch 2/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.8043 - accuracy: 0.2773 - val_loss: 1.7917 - val_accuracy: 0.2865
# Epoch 3/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.7640 - accuracy: 0.3021 - val_loss: 1.7656 - val_accuracy: 0.3019
# Epoch 4/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.7381 - accuracy: 0.3182 - val_loss: 1.7477 - val_accuracy: 0.3139
# Epoch 5/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.7208 - accuracy: 0.3305 - val_loss: 1.7356 - val_accuracy: 0.3217
# Epoch 6/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.7077 - accuracy: 0.3362 - val_loss: 1.7265 - val_accuracy: 0.3285
# Epoch 7/100
# 90/90 [==============================] - 1s 9ms/step - loss: 1.6974 - accuracy: 0.3427 - val_loss: 1.7191 - val_accuracy: 0.3334
# Epoch 8/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6890 - accuracy: 0.3453 - val_loss: 1.7138 - val_accuracy: 0.3369
# Epoch 9/100
# 90/90 [==============================] - 1s 10ms/step - loss: 1.6817 - accuracy: 0.3478 - val_loss: 1.7077 - val_accuracy: 0.3395
# Epoch 10/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6756 - accuracy: 0.3534 - val_loss: 1.7048 - val_accuracy: 0.3386
# Epoch 11/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6701 - accuracy: 0.3554 - val_loss: 1.7004 - val_accuracy: 0.3463
# Epoch 12/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6654 - accuracy: 0.3590 - val_loss: 1.6976 - val_accuracy: 0.3418
# Epoch 13/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6607 - accuracy: 0.3602 - val_loss: 1.6936 - val_accuracy: 0.3485
# Epoch 14/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6564 - accuracy: 0.3631 - val_loss: 1.6931 - val_accuracy: 0.3478
# Epoch 15/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6528 - accuracy: 0.3647 - val_loss: 1.6891 - val_accuracy: 0.3501
# Epoch 16/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6492 - accuracy: 0.3657 - val_loss: 1.6879 - val_accuracy: 0.3524
# Epoch 17/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6461 - accuracy: 0.3662 - val_loss: 1.6853 - val_accuracy: 0.3552
# Epoch 18/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6423 - accuracy: 0.3675 - val_loss: 1.6840 - val_accuracy: 0.3550
# Epoch 19/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6398 - accuracy: 0.3697 - val_loss: 1.6817 - val_accuracy: 0.3520
# Epoch 20/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6369 - accuracy: 0.3721 - val_loss: 1.6818 - val_accuracy: 0.3519
# Epoch 21/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6341 - accuracy: 0.3719 - val_loss: 1.6778 - val_accuracy: 0.3531
# Epoch 22/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6315 - accuracy: 0.3730 - val_loss: 1.6779 - val_accuracy: 0.3526
# Epoch 23/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6290 - accuracy: 0.3734 - val_loss: 1.6752 - val_accuracy: 0.3613
# Epoch 24/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6265 - accuracy: 0.3766 - val_loss: 1.6769 - val_accuracy: 0.3573
# Epoch 25/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6246 - accuracy: 0.3749 - val_loss: 1.6736 - val_accuracy: 0.3536
# Epoch 26/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6225 - accuracy: 0.3766 - val_loss: 1.6713 - val_accuracy: 0.3571
# Epoch 27/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6202 - accuracy: 0.3756 - val_loss: 1.6743 - val_accuracy: 0.3550
# Epoch 28/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6184 - accuracy: 0.3788 - val_loss: 1.6716 - val_accuracy: 0.3560
# Epoch 29/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6162 - accuracy: 0.3802 - val_loss: 1.6692 - val_accuracy: 0.3593
# Epoch 30/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6144 - accuracy: 0.3800 - val_loss: 1.6687 - val_accuracy: 0.3564
# Epoch 31/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6128 - accuracy: 0.3805 - val_loss: 1.6680 - val_accuracy: 0.3607
# Epoch 32/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6106 - accuracy: 0.3828 - val_loss: 1.6686 - val_accuracy: 0.3627
# Epoch 33/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6091 - accuracy: 0.3822 - val_loss: 1.6647 - val_accuracy: 0.3634
# Epoch 34/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6073 - accuracy: 0.3833 - val_loss: 1.6687 - val_accuracy: 0.3573
# Epoch 35/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6056 - accuracy: 0.3851 - val_loss: 1.6633 - val_accuracy: 0.3658
# Epoch 36/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6046 - accuracy: 0.3842 - val_loss: 1.6652 - val_accuracy: 0.3588
# Epoch 37/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6025 - accuracy: 0.3871 - val_loss: 1.6629 - val_accuracy: 0.3634
# Epoch 38/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6015 - accuracy: 0.3866 - val_loss: 1.6608 - val_accuracy: 0.3667
# Epoch 39/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5998 - accuracy: 0.3878 - val_loss: 1.6606 - val_accuracy: 0.3651
# Epoch 40/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5981 - accuracy: 0.3875 - val_loss: 1.6607 - val_accuracy: 0.3670
# Epoch 41/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5968 - accuracy: 0.3878 - val_loss: 1.6598 - val_accuracy: 0.3635
# Epoch 42/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5952 - accuracy: 0.3901 - val_loss: 1.6610 - val_accuracy: 0.3621
# Epoch 43/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5940 - accuracy: 0.3901 - val_loss: 1.6606 - val_accuracy: 0.3621
# Epoch 44/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5930 - accuracy: 0.3884 - val_loss: 1.6570 - val_accuracy: 0.3677
# Epoch 45/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5917 - accuracy: 0.3904 - val_loss: 1.6588 - val_accuracy: 0.3660
# Epoch 46/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5905 - accuracy: 0.3898 - val_loss: 1.6599 - val_accuracy: 0.3644
# Epoch 47/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5891 - accuracy: 0.3907 - val_loss: 1.6594 - val_accuracy: 0.3632
# Epoch 48/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5881 - accuracy: 0.3916 - val_loss: 1.6569 - val_accuracy: 0.3668
# Epoch 49/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5867 - accuracy: 0.3922 - val_loss: 1.6550 - val_accuracy: 0.3679
# Epoch 50/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5856 - accuracy: 0.3932 - val_loss: 1.6556 - val_accuracy: 0.3658
# Epoch 51/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5846 - accuracy: 0.3953 - val_loss: 1.6563 - val_accuracy: 0.3658
# Epoch 52/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5837 - accuracy: 0.3962 - val_loss: 1.6555 - val_accuracy: 0.3658
# Epoch 53/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5824 - accuracy: 0.3952 - val_loss: 1.6554 - val_accuracy: 0.3660
# Epoch 54/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5814 - accuracy: 0.3963 - val_loss: 1.6557 - val_accuracy: 0.3682
# Epoch 55/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5802 - accuracy: 0.3963 - val_loss: 1.6527 - val_accuracy: 0.3686
# Epoch 56/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5793 - accuracy: 0.3962 - val_loss: 1.6528 - val_accuracy: 0.3675
# Epoch 57/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5784 - accuracy: 0.3964 - val_loss: 1.6543 - val_accuracy: 0.3705
# Epoch 58/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5774 - accuracy: 0.3974 - val_loss: 1.6540 - val_accuracy: 0.3684
# Epoch 59/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5761 - accuracy: 0.3967 - val_loss: 1.6515 - val_accuracy: 0.3677
# Epoch 60/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5752 - accuracy: 0.3996 - val_loss: 1.6517 - val_accuracy: 0.3694
# Epoch 61/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5741 - accuracy: 0.3987 - val_loss: 1.6529 - val_accuracy: 0.3682
# Epoch 62/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5734 - accuracy: 0.3997 - val_loss: 1.6519 - val_accuracy: 0.3679
# Epoch 63/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5727 - accuracy: 0.3986 - val_loss: 1.6512 - val_accuracy: 0.3703
# Epoch 64/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5718 - accuracy: 0.3990 - val_loss: 1.6497 - val_accuracy: 0.3694
# Epoch 65/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5709 - accuracy: 0.4001 - val_loss: 1.6517 - val_accuracy: 0.3674
# Epoch 66/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5702 - accuracy: 0.4010 - val_loss: 1.6494 - val_accuracy: 0.3698
# Epoch 67/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5692 - accuracy: 0.3993 - val_loss: 1.6506 - val_accuracy: 0.3701
# Epoch 68/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.5682 - accuracy: 0.3996 - val_loss: 1.6521 - val_accuracy: 0.3677
# Epoch 69/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5675 - accuracy: 0.4016 - val_loss: 1.6528 - val_accuracy: 0.3670
# Epoch 70/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5668 - accuracy: 0.4011 - val_loss: 1.6487 - val_accuracy: 0.3698
# Epoch 71/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.5659 - accuracy: 0.4028 - val_loss: 1.6505 - val_accuracy: 0.3679
# Epoch 72/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5651 - accuracy: 0.4020 - val_loss: 1.6500 - val_accuracy: 0.3693
# Epoch 73/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5644 - accuracy: 0.4016 - val_loss: 1.6502 - val_accuracy: 0.3686
# Epoch 74/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5636 - accuracy: 0.4029 - val_loss: 1.6487 - val_accuracy: 0.3710
# Epoch 75/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5629 - accuracy: 0.4037 - val_loss: 1.6482 - val_accuracy: 0.3708
# Epoch 76/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5622 - accuracy: 0.4036 - val_loss: 1.6503 - val_accuracy: 0.3691
# Epoch 77/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5612 - accuracy: 0.4024 - val_loss: 1.6492 - val_accuracy: 0.3717
# Epoch 78/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5608 - accuracy: 0.4046 - val_loss: 1.6468 - val_accuracy: 0.3722
# Epoch 79/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5595 - accuracy: 0.4043 - val_loss: 1.6480 - val_accuracy: 0.3703
# Epoch 80/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5590 - accuracy: 0.4046 - val_loss: 1.6481 - val_accuracy: 0.3693
# Epoch 81/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5584 - accuracy: 0.4043 - val_loss: 1.6490 - val_accuracy: 0.3715
# Epoch 82/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5580 - accuracy: 0.4043 - val_loss: 1.6488 - val_accuracy: 0.3693
# Epoch 83/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5571 - accuracy: 0.4056 - val_loss: 1.6484 - val_accuracy: 0.3701
# Epoch 84/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5563 - accuracy: 0.4062 - val_loss: 1.6518 - val_accuracy: 0.3682
# Epoch 85/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5560 - accuracy: 0.4065 - val_loss: 1.6471 - val_accuracy: 0.3721
# Epoch 86/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5553 - accuracy: 0.4050 - val_loss: 1.6489 - val_accuracy: 0.3674
# Epoch 87/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5545 - accuracy: 0.4064 - val_loss: 1.6485 - val_accuracy: 0.3714
# Epoch 88/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5535 - accuracy: 0.4066 - val_loss: 1.6511 - val_accuracy: 0.3693
# Epoch 89/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5532 - accuracy: 0.4074 - val_loss: 1.6477 - val_accuracy: 0.3717
# Epoch 90/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5525 - accuracy: 0.4091 - val_loss: 1.6459 - val_accuracy: 0.3719
# Epoch 91/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5520 - accuracy: 0.4077 - val_loss: 1.6462 - val_accuracy: 0.3703
# Epoch 92/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5514 - accuracy: 0.4084 - val_loss: 1.6461 - val_accuracy: 0.3745
# Epoch 93/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5509 - accuracy: 0.4073 - val_loss: 1.6467 - val_accuracy: 0.3707
# Epoch 94/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5502 - accuracy: 0.4091 - val_loss: 1.6462 - val_accuracy: 0.3733
# Epoch 95/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5495 - accuracy: 0.4086 - val_loss: 1.6468 - val_accuracy: 0.3719
# Epoch 96/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5490 - accuracy: 0.4097 - val_loss: 1.6466 - val_accuracy: 0.3684
# Epoch 97/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5484 - accuracy: 0.4107 - val_loss: 1.6454 - val_accuracy: 0.3742
# Epoch 98/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5477 - accuracy: 0.4088 - val_loss: 1.6455 - val_accuracy: 0.3717
# Epoch 99/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5473 - accuracy: 0.4090 - val_loss: 1.6470 - val_accuracy: 0.3701
# Epoch 100/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5466 - accuracy: 0.4082 - val_loss: 1.6481 - val_accuracy: 0.3698

# %%
fig = plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.plot(FER_SRN_history.history['loss'], label='loss', color='red')
plt.plot(FER_SRN_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(FER_SRN_history.history['accuracy'], label='accuracy', color='red')
plt.plot(FER_SRN_history.history['val_accuracy'], label='val_accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(FER_SRN_history.history['loss'], label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(FER_SRN_history.history['accuracy'], label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(FER_SRN_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(FER_SRN_history.history['val_accuracy'], label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(FER_SRN_history.history)
hist['epoch'] = FER_SRN_history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 95  1.548996  0.409657  1.646556      0.368403     95
# 96  1.548406  0.410745  1.645396      0.374151     96
# 97  1.547715  0.408786  1.645513      0.371712     97
# 98  1.547278  0.409004  1.647018      0.370145     98
# 99  1.546625  0.408177  1.648090      0.369796     99

# %%
print("Max train acc: ", max(hist['accuracy']))
print("Max val acc: ", max(hist['val_accuracy']))

print("Min train loss: ", min(hist['loss']))
print("Min val loss: ", min(hist['val_loss']))
# Out:
# Max train acc:  0.41074538230895996
# Max val acc:  0.37449920177459717
# Min train loss:  1.5466246604919434
# Min val loss:  1.64539635181427
