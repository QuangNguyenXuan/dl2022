# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# To: /content/FER-2013.zip
# 100% 63.3M/63.3M [00:01<00:00, 43.6MB/s]

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/FER-2013.zip"

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng tf.data

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %%
import os
import pathlib
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
tf.keras.utils.set_random_seed(1)
tf.config.experimental.enable_op_determinism()

# %%
batch_size = 256
img_height = 48
img_width = 48
image_count = 28709 
train_dir = pathlib.Path("/content/train") 
test_dir = pathlib.Path("/content/test")

# %%
list_ds = tf.data.Dataset.list_files(str(train_dir/'*/*'), shuffle=False)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

# %%
for f in list_ds.take(7):
  print(f.numpy())
# Out:
# b'/content/train/neutral/Training_40464326.jpg'
# b'/content/train/fear/Training_89575609.jpg'
# b'/content/train/neutral/Training_94342256.jpg'
# b'/content/train/sad/Training_39660363.jpg'
# b'/content/train/sad/Training_70583207.jpg'
# b'/content/train/happy/Training_34322110.jpg'
# b'/content/train/happy/Training_96376941.jpg'

# %%
class_names = np.array(sorted([item.name for item in train_dir.glob('*')]))
print(class_names)
# Out:
# ['angry' 'disgust' 'fear' 'happy' 'neutral' 'sad' 'surprise']

# %%
val_size = int(image_count * 0.2)
train_ds = list_ds.skip(val_size)
val_ds = list_ds.take(val_size)

normalized_train_ds = list_ds.skip(val_size)
normalized_val_ds = list_ds.take(val_size)

# %%
# number of data
print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
# Out:
# 22968
# 5741

# %%
a = '/content/train/neutral/Training_79965780.jpg'
tf.strings.split(a, os.path.sep)
# Out:
# <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'', b'content', b'train', b'neutral', b'Training_79965780.jpg'],
#       dtype=object)>

# %%
np.array(["neutral"]) == np.array(['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise'])
# Out:
# array([False, False, False, False,  True, False, False])

# %%
def get_label(file_path):
  # Convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

# %%
def decode_img(img, norm):
  # Convert the compressed string to a 3D uint8 tensor
  img = tf.io.decode_jpeg(img, channels=1)
  # Resize the image to the desired size
  img = tf.image.resize(img, [img_height, img_width])
  # normalize
  if norm:
    img = img/127.5 - 1
  return img

# %%
def process_path(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img, norm=False)
  return img, label

def process_path_with_norm(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img, norm=True)
  return img, label

# %%
# for f in list_ds.take(7):
#   print(f.numpy())
#   print(process_path(f.numpy())[1])

# %%
AUTOTUNE = tf.data.AUTOTUNE
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=AUTOTUNE)

normalized_train_ds = normalized_train_ds.map(process_path_with_norm, num_parallel_calls=AUTOTUNE)
normalized_val_ds = normalized_val_ds.map(process_path_with_norm, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (48, 48, 1)
# Label:  3

# %%
def configure_for_performance(ds, train):
  ds = ds.cache()
  if train:
    ds = ds.shuffle(buffer_size=512)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

train_ds2 = configure_for_performance(train_ds, train=True)
val_ds2 = configure_for_performance(val_ds, train=False)

normalized_train_ds2 = configure_for_performance(normalized_train_ds, train=True)
normalized_val_ds2 = configure_for_performance(normalized_val_ds, train=False)

# %%
image_batch, label_batch = next(iter(train_ds2))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  minv = image_batch[i].numpy().min()
  maxv = image_batch[i].numpy().max()
  plt.imshow(np.squeeze(image_batch[i].numpy()), vmin=minv, vmax=maxv, cmap="gray")
  label = label_batch[i]
  plt.title(class_names[label])
  plt.axis("off")

# %% [markdown]
# ##### MLP - relu

# %%
num_class = 7

######################### YOUR CODE HERE #########################
# Sử dụng tf.keras.Sequential để thiết kế model theo yêu cầu đề  bài 
MLP_relu_model = tf.keras.Sequential([
    # Flaten layer: input shape = (48,48,1)

    # Hidden layer 1: 1024 nodes, activation = relu

    # Hidden layer 2: 512 nodes, activation = relu

    # Hidden layer 3: 256 nodes, activation = relu

    # Output layer: 7 nodes (num_class)
])
##################################################################
MLP_relu_model.summary()
#
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
opt = tf.keras.optimizers.SGD(learning_rate=0.006)
# metric = tf.keras.metrics.SparseCategoricalAccuracy()
MLP_relu_model.compile(optimizer=opt,loss=loss, metrics=['accuracy'])

#
MLP_relu_history = MLP_relu_model.fit(normalized_train_ds2, validation_data=normalized_val_ds2, epochs=100)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_7 (Flatten)         (None, 2304)              0
#
#  dense_16 (Dense)            (None, 1024)              2360320
#
#  dense_17 (Dense)            (None, 512)               524800
#
#  dense_18 (Dense)            (None, 256)               131328
#
#  dense_19 (Dense)            (None, 7)                 1799
#
# =================================================================
# Total params: 3,018,247
# Trainable params: 3,018,247
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 90/90 [==============================] - 1s 8ms/step - loss: 1.8441 - accuracy: 0.2398 - val_loss: 1.7841 - val_accuracy: 0.2747
# Epoch 2/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.7609 - accuracy: 0.2869 - val_loss: 1.7504 - val_accuracy: 0.2959
# Epoch 3/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.7259 - accuracy: 0.3113 - val_loss: 1.7267 - val_accuracy: 0.3128
# Epoch 4/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6972 - accuracy: 0.3349 - val_loss: 1.7067 - val_accuracy: 0.3226
# Epoch 5/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6720 - accuracy: 0.3509 - val_loss: 1.6899 - val_accuracy: 0.3353
# Epoch 6/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6496 - accuracy: 0.3669 - val_loss: 1.6758 - val_accuracy: 0.3437
# Epoch 7/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6303 - accuracy: 0.3747 - val_loss: 1.6643 - val_accuracy: 0.3484
# Epoch 8/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6133 - accuracy: 0.3838 - val_loss: 1.6548 - val_accuracy: 0.3526
# Epoch 9/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5987 - accuracy: 0.3911 - val_loss: 1.6469 - val_accuracy: 0.3578
# Epoch 10/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5852 - accuracy: 0.3972 - val_loss: 1.6410 - val_accuracy: 0.3604
# Epoch 11/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5734 - accuracy: 0.4032 - val_loss: 1.6351 - val_accuracy: 0.3602
# Epoch 12/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5621 - accuracy: 0.4096 - val_loss: 1.6300 - val_accuracy: 0.3634
# Epoch 13/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5517 - accuracy: 0.4134 - val_loss: 1.6256 - val_accuracy: 0.3660
# Epoch 14/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5416 - accuracy: 0.4189 - val_loss: 1.6212 - val_accuracy: 0.3668
# Epoch 15/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5318 - accuracy: 0.4224 - val_loss: 1.6168 - val_accuracy: 0.3675
# Epoch 16/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5227 - accuracy: 0.4265 - val_loss: 1.6132 - val_accuracy: 0.3698
# Epoch 17/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5130 - accuracy: 0.4312 - val_loss: 1.6097 - val_accuracy: 0.3728
# Epoch 18/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5039 - accuracy: 0.4355 - val_loss: 1.6069 - val_accuracy: 0.3719
# Epoch 19/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4952 - accuracy: 0.4402 - val_loss: 1.6027 - val_accuracy: 0.3743
# Epoch 20/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4866 - accuracy: 0.4434 - val_loss: 1.5997 - val_accuracy: 0.3757
# Epoch 21/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4779 - accuracy: 0.4491 - val_loss: 1.5972 - val_accuracy: 0.3780
# Epoch 22/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4692 - accuracy: 0.4516 - val_loss: 1.5940 - val_accuracy: 0.3797
# Epoch 23/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4608 - accuracy: 0.4564 - val_loss: 1.5913 - val_accuracy: 0.3796
# Epoch 24/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4519 - accuracy: 0.4605 - val_loss: 1.5880 - val_accuracy: 0.3809
# Epoch 25/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4433 - accuracy: 0.4649 - val_loss: 1.5869 - val_accuracy: 0.3815
# Epoch 26/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4350 - accuracy: 0.4697 - val_loss: 1.5846 - val_accuracy: 0.3832
# Epoch 27/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4264 - accuracy: 0.4749 - val_loss: 1.5808 - val_accuracy: 0.3853
# Epoch 28/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4176 - accuracy: 0.4787 - val_loss: 1.5785 - val_accuracy: 0.3860
# Epoch 29/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4095 - accuracy: 0.4812 - val_loss: 1.5787 - val_accuracy: 0.3881
# Epoch 30/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4006 - accuracy: 0.4888 - val_loss: 1.5742 - val_accuracy: 0.3870
# Epoch 31/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.3924 - accuracy: 0.4912 - val_loss: 1.5724 - val_accuracy: 0.3912
# Epoch 32/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3837 - accuracy: 0.4940 - val_loss: 1.5703 - val_accuracy: 0.3907
# Epoch 33/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3750 - accuracy: 0.4979 - val_loss: 1.5678 - val_accuracy: 0.3942
# Epoch 34/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3662 - accuracy: 0.5020 - val_loss: 1.5664 - val_accuracy: 0.3928
# Epoch 35/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3579 - accuracy: 0.5071 - val_loss: 1.5656 - val_accuracy: 0.3940
# Epoch 36/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3488 - accuracy: 0.5120 - val_loss: 1.5650 - val_accuracy: 0.3938
# Epoch 37/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3399 - accuracy: 0.5145 - val_loss: 1.5650 - val_accuracy: 0.3942
# Epoch 38/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3307 - accuracy: 0.5183 - val_loss: 1.5629 - val_accuracy: 0.3998
# Epoch 39/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3220 - accuracy: 0.5219 - val_loss: 1.5596 - val_accuracy: 0.3987
# Epoch 40/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3128 - accuracy: 0.5281 - val_loss: 1.5567 - val_accuracy: 0.3954
# Epoch 41/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3025 - accuracy: 0.5294 - val_loss: 1.5575 - val_accuracy: 0.3973
# Epoch 42/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2938 - accuracy: 0.5343 - val_loss: 1.5610 - val_accuracy: 0.3992
# Epoch 43/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2849 - accuracy: 0.5388 - val_loss: 1.5562 - val_accuracy: 0.4001
# Epoch 44/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2754 - accuracy: 0.5426 - val_loss: 1.5565 - val_accuracy: 0.3987
# Epoch 45/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2656 - accuracy: 0.5467 - val_loss: 1.5585 - val_accuracy: 0.4003
# Epoch 46/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2559 - accuracy: 0.5514 - val_loss: 1.5556 - val_accuracy: 0.3998
# Epoch 47/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2460 - accuracy: 0.5545 - val_loss: 1.5551 - val_accuracy: 0.4018
# Epoch 48/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2363 - accuracy: 0.5584 - val_loss: 1.5525 - val_accuracy: 0.4003
# Epoch 49/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2261 - accuracy: 0.5639 - val_loss: 1.5517 - val_accuracy: 0.4024
# Epoch 50/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2173 - accuracy: 0.5679 - val_loss: 1.5569 - val_accuracy: 0.4017
# Epoch 51/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2066 - accuracy: 0.5717 - val_loss: 1.5534 - val_accuracy: 0.4050
# Epoch 52/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1964 - accuracy: 0.5775 - val_loss: 1.5548 - val_accuracy: 0.4018
# Epoch 53/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1847 - accuracy: 0.5832 - val_loss: 1.5517 - val_accuracy: 0.4048
# Epoch 54/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1747 - accuracy: 0.5849 - val_loss: 1.5566 - val_accuracy: 0.4050
# Epoch 55/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1639 - accuracy: 0.5904 - val_loss: 1.5580 - val_accuracy: 0.4032
# Epoch 56/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1534 - accuracy: 0.5947 - val_loss: 1.5545 - val_accuracy: 0.4074
# Epoch 57/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1415 - accuracy: 0.6001 - val_loss: 1.5565 - val_accuracy: 0.4036
# Epoch 58/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1325 - accuracy: 0.6046 - val_loss: 1.5572 - val_accuracy: 0.4055
# Epoch 59/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1201 - accuracy: 0.6079 - val_loss: 1.5590 - val_accuracy: 0.4067
# Epoch 60/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1086 - accuracy: 0.6151 - val_loss: 1.5580 - val_accuracy: 0.4088
# Epoch 61/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0979 - accuracy: 0.6179 - val_loss: 1.5588 - val_accuracy: 0.4052
# Epoch 62/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0855 - accuracy: 0.6272 - val_loss: 1.5655 - val_accuracy: 0.4076
# Epoch 63/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0763 - accuracy: 0.6276 - val_loss: 1.5730 - val_accuracy: 0.4050
# Epoch 64/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0636 - accuracy: 0.6368 - val_loss: 1.5713 - val_accuracy: 0.4088
# Epoch 65/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0513 - accuracy: 0.6425 - val_loss: 1.5863 - val_accuracy: 0.4039
# Epoch 66/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0393 - accuracy: 0.6496 - val_loss: 1.6123 - val_accuracy: 0.3942
# Epoch 67/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0305 - accuracy: 0.6522 - val_loss: 1.5726 - val_accuracy: 0.4074
# Epoch 68/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0147 - accuracy: 0.6567 - val_loss: 1.5749 - val_accuracy: 0.4111
# Epoch 69/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0053 - accuracy: 0.6620 - val_loss: 1.5854 - val_accuracy: 0.4011
# Epoch 70/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.9927 - accuracy: 0.6674 - val_loss: 1.5845 - val_accuracy: 0.4062
# Epoch 71/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.9778 - accuracy: 0.6775 - val_loss: 1.6012 - val_accuracy: 0.4085
# Epoch 72/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.9672 - accuracy: 0.6783 - val_loss: 1.5885 - val_accuracy: 0.4078
# Epoch 73/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.9580 - accuracy: 0.6831 - val_loss: 1.6011 - val_accuracy: 0.4088
# Epoch 74/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.9426 - accuracy: 0.6885 - val_loss: 1.6065 - val_accuracy: 0.4079
# Epoch 75/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.9358 - accuracy: 0.6930 - val_loss: 1.6182 - val_accuracy: 0.4018
# Epoch 76/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.9273 - accuracy: 0.6935 - val_loss: 1.6040 - val_accuracy: 0.4067
# Epoch 77/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.9125 - accuracy: 0.7035 - val_loss: 1.6121 - val_accuracy: 0.4130
# Epoch 78/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.9019 - accuracy: 0.7037 - val_loss: 1.6527 - val_accuracy: 0.4062
# Epoch 79/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8893 - accuracy: 0.7121 - val_loss: 1.6690 - val_accuracy: 0.4114
# Epoch 80/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8821 - accuracy: 0.7153 - val_loss: 1.6237 - val_accuracy: 0.4149
# Epoch 81/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8653 - accuracy: 0.7204 - val_loss: 1.7089 - val_accuracy: 0.4067
# Epoch 82/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8545 - accuracy: 0.7255 - val_loss: 1.6360 - val_accuracy: 0.4038
# Epoch 83/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8443 - accuracy: 0.7302 - val_loss: 1.6325 - val_accuracy: 0.4137
# Epoch 84/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8303 - accuracy: 0.7344 - val_loss: 1.6465 - val_accuracy: 0.4139
# Epoch 85/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8328 - accuracy: 0.7315 - val_loss: 1.7620 - val_accuracy: 0.3883
# Epoch 86/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8152 - accuracy: 0.7430 - val_loss: 1.7283 - val_accuracy: 0.3904
# Epoch 87/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8023 - accuracy: 0.7468 - val_loss: 1.6721 - val_accuracy: 0.4156
# Epoch 88/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7933 - accuracy: 0.7529 - val_loss: 1.6914 - val_accuracy: 0.4104
# Epoch 89/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7745 - accuracy: 0.7595 - val_loss: 1.7193 - val_accuracy: 0.3989
# Epoch 90/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7585 - accuracy: 0.7669 - val_loss: 1.7005 - val_accuracy: 0.4006
# Epoch 91/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7495 - accuracy: 0.7711 - val_loss: 1.7459 - val_accuracy: 0.4118
# Epoch 92/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7478 - accuracy: 0.7718 - val_loss: 1.7950 - val_accuracy: 0.4097
# Epoch 93/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7182 - accuracy: 0.7802 - val_loss: 1.7825 - val_accuracy: 0.4069
# Epoch 94/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7219 - accuracy: 0.7824 - val_loss: 1.7371 - val_accuracy: 0.4072
# Epoch 95/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7257 - accuracy: 0.7781 - val_loss: 1.7509 - val_accuracy: 0.4107
# Epoch 96/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.6863 - accuracy: 0.7945 - val_loss: 1.8195 - val_accuracy: 0.4041
# Epoch 97/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.6746 - accuracy: 0.7984 - val_loss: 1.8115 - val_accuracy: 0.3926
# Epoch 98/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.6759 - accuracy: 0.8020 - val_loss: 1.7586 - val_accuracy: 0.4064
# Epoch 99/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.6926 - accuracy: 0.7939 - val_loss: 1.8175 - val_accuracy: 0.4100
# Epoch 100/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.6445 - accuracy: 0.8149 - val_loss: 1.7446 - val_accuracy: 0.4126

# %%
fig = plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.plot(MLP_relu_history.history['loss'], label='loss', color='red')
plt.plot(MLP_relu_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(MLP_relu_history.history['accuracy'], label='accuracy', color='red')
plt.plot(MLP_relu_history.history['val_accuracy'], label='val_accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(MLP_relu_history.history['loss'], label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(MLP_relu_history.history['accuracy'], label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(MLP_relu_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(MLP_relu_history.history['val_accuracy'], label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(MLP_relu_history.history)
hist['epoch'] = MLP_relu_history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 95  0.686313  0.794497  1.819481      0.404111     95
# 96  0.674639  0.798372  1.811483      0.392615     96
# 97  0.675895  0.802029  1.758592      0.406375     97
# 98  0.692637  0.793931  1.817509      0.410033     98
# 99  0.644516  0.814873  1.744606      0.412646     99

# %%
print("Max train acc: ", max(hist['accuracy']))
print("Max val acc: ", max(hist['val_accuracy']))

print("Min train loss: ", min(hist['loss']))
print("Min val loss: ", min(hist['val_loss']))
# Out:
# Max train acc:  0.8148728609085083
# Max val acc:  0.4156070351600647
# Min train loss:  0.6445164680480957
# Min val loss:  1.5517104864120483

# %%
# Min val loss:  1.5517104864120483
