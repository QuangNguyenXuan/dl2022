# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# To: /content/FER-2013.zip
# 100% 63.3M/63.3M [00:01<00:00, 43.6MB/s]

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/FER-2013.zip"

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng tf.data

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %%
import os
import pathlib
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
tf.keras.utils.set_random_seed(1)
tf.config.experimental.enable_op_determinism()

# %%
batch_size = 256
img_height = 48
img_width = 48
image_count = 28709 
train_dir = pathlib.Path("/content/train") 
test_dir = pathlib.Path("/content/test")

# %%
list_ds = tf.data.Dataset.list_files(str(train_dir/'*/*'), shuffle=False)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

# %%
for f in list_ds.take(7):
  print(f.numpy())
# Out:
# b'/content/train/neutral/Training_40464326.jpg'
# b'/content/train/fear/Training_89575609.jpg'
# b'/content/train/neutral/Training_94342256.jpg'
# b'/content/train/sad/Training_39660363.jpg'
# b'/content/train/sad/Training_70583207.jpg'
# b'/content/train/happy/Training_34322110.jpg'
# b'/content/train/happy/Training_96376941.jpg'

# %%
class_names = np.array(sorted([item.name for item in train_dir.glob('*')]))
print(class_names)
# Out:
# ['angry' 'disgust' 'fear' 'happy' 'neutral' 'sad' 'surprise']

# %%
val_size = int(image_count * 0.2)
train_ds = list_ds.skip(val_size)
val_ds = list_ds.take(val_size)

normalized_train_ds = list_ds.skip(val_size)
normalized_val_ds = list_ds.take(val_size)

# %%
# number of data
print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
# Out:
# 22968
# 5741

# %%
a = '/content/train/neutral/Training_79965780.jpg'
tf.strings.split(a, os.path.sep)
# Out:
# <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'', b'content', b'train', b'neutral', b'Training_79965780.jpg'],
#       dtype=object)>

# %%
np.array(["neutral"]) == np.array(['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise'])
# Out:
# array([False, False, False, False,  True, False, False])

# %%
def get_label(file_path):
  # Convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

# %%
def decode_img(img, norm):
  # Convert the compressed string to a 3D uint8 tensor
  img = tf.io.decode_jpeg(img, channels=1)
  # Resize the image to the desired size
  img = tf.image.resize(img, [img_height, img_width])
  # normalize
  if norm:
    img = img/127.5 - 1
  return img

# %%
def process_path(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img, norm=False)
  return img, label

def process_path_with_norm(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img, norm=True)
  return img, label

# %%
# for f in list_ds.take(7):
#   print(f.numpy())
#   print(process_path(f.numpy())[1])

# %%
AUTOTUNE = tf.data.AUTOTUNE
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=AUTOTUNE)

normalized_train_ds = normalized_train_ds.map(process_path_with_norm, num_parallel_calls=AUTOTUNE)
normalized_val_ds = normalized_val_ds.map(process_path_with_norm, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (48, 48, 1)
# Label:  3

# %%
def configure_for_performance(ds, train):
  ds = ds.cache()
  if train:
    ds = ds.shuffle(buffer_size=512)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

train_ds2 = configure_for_performance(train_ds, train=True)
val_ds2 = configure_for_performance(val_ds, train=False)

normalized_train_ds2 = configure_for_performance(normalized_train_ds, train=True)
normalized_val_ds2 = configure_for_performance(normalized_val_ds, train=False)

# %%
image_batch, label_batch = next(iter(train_ds2))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  minv = image_batch[i].numpy().min()
  maxv = image_batch[i].numpy().max()
  plt.imshow(np.squeeze(image_batch[i].numpy()), vmin=minv, vmax=maxv, cmap="gray")
  label = label_batch[i]
  plt.title(class_names[label])
  plt.axis("off")

# %% [markdown]
# ##### MLP - tanh

# %%
num_class = 7

######################### YOUR CODE HERE #########################
# Sử dụng tf.keras.Sequential để thiết kế model theo yêu cầu đề  bài 
MLP_tanh_model = tf.keras.Sequential([
    # Flaten layer: input shape = (48,48,1)

    # Hidden layer 1: 1024 nodes, activation = tanh

    # Hidden layer 2: 512 nodes, activation = tanh

    # Hidden layer 3: 256 nodes, activation = tanh

    # Output layer: 7 nodes (num_class)
])
##################################################################

MLP_tanh_model.summary()
#
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
opt = tf.keras.optimizers.SGD(learning_rate=0.006)
# metric = tf.keras.metrics.SparseCategoricalAccuracy()
MLP_tanh_model.compile(optimizer=opt,loss=loss, metrics=['accuracy'])

#
MLP_tanh_history = MLP_tanh_model.fit(normalized_train_ds2, validation_data=normalized_val_ds2, epochs=100)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_6 (Flatten)         (None, 2304)              0
#
#  dense_12 (Dense)            (None, 1024)              2360320
#
#  dense_13 (Dense)            (None, 512)               524800
#
#  dense_14 (Dense)            (None, 256)               131328
#
#  dense_15 (Dense)            (None, 7)                 1799
#
# =================================================================
# Total params: 3,018,247
# Trainable params: 3,018,247
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 90/90 [==============================] - 1s 8ms/step - loss: 1.8479 - accuracy: 0.2504 - val_loss: 1.7839 - val_accuracy: 0.2818
# Epoch 2/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.7405 - accuracy: 0.3149 - val_loss: 1.7331 - val_accuracy: 0.3196
# Epoch 3/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6958 - accuracy: 0.3378 - val_loss: 1.7084 - val_accuracy: 0.3289
# Epoch 4/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6688 - accuracy: 0.3531 - val_loss: 1.6910 - val_accuracy: 0.3365
# Epoch 5/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6489 - accuracy: 0.3634 - val_loss: 1.6796 - val_accuracy: 0.3405
# Epoch 6/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6331 - accuracy: 0.3716 - val_loss: 1.6725 - val_accuracy: 0.3437
# Epoch 7/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6198 - accuracy: 0.3789 - val_loss: 1.6623 - val_accuracy: 0.3499
# Epoch 8/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6085 - accuracy: 0.3829 - val_loss: 1.6571 - val_accuracy: 0.3538
# Epoch 9/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5983 - accuracy: 0.3886 - val_loss: 1.6507 - val_accuracy: 0.3578
# Epoch 10/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5887 - accuracy: 0.3946 - val_loss: 1.6460 - val_accuracy: 0.3600
# Epoch 11/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5802 - accuracy: 0.4002 - val_loss: 1.6419 - val_accuracy: 0.3621
# Epoch 12/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5723 - accuracy: 0.4028 - val_loss: 1.6386 - val_accuracy: 0.3637
# Epoch 13/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5651 - accuracy: 0.4088 - val_loss: 1.6345 - val_accuracy: 0.3628
# Epoch 14/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.5573 - accuracy: 0.4083 - val_loss: 1.6329 - val_accuracy: 0.3647
# Epoch 15/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5512 - accuracy: 0.4133 - val_loss: 1.6302 - val_accuracy: 0.3656
# Epoch 16/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5453 - accuracy: 0.4151 - val_loss: 1.6279 - val_accuracy: 0.3672
# Epoch 17/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5386 - accuracy: 0.4180 - val_loss: 1.6248 - val_accuracy: 0.3653
# Epoch 18/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5326 - accuracy: 0.4207 - val_loss: 1.6243 - val_accuracy: 0.3688
# Epoch 19/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5268 - accuracy: 0.4226 - val_loss: 1.6226 - val_accuracy: 0.3674
# Epoch 20/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5208 - accuracy: 0.4275 - val_loss: 1.6209 - val_accuracy: 0.3672
# Epoch 21/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5156 - accuracy: 0.4287 - val_loss: 1.6183 - val_accuracy: 0.3708
# Epoch 22/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5099 - accuracy: 0.4319 - val_loss: 1.6174 - val_accuracy: 0.3715
# Epoch 23/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5046 - accuracy: 0.4337 - val_loss: 1.6163 - val_accuracy: 0.3728
# Epoch 24/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4997 - accuracy: 0.4359 - val_loss: 1.6164 - val_accuracy: 0.3714
# Epoch 25/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4942 - accuracy: 0.4370 - val_loss: 1.6129 - val_accuracy: 0.3726
# Epoch 26/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4889 - accuracy: 0.4412 - val_loss: 1.6125 - val_accuracy: 0.3742
# Epoch 27/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4840 - accuracy: 0.4433 - val_loss: 1.6139 - val_accuracy: 0.3712
# Epoch 28/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4793 - accuracy: 0.4457 - val_loss: 1.6093 - val_accuracy: 0.3794
# Epoch 29/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.4738 - accuracy: 0.4474 - val_loss: 1.6077 - val_accuracy: 0.3762
# Epoch 30/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4690 - accuracy: 0.4505 - val_loss: 1.6071 - val_accuracy: 0.3790
# Epoch 31/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4637 - accuracy: 0.4508 - val_loss: 1.6081 - val_accuracy: 0.3776
# Epoch 32/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4586 - accuracy: 0.4543 - val_loss: 1.6076 - val_accuracy: 0.3773
# Epoch 33/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4535 - accuracy: 0.4585 - val_loss: 1.6059 - val_accuracy: 0.3832
# Epoch 34/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4482 - accuracy: 0.4617 - val_loss: 1.6061 - val_accuracy: 0.3782
# Epoch 35/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4435 - accuracy: 0.4645 - val_loss: 1.6025 - val_accuracy: 0.3839
# Epoch 36/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4390 - accuracy: 0.4633 - val_loss: 1.6013 - val_accuracy: 0.3823
# Epoch 37/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4332 - accuracy: 0.4672 - val_loss: 1.6059 - val_accuracy: 0.3811
# Epoch 38/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4283 - accuracy: 0.4710 - val_loss: 1.6017 - val_accuracy: 0.3822
# Epoch 39/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4230 - accuracy: 0.4707 - val_loss: 1.6095 - val_accuracy: 0.3747
# Epoch 40/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4189 - accuracy: 0.4728 - val_loss: 1.6020 - val_accuracy: 0.3829
# Epoch 41/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4133 - accuracy: 0.4778 - val_loss: 1.5998 - val_accuracy: 0.3855
# Epoch 42/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4073 - accuracy: 0.4809 - val_loss: 1.6021 - val_accuracy: 0.3783
# Epoch 43/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4022 - accuracy: 0.4827 - val_loss: 1.6032 - val_accuracy: 0.3813
# Epoch 44/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3966 - accuracy: 0.4838 - val_loss: 1.6130 - val_accuracy: 0.3726
# Epoch 45/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3915 - accuracy: 0.4879 - val_loss: 1.5989 - val_accuracy: 0.3865
# Epoch 46/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3860 - accuracy: 0.4922 - val_loss: 1.6018 - val_accuracy: 0.3794
# Epoch 47/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3812 - accuracy: 0.4935 - val_loss: 1.5994 - val_accuracy: 0.3850
# Epoch 48/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.3756 - accuracy: 0.4959 - val_loss: 1.6022 - val_accuracy: 0.3773
# Epoch 49/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3697 - accuracy: 0.4991 - val_loss: 1.6005 - val_accuracy: 0.3811
# Epoch 50/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3647 - accuracy: 0.5007 - val_loss: 1.6001 - val_accuracy: 0.3858
# Epoch 51/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3594 - accuracy: 0.5031 - val_loss: 1.6028 - val_accuracy: 0.3850
# Epoch 52/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3539 - accuracy: 0.5045 - val_loss: 1.6031 - val_accuracy: 0.3797
# Epoch 53/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.3470 - accuracy: 0.5094 - val_loss: 1.6043 - val_accuracy: 0.3792
# Epoch 54/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3416 - accuracy: 0.5121 - val_loss: 1.6027 - val_accuracy: 0.3921
# Epoch 55/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3348 - accuracy: 0.5152 - val_loss: 1.5984 - val_accuracy: 0.3888
# Epoch 56/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.3299 - accuracy: 0.5187 - val_loss: 1.6007 - val_accuracy: 0.3879
# Epoch 57/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3245 - accuracy: 0.5176 - val_loss: 1.6001 - val_accuracy: 0.3869
# Epoch 58/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3177 - accuracy: 0.5234 - val_loss: 1.6022 - val_accuracy: 0.3897
# Epoch 59/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3115 - accuracy: 0.5259 - val_loss: 1.5974 - val_accuracy: 0.3926
# Epoch 60/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3049 - accuracy: 0.5272 - val_loss: 1.6088 - val_accuracy: 0.3771
# Epoch 61/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2996 - accuracy: 0.5294 - val_loss: 1.6009 - val_accuracy: 0.3914
# Epoch 62/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2927 - accuracy: 0.5339 - val_loss: 1.6061 - val_accuracy: 0.3830
# Epoch 63/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2853 - accuracy: 0.5341 - val_loss: 1.6180 - val_accuracy: 0.3722
# Epoch 64/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.2799 - accuracy: 0.5381 - val_loss: 1.6032 - val_accuracy: 0.3931
# Epoch 65/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.2725 - accuracy: 0.5428 - val_loss: 1.6061 - val_accuracy: 0.3872
# Epoch 66/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.2665 - accuracy: 0.5456 - val_loss: 1.6029 - val_accuracy: 0.3900
# Epoch 67/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2582 - accuracy: 0.5481 - val_loss: 1.6181 - val_accuracy: 0.3813
# Epoch 68/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2538 - accuracy: 0.5515 - val_loss: 1.6110 - val_accuracy: 0.3816
# Epoch 69/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2477 - accuracy: 0.5551 - val_loss: 1.6181 - val_accuracy: 0.3811
# Epoch 70/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2402 - accuracy: 0.5561 - val_loss: 1.6097 - val_accuracy: 0.3870
# Epoch 71/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2328 - accuracy: 0.5609 - val_loss: 1.6033 - val_accuracy: 0.3930
# Epoch 72/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.2267 - accuracy: 0.5616 - val_loss: 1.6078 - val_accuracy: 0.3879
# Epoch 73/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2191 - accuracy: 0.5646 - val_loss: 1.6064 - val_accuracy: 0.3877
# Epoch 74/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2113 - accuracy: 0.5690 - val_loss: 1.6122 - val_accuracy: 0.3890
# Epoch 75/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.2045 - accuracy: 0.5722 - val_loss: 1.6192 - val_accuracy: 0.3897
# Epoch 76/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1983 - accuracy: 0.5762 - val_loss: 1.6296 - val_accuracy: 0.3848
# Epoch 77/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1899 - accuracy: 0.5779 - val_loss: 1.6137 - val_accuracy: 0.3872
# Epoch 78/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1824 - accuracy: 0.5831 - val_loss: 1.6163 - val_accuracy: 0.3904
# Epoch 79/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1758 - accuracy: 0.5850 - val_loss: 1.6153 - val_accuracy: 0.3928
# Epoch 80/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1690 - accuracy: 0.5876 - val_loss: 1.6303 - val_accuracy: 0.3836
# Epoch 81/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1611 - accuracy: 0.5932 - val_loss: 1.6178 - val_accuracy: 0.3886
# Epoch 82/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1514 - accuracy: 0.5979 - val_loss: 1.6201 - val_accuracy: 0.3928
# Epoch 83/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.1438 - accuracy: 0.6005 - val_loss: 1.6318 - val_accuracy: 0.3863
# Epoch 84/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1380 - accuracy: 0.6020 - val_loss: 1.6377 - val_accuracy: 0.3888
# Epoch 85/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1307 - accuracy: 0.6064 - val_loss: 1.6472 - val_accuracy: 0.3928
# Epoch 86/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1222 - accuracy: 0.6114 - val_loss: 1.6209 - val_accuracy: 0.3907
# Epoch 87/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.1173 - accuracy: 0.6114 - val_loss: 1.6208 - val_accuracy: 0.3926
# Epoch 88/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1049 - accuracy: 0.6180 - val_loss: 1.6548 - val_accuracy: 0.3863
# Epoch 89/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1043 - accuracy: 0.6162 - val_loss: 1.6409 - val_accuracy: 0.3872
# Epoch 90/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.0993 - accuracy: 0.6196 - val_loss: 1.6321 - val_accuracy: 0.3905
# Epoch 91/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.0859 - accuracy: 0.6260 - val_loss: 1.6448 - val_accuracy: 0.3961
# Epoch 92/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.0753 - accuracy: 0.6314 - val_loss: 1.6322 - val_accuracy: 0.3904
# Epoch 93/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0726 - accuracy: 0.6303 - val_loss: 1.6662 - val_accuracy: 0.3820
# Epoch 94/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.0661 - accuracy: 0.6317 - val_loss: 1.6623 - val_accuracy: 0.3796
# Epoch 95/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0624 - accuracy: 0.6355 - val_loss: 1.7775 - val_accuracy: 0.3675
# Epoch 96/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0453 - accuracy: 0.6441 - val_loss: 1.6387 - val_accuracy: 0.3935
# Epoch 97/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0365 - accuracy: 0.6485 - val_loss: 1.6700 - val_accuracy: 0.3947
# Epoch 98/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.0322 - accuracy: 0.6486 - val_loss: 1.6587 - val_accuracy: 0.3947
# Epoch 99/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.0321 - accuracy: 0.6478 - val_loss: 1.6572 - val_accuracy: 0.3900
# Epoch 100/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0153 - accuracy: 0.6570 - val_loss: 1.6677 - val_accuracy: 0.3867

# %%
fig = plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.plot(MLP_tanh_history.history['loss'], label='loss', color='red')
plt.plot(MLP_tanh_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(MLP_tanh_history.history['accuracy'], label='accuracy', color='red')
plt.plot(MLP_tanh_history.history['val_accuracy'], label='val_accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(MLP_tanh_history.history['loss'], label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(MLP_tanh_history.history['accuracy'], label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(MLP_tanh_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(MLP_tanh_history.history['val_accuracy'], label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(MLP_tanh_history.history)
hist['epoch'] = MLP_tanh_history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 95  1.045316  0.644114  1.638662      0.393485     95
# 96  1.036528  0.648511  1.670021      0.394705     96
# 97  1.032171  0.648642  1.658699      0.394705     97
# 98  1.032062  0.647771  1.657216      0.390002     98
# 99  1.015295  0.656958  1.667725      0.386692     99

# %%
print("Max train acc: ", max(hist['accuracy']))
print("Max val acc: ", max(hist['val_accuracy']))

print("Min train loss: ", min(hist['loss']))
print("Min val loss: ", min(hist['val_loss']))
# Out:
# Max train acc:  0.6569575071334839
# Max val acc:  0.39609822630882263
# Min train loss:  1.015295386314392
# Min val loss:  1.5973646640777588
