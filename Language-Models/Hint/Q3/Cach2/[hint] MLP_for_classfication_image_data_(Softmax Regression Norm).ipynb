# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# To: /content/FER-2013.zip
# 100% 63.3M/63.3M [00:01<00:00, 43.6MB/s]

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/FER-2013.zip"

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng tf.data

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %%
import os
import pathlib
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
tf.keras.utils.set_random_seed(1)
tf.config.experimental.enable_op_determinism()

# %%
batch_size = 256
img_height = 48
img_width = 48
image_count = 28709 
train_dir = pathlib.Path("/content/train") 
test_dir = pathlib.Path("/content/test")

# %%
list_ds = tf.data.Dataset.list_files(str(train_dir/'*/*'), shuffle=False)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

# %%
for f in list_ds.take(7):
  print(f.numpy())
# Out:
# b'/content/train/neutral/Training_40464326.jpg'
# b'/content/train/fear/Training_89575609.jpg'
# b'/content/train/neutral/Training_94342256.jpg'
# b'/content/train/sad/Training_39660363.jpg'
# b'/content/train/sad/Training_70583207.jpg'
# b'/content/train/happy/Training_34322110.jpg'
# b'/content/train/happy/Training_96376941.jpg'

# %%
class_names = np.array(sorted([item.name for item in train_dir.glob('*')]))
print(class_names)
# Out:
# ['angry' 'disgust' 'fear' 'happy' 'neutral' 'sad' 'surprise']

# %%
val_size = int(image_count * 0.2)
train_ds = list_ds.skip(val_size)
val_ds = list_ds.take(val_size)

normalized_train_ds = list_ds.skip(val_size)
normalized_val_ds = list_ds.take(val_size)

# %%
# number of data
print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
# Out:
# 22968
# 5741

# %%
a = '/content/train/neutral/Training_79965780.jpg'
tf.strings.split(a, os.path.sep)
# Out:
# <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'', b'content', b'train', b'neutral', b'Training_79965780.jpg'],
#       dtype=object)>

# %%
np.array(["neutral"]) == np.array(['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise'])
# Out:
# array([False, False, False, False,  True, False, False])

# %%
def get_label(file_path):
  # Convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

# %%
def decode_img(img, norm):
  # Convert the compressed string to a 3D uint8 tensor
  img = tf.io.decode_jpeg(img, channels=1)
  # Resize the image to the desired size
  img = tf.image.resize(img, [img_height, img_width])
  # normalize
  if norm:
    img = img/127.5 - 1
  return img

# %%
def process_path(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img, norm=False)
  return img, label

def process_path_with_norm(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img, norm=True)
  return img, label

# %%
# for f in list_ds.take(7):
#   print(f.numpy())
#   print(process_path(f.numpy())[1])

# %%
AUTOTUNE = tf.data.AUTOTUNE
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=AUTOTUNE)

normalized_train_ds = normalized_train_ds.map(process_path_with_norm, num_parallel_calls=AUTOTUNE)
normalized_val_ds = normalized_val_ds.map(process_path_with_norm, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (48, 48, 1)
# Label:  3

# %%
def configure_for_performance(ds, train):
  ds = ds.cache()
  if train:
    ds = ds.shuffle(buffer_size=512)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

train_ds2 = configure_for_performance(train_ds, train=True)
val_ds2 = configure_for_performance(val_ds, train=False)

normalized_train_ds2 = configure_for_performance(normalized_train_ds, train=True)
normalized_val_ds2 = configure_for_performance(normalized_val_ds, train=False)

# %%
image_batch, label_batch = next(iter(train_ds2))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  minv = image_batch[i].numpy().min()
  maxv = image_batch[i].numpy().max()
  plt.imshow(np.squeeze(image_batch[i].numpy()), vmin=minv, vmax=maxv, cmap="gray")
  label = label_batch[i]
  plt.title(class_names[label])
  plt.axis("off")

# %% [markdown]
# ##### Softmax Regression Norm

# %%
num_class = 7

######################### YOUR CODE HERE #########################
# Sử dụng tf.keras.Sequential để thiết kế model theo yêu cầu đề  bài 
FER_SRN_model = tf.keras.Sequential([
    # Flaten layer: input shape = (48,48,1)

    # Dense layer: 7 nodes (num_class)

])
FER_SRN_model.summary()
#
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
opt = tf.keras.optimizers.SGD(learning_rate=0.006)
# metric = tf.keras.metrics.SparseCategoricalAccuracy()
FER_SRN_model.compile(optimizer=opt,loss=loss, metrics=['accuracy'])

#
FER_SRN_history = FER_SRN_model.fit(normalized_train_ds2, validation_data=normalized_val_ds2, epochs=100)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_5 (Flatten)         (None, 2304)              0
#
#  dense_11 (Dense)            (None, 7)                 16135
#
# =================================================================
# Total params: 16,135
# Trainable params: 16,135
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 90/90 [==============================] - 10s 100ms/step - loss: 1.9145 - accuracy: 0.2264 - val_loss: 1.8413 - val_accuracy: 0.2592
# Epoch 2/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.8096 - accuracy: 0.2808 - val_loss: 1.7907 - val_accuracy: 0.2935
# Epoch 3/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.7667 - accuracy: 0.3055 - val_loss: 1.7635 - val_accuracy: 0.3148
# Epoch 4/100
# 90/90 [==============================] - 1s 5ms/step - loss: 1.7404 - accuracy: 0.3201 - val_loss: 1.7456 - val_accuracy: 0.3256
# Epoch 5/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.7223 - accuracy: 0.3314 - val_loss: 1.7332 - val_accuracy: 0.3303
# Epoch 6/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.7091 - accuracy: 0.3384 - val_loss: 1.7245 - val_accuracy: 0.3336
# Epoch 7/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6988 - accuracy: 0.3440 - val_loss: 1.7171 - val_accuracy: 0.3404
# Epoch 8/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6902 - accuracy: 0.3497 - val_loss: 1.7118 - val_accuracy: 0.3405
# Epoch 9/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6830 - accuracy: 0.3524 - val_loss: 1.7065 - val_accuracy: 0.3418
# Epoch 10/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6770 - accuracy: 0.3565 - val_loss: 1.7029 - val_accuracy: 0.3424
# Epoch 11/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6716 - accuracy: 0.3586 - val_loss: 1.6978 - val_accuracy: 0.3438
# Epoch 12/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6664 - accuracy: 0.3619 - val_loss: 1.6950 - val_accuracy: 0.3452
# Epoch 13/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6619 - accuracy: 0.3650 - val_loss: 1.6922 - val_accuracy: 0.3465
# Epoch 14/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6580 - accuracy: 0.3656 - val_loss: 1.6894 - val_accuracy: 0.3484
# Epoch 15/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6539 - accuracy: 0.3681 - val_loss: 1.6868 - val_accuracy: 0.3506
# Epoch 16/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6501 - accuracy: 0.3695 - val_loss: 1.6850 - val_accuracy: 0.3505
# Epoch 17/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6469 - accuracy: 0.3725 - val_loss: 1.6826 - val_accuracy: 0.3517
# Epoch 18/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6440 - accuracy: 0.3744 - val_loss: 1.6806 - val_accuracy: 0.3520
# Epoch 19/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6406 - accuracy: 0.3757 - val_loss: 1.6784 - val_accuracy: 0.3541
# Epoch 20/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6377 - accuracy: 0.3779 - val_loss: 1.6773 - val_accuracy: 0.3573
# Epoch 21/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6355 - accuracy: 0.3794 - val_loss: 1.6757 - val_accuracy: 0.3548
# Epoch 22/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6327 - accuracy: 0.3800 - val_loss: 1.6744 - val_accuracy: 0.3567
# Epoch 23/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6303 - accuracy: 0.3816 - val_loss: 1.6726 - val_accuracy: 0.3566
# Epoch 24/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6276 - accuracy: 0.3831 - val_loss: 1.6716 - val_accuracy: 0.3580
# Epoch 25/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6256 - accuracy: 0.3824 - val_loss: 1.6700 - val_accuracy: 0.3599
# Epoch 26/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6234 - accuracy: 0.3840 - val_loss: 1.6689 - val_accuracy: 0.3614
# Epoch 27/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6212 - accuracy: 0.3851 - val_loss: 1.6680 - val_accuracy: 0.3625
# Epoch 28/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6191 - accuracy: 0.3863 - val_loss: 1.6667 - val_accuracy: 0.3600
# Epoch 29/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6172 - accuracy: 0.3879 - val_loss: 1.6654 - val_accuracy: 0.3613
# Epoch 30/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6153 - accuracy: 0.3877 - val_loss: 1.6645 - val_accuracy: 0.3625
# Epoch 31/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6134 - accuracy: 0.3892 - val_loss: 1.6637 - val_accuracy: 0.3621
# Epoch 32/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6117 - accuracy: 0.3886 - val_loss: 1.6626 - val_accuracy: 0.3628
# Epoch 33/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6097 - accuracy: 0.3895 - val_loss: 1.6629 - val_accuracy: 0.3627
# Epoch 34/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6081 - accuracy: 0.3916 - val_loss: 1.6609 - val_accuracy: 0.3637
# Epoch 35/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6065 - accuracy: 0.3912 - val_loss: 1.6602 - val_accuracy: 0.3644
# Epoch 36/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6049 - accuracy: 0.3920 - val_loss: 1.6601 - val_accuracy: 0.3635
# Epoch 37/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6035 - accuracy: 0.3938 - val_loss: 1.6585 - val_accuracy: 0.3658
# Epoch 38/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6021 - accuracy: 0.3928 - val_loss: 1.6584 - val_accuracy: 0.3656
# Epoch 39/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6003 - accuracy: 0.3942 - val_loss: 1.6570 - val_accuracy: 0.3670
# Epoch 40/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5989 - accuracy: 0.3944 - val_loss: 1.6572 - val_accuracy: 0.3656
# Epoch 41/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5975 - accuracy: 0.3945 - val_loss: 1.6566 - val_accuracy: 0.3670
# Epoch 42/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5962 - accuracy: 0.3962 - val_loss: 1.6561 - val_accuracy: 0.3660
# Epoch 43/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5949 - accuracy: 0.3965 - val_loss: 1.6552 - val_accuracy: 0.3670
# Epoch 44/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5933 - accuracy: 0.3969 - val_loss: 1.6546 - val_accuracy: 0.3668
# Epoch 45/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5921 - accuracy: 0.3979 - val_loss: 1.6542 - val_accuracy: 0.3677
# Epoch 46/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5912 - accuracy: 0.3966 - val_loss: 1.6535 - val_accuracy: 0.3682
# Epoch 47/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5899 - accuracy: 0.3980 - val_loss: 1.6531 - val_accuracy: 0.3682
# Epoch 48/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5887 - accuracy: 0.3981 - val_loss: 1.6529 - val_accuracy: 0.3682
# Epoch 49/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5874 - accuracy: 0.3984 - val_loss: 1.6527 - val_accuracy: 0.3675
# Epoch 50/100
# 90/90 [==============================] - 1s 5ms/step - loss: 1.5863 - accuracy: 0.3997 - val_loss: 1.6523 - val_accuracy: 0.3665
# Epoch 51/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5850 - accuracy: 0.4004 - val_loss: 1.6517 - val_accuracy: 0.3672
# Epoch 52/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5840 - accuracy: 0.3997 - val_loss: 1.6515 - val_accuracy: 0.3674
# Epoch 53/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5830 - accuracy: 0.4018 - val_loss: 1.6505 - val_accuracy: 0.3698
# Epoch 54/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5819 - accuracy: 0.4014 - val_loss: 1.6509 - val_accuracy: 0.3679
# Epoch 55/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5808 - accuracy: 0.4018 - val_loss: 1.6504 - val_accuracy: 0.3686
# Epoch 56/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5799 - accuracy: 0.4014 - val_loss: 1.6504 - val_accuracy: 0.3684
# Epoch 57/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5788 - accuracy: 0.4022 - val_loss: 1.6496 - val_accuracy: 0.3682
# Epoch 58/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5779 - accuracy: 0.4028 - val_loss: 1.6488 - val_accuracy: 0.3712
# Epoch 59/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5769 - accuracy: 0.4036 - val_loss: 1.6492 - val_accuracy: 0.3696
# Epoch 60/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5760 - accuracy: 0.4036 - val_loss: 1.6490 - val_accuracy: 0.3691
# Epoch 61/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5752 - accuracy: 0.4049 - val_loss: 1.6485 - val_accuracy: 0.3696
# Epoch 62/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5738 - accuracy: 0.4034 - val_loss: 1.6481 - val_accuracy: 0.3694
# Epoch 63/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5731 - accuracy: 0.4057 - val_loss: 1.6482 - val_accuracy: 0.3691
# Epoch 64/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5723 - accuracy: 0.4056 - val_loss: 1.6473 - val_accuracy: 0.3717
# Epoch 65/100
# 90/90 [==============================] - 1s 5ms/step - loss: 1.5713 - accuracy: 0.4058 - val_loss: 1.6471 - val_accuracy: 0.3703
# Epoch 66/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5704 - accuracy: 0.4066 - val_loss: 1.6469 - val_accuracy: 0.3712
# Epoch 67/100
# 90/90 [==============================] - 1s 5ms/step - loss: 1.5698 - accuracy: 0.4076 - val_loss: 1.6467 - val_accuracy: 0.3714
# Epoch 68/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5687 - accuracy: 0.4065 - val_loss: 1.6470 - val_accuracy: 0.3688
# Epoch 69/100
# 90/90 [==============================] - 1s 5ms/step - loss: 1.5680 - accuracy: 0.4070 - val_loss: 1.6466 - val_accuracy: 0.3703
# Epoch 70/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5671 - accuracy: 0.4066 - val_loss: 1.6462 - val_accuracy: 0.3705
# Epoch 71/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5664 - accuracy: 0.4077 - val_loss: 1.6462 - val_accuracy: 0.3694
# Epoch 72/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5656 - accuracy: 0.4078 - val_loss: 1.6463 - val_accuracy: 0.3698
# Epoch 73/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5649 - accuracy: 0.4093 - val_loss: 1.6456 - val_accuracy: 0.3715
# Epoch 74/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5642 - accuracy: 0.4091 - val_loss: 1.6456 - val_accuracy: 0.3705
# Epoch 75/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5633 - accuracy: 0.4097 - val_loss: 1.6454 - val_accuracy: 0.3700
# Epoch 76/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5627 - accuracy: 0.4092 - val_loss: 1.6449 - val_accuracy: 0.3712
# Epoch 77/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5618 - accuracy: 0.4097 - val_loss: 1.6449 - val_accuracy: 0.3708
# Epoch 78/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5611 - accuracy: 0.4107 - val_loss: 1.6446 - val_accuracy: 0.3694
# Epoch 79/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5605 - accuracy: 0.4097 - val_loss: 1.6447 - val_accuracy: 0.3703
# Epoch 80/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5598 - accuracy: 0.4102 - val_loss: 1.6444 - val_accuracy: 0.3701
# Epoch 81/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5592 - accuracy: 0.4104 - val_loss: 1.6442 - val_accuracy: 0.3715
# Epoch 82/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5583 - accuracy: 0.4102 - val_loss: 1.6442 - val_accuracy: 0.3701
# Epoch 83/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5577 - accuracy: 0.4111 - val_loss: 1.6445 - val_accuracy: 0.3681
# Epoch 84/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5569 - accuracy: 0.4101 - val_loss: 1.6441 - val_accuracy: 0.3701
# Epoch 85/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5564 - accuracy: 0.4119 - val_loss: 1.6437 - val_accuracy: 0.3722
# Epoch 86/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5557 - accuracy: 0.4120 - val_loss: 1.6433 - val_accuracy: 0.3715
# Epoch 87/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5549 - accuracy: 0.4120 - val_loss: 1.6438 - val_accuracy: 0.3698
# Epoch 88/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5545 - accuracy: 0.4126 - val_loss: 1.6433 - val_accuracy: 0.3712
# Epoch 89/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5537 - accuracy: 0.4124 - val_loss: 1.6435 - val_accuracy: 0.3710
# Epoch 90/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5533 - accuracy: 0.4128 - val_loss: 1.6434 - val_accuracy: 0.3691
# Epoch 91/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5525 - accuracy: 0.4121 - val_loss: 1.6428 - val_accuracy: 0.3721
# Epoch 92/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5518 - accuracy: 0.4127 - val_loss: 1.6429 - val_accuracy: 0.3722
# Epoch 93/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5513 - accuracy: 0.4144 - val_loss: 1.6434 - val_accuracy: 0.3712
# Epoch 94/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5507 - accuracy: 0.4144 - val_loss: 1.6432 - val_accuracy: 0.3724
# Epoch 95/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5503 - accuracy: 0.4147 - val_loss: 1.6429 - val_accuracy: 0.3728
# Epoch 96/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5496 - accuracy: 0.4134 - val_loss: 1.6427 - val_accuracy: 0.3721
# Epoch 97/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5490 - accuracy: 0.4141 - val_loss: 1.6426 - val_accuracy: 0.3729
# Epoch 98/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5485 - accuracy: 0.4136 - val_loss: 1.6429 - val_accuracy: 0.3705
# Epoch 99/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5479 - accuracy: 0.4142 - val_loss: 1.6424 - val_accuracy: 0.3719
# Epoch 100/100
# 90/90 [==============================] - 1s 5ms/step - loss: 1.5474 - accuracy: 0.4147 - val_loss: 1.6431 - val_accuracy: 0.3726

# %%
fig = plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.plot(FER_SRN_history.history['loss'], label='loss', color='red')
plt.plot(FER_SRN_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(FER_SRN_history.history['accuracy'], label='accuracy', color='red')
plt.plot(FER_SRN_history.history['val_accuracy'], label='val_accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(FER_SRN_history.history['loss'], label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(FER_SRN_history.history['accuracy'], label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(FER_SRN_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(FER_SRN_history.history['val_accuracy'], label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(FER_SRN_history.history)
hist['epoch'] = FER_SRN_history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 95  1.549627  0.413445  1.642713      0.372061     95
# 96  1.549027  0.414054  1.642617      0.372932     96
# 97  1.548454  0.413619  1.642864      0.370493     97
# 98  1.547877  0.414185  1.642392      0.371886     98
# 99  1.547378  0.414707  1.643099      0.372583     99

# %%
print("Max train acc: ", max(hist['accuracy']))
print("Max val acc: ", max(hist['val_accuracy']))

print("Min train loss: ", min(hist['loss']))
print("Min val loss: ", min(hist['val_loss']))
# Out:
# Max train acc:  0.4147074222564697
# Max val acc:  0.3729315400123596
# Min train loss:  1.5473779439926147
# Min val loss:  1.642391562461853
