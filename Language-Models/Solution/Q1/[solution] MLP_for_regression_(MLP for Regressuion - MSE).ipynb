# %% [markdown]
# ## Download data

# %%
# !gdown --id 1fB9P1Ha1ofQiYWU9wkLAxDZTbtp3Gfqz
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1fB9P1Ha1ofQiYWU9wkLAxDZTbtp3Gfqz
# To: /content/Auto_MPG_data.csv
# 100% 15.4k/15.4k [00:00<00:00, 22.7MB/s]

# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 35.8 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
tf.keras.utils.set_random_seed(1)
tf.config.experimental.enable_op_determinism()

# %% [markdown]
# ## Load Data

# %%
dataset = pd.read_csv("/content/Auto_MPG_data.csv")
dataset.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Europe  Japan  USA
# 0          70       0      0    1
# 1          70       0      0    1
# 2          70       0      0    1
# 3          70       0      0    1
# 4          70       0      0    1

# %% [markdown]
# ## Tiền xử lý dữ liệu dạng table

# %% [markdown]
# ### Lấy label và chia bộ dữ liệu train/val

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
val_dataset = dataset.drop(train_dataset.index)

# %%
X_train = train_dataset.copy()
X_val = val_dataset.copy()

y_train = X_train.pop('MPG')
y_val = X_val.pop('MPG')

X_train, y_train = X_train.to_numpy().astype(np.float32), y_train.to_numpy().astype(np.float32)
X_val, y_val = X_val.to_numpy().astype(np.float32), y_val.to_numpy().astype(np.float32)

# %% [markdown]
# ### Chuẩn hóa dữ liệu (Data Standardisation)

# %%
_MEAN = X_train.mean(axis=0)
_STD = X_train.std(axis=0)

X_train = ( X_train-_MEAN)/_STD
X_val = ( X_val-_MEAN)/_STD

# %% [markdown]
# ## Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %% [markdown]
# ### MLP for Regressuion - MSE

# %%
#
MLP_Regression_model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=64, input_shape=[9], activation="relu"),
    tf.keras.layers.Dense(units=64,  activation="relu"),
    tf.keras.layers.Dense(units=1)
])
MLP_Regression_model.summary()
#
opt = tf.keras.optimizers.SGD(learning_rate=0.003)
MLP_Regression_model.compile(optimizer=opt,loss="mse",
                             metrics=[tfa.metrics.RSquare(), tf.keras.metrics.MeanAbsoluteError()])

#
# MLP_Regression_history = MLP_Regression_model.fit(X_train, y_train, batch_size=X_train.shape[0], epochs=100, validation_split = 0.2)
MLP_Regression_history = MLP_Regression_model.fit( X_train, y_train, validation_data=(X_val, y_val) ,epochs=100)

# Epoch 100/100
# 10/10 [==============================] - 0s 10ms/step - loss: 6.0924 - r_square: 0.8977 - mean_absolute_error: 1.7126 - val_loss: 5.6777 - val_r_square: 0.9131 - val_mean_absolute_error: 1.8778
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                640
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 3s 27ms/step - loss: 296.0734 - r_square: -3.9725 - mean_absolute_error: 14.5132 - val_loss: 26.3167 - val_r_square: 0.5970 - val_mean_absolute_error: 4.2432
# Epoch 2/100
# 10/10 [==============================] - 0s 6ms/step - loss: 19.5951 - r_square: 0.6709 - mean_absolute_error: 3.3382 - val_loss: 11.0159 - val_r_square: 0.8313 - val_mean_absolute_error: 2.6030
# Epoch 3/100
# 10/10 [==============================] - 0s 5ms/step - loss: 11.7289 - r_square: 0.8030 - mean_absolute_error: 2.6248 - val_loss: 8.9781 - val_r_square: 0.8625 - val_mean_absolute_error: 2.3198
# Epoch 4/100
# 10/10 [==============================] - 0s 5ms/step - loss: 9.7467 - r_square: 0.8363 - mean_absolute_error: 2.3390 - val_loss: 8.7019 - val_r_square: 0.8668 - val_mean_absolute_error: 2.0379
# Epoch 5/100
# 10/10 [==============================] - 0s 5ms/step - loss: 9.5639 - r_square: 0.8394 - mean_absolute_error: 2.2224 - val_loss: 10.9111 - val_r_square: 0.8329 - val_mean_absolute_error: 2.5635
# Epoch 6/100
# 10/10 [==============================] - 0s 5ms/step - loss: 8.5742 - r_square: 0.8560 - mean_absolute_error: 2.1148 - val_loss: 6.8171 - val_r_square: 0.8956 - val_mean_absolute_error: 1.8636
# Epoch 7/100
# 10/10 [==============================] - 0s 5ms/step - loss: 9.1171 - r_square: 0.8469 - mean_absolute_error: 2.1946 - val_loss: 6.3697 - val_r_square: 0.9025 - val_mean_absolute_error: 1.8566
# Epoch 8/100
# 10/10 [==============================] - 0s 7ms/step - loss: 8.0550 - r_square: 0.8647 - mean_absolute_error: 2.0689 - val_loss: 7.2775 - val_r_square: 0.8886 - val_mean_absolute_error: 2.0630
# Epoch 9/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.4791 - r_square: 0.8744 - mean_absolute_error: 2.0063 - val_loss: 6.7576 - val_r_square: 0.8965 - val_mean_absolute_error: 1.9427
# Epoch 10/100
# 10/10 [==============================] - 0s 5ms/step - loss: 8.1495 - r_square: 0.8631 - mean_absolute_error: 2.0037 - val_loss: 6.1019 - val_r_square: 0.9066 - val_mean_absolute_error: 1.8004
# Epoch 11/100
# 10/10 [==============================] - 0s 7ms/step - loss: 7.4969 - r_square: 0.8741 - mean_absolute_error: 2.0050 - val_loss: 5.8853 - val_r_square: 0.9099 - val_mean_absolute_error: 1.7823
# Epoch 12/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.2194 - r_square: 0.8788 - mean_absolute_error: 1.9802 - val_loss: 8.6299 - val_r_square: 0.8679 - val_mean_absolute_error: 2.3203
# Epoch 13/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.7326 - r_square: 0.8701 - mean_absolute_error: 1.9749 - val_loss: 9.3529 - val_r_square: 0.8568 - val_mean_absolute_error: 2.4118
# Epoch 14/100
# 10/10 [==============================] - 0s 6ms/step - loss: 7.0694 - r_square: 0.8813 - mean_absolute_error: 1.9296 - val_loss: 6.8211 - val_r_square: 0.8956 - val_mean_absolute_error: 2.0104
# Epoch 15/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.0085 - r_square: 0.8823 - mean_absolute_error: 1.9379 - val_loss: 5.7772 - val_r_square: 0.9115 - val_mean_absolute_error: 1.8360
# Epoch 16/100
# 10/10 [==============================] - 0s 6ms/step - loss: 7.1303 - r_square: 0.8802 - mean_absolute_error: 1.9310 - val_loss: 6.2136 - val_r_square: 0.9049 - val_mean_absolute_error: 1.9996
# Epoch 17/100
# 10/10 [==============================] - 0s 8ms/step - loss: 8.0258 - r_square: 0.8652 - mean_absolute_error: 2.0605 - val_loss: 7.6327 - val_r_square: 0.8831 - val_mean_absolute_error: 2.2127
# Epoch 18/100
# 10/10 [==============================] - 0s 6ms/step - loss: 7.8534 - r_square: 0.8681 - mean_absolute_error: 2.0984 - val_loss: 7.5088 - val_r_square: 0.8850 - val_mean_absolute_error: 2.1416
# Epoch 19/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.8397 - r_square: 0.8851 - mean_absolute_error: 1.8623 - val_loss: 5.6765 - val_r_square: 0.9131 - val_mean_absolute_error: 1.7737
# Epoch 20/100
# 10/10 [==============================] - 0s 7ms/step - loss: 8.1590 - r_square: 0.8630 - mean_absolute_error: 2.0606 - val_loss: 5.7532 - val_r_square: 0.9119 - val_mean_absolute_error: 1.7952
# Epoch 21/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.8186 - r_square: 0.8855 - mean_absolute_error: 1.9096 - val_loss: 6.8754 - val_r_square: 0.8947 - val_mean_absolute_error: 2.0164
# Epoch 22/100
# 10/10 [==============================] - 0s 6ms/step - loss: 7.4766 - r_square: 0.8744 - mean_absolute_error: 1.9808 - val_loss: 6.1158 - val_r_square: 0.9064 - val_mean_absolute_error: 1.9658
# Epoch 23/100
# 10/10 [==============================] - 0s 6ms/step - loss: 7.2841 - r_square: 0.8777 - mean_absolute_error: 1.9418 - val_loss: 6.6051 - val_r_square: 0.8989 - val_mean_absolute_error: 1.9231
# Epoch 24/100
# 10/10 [==============================] - 0s 7ms/step - loss: 7.1471 - r_square: 0.8800 - mean_absolute_error: 1.8735 - val_loss: 6.9197 - val_r_square: 0.8940 - val_mean_absolute_error: 2.0778
# Epoch 25/100
# 10/10 [==============================] - 0s 6ms/step - loss: 7.0090 - r_square: 0.8823 - mean_absolute_error: 1.9049 - val_loss: 6.2800 - val_r_square: 0.9038 - val_mean_absolute_error: 1.7810
# Epoch 26/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.2934 - r_square: 0.8775 - mean_absolute_error: 1.9794 - val_loss: 5.7589 - val_r_square: 0.9118 - val_mean_absolute_error: 1.9116
# Epoch 27/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.7060 - r_square: 0.8874 - mean_absolute_error: 1.8526 - val_loss: 5.6645 - val_r_square: 0.9133 - val_mean_absolute_error: 1.9015
# Epoch 28/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.8918 - r_square: 0.8843 - mean_absolute_error: 1.8656 - val_loss: 5.3155 - val_r_square: 0.9186 - val_mean_absolute_error: 1.7883
# Epoch 29/100
# 10/10 [==============================] - 0s 6ms/step - loss: 7.0560 - r_square: 0.8815 - mean_absolute_error: 1.8988 - val_loss: 10.0975 - val_r_square: 0.8454 - val_mean_absolute_error: 2.5123
# Epoch 30/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.7153 - r_square: 0.8872 - mean_absolute_error: 1.8688 - val_loss: 6.4927 - val_r_square: 0.9006 - val_mean_absolute_error: 2.0473
# Epoch 31/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.5250 - r_square: 0.8904 - mean_absolute_error: 1.8602 - val_loss: 6.8117 - val_r_square: 0.8957 - val_mean_absolute_error: 1.8839
# Epoch 32/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.2026 - r_square: 0.8790 - mean_absolute_error: 1.8755 - val_loss: 5.7057 - val_r_square: 0.9126 - val_mean_absolute_error: 1.7678
# Epoch 33/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.5634 - r_square: 0.8898 - mean_absolute_error: 1.8457 - val_loss: 7.4358 - val_r_square: 0.8861 - val_mean_absolute_error: 2.1430
# Epoch 34/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.4849 - r_square: 0.8911 - mean_absolute_error: 1.8088 - val_loss: 13.3377 - val_r_square: 0.7958 - val_mean_absolute_error: 2.8387
# Epoch 35/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.0410 - r_square: 0.8817 - mean_absolute_error: 1.8823 - val_loss: 5.9424 - val_r_square: 0.9090 - val_mean_absolute_error: 1.7682
# Epoch 36/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.7730 - r_square: 0.8862 - mean_absolute_error: 1.8262 - val_loss: 5.7714 - val_r_square: 0.9116 - val_mean_absolute_error: 1.8333
# Epoch 37/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.1164 - r_square: 0.8805 - mean_absolute_error: 1.9162 - val_loss: 5.6491 - val_r_square: 0.9135 - val_mean_absolute_error: 1.7699
# Epoch 38/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.5748 - r_square: 0.8728 - mean_absolute_error: 1.9395 - val_loss: 5.7466 - val_r_square: 0.9120 - val_mean_absolute_error: 1.8249
# Epoch 39/100
# 10/10 [==============================] - 0s 8ms/step - loss: 6.8782 - r_square: 0.8845 - mean_absolute_error: 1.8786 - val_loss: 5.7184 - val_r_square: 0.9124 - val_mean_absolute_error: 1.7861
# Epoch 40/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.2692 - r_square: 0.8779 - mean_absolute_error: 1.9314 - val_loss: 5.6887 - val_r_square: 0.9129 - val_mean_absolute_error: 1.7910
# Epoch 41/100
# 10/10 [==============================] - 0s 7ms/step - loss: 6.6077 - r_square: 0.8890 - mean_absolute_error: 1.8673 - val_loss: 6.1129 - val_r_square: 0.9064 - val_mean_absolute_error: 1.8120
# Epoch 42/100
# 10/10 [==============================] - 0s 7ms/step - loss: 6.4532 - r_square: 0.8916 - mean_absolute_error: 1.8182 - val_loss: 6.7707 - val_r_square: 0.8963 - val_mean_absolute_error: 2.0413
# Epoch 43/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.6691 - r_square: 0.8712 - mean_absolute_error: 2.0090 - val_loss: 5.2394 - val_r_square: 0.9198 - val_mean_absolute_error: 1.7192
# Epoch 44/100
# 10/10 [==============================] - 0s 6ms/step - loss: 7.3760 - r_square: 0.8761 - mean_absolute_error: 1.9502 - val_loss: 5.6584 - val_r_square: 0.9134 - val_mean_absolute_error: 1.9254
# Epoch 45/100
# 10/10 [==============================] - 0s 7ms/step - loss: 6.8146 - r_square: 0.8855 - mean_absolute_error: 1.8708 - val_loss: 5.6826 - val_r_square: 0.9130 - val_mean_absolute_error: 1.7794
# Epoch 46/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.6027 - r_square: 0.8891 - mean_absolute_error: 1.8021 - val_loss: 8.6434 - val_r_square: 0.8676 - val_mean_absolute_error: 2.2748
# Epoch 47/100
# 10/10 [==============================] - 0s 8ms/step - loss: 6.4944 - r_square: 0.8909 - mean_absolute_error: 1.8565 - val_loss: 6.7130 - val_r_square: 0.8972 - val_mean_absolute_error: 1.8567
# Epoch 48/100
# 10/10 [==============================] - 0s 7ms/step - loss: 6.7373 - r_square: 0.8868 - mean_absolute_error: 1.8276 - val_loss: 9.1944 - val_r_square: 0.8592 - val_mean_absolute_error: 2.3668
# Epoch 49/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.7552 - r_square: 0.8865 - mean_absolute_error: 1.8342 - val_loss: 5.2123 - val_r_square: 0.9202 - val_mean_absolute_error: 1.7883
# Epoch 50/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.7162 - r_square: 0.8872 - mean_absolute_error: 1.8316 - val_loss: 5.3354 - val_r_square: 0.9183 - val_mean_absolute_error: 1.7259
# Epoch 51/100
# 10/10 [==============================] - 0s 6ms/step - loss: 7.0379 - r_square: 0.8818 - mean_absolute_error: 1.9019 - val_loss: 5.3561 - val_r_square: 0.9180 - val_mean_absolute_error: 1.7412
# Epoch 52/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.4018 - r_square: 0.8925 - mean_absolute_error: 1.7905 - val_loss: 9.4428 - val_r_square: 0.8554 - val_mean_absolute_error: 2.3786
# Epoch 53/100
# 10/10 [==============================] - 0s 6ms/step - loss: 7.3058 - r_square: 0.8773 - mean_absolute_error: 1.9096 - val_loss: 5.8049 - val_r_square: 0.9111 - val_mean_absolute_error: 1.8171
# Epoch 54/100
# 10/10 [==============================] - 0s 7ms/step - loss: 6.9029 - r_square: 0.8841 - mean_absolute_error: 1.8533 - val_loss: 5.5171 - val_r_square: 0.9155 - val_mean_absolute_error: 1.8295
# Epoch 55/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.2648 - r_square: 0.8948 - mean_absolute_error: 1.7291 - val_loss: 5.6825 - val_r_square: 0.9130 - val_mean_absolute_error: 1.8504
# Epoch 56/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.3347 - r_square: 0.8936 - mean_absolute_error: 1.7631 - val_loss: 8.2597 - val_r_square: 0.8735 - val_mean_absolute_error: 2.2659
# Epoch 57/100
# 10/10 [==============================] - 0s 8ms/step - loss: 6.9334 - r_square: 0.8836 - mean_absolute_error: 1.8501 - val_loss: 9.1883 - val_r_square: 0.8593 - val_mean_absolute_error: 2.3723
# Epoch 58/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.9940 - r_square: 0.8825 - mean_absolute_error: 1.8832 - val_loss: 5.8321 - val_r_square: 0.9107 - val_mean_absolute_error: 1.9318
# Epoch 59/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.2399 - r_square: 0.8952 - mean_absolute_error: 1.7472 - val_loss: 6.3202 - val_r_square: 0.9032 - val_mean_absolute_error: 1.9297
# Epoch 60/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.2442 - r_square: 0.8951 - mean_absolute_error: 1.7768 - val_loss: 7.5588 - val_r_square: 0.8843 - val_mean_absolute_error: 2.1923
# Epoch 61/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.2916 - r_square: 0.8943 - mean_absolute_error: 1.7909 - val_loss: 9.3981 - val_r_square: 0.8561 - val_mean_absolute_error: 2.3638
# Epoch 62/100
# 10/10 [==============================] - 0s 7ms/step - loss: 6.4908 - r_square: 0.8910 - mean_absolute_error: 1.8185 - val_loss: 6.3504 - val_r_square: 0.9028 - val_mean_absolute_error: 1.9260
# Epoch 63/100
# 10/10 [==============================] - 0s 7ms/step - loss: 6.2599 - r_square: 0.8949 - mean_absolute_error: 1.7628 - val_loss: 9.1167 - val_r_square: 0.8604 - val_mean_absolute_error: 2.3460
# Epoch 64/100
# 10/10 [==============================] - 0s 6ms/step - loss: 7.5378 - r_square: 0.8734 - mean_absolute_error: 1.9343 - val_loss: 9.4516 - val_r_square: 0.8553 - val_mean_absolute_error: 2.4175
# Epoch 65/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.3085 - r_square: 0.8940 - mean_absolute_error: 1.8066 - val_loss: 5.9472 - val_r_square: 0.9089 - val_mean_absolute_error: 1.8885
# Epoch 66/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.0667 - r_square: 0.8981 - mean_absolute_error: 1.7665 - val_loss: 5.6686 - val_r_square: 0.9132 - val_mean_absolute_error: 1.8548
# Epoch 67/100
# 10/10 [==============================] - 0s 6ms/step - loss: 6.9832 - r_square: 0.8827 - mean_absolute_error: 1.8853 - val_loss: 6.0257 - val_r_square: 0.9077 - val_mean_absolute_error: 1.8664
# Epoch 68/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.2938 - r_square: 0.8943 - mean_absolute_error: 1.8236 - val_loss: 7.5968 - val_r_square: 0.8837 - val_mean_absolute_error: 2.1079
# Epoch 69/100
# 10/10 [==============================] - 0s 7ms/step - loss: 7.1535 - r_square: 0.8799 - mean_absolute_error: 1.9088 - val_loss: 6.6650 - val_r_square: 0.8979 - val_mean_absolute_error: 2.0310
# Epoch 70/100
# 10/10 [==============================] - 0s 8ms/step - loss: 6.8136 - r_square: 0.8856 - mean_absolute_error: 1.8456 - val_loss: 6.4187 - val_r_square: 0.9017 - val_mean_absolute_error: 1.9759
# Epoch 71/100
# 10/10 [==============================] - 0s 11ms/step - loss: 6.8423 - r_square: 0.8851 - mean_absolute_error: 1.8400 - val_loss: 5.6203 - val_r_square: 0.9139 - val_mean_absolute_error: 1.7829
# Epoch 72/100
# 10/10 [==============================] - 0s 10ms/step - loss: 6.4792 - r_square: 0.8912 - mean_absolute_error: 1.7642 - val_loss: 5.4042 - val_r_square: 0.9172 - val_mean_absolute_error: 1.7489
# Epoch 73/100
# 10/10 [==============================] - 0s 9ms/step - loss: 6.1276 - r_square: 0.8971 - mean_absolute_error: 1.7451 - val_loss: 5.7050 - val_r_square: 0.9126 - val_mean_absolute_error: 1.8929
# Epoch 74/100
# 10/10 [==============================] - 0s 9ms/step - loss: 5.9614 - r_square: 0.8999 - mean_absolute_error: 1.7490 - val_loss: 7.5480 - val_r_square: 0.8844 - val_mean_absolute_error: 2.1718
# Epoch 75/100
# 10/10 [==============================] - 0s 11ms/step - loss: 6.4185 - r_square: 0.8922 - mean_absolute_error: 1.7878 - val_loss: 5.9180 - val_r_square: 0.9094 - val_mean_absolute_error: 1.9224
# Epoch 76/100
# 10/10 [==============================] - 0s 11ms/step - loss: 5.9380 - r_square: 0.9003 - mean_absolute_error: 1.7263 - val_loss: 5.6444 - val_r_square: 0.9136 - val_mean_absolute_error: 1.8370
# Epoch 77/100
# 10/10 [==============================] - 0s 9ms/step - loss: 7.1866 - r_square: 0.8793 - mean_absolute_error: 1.9448 - val_loss: 5.3436 - val_r_square: 0.9182 - val_mean_absolute_error: 1.7731
# Epoch 78/100
# 10/10 [==============================] - 0s 12ms/step - loss: 5.9227 - r_square: 0.9005 - mean_absolute_error: 1.7259 - val_loss: 6.8444 - val_r_square: 0.8952 - val_mean_absolute_error: 2.0258
# Epoch 79/100
# 10/10 [==============================] - 0s 8ms/step - loss: 6.0364 - r_square: 0.8986 - mean_absolute_error: 1.7058 - val_loss: 5.7294 - val_r_square: 0.9123 - val_mean_absolute_error: 1.8009
# Epoch 80/100
# 10/10 [==============================] - 0s 11ms/step - loss: 6.2686 - r_square: 0.8947 - mean_absolute_error: 1.7626 - val_loss: 5.2441 - val_r_square: 0.9197 - val_mean_absolute_error: 1.7560
# Epoch 81/100
# 10/10 [==============================] - 0s 11ms/step - loss: 6.5500 - r_square: 0.8900 - mean_absolute_error: 1.8430 - val_loss: 5.5113 - val_r_square: 0.9156 - val_mean_absolute_error: 1.8439
# Epoch 82/100
# 10/10 [==============================] - 0s 9ms/step - loss: 6.1443 - r_square: 0.8968 - mean_absolute_error: 1.7599 - val_loss: 5.3950 - val_r_square: 0.9174 - val_mean_absolute_error: 1.7922
# Epoch 83/100
# 10/10 [==============================] - 0s 13ms/step - loss: 6.6113 - r_square: 0.8890 - mean_absolute_error: 1.8439 - val_loss: 6.0343 - val_r_square: 0.9076 - val_mean_absolute_error: 1.8488
# Epoch 84/100
# 10/10 [==============================] - 0s 8ms/step - loss: 7.7861 - r_square: 0.8692 - mean_absolute_error: 1.9993 - val_loss: 7.7317 - val_r_square: 0.8816 - val_mean_absolute_error: 2.1242
# Epoch 85/100
# 10/10 [==============================] - 0s 10ms/step - loss: 6.5232 - r_square: 0.8904 - mean_absolute_error: 1.8440 - val_loss: 5.6749 - val_r_square: 0.9131 - val_mean_absolute_error: 1.8936
# Epoch 86/100
# 10/10 [==============================] - 0s 15ms/step - loss: 5.8700 - r_square: 0.9014 - mean_absolute_error: 1.7336 - val_loss: 5.2898 - val_r_square: 0.9190 - val_mean_absolute_error: 1.7686
# Epoch 87/100
# 10/10 [==============================] - 0s 16ms/step - loss: 5.9233 - r_square: 0.9005 - mean_absolute_error: 1.7180 - val_loss: 5.7499 - val_r_square: 0.9120 - val_mean_absolute_error: 1.8983
# Epoch 88/100
# 10/10 [==============================] - 0s 10ms/step - loss: 5.9011 - r_square: 0.9009 - mean_absolute_error: 1.7119 - val_loss: 6.7192 - val_r_square: 0.8971 - val_mean_absolute_error: 2.0232
# Epoch 89/100
# 10/10 [==============================] - 0s 9ms/step - loss: 7.5676 - r_square: 0.8729 - mean_absolute_error: 1.9030 - val_loss: 8.1396 - val_r_square: 0.8754 - val_mean_absolute_error: 2.1873
# Epoch 90/100
# 10/10 [==============================] - 0s 10ms/step - loss: 6.0793 - r_square: 0.8979 - mean_absolute_error: 1.7473 - val_loss: 5.7285 - val_r_square: 0.9123 - val_mean_absolute_error: 1.8437
# Epoch 91/100
# 10/10 [==============================] - 0s 9ms/step - loss: 6.0647 - r_square: 0.8981 - mean_absolute_error: 1.7375 - val_loss: 6.2446 - val_r_square: 0.9044 - val_mean_absolute_error: 1.9393
# Epoch 92/100
# 10/10 [==============================] - 0s 8ms/step - loss: 6.0429 - r_square: 0.8985 - mean_absolute_error: 1.7626 - val_loss: 5.7805 - val_r_square: 0.9115 - val_mean_absolute_error: 1.8312
# Epoch 93/100
# 10/10 [==============================] - 0s 9ms/step - loss: 6.4159 - r_square: 0.8922 - mean_absolute_error: 1.8170 - val_loss: 6.0517 - val_r_square: 0.9073 - val_mean_absolute_error: 1.9480
# Epoch 94/100
# 10/10 [==============================] - 0s 9ms/step - loss: 6.7339 - r_square: 0.8869 - mean_absolute_error: 1.8338 - val_loss: 5.1857 - val_r_square: 0.9206 - val_mean_absolute_error: 1.8097
# Epoch 95/100
# 10/10 [==============================] - 0s 13ms/step - loss: 6.5466 - r_square: 0.8901 - mean_absolute_error: 1.7784 - val_loss: 6.5198 - val_r_square: 0.9002 - val_mean_absolute_error: 1.9715
# Epoch 96/100
# 10/10 [==============================] - 0s 10ms/step - loss: 6.1813 - r_square: 0.8962 - mean_absolute_error: 1.7345 - val_loss: 5.5156 - val_r_square: 0.9155 - val_mean_absolute_error: 1.8380
# Epoch 97/100
# 10/10 [==============================] - 0s 8ms/step - loss: 5.8421 - r_square: 0.9019 - mean_absolute_error: 1.7520 - val_loss: 5.5514 - val_r_square: 0.9150 - val_mean_absolute_error: 1.8066
# Epoch 98/100
# 10/10 [==============================] - 0s 11ms/step - loss: 5.7898 - r_square: 0.9028 - mean_absolute_error: 1.6595 - val_loss: 7.9402 - val_r_square: 0.8784 - val_mean_absolute_error: 2.2160
# Epoch 99/100
# 10/10 [==============================] - 0s 9ms/step - loss: 6.9982 - r_square: 0.8825 - mean_absolute_error: 1.8657 - val_loss: 6.9127 - val_r_square: 0.8941 - val_mean_absolute_error: 1.9248
# Epoch 100/100
# 10/10 [==============================] - 0s 10ms/step - loss: 6.0924 - r_square: 0.8977 - mean_absolute_error: 1.7126 - val_loss: 5.6777 - val_r_square: 0.9131 - val_mean_absolute_error: 1.8778

# %%
plt.plot(MLP_Regression_history.history['loss'], label='loss')
plt.plot(MLP_Regression_history.history['val_loss'], label='val_loss')
plt.ylim([0, 50])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(MLP_Regression_history.history)
hist['epoch'] = MLP_Regression_history.epoch
hist.tail()
# Out:
#         loss  r_square  mean_absolute_error  val_loss  val_r_square  \
# 95  6.181332  0.896185             1.734503  5.515628      0.915543
# 96  5.842118  0.901882             1.752027  5.551438      0.914994
# 97  5.789838  0.902760             1.659464  7.940225      0.878416
# 98  6.998153  0.882467             1.865729  6.912735      0.894150
# 99  6.092406  0.897679             1.712639  5.677711      0.913061
#
#     val_mean_absolute_error  epoch
# 95                 1.837961     95
# 96                 1.806554     96
# 97                 2.216022     97
# 98                 1.924827     98
# 99                 1.877760     99

# %%
print("Min train loss: ", min(hist['loss']))
print("Min val loss: ", min(hist['val_loss']))
print("Min MAE: ", min(hist['mean_absolute_error']))
print("Min val MAE: ", min(hist['val_mean_absolute_error']))
print("Max r-squared loss: ", max(hist['r_square']))
print("Max val r-squared loss: ", max(hist['val_r_square']))
# Out:
# Min train loss:  5.789837837219238
# Min val loss:  5.185681343078613
# Min MAE:  1.6594642400741577
# Min val MAE:  1.7192461490631104
# Max r-squared loss:  0.9027602672576904
# Max val r-squared loss:  0.9205949902534485
