# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# To: /content/FER-2013.zip
# 100% 63.3M/63.3M [00:00<00:00, 165MB/s]

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/FER-2013.zip"

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng image_dataset_from_directory

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
tf.keras.utils.set_random_seed(1)
tf.config.experimental.enable_op_determinism()

# %%
batch_size = 256
img_height = 48
img_width = 48
train_dir = "/content/train" 
test_dir = "/content/test"

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  color_mode="grayscale")
# Out:
# Found 28709 files belonging to 7 classes.
# Using 22968 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  color_mode="grayscale")
# Out:
# Found 28709 files belonging to 7 classes.
# Using 5741 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(np.squeeze(images[i].numpy()).astype("uint8"), cmap="gray")
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
normalized_train_ds = train_ds.map(lambda x, y: (tf.subtract(tf.divide(x, 127.5),1), y))
normalized_val_ds = val_ds.map(lambda x, y: (tf.subtract(tf.divide(x, 127.5),1), y))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(buffer_size=512).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

normalized_train_ds = normalized_train_ds.cache().shuffle(buffer_size=512).prefetch(buffer_size=AUTOTUNE)
normalized_val_ds = normalized_val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %% [markdown]
# ##### MLP - relu

# %%
num_class = 7

#
MLP_relu_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(48,48,1)),
    tf.keras.layers.Dense(units=1024, activation="relu"),
    tf.keras.layers.Dense(units=512, activation="relu"),
    tf.keras.layers.Dense(units=256, activation="relu"),
    tf.keras.layers.Dense(units=num_class)
])
MLP_relu_model.summary()
#
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
opt = tf.keras.optimizers.SGD(learning_rate=0.006)

MLP_relu_model.compile(optimizer=opt,loss=loss, metrics=['accuracy'])

#
MLP_relu_history = MLP_relu_model.fit(normalized_train_ds, validation_data=normalized_val_ds, epochs=100)

# Epoch 90/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.7396 - accuracy: 0.7749 - val_loss: 1.7414 - val_accuracy: 0.4135
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 1024)              2360320
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 3,018,247
# Trainable params: 3,018,247
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 90/90 [==============================] - 14s 19ms/step - loss: 1.8210 - accuracy: 0.2453 - val_loss: 1.7879 - val_accuracy: 0.2625
# Epoch 2/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.7588 - accuracy: 0.2872 - val_loss: 1.7598 - val_accuracy: 0.2801
# Epoch 3/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.7285 - accuracy: 0.3092 - val_loss: 1.7369 - val_accuracy: 0.3017
# Epoch 4/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.7024 - accuracy: 0.3305 - val_loss: 1.7168 - val_accuracy: 0.3200
# Epoch 5/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6786 - accuracy: 0.3484 - val_loss: 1.6995 - val_accuracy: 0.3304
# Epoch 6/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6566 - accuracy: 0.3629 - val_loss: 1.6818 - val_accuracy: 0.3428
# Epoch 7/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6366 - accuracy: 0.3724 - val_loss: 1.6675 - val_accuracy: 0.3524
# Epoch 8/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6186 - accuracy: 0.3824 - val_loss: 1.6559 - val_accuracy: 0.3590
# Epoch 9/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6030 - accuracy: 0.3910 - val_loss: 1.6454 - val_accuracy: 0.3639
# Epoch 10/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5885 - accuracy: 0.3969 - val_loss: 1.6374 - val_accuracy: 0.3668
# Epoch 11/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5754 - accuracy: 0.4021 - val_loss: 1.6296 - val_accuracy: 0.3684
# Epoch 12/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5637 - accuracy: 0.4077 - val_loss: 1.6246 - val_accuracy: 0.3735
# Epoch 13/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5528 - accuracy: 0.4107 - val_loss: 1.6178 - val_accuracy: 0.3708
# Epoch 14/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5423 - accuracy: 0.4189 - val_loss: 1.6150 - val_accuracy: 0.3748
# Epoch 15/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5322 - accuracy: 0.4221 - val_loss: 1.6074 - val_accuracy: 0.3775
# Epoch 16/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5224 - accuracy: 0.4271 - val_loss: 1.6029 - val_accuracy: 0.3836
# Epoch 17/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5127 - accuracy: 0.4309 - val_loss: 1.5980 - val_accuracy: 0.3813
# Epoch 18/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5031 - accuracy: 0.4337 - val_loss: 1.5937 - val_accuracy: 0.3816
# Epoch 19/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4944 - accuracy: 0.4404 - val_loss: 1.5904 - val_accuracy: 0.3862
# Epoch 20/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4849 - accuracy: 0.4453 - val_loss: 1.5885 - val_accuracy: 0.3890
# Epoch 21/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4760 - accuracy: 0.4482 - val_loss: 1.5850 - val_accuracy: 0.3914
# Epoch 22/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4670 - accuracy: 0.4510 - val_loss: 1.5790 - val_accuracy: 0.3933
# Epoch 23/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4574 - accuracy: 0.4552 - val_loss: 1.5786 - val_accuracy: 0.3933
# Epoch 24/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4494 - accuracy: 0.4594 - val_loss: 1.5744 - val_accuracy: 0.3971
# Epoch 25/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4405 - accuracy: 0.4633 - val_loss: 1.5711 - val_accuracy: 0.3970
# Epoch 26/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4318 - accuracy: 0.4666 - val_loss: 1.5685 - val_accuracy: 0.3985
# Epoch 27/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4228 - accuracy: 0.4711 - val_loss: 1.5696 - val_accuracy: 0.3961
# Epoch 28/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4144 - accuracy: 0.4744 - val_loss: 1.5669 - val_accuracy: 0.3994
# Epoch 29/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4051 - accuracy: 0.4781 - val_loss: 1.5646 - val_accuracy: 0.3996
# Epoch 30/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3965 - accuracy: 0.4842 - val_loss: 1.5611 - val_accuracy: 0.4038
# Epoch 31/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3878 - accuracy: 0.4854 - val_loss: 1.5552 - val_accuracy: 0.4043
# Epoch 32/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3782 - accuracy: 0.4919 - val_loss: 1.5533 - val_accuracy: 0.4060
# Epoch 33/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3695 - accuracy: 0.4973 - val_loss: 1.5515 - val_accuracy: 0.4062
# Epoch 34/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3602 - accuracy: 0.5002 - val_loss: 1.5537 - val_accuracy: 0.4010
# Epoch 35/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3507 - accuracy: 0.5067 - val_loss: 1.5605 - val_accuracy: 0.4003
# Epoch 36/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3417 - accuracy: 0.5091 - val_loss: 1.5518 - val_accuracy: 0.4038
# Epoch 37/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3330 - accuracy: 0.5132 - val_loss: 1.5478 - val_accuracy: 0.4072
# Epoch 38/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3230 - accuracy: 0.5165 - val_loss: 1.5475 - val_accuracy: 0.4055
# Epoch 39/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3137 - accuracy: 0.5212 - val_loss: 1.5421 - val_accuracy: 0.4111
# Epoch 40/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3033 - accuracy: 0.5306 - val_loss: 1.5463 - val_accuracy: 0.4071
# Epoch 41/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2939 - accuracy: 0.5330 - val_loss: 1.5423 - val_accuracy: 0.4069
# Epoch 42/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2835 - accuracy: 0.5405 - val_loss: 1.5400 - val_accuracy: 0.4078
# Epoch 43/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2742 - accuracy: 0.5438 - val_loss: 1.5432 - val_accuracy: 0.4097
# Epoch 44/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2638 - accuracy: 0.5489 - val_loss: 1.5385 - val_accuracy: 0.4079
# Epoch 45/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2536 - accuracy: 0.5523 - val_loss: 1.5390 - val_accuracy: 0.4097
# Epoch 46/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2433 - accuracy: 0.5583 - val_loss: 1.5406 - val_accuracy: 0.4119
# Epoch 47/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2334 - accuracy: 0.5611 - val_loss: 1.5398 - val_accuracy: 0.4102
# Epoch 48/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2224 - accuracy: 0.5674 - val_loss: 1.5473 - val_accuracy: 0.4119
# Epoch 49/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2129 - accuracy: 0.5698 - val_loss: 1.5384 - val_accuracy: 0.4156
# Epoch 50/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2020 - accuracy: 0.5754 - val_loss: 1.5400 - val_accuracy: 0.4099
# Epoch 51/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1908 - accuracy: 0.5822 - val_loss: 1.5378 - val_accuracy: 0.4147
# Epoch 52/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1803 - accuracy: 0.5848 - val_loss: 1.5384 - val_accuracy: 0.4102
# Epoch 53/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1690 - accuracy: 0.5896 - val_loss: 1.5497 - val_accuracy: 0.4123
# Epoch 54/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1572 - accuracy: 0.5968 - val_loss: 1.5403 - val_accuracy: 0.4121
# Epoch 55/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1466 - accuracy: 0.6012 - val_loss: 1.5392 - val_accuracy: 0.4140
# Epoch 56/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1355 - accuracy: 0.6058 - val_loss: 1.5431 - val_accuracy: 0.4151
# Epoch 57/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.1235 - accuracy: 0.6132 - val_loss: 1.5453 - val_accuracy: 0.4154
# Epoch 58/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1112 - accuracy: 0.6166 - val_loss: 1.5416 - val_accuracy: 0.4186
# Epoch 59/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.0996 - accuracy: 0.6209 - val_loss: 1.5521 - val_accuracy: 0.4147
# Epoch 60/100
# 90/90 [==============================] - 1s 9ms/step - loss: 1.0879 - accuracy: 0.6276 - val_loss: 1.5531 - val_accuracy: 0.4123
# Epoch 61/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0766 - accuracy: 0.6321 - val_loss: 1.5491 - val_accuracy: 0.4187
# Epoch 62/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0639 - accuracy: 0.6389 - val_loss: 1.5635 - val_accuracy: 0.4107
# Epoch 63/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0524 - accuracy: 0.6454 - val_loss: 1.5749 - val_accuracy: 0.4126
# Epoch 64/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0377 - accuracy: 0.6491 - val_loss: 1.5532 - val_accuracy: 0.4165
# Epoch 65/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0269 - accuracy: 0.6522 - val_loss: 1.5609 - val_accuracy: 0.4172
# Epoch 66/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0136 - accuracy: 0.6588 - val_loss: 1.5585 - val_accuracy: 0.4160
# Epoch 67/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0041 - accuracy: 0.6654 - val_loss: 1.5663 - val_accuracy: 0.4137
# Epoch 68/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.9900 - accuracy: 0.6702 - val_loss: 1.5771 - val_accuracy: 0.4172
# Epoch 69/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.9752 - accuracy: 0.6784 - val_loss: 1.5716 - val_accuracy: 0.4194
# Epoch 70/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.9652 - accuracy: 0.6811 - val_loss: 1.5787 - val_accuracy: 0.4193
# Epoch 71/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.9572 - accuracy: 0.6849 - val_loss: 1.5772 - val_accuracy: 0.4203
# Epoch 72/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.9433 - accuracy: 0.6900 - val_loss: 1.5843 - val_accuracy: 0.4227
# Epoch 73/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.9352 - accuracy: 0.6920 - val_loss: 1.5904 - val_accuracy: 0.4182
# Epoch 74/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.9205 - accuracy: 0.6971 - val_loss: 1.5914 - val_accuracy: 0.4215
# Epoch 75/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.9125 - accuracy: 0.7001 - val_loss: 1.6221 - val_accuracy: 0.4149
# Epoch 76/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.8983 - accuracy: 0.7048 - val_loss: 1.6177 - val_accuracy: 0.4140
# Epoch 77/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.8822 - accuracy: 0.7137 - val_loss: 1.6165 - val_accuracy: 0.4165
# Epoch 78/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.8838 - accuracy: 0.7148 - val_loss: 1.6161 - val_accuracy: 0.4173
# Epoch 79/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.8657 - accuracy: 0.7200 - val_loss: 1.6560 - val_accuracy: 0.4147
# Epoch 80/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.8473 - accuracy: 0.7283 - val_loss: 1.6262 - val_accuracy: 0.4203
# Epoch 81/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.8438 - accuracy: 0.7308 - val_loss: 1.6274 - val_accuracy: 0.4208
# Epoch 82/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.8326 - accuracy: 0.7338 - val_loss: 1.7238 - val_accuracy: 0.4086
# Epoch 83/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.8109 - accuracy: 0.7466 - val_loss: 1.6512 - val_accuracy: 0.4182
# Epoch 84/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.8043 - accuracy: 0.7453 - val_loss: 1.6471 - val_accuracy: 0.4219
# Epoch 85/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.8069 - accuracy: 0.7454 - val_loss: 1.6553 - val_accuracy: 0.4198
# Epoch 86/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.7783 - accuracy: 0.7563 - val_loss: 1.6523 - val_accuracy: 0.4215
# Epoch 87/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.7698 - accuracy: 0.7606 - val_loss: 1.7682 - val_accuracy: 0.4085
# Epoch 88/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.7516 - accuracy: 0.7702 - val_loss: 1.6572 - val_accuracy: 0.4252
# Epoch 89/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.7516 - accuracy: 0.7668 - val_loss: 1.6876 - val_accuracy: 0.4221
# Epoch 90/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.7396 - accuracy: 0.7749 - val_loss: 1.7414 - val_accuracy: 0.4135
# Epoch 91/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7177 - accuracy: 0.7817 - val_loss: 1.7362 - val_accuracy: 0.4128
# Epoch 92/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7009 - accuracy: 0.7907 - val_loss: 1.7418 - val_accuracy: 0.4205
# Epoch 93/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.7109 - accuracy: 0.7846 - val_loss: 1.7454 - val_accuracy: 0.4196
# Epoch 94/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.6949 - accuracy: 0.7905 - val_loss: 1.9102 - val_accuracy: 0.3973
# Epoch 95/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.6843 - accuracy: 0.7925 - val_loss: 1.7543 - val_accuracy: 0.4133
# Epoch 96/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.6808 - accuracy: 0.7995 - val_loss: 1.7048 - val_accuracy: 0.4233
# Epoch 97/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.6526 - accuracy: 0.8079 - val_loss: 1.7448 - val_accuracy: 0.4153
# Epoch 98/100
# 90/90 [==============================] - 0s 6ms/step - loss: 0.6450 - accuracy: 0.8095 - val_loss: 1.7690 - val_accuracy: 0.4151
# Epoch 99/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.6129 - accuracy: 0.8243 - val_loss: 1.7340 - val_accuracy: 0.4212
# Epoch 100/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.6021 - accuracy: 0.8268 - val_loss: 1.8487 - val_accuracy: 0.4079

# %%
fig = plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.plot(MLP_relu_history.history['loss'], label='loss', color='red')
plt.plot(MLP_relu_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(MLP_relu_history.history['accuracy'], label='accuracy', color='red')
plt.plot(MLP_relu_history.history['val_accuracy'], label='val_accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(MLP_relu_history.history['loss'], label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(MLP_relu_history.history['accuracy'], label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(MLP_relu_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(MLP_relu_history.history['val_accuracy'], label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(MLP_relu_history.history)
hist['epoch'] = MLP_relu_history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 95  0.680781  0.799547  1.704829      0.423271     95
# 96  0.652609  0.807863  1.744805      0.415259     96
# 97  0.645036  0.809474  1.769006      0.415084     97
# 98  0.612891  0.824277  1.734049      0.421181     98
# 99  0.602064  0.826759  1.848673      0.407943     99

# %%
print("Max train acc: ", max(hist['accuracy']))
print("Max val acc: ", max(hist['val_accuracy']))

print("Min train loss: ", min(hist['loss']))
print("Min val loss: ", min(hist['val_loss']))
# Out:
# Max train acc:  0.8267589807510376
# Max val acc:  0.42518725991249084
# Min train loss:  0.6020644307136536
# Min val loss:  1.5377658605575562
