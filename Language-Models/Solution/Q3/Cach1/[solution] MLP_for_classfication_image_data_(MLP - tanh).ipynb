# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# To: /content/FER-2013.zip
# 100% 63.3M/63.3M [00:01<00:00, 59.2MB/s]

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/FER-2013.zip"

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng image_dataset_from_directory

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
tf.keras.utils.set_random_seed(1)
tf.config.experimental.enable_op_determinism()

# %%
batch_size = 256
img_height = 48
img_width = 48
train_dir = "/content/train" 
test_dir = "/content/test"

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  color_mode="grayscale")
# Out:
# Found 28709 files belonging to 7 classes.
# Using 22968 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  color_mode="grayscale")
# Out:
# Found 28709 files belonging to 7 classes.
# Using 5741 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(np.squeeze(images[i].numpy()).astype("uint8"), cmap="gray")
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
normalized_train_ds = train_ds.map(lambda x, y: (tf.subtract(tf.divide(x, 127.5),1), y))
normalized_val_ds = val_ds.map(lambda x, y: (tf.subtract(tf.divide(x, 127.5),1), y))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(buffer_size=512).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

normalized_train_ds = normalized_train_ds.cache().shuffle(buffer_size=512).prefetch(buffer_size=AUTOTUNE)
normalized_val_ds = normalized_val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %% [markdown]
# ##### MLP - tanh

# %%
num_class = 7

#
MLP_tanh_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(48,48,1)),
    tf.keras.layers.Dense(units=1024, activation="tanh"),
    tf.keras.layers.Dense(units=512, activation="tanh"),
    tf.keras.layers.Dense(units=256, activation="tanh"),
    tf.keras.layers.Dense(units=num_class)
])
MLP_tanh_model.summary()
#
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
opt = tf.keras.optimizers.SGD(learning_rate=0.006)

MLP_tanh_model.compile(optimizer=opt,loss=loss, metrics=['accuracy'])

#
MLP_tanh_history = MLP_tanh_model.fit(normalized_train_ds, validation_data=normalized_val_ds, epochs=100)
# Epoch 100/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0323 - accuracy: 0.6470 - val_loss: 1.7297 - val_accuracy: 0.3764

# Epoch 100/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0432 - accuracy: 0.6434 - val_loss: 1.6309 - val_accuracy: 0.3998
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 1024)              2360320
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 3,018,247
# Trainable params: 3,018,247
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 90/90 [==============================] - 9s 21ms/step - loss: 1.8309 - accuracy: 0.2615 - val_loss: 1.7753 - val_accuracy: 0.2893
# Epoch 2/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.7355 - accuracy: 0.3168 - val_loss: 1.7253 - val_accuracy: 0.3212
# Epoch 3/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6943 - accuracy: 0.3397 - val_loss: 1.6983 - val_accuracy: 0.3367
# Epoch 4/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6686 - accuracy: 0.3539 - val_loss: 1.6843 - val_accuracy: 0.3477
# Epoch 5/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6504 - accuracy: 0.3652 - val_loss: 1.6747 - val_accuracy: 0.3482
# Epoch 6/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.6357 - accuracy: 0.3703 - val_loss: 1.6631 - val_accuracy: 0.3585
# Epoch 7/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6230 - accuracy: 0.3765 - val_loss: 1.6565 - val_accuracy: 0.3618
# Epoch 8/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6120 - accuracy: 0.3806 - val_loss: 1.6499 - val_accuracy: 0.3635
# Epoch 9/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6027 - accuracy: 0.3867 - val_loss: 1.6419 - val_accuracy: 0.3726
# Epoch 10/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5936 - accuracy: 0.3893 - val_loss: 1.6385 - val_accuracy: 0.3712
# Epoch 11/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5848 - accuracy: 0.3928 - val_loss: 1.6348 - val_accuracy: 0.3731
# Epoch 12/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5775 - accuracy: 0.3974 - val_loss: 1.6309 - val_accuracy: 0.3764
# Epoch 13/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5702 - accuracy: 0.3993 - val_loss: 1.6259 - val_accuracy: 0.3742
# Epoch 14/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5637 - accuracy: 0.4047 - val_loss: 1.6263 - val_accuracy: 0.3743
# Epoch 15/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5571 - accuracy: 0.4067 - val_loss: 1.6215 - val_accuracy: 0.3773
# Epoch 16/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5512 - accuracy: 0.4091 - val_loss: 1.6162 - val_accuracy: 0.3815
# Epoch 17/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5448 - accuracy: 0.4100 - val_loss: 1.6154 - val_accuracy: 0.3799
# Epoch 18/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5392 - accuracy: 0.4131 - val_loss: 1.6115 - val_accuracy: 0.3855
# Epoch 19/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5337 - accuracy: 0.4156 - val_loss: 1.6111 - val_accuracy: 0.3822
# Epoch 20/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5277 - accuracy: 0.4221 - val_loss: 1.6116 - val_accuracy: 0.3809
# Epoch 21/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5228 - accuracy: 0.4230 - val_loss: 1.6072 - val_accuracy: 0.3830
# Epoch 22/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5175 - accuracy: 0.4260 - val_loss: 1.6038 - val_accuracy: 0.3870
# Epoch 23/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5115 - accuracy: 0.4275 - val_loss: 1.6039 - val_accuracy: 0.3850
# Epoch 24/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5069 - accuracy: 0.4294 - val_loss: 1.6013 - val_accuracy: 0.3893
# Epoch 25/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5020 - accuracy: 0.4323 - val_loss: 1.6011 - val_accuracy: 0.3876
# Epoch 26/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4969 - accuracy: 0.4378 - val_loss: 1.5993 - val_accuracy: 0.3881
# Epoch 27/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4918 - accuracy: 0.4365 - val_loss: 1.6022 - val_accuracy: 0.3841
# Epoch 28/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4873 - accuracy: 0.4390 - val_loss: 1.5990 - val_accuracy: 0.3905
# Epoch 29/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4823 - accuracy: 0.4419 - val_loss: 1.5970 - val_accuracy: 0.3904
# Epoch 30/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4774 - accuracy: 0.4431 - val_loss: 1.5965 - val_accuracy: 0.3933
# Epoch 31/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4723 - accuracy: 0.4461 - val_loss: 1.5919 - val_accuracy: 0.3931
# Epoch 32/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4672 - accuracy: 0.4481 - val_loss: 1.5908 - val_accuracy: 0.3963
# Epoch 33/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4625 - accuracy: 0.4493 - val_loss: 1.5905 - val_accuracy: 0.3949
# Epoch 34/100
# 90/90 [==============================] - 1s 8ms/step - loss: 1.4573 - accuracy: 0.4547 - val_loss: 1.5959 - val_accuracy: 0.3893
# Epoch 35/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4520 - accuracy: 0.4562 - val_loss: 1.5963 - val_accuracy: 0.3921
# Epoch 36/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4476 - accuracy: 0.4597 - val_loss: 1.5930 - val_accuracy: 0.3926
# Epoch 37/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4434 - accuracy: 0.4583 - val_loss: 1.5888 - val_accuracy: 0.3966
# Epoch 38/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4379 - accuracy: 0.4600 - val_loss: 1.5915 - val_accuracy: 0.3938
# Epoch 39/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4327 - accuracy: 0.4654 - val_loss: 1.5845 - val_accuracy: 0.4017
# Epoch 40/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4268 - accuracy: 0.4686 - val_loss: 1.5905 - val_accuracy: 0.3977
# Epoch 41/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4223 - accuracy: 0.4711 - val_loss: 1.5875 - val_accuracy: 0.3954
# Epoch 42/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4173 - accuracy: 0.4738 - val_loss: 1.5841 - val_accuracy: 0.4027
# Epoch 43/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4119 - accuracy: 0.4743 - val_loss: 1.5882 - val_accuracy: 0.3978
# Epoch 44/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4063 - accuracy: 0.4775 - val_loss: 1.5847 - val_accuracy: 0.3963
# Epoch 45/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4016 - accuracy: 0.4810 - val_loss: 1.5827 - val_accuracy: 0.3999
# Epoch 46/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3960 - accuracy: 0.4870 - val_loss: 1.5865 - val_accuracy: 0.3966
# Epoch 47/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3910 - accuracy: 0.4849 - val_loss: 1.5861 - val_accuracy: 0.3957
# Epoch 48/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3856 - accuracy: 0.4897 - val_loss: 1.5864 - val_accuracy: 0.4027
# Epoch 49/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3803 - accuracy: 0.4916 - val_loss: 1.5858 - val_accuracy: 0.3971
# Epoch 50/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3747 - accuracy: 0.4930 - val_loss: 1.5820 - val_accuracy: 0.3985
# Epoch 51/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3692 - accuracy: 0.4949 - val_loss: 1.5856 - val_accuracy: 0.4027
# Epoch 52/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3634 - accuracy: 0.4984 - val_loss: 1.5809 - val_accuracy: 0.3996
# Epoch 53/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3578 - accuracy: 0.5020 - val_loss: 1.5986 - val_accuracy: 0.3928
# Epoch 54/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3523 - accuracy: 0.5047 - val_loss: 1.5815 - val_accuracy: 0.4036
# Epoch 55/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3466 - accuracy: 0.5066 - val_loss: 1.5833 - val_accuracy: 0.4041
# Epoch 56/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3401 - accuracy: 0.5095 - val_loss: 1.5869 - val_accuracy: 0.3944
# Epoch 57/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3347 - accuracy: 0.5154 - val_loss: 1.5843 - val_accuracy: 0.4036
# Epoch 58/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3282 - accuracy: 0.5137 - val_loss: 1.5821 - val_accuracy: 0.4046
# Epoch 59/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3226 - accuracy: 0.5177 - val_loss: 1.5828 - val_accuracy: 0.4027
# Epoch 60/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3162 - accuracy: 0.5227 - val_loss: 1.5880 - val_accuracy: 0.3992
# Epoch 61/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3097 - accuracy: 0.5266 - val_loss: 1.5818 - val_accuracy: 0.4053
# Epoch 62/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3040 - accuracy: 0.5293 - val_loss: 1.5896 - val_accuracy: 0.3923
# Epoch 63/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2980 - accuracy: 0.5333 - val_loss: 1.5954 - val_accuracy: 0.3902
# Epoch 64/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2908 - accuracy: 0.5358 - val_loss: 1.5838 - val_accuracy: 0.4053
# Epoch 65/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2848 - accuracy: 0.5387 - val_loss: 1.5841 - val_accuracy: 0.3999
# Epoch 66/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2781 - accuracy: 0.5398 - val_loss: 1.5834 - val_accuracy: 0.4057
# Epoch 67/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2716 - accuracy: 0.5463 - val_loss: 1.5870 - val_accuracy: 0.3978
# Epoch 68/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2645 - accuracy: 0.5489 - val_loss: 1.5855 - val_accuracy: 0.4045
# Epoch 69/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2573 - accuracy: 0.5516 - val_loss: 1.5818 - val_accuracy: 0.4059
# Epoch 70/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2514 - accuracy: 0.5551 - val_loss: 1.5844 - val_accuracy: 0.4121
# Epoch 71/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2449 - accuracy: 0.5563 - val_loss: 1.5842 - val_accuracy: 0.4060
# Epoch 72/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2383 - accuracy: 0.5591 - val_loss: 1.5852 - val_accuracy: 0.4095
# Epoch 73/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2317 - accuracy: 0.5601 - val_loss: 1.5874 - val_accuracy: 0.4010
# Epoch 74/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2239 - accuracy: 0.5645 - val_loss: 1.5876 - val_accuracy: 0.4053
# Epoch 75/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2212 - accuracy: 0.5663 - val_loss: 1.5903 - val_accuracy: 0.4074
# Epoch 76/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2114 - accuracy: 0.5694 - val_loss: 1.5883 - val_accuracy: 0.4036
# Epoch 77/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2024 - accuracy: 0.5790 - val_loss: 1.5988 - val_accuracy: 0.4010
# Epoch 78/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1980 - accuracy: 0.5761 - val_loss: 1.5883 - val_accuracy: 0.4090
# Epoch 79/100
# 90/90 [==============================] - 0s 6ms/step - loss: 1.1892 - accuracy: 0.5793 - val_loss: 1.5952 - val_accuracy: 0.4081
# Epoch 80/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1823 - accuracy: 0.5831 - val_loss: 1.5965 - val_accuracy: 0.4011
# Epoch 81/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1763 - accuracy: 0.5869 - val_loss: 1.6215 - val_accuracy: 0.3959
# Epoch 82/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1677 - accuracy: 0.5900 - val_loss: 1.6422 - val_accuracy: 0.3839
# Epoch 83/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1629 - accuracy: 0.5925 - val_loss: 1.6070 - val_accuracy: 0.4001
# Epoch 84/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1567 - accuracy: 0.5915 - val_loss: 1.6069 - val_accuracy: 0.4010
# Epoch 85/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1503 - accuracy: 0.5964 - val_loss: 1.6055 - val_accuracy: 0.4069
# Epoch 86/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1358 - accuracy: 0.6041 - val_loss: 1.6027 - val_accuracy: 0.4039
# Epoch 87/100
# 90/90 [==============================] - 1s 8ms/step - loss: 1.1302 - accuracy: 0.6065 - val_loss: 1.6270 - val_accuracy: 0.3977
# Epoch 88/100
# 90/90 [==============================] - 1s 8ms/step - loss: 1.1273 - accuracy: 0.6079 - val_loss: 1.6298 - val_accuracy: 0.4031
# Epoch 89/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1203 - accuracy: 0.6117 - val_loss: 1.6103 - val_accuracy: 0.4092
# Epoch 90/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1202 - accuracy: 0.6113 - val_loss: 1.6094 - val_accuracy: 0.4046
# Epoch 91/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1016 - accuracy: 0.6166 - val_loss: 1.6380 - val_accuracy: 0.4025
# Epoch 92/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0948 - accuracy: 0.6212 - val_loss: 1.6347 - val_accuracy: 0.3989
# Epoch 93/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0939 - accuracy: 0.6235 - val_loss: 1.6322 - val_accuracy: 0.4052
# Epoch 94/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0873 - accuracy: 0.6224 - val_loss: 1.8359 - val_accuracy: 0.3674
# Epoch 95/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0819 - accuracy: 0.6243 - val_loss: 1.6511 - val_accuracy: 0.3992
# Epoch 96/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0665 - accuracy: 0.6328 - val_loss: 1.6166 - val_accuracy: 0.4085
# Epoch 97/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0683 - accuracy: 0.6333 - val_loss: 1.6240 - val_accuracy: 0.4006
# Epoch 98/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0527 - accuracy: 0.6400 - val_loss: 1.6444 - val_accuracy: 0.4055
# Epoch 99/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0451 - accuracy: 0.6400 - val_loss: 1.6417 - val_accuracy: 0.3959
# Epoch 100/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.0432 - accuracy: 0.6434 - val_loss: 1.6309 - val_accuracy: 0.3998

# %%
fig = plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.plot(MLP_tanh_history.history['loss'], label='loss', color='red')
plt.plot(MLP_tanh_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(MLP_tanh_history.history['accuracy'], label='accuracy', color='red')
plt.plot(MLP_tanh_history.history['val_accuracy'], label='val_accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(MLP_tanh_history.history['loss'], label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(MLP_tanh_history.history['accuracy'], label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(MLP_tanh_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(MLP_tanh_history.history['val_accuracy'], label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(MLP_tanh_history.history)
hist['epoch'] = MLP_tanh_history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 95  1.066538  0.632837  1.616623      0.408465     95
# 96  1.068259  0.633316  1.624040      0.400627     96
# 97  1.052722  0.639977  1.644385      0.405504     97
# 98  1.045084  0.640021  1.641680      0.395924     98
# 99  1.043247  0.643373  1.630884      0.399756     99

# %%
print("Max train acc: ", max(hist['accuracy']))
print("Max val acc: ", max(hist['val_accuracy']))

print("Min train loss: ", min(hist['loss']))
print("Min val loss: ", min(hist['val_loss']))
# Out:
# Max train acc:  0.6433733701705933
# Max val acc:  0.41212332248687744
# Min train loss:  1.043247103691101
# Min val loss:  1.5809451341629028
