# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# To: /content/FER-2013.zip
# 100% 63.3M/63.3M [00:01<00:00, 45.6MB/s]

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/FER-2013.zip"

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng image_dataset_from_directory

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
tf.keras.utils.set_random_seed(1)
tf.config.experimental.enable_op_determinism()

# %%
batch_size = 256
img_height = 48
img_width = 48
train_dir = "/content/train" 
test_dir = "/content/test"

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  color_mode="grayscale")
# Out:
# Found 28709 files belonging to 7 classes.
# Using 22968 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  color_mode="grayscale")
# Out:
# Found 28709 files belonging to 7 classes.
# Using 5741 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(np.squeeze(images[i].numpy()).astype("uint8"), cmap="gray")
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
normalized_train_ds = train_ds.map(lambda x, y: (tf.subtract(tf.divide(x, 127.5),1), y))
normalized_val_ds = val_ds.map(lambda x, y: (tf.subtract(tf.divide(x, 127.5),1), y))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(buffer_size=512).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

normalized_train_ds = normalized_train_ds.cache().shuffle(buffer_size=512).prefetch(buffer_size=AUTOTUNE)
normalized_val_ds = normalized_val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %% [markdown]
# ##### Softmax Regression Norm

# %%
num_class = 7

#
FER_SRN_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(48,48,1)),
    tf.keras.layers.Dense(units=num_class)
])
FER_SRN_model.summary()
#
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
opt = tf.keras.optimizers.SGD(learning_rate=0.006)

FER_SRN_model.compile(optimizer=opt,loss=loss, metrics=['accuracy'])

#
FER_SRN_history = FER_SRN_model.fit(normalized_train_ds, validation_data=normalized_val_ds, epochs=100)

# Epoch 100/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5470 - accuracy: 0.4105 - val_loss: 1.6447 - val_accuracy: 0.3714
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 7)                 16135
#
# =================================================================
# Total params: 16,135
# Trainable params: 16,135
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 90/90 [==============================] - 12s 19ms/step - loss: 1.8840 - accuracy: 0.2382 - val_loss: 1.8316 - val_accuracy: 0.2554
# Epoch 2/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.7952 - accuracy: 0.2879 - val_loss: 1.7839 - val_accuracy: 0.2921
# Epoch 3/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.7571 - accuracy: 0.3096 - val_loss: 1.7570 - val_accuracy: 0.3109
# Epoch 4/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.7334 - accuracy: 0.3247 - val_loss: 1.7407 - val_accuracy: 0.3226
# Epoch 5/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.7175 - accuracy: 0.3352 - val_loss: 1.7315 - val_accuracy: 0.3243
# Epoch 6/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.7055 - accuracy: 0.3420 - val_loss: 1.7205 - val_accuracy: 0.3339
# Epoch 7/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6956 - accuracy: 0.3467 - val_loss: 1.7141 - val_accuracy: 0.3355
# Epoch 8/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6874 - accuracy: 0.3498 - val_loss: 1.7084 - val_accuracy: 0.3367
# Epoch 9/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6810 - accuracy: 0.3537 - val_loss: 1.7018 - val_accuracy: 0.3428
# Epoch 10/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6748 - accuracy: 0.3573 - val_loss: 1.6988 - val_accuracy: 0.3449
# Epoch 11/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6691 - accuracy: 0.3592 - val_loss: 1.6956 - val_accuracy: 0.3466
# Epoch 12/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6644 - accuracy: 0.3608 - val_loss: 1.6926 - val_accuracy: 0.3484
# Epoch 13/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6601 - accuracy: 0.3630 - val_loss: 1.6884 - val_accuracy: 0.3515
# Epoch 14/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6564 - accuracy: 0.3659 - val_loss: 1.6886 - val_accuracy: 0.3510
# Epoch 15/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6525 - accuracy: 0.3675 - val_loss: 1.6865 - val_accuracy: 0.3512
# Epoch 16/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6491 - accuracy: 0.3684 - val_loss: 1.6814 - val_accuracy: 0.3566
# Epoch 17/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6454 - accuracy: 0.3704 - val_loss: 1.6812 - val_accuracy: 0.3567
# Epoch 18/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6426 - accuracy: 0.3715 - val_loss: 1.6775 - val_accuracy: 0.3602
# Epoch 19/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6398 - accuracy: 0.3737 - val_loss: 1.6778 - val_accuracy: 0.3583
# Epoch 20/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6366 - accuracy: 0.3736 - val_loss: 1.6777 - val_accuracy: 0.3564
# Epoch 21/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6344 - accuracy: 0.3749 - val_loss: 1.6740 - val_accuracy: 0.3625
# Epoch 22/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6318 - accuracy: 0.3756 - val_loss: 1.6714 - val_accuracy: 0.3635
# Epoch 23/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6289 - accuracy: 0.3773 - val_loss: 1.6716 - val_accuracy: 0.3632
# Epoch 24/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6269 - accuracy: 0.3786 - val_loss: 1.6687 - val_accuracy: 0.3611
# Epoch 25/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6248 - accuracy: 0.3802 - val_loss: 1.6690 - val_accuracy: 0.3616
# Epoch 26/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6225 - accuracy: 0.3809 - val_loss: 1.6676 - val_accuracy: 0.3660
# Epoch 27/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6205 - accuracy: 0.3798 - val_loss: 1.6671 - val_accuracy: 0.3634
# Epoch 28/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6186 - accuracy: 0.3817 - val_loss: 1.6664 - val_accuracy: 0.3670
# Epoch 29/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6166 - accuracy: 0.3821 - val_loss: 1.6656 - val_accuracy: 0.3675
# Epoch 30/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6148 - accuracy: 0.3826 - val_loss: 1.6645 - val_accuracy: 0.3696
# Epoch 31/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6128 - accuracy: 0.3833 - val_loss: 1.6621 - val_accuracy: 0.3689
# Epoch 32/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6109 - accuracy: 0.3854 - val_loss: 1.6604 - val_accuracy: 0.3684
# Epoch 33/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6092 - accuracy: 0.3862 - val_loss: 1.6606 - val_accuracy: 0.3688
# Epoch 34/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6076 - accuracy: 0.3858 - val_loss: 1.6633 - val_accuracy: 0.3668
# Epoch 35/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6058 - accuracy: 0.3881 - val_loss: 1.6609 - val_accuracy: 0.3693
# Epoch 36/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6045 - accuracy: 0.3877 - val_loss: 1.6605 - val_accuracy: 0.3654
# Epoch 37/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6033 - accuracy: 0.3885 - val_loss: 1.6578 - val_accuracy: 0.3700
# Epoch 38/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6015 - accuracy: 0.3895 - val_loss: 1.6594 - val_accuracy: 0.3656
# Epoch 39/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6000 - accuracy: 0.3888 - val_loss: 1.6555 - val_accuracy: 0.3703
# Epoch 40/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5982 - accuracy: 0.3892 - val_loss: 1.6569 - val_accuracy: 0.3688
# Epoch 41/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5970 - accuracy: 0.3915 - val_loss: 1.6562 - val_accuracy: 0.3714
# Epoch 42/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5958 - accuracy: 0.3919 - val_loss: 1.6548 - val_accuracy: 0.3717
# Epoch 43/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5945 - accuracy: 0.3927 - val_loss: 1.6564 - val_accuracy: 0.3707
# Epoch 44/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5930 - accuracy: 0.3931 - val_loss: 1.6532 - val_accuracy: 0.3708
# Epoch 45/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5918 - accuracy: 0.3935 - val_loss: 1.6536 - val_accuracy: 0.3675
# Epoch 46/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5906 - accuracy: 0.3945 - val_loss: 1.6528 - val_accuracy: 0.3672
# Epoch 47/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5894 - accuracy: 0.3944 - val_loss: 1.6533 - val_accuracy: 0.3696
# Epoch 48/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5881 - accuracy: 0.3952 - val_loss: 1.6528 - val_accuracy: 0.3705
# Epoch 49/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5870 - accuracy: 0.3954 - val_loss: 1.6511 - val_accuracy: 0.3721
# Epoch 50/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5861 - accuracy: 0.3977 - val_loss: 1.6517 - val_accuracy: 0.3691
# Epoch 51/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5848 - accuracy: 0.3952 - val_loss: 1.6520 - val_accuracy: 0.3701
# Epoch 52/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5840 - accuracy: 0.3956 - val_loss: 1.6504 - val_accuracy: 0.3724
# Epoch 53/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5827 - accuracy: 0.3971 - val_loss: 1.6527 - val_accuracy: 0.3696
# Epoch 54/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5816 - accuracy: 0.3959 - val_loss: 1.6501 - val_accuracy: 0.3705
# Epoch 55/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5808 - accuracy: 0.3965 - val_loss: 1.6503 - val_accuracy: 0.3731
# Epoch 56/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5796 - accuracy: 0.3984 - val_loss: 1.6492 - val_accuracy: 0.3726
# Epoch 57/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5785 - accuracy: 0.3995 - val_loss: 1.6488 - val_accuracy: 0.3708
# Epoch 58/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5776 - accuracy: 0.3991 - val_loss: 1.6483 - val_accuracy: 0.3715
# Epoch 59/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5765 - accuracy: 0.3995 - val_loss: 1.6491 - val_accuracy: 0.3703
# Epoch 60/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5755 - accuracy: 0.3997 - val_loss: 1.6488 - val_accuracy: 0.3691
# Epoch 61/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5746 - accuracy: 0.4011 - val_loss: 1.6473 - val_accuracy: 0.3715
# Epoch 62/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5738 - accuracy: 0.4011 - val_loss: 1.6491 - val_accuracy: 0.3693
# Epoch 63/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5731 - accuracy: 0.3986 - val_loss: 1.6489 - val_accuracy: 0.3715
# Epoch 64/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5722 - accuracy: 0.4020 - val_loss: 1.6471 - val_accuracy: 0.3715
# Epoch 65/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5710 - accuracy: 0.4010 - val_loss: 1.6477 - val_accuracy: 0.3688
# Epoch 66/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5703 - accuracy: 0.4026 - val_loss: 1.6459 - val_accuracy: 0.3726
# Epoch 67/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5695 - accuracy: 0.4019 - val_loss: 1.6478 - val_accuracy: 0.3724
# Epoch 68/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5684 - accuracy: 0.4026 - val_loss: 1.6472 - val_accuracy: 0.3722
# Epoch 69/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5678 - accuracy: 0.4030 - val_loss: 1.6453 - val_accuracy: 0.3724
# Epoch 70/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5671 - accuracy: 0.4029 - val_loss: 1.6461 - val_accuracy: 0.3724
# Epoch 71/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5660 - accuracy: 0.4052 - val_loss: 1.6471 - val_accuracy: 0.3729
# Epoch 72/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5655 - accuracy: 0.4035 - val_loss: 1.6450 - val_accuracy: 0.3750
# Epoch 73/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5645 - accuracy: 0.4024 - val_loss: 1.6486 - val_accuracy: 0.3701
# Epoch 74/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5638 - accuracy: 0.4053 - val_loss: 1.6464 - val_accuracy: 0.3736
# Epoch 75/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5632 - accuracy: 0.4040 - val_loss: 1.6448 - val_accuracy: 0.3740
# Epoch 76/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5625 - accuracy: 0.4050 - val_loss: 1.6442 - val_accuracy: 0.3757
# Epoch 77/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5615 - accuracy: 0.4046 - val_loss: 1.6460 - val_accuracy: 0.3764
# Epoch 78/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5609 - accuracy: 0.4043 - val_loss: 1.6441 - val_accuracy: 0.3802
# Epoch 79/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5603 - accuracy: 0.4051 - val_loss: 1.6444 - val_accuracy: 0.3743
# Epoch 80/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5594 - accuracy: 0.4074 - val_loss: 1.6435 - val_accuracy: 0.3755
# Epoch 81/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5588 - accuracy: 0.4072 - val_loss: 1.6471 - val_accuracy: 0.3693
# Epoch 82/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5580 - accuracy: 0.4042 - val_loss: 1.6456 - val_accuracy: 0.3728
# Epoch 83/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5576 - accuracy: 0.4075 - val_loss: 1.6436 - val_accuracy: 0.3757
# Epoch 84/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5567 - accuracy: 0.4060 - val_loss: 1.6433 - val_accuracy: 0.3736
# Epoch 85/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5557 - accuracy: 0.4087 - val_loss: 1.6449 - val_accuracy: 0.3762
# Epoch 86/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5555 - accuracy: 0.4070 - val_loss: 1.6425 - val_accuracy: 0.3776
# Epoch 87/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5546 - accuracy: 0.4090 - val_loss: 1.6437 - val_accuracy: 0.3745
# Epoch 88/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5541 - accuracy: 0.4083 - val_loss: 1.6430 - val_accuracy: 0.3768
# Epoch 89/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5535 - accuracy: 0.4086 - val_loss: 1.6446 - val_accuracy: 0.3771
# Epoch 90/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5531 - accuracy: 0.4062 - val_loss: 1.6433 - val_accuracy: 0.3721
# Epoch 91/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5523 - accuracy: 0.4099 - val_loss: 1.6434 - val_accuracy: 0.3754
# Epoch 92/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5518 - accuracy: 0.4092 - val_loss: 1.6421 - val_accuracy: 0.3764
# Epoch 93/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5508 - accuracy: 0.4097 - val_loss: 1.6441 - val_accuracy: 0.3768
# Epoch 94/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5503 - accuracy: 0.4096 - val_loss: 1.6445 - val_accuracy: 0.3710
# Epoch 95/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5499 - accuracy: 0.4106 - val_loss: 1.6432 - val_accuracy: 0.3731
# Epoch 96/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5490 - accuracy: 0.4100 - val_loss: 1.6432 - val_accuracy: 0.3757
# Epoch 97/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5487 - accuracy: 0.4106 - val_loss: 1.6433 - val_accuracy: 0.3775
# Epoch 98/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5483 - accuracy: 0.4117 - val_loss: 1.6447 - val_accuracy: 0.3754
# Epoch 99/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5474 - accuracy: 0.4111 - val_loss: 1.6422 - val_accuracy: 0.3771
# Epoch 100/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5470 - accuracy: 0.4105 - val_loss: 1.6447 - val_accuracy: 0.3714

# %%
fig = plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.plot(FER_SRN_history.history['loss'], label='loss', color='red')
plt.plot(FER_SRN_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(FER_SRN_history.history['accuracy'], label='accuracy', color='red')
plt.plot(FER_SRN_history.history['val_accuracy'], label='val_accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(FER_SRN_history.history['loss'], label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(FER_SRN_history.history['accuracy'], label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(FER_SRN_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(FER_SRN_history.history['val_accuracy'], label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(FER_SRN_history.history)
hist['epoch'] = FER_SRN_history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 95  1.549048  0.409962  1.643165      0.375719     95
# 96  1.548686  0.410615  1.643262      0.377460     96
# 97  1.548254  0.411660  1.644676      0.375370     97
# 98  1.547422  0.411050  1.642190      0.377112     98
# 99  1.547015  0.410528  1.644736      0.371364     99

# %%
print("Max train acc: ", max(hist['accuracy']))
print("Max val acc: ", max(hist['val_accuracy']))

print("Min train loss: ", min(hist['loss']))
print("Min val loss: ", min(hist['val_loss']))
# Out:
# Max train acc:  0.41165968775749207
# Max val acc:  0.3802473545074463
# Min train loss:  1.5470153093338013
# Min val loss:  1.6421092748641968
