# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# To: /content/FER-2013.zip
# 100% 63.3M/63.3M [00:00<00:00, 216MB/s]

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/FER-2013.zip"

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng tf.data

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %%
import os
import pathlib
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
tf.keras.utils.set_random_seed(1)
tf.config.experimental.enable_op_determinism()

# %%
batch_size = 256
img_height = 48
img_width = 48
image_count = 28709 
train_dir = pathlib.Path("/content/train") 
test_dir = pathlib.Path("/content/test")

# %%
list_ds = tf.data.Dataset.list_files(str(train_dir/'*/*'), shuffle=False)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

# %%
for f in list_ds.take(7):
  print(f.numpy())
# Out:
# b'/content/train/neutral/Training_40464326.jpg'
# b'/content/train/fear/Training_89575609.jpg'
# b'/content/train/neutral/Training_94342256.jpg'
# b'/content/train/sad/Training_39660363.jpg'
# b'/content/train/sad/Training_70583207.jpg'
# b'/content/train/happy/Training_34322110.jpg'
# b'/content/train/happy/Training_96376941.jpg'

# %%
class_names = np.array(sorted([item.name for item in train_dir.glob('*')]))
print(class_names)
# Out:
# ['angry' 'disgust' 'fear' 'happy' 'neutral' 'sad' 'surprise']

# %%
val_size = int(image_count * 0.2)
train_ds = list_ds.skip(val_size)
val_ds = list_ds.take(val_size)

normalized_train_ds = list_ds.skip(val_size)
normalized_val_ds = list_ds.take(val_size)

# %%
# number of data
print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
# Out:
# 22968
# 5741

# %%
a = '/content/train/neutral/Training_79965780.jpg'
tf.strings.split(a, os.path.sep)
# Out:
# <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'', b'content', b'train', b'neutral', b'Training_79965780.jpg'],
#       dtype=object)>

# %%
np.array(["neutral"]) == np.array(['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise'])
# Out:
# array([False, False, False, False,  True, False, False])

# %%
def get_label(file_path):
  # Convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

# %%
def decode_img(img, norm):
  # Convert the compressed string to a 3D uint8 tensor
  img = tf.io.decode_jpeg(img, channels=1)
  # Resize the image to the desired size
  img = tf.image.resize(img, [img_height, img_width])
  # normalize
  if norm:
    img = img/127.5 - 1
  return img

# %%
def process_path(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img, norm=False)
  return img, label

def process_path_with_norm(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img, norm=True)
  return img, label

# %%
# for f in list_ds.take(7):
#   print(f.numpy())
#   print(process_path(f.numpy())[1])

# %%
AUTOTUNE = tf.data.AUTOTUNE
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=AUTOTUNE)

normalized_train_ds = normalized_train_ds.map(process_path_with_norm, num_parallel_calls=AUTOTUNE)
normalized_val_ds = normalized_val_ds.map(process_path_with_norm, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (48, 48, 1)
# Label:  3

# %%
def configure_for_performance(ds, train):
  ds = ds.cache()
  if train:
    ds = ds.shuffle(buffer_size=512)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

train_ds2 = configure_for_performance(train_ds, train=True)
val_ds2 = configure_for_performance(val_ds, train=False)

normalized_train_ds2 = configure_for_performance(normalized_train_ds, train=True)
normalized_val_ds2 = configure_for_performance(normalized_val_ds, train=False)

# %%
image_batch, label_batch = next(iter(train_ds2))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  minv = image_batch[i].numpy().min()
  maxv = image_batch[i].numpy().max()
  plt.imshow(np.squeeze(image_batch[i].numpy()), vmin=minv, vmax=maxv, cmap="gray")
  label = label_batch[i]
  plt.title(class_names[label])
  plt.axis("off")

# %% [markdown]
# ##### MLP - relu

# %%
num_class = 7

#
MLP_relu_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(48,48,1)),
    tf.keras.layers.Dense(units=1024, activation="relu"),
    tf.keras.layers.Dense(units=512, activation="relu"),
    tf.keras.layers.Dense(units=256, activation="relu"),
    tf.keras.layers.Dense(units=num_class)
])
MLP_relu_model.summary()
#
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
opt = tf.keras.optimizers.SGD(learning_rate=0.006)

MLP_relu_model.compile(optimizer=opt,loss=loss, metrics=['accuracy'])

#
MLP_relu_history = MLP_relu_model.fit(normalized_train_ds2, validation_data=normalized_val_ds2, epochs=100)

# Epoch 100/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.6444 - accuracy: 0.8083 - val_loss: 1.7872 - val_accuracy: 0.4057
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 1024)              2360320
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 3,018,247
# Trainable params: 3,018,247
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 90/90 [==============================] - 17s 131ms/step - loss: 1.8450 - accuracy: 0.2223 - val_loss: 1.7834 - val_accuracy: 0.2641
# Epoch 2/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.7636 - accuracy: 0.2838 - val_loss: 1.7537 - val_accuracy: 0.2879
# Epoch 3/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.7328 - accuracy: 0.3095 - val_loss: 1.7328 - val_accuracy: 0.3048
# Epoch 4/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.7068 - accuracy: 0.3314 - val_loss: 1.7144 - val_accuracy: 0.3214
# Epoch 5/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6830 - accuracy: 0.3485 - val_loss: 1.6974 - val_accuracy: 0.3370
# Epoch 6/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6611 - accuracy: 0.3625 - val_loss: 1.6826 - val_accuracy: 0.3468
# Epoch 7/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6412 - accuracy: 0.3727 - val_loss: 1.6695 - val_accuracy: 0.3545
# Epoch 8/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6232 - accuracy: 0.3818 - val_loss: 1.6582 - val_accuracy: 0.3585
# Epoch 9/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6071 - accuracy: 0.3891 - val_loss: 1.6489 - val_accuracy: 0.3613
# Epoch 10/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5927 - accuracy: 0.3952 - val_loss: 1.6406 - val_accuracy: 0.3644
# Epoch 11/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5797 - accuracy: 0.4031 - val_loss: 1.6339 - val_accuracy: 0.3656
# Epoch 12/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5678 - accuracy: 0.4100 - val_loss: 1.6278 - val_accuracy: 0.3696
# Epoch 13/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5565 - accuracy: 0.4151 - val_loss: 1.6227 - val_accuracy: 0.3717
# Epoch 14/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5461 - accuracy: 0.4201 - val_loss: 1.6182 - val_accuracy: 0.3736
# Epoch 15/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5361 - accuracy: 0.4241 - val_loss: 1.6135 - val_accuracy: 0.3759
# Epoch 16/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5261 - accuracy: 0.4291 - val_loss: 1.6100 - val_accuracy: 0.3771
# Epoch 17/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5167 - accuracy: 0.4326 - val_loss: 1.6065 - val_accuracy: 0.3773
# Epoch 18/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5079 - accuracy: 0.4363 - val_loss: 1.6030 - val_accuracy: 0.3787
# Epoch 19/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4985 - accuracy: 0.4403 - val_loss: 1.5994 - val_accuracy: 0.3806
# Epoch 20/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4896 - accuracy: 0.4424 - val_loss: 1.5962 - val_accuracy: 0.3815
# Epoch 21/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4815 - accuracy: 0.4478 - val_loss: 1.5938 - val_accuracy: 0.3809
# Epoch 22/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4723 - accuracy: 0.4516 - val_loss: 1.5906 - val_accuracy: 0.3850
# Epoch 23/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4638 - accuracy: 0.4562 - val_loss: 1.5882 - val_accuracy: 0.3853
# Epoch 24/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4549 - accuracy: 0.4598 - val_loss: 1.5853 - val_accuracy: 0.3850
# Epoch 25/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4468 - accuracy: 0.4643 - val_loss: 1.5826 - val_accuracy: 0.3844
# Epoch 26/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.4384 - accuracy: 0.4685 - val_loss: 1.5804 - val_accuracy: 0.3858
# Epoch 27/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4298 - accuracy: 0.4719 - val_loss: 1.5782 - val_accuracy: 0.3879
# Epoch 28/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4215 - accuracy: 0.4754 - val_loss: 1.5758 - val_accuracy: 0.3886
# Epoch 29/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4127 - accuracy: 0.4782 - val_loss: 1.5756 - val_accuracy: 0.3898
# Epoch 30/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.4046 - accuracy: 0.4840 - val_loss: 1.5728 - val_accuracy: 0.3905
# Epoch 31/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3962 - accuracy: 0.4864 - val_loss: 1.5699 - val_accuracy: 0.3923
# Epoch 32/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3877 - accuracy: 0.4913 - val_loss: 1.5678 - val_accuracy: 0.3904
# Epoch 33/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3789 - accuracy: 0.4934 - val_loss: 1.5677 - val_accuracy: 0.3912
# Epoch 34/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3703 - accuracy: 0.4979 - val_loss: 1.5642 - val_accuracy: 0.3949
# Epoch 35/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3616 - accuracy: 0.5040 - val_loss: 1.5631 - val_accuracy: 0.3944
# Epoch 36/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3530 - accuracy: 0.5065 - val_loss: 1.5618 - val_accuracy: 0.3956
# Epoch 37/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3443 - accuracy: 0.5115 - val_loss: 1.5609 - val_accuracy: 0.3982
# Epoch 38/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3358 - accuracy: 0.5152 - val_loss: 1.5608 - val_accuracy: 0.3975
# Epoch 39/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3264 - accuracy: 0.5206 - val_loss: 1.5580 - val_accuracy: 0.4001
# Epoch 40/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3171 - accuracy: 0.5245 - val_loss: 1.5572 - val_accuracy: 0.4010
# Epoch 41/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3082 - accuracy: 0.5283 - val_loss: 1.5569 - val_accuracy: 0.4024
# Epoch 42/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2991 - accuracy: 0.5307 - val_loss: 1.5569 - val_accuracy: 0.4024
# Epoch 43/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2901 - accuracy: 0.5363 - val_loss: 1.5560 - val_accuracy: 0.4011
# Epoch 44/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2806 - accuracy: 0.5400 - val_loss: 1.5527 - val_accuracy: 0.4045
# Epoch 45/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2707 - accuracy: 0.5448 - val_loss: 1.5546 - val_accuracy: 0.4050
# Epoch 46/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2617 - accuracy: 0.5504 - val_loss: 1.5548 - val_accuracy: 0.4034
# Epoch 47/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2519 - accuracy: 0.5556 - val_loss: 1.5527 - val_accuracy: 0.4041
# Epoch 48/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.2417 - accuracy: 0.5605 - val_loss: 1.5535 - val_accuracy: 0.4067
# Epoch 49/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2321 - accuracy: 0.5631 - val_loss: 1.5538 - val_accuracy: 0.4041
# Epoch 50/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2218 - accuracy: 0.5697 - val_loss: 1.5549 - val_accuracy: 0.4029
# Epoch 51/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2110 - accuracy: 0.5735 - val_loss: 1.5541 - val_accuracy: 0.4059
# Epoch 52/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.2008 - accuracy: 0.5785 - val_loss: 1.5518 - val_accuracy: 0.4055
# Epoch 53/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1914 - accuracy: 0.5835 - val_loss: 1.5542 - val_accuracy: 0.4079
# Epoch 54/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1800 - accuracy: 0.5880 - val_loss: 1.5557 - val_accuracy: 0.4071
# Epoch 55/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1695 - accuracy: 0.5923 - val_loss: 1.5517 - val_accuracy: 0.4097
# Epoch 56/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1586 - accuracy: 0.5974 - val_loss: 1.5582 - val_accuracy: 0.4100
# Epoch 57/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1479 - accuracy: 0.6024 - val_loss: 1.5584 - val_accuracy: 0.4111
# Epoch 58/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1367 - accuracy: 0.6070 - val_loss: 1.5574 - val_accuracy: 0.4119
# Epoch 59/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1257 - accuracy: 0.6116 - val_loss: 1.5586 - val_accuracy: 0.4095
# Epoch 60/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1145 - accuracy: 0.6167 - val_loss: 1.5615 - val_accuracy: 0.4078
# Epoch 61/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1039 - accuracy: 0.6218 - val_loss: 1.5599 - val_accuracy: 0.4121
# Epoch 62/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0909 - accuracy: 0.6277 - val_loss: 1.5625 - val_accuracy: 0.4102
# Epoch 63/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0806 - accuracy: 0.6316 - val_loss: 1.5734 - val_accuracy: 0.4106
# Epoch 64/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0678 - accuracy: 0.6381 - val_loss: 1.5646 - val_accuracy: 0.4125
# Epoch 65/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0580 - accuracy: 0.6418 - val_loss: 1.5690 - val_accuracy: 0.4130
# Epoch 66/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0433 - accuracy: 0.6487 - val_loss: 1.6026 - val_accuracy: 0.3977
# Epoch 67/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0334 - accuracy: 0.6526 - val_loss: 1.5713 - val_accuracy: 0.4104
# Epoch 68/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0194 - accuracy: 0.6593 - val_loss: 1.5847 - val_accuracy: 0.4095
# Epoch 69/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0095 - accuracy: 0.6613 - val_loss: 1.5973 - val_accuracy: 0.4041
# Epoch 70/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.9966 - accuracy: 0.6687 - val_loss: 1.5888 - val_accuracy: 0.4107
# Epoch 71/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.9847 - accuracy: 0.6712 - val_loss: 1.5853 - val_accuracy: 0.4140
# Epoch 72/100
# 90/90 [==============================] - 1s 10ms/step - loss: 0.9722 - accuracy: 0.6754 - val_loss: 1.5937 - val_accuracy: 0.4111
# Epoch 73/100
# 90/90 [==============================] - 1s 11ms/step - loss: 0.9608 - accuracy: 0.6830 - val_loss: 1.6366 - val_accuracy: 0.4088
# Epoch 74/100
# 90/90 [==============================] - 1s 8ms/step - loss: 0.9512 - accuracy: 0.6842 - val_loss: 1.5942 - val_accuracy: 0.4102
# Epoch 75/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.9370 - accuracy: 0.6930 - val_loss: 1.5992 - val_accuracy: 0.4147
# Epoch 76/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.9269 - accuracy: 0.6949 - val_loss: 1.6327 - val_accuracy: 0.4064
# Epoch 77/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.9095 - accuracy: 0.7039 - val_loss: 1.6275 - val_accuracy: 0.4125
# Epoch 78/100
# 90/90 [==============================] - 1s 7ms/step - loss: 0.9018 - accuracy: 0.7061 - val_loss: 1.6268 - val_accuracy: 0.4038
# Epoch 79/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8819 - accuracy: 0.7170 - val_loss: 1.6416 - val_accuracy: 0.4059
# Epoch 80/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8749 - accuracy: 0.7192 - val_loss: 1.6349 - val_accuracy: 0.4083
# Epoch 81/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8617 - accuracy: 0.7220 - val_loss: 1.6480 - val_accuracy: 0.4100
# Epoch 82/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8507 - accuracy: 0.7273 - val_loss: 1.6376 - val_accuracy: 0.4055
# Epoch 83/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8381 - accuracy: 0.7321 - val_loss: 1.7512 - val_accuracy: 0.3801
# Epoch 84/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8340 - accuracy: 0.7343 - val_loss: 1.6663 - val_accuracy: 0.3998
# Epoch 85/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8185 - accuracy: 0.7409 - val_loss: 1.7142 - val_accuracy: 0.4088
# Epoch 86/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.8108 - accuracy: 0.7455 - val_loss: 1.7211 - val_accuracy: 0.4011
# Epoch 87/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7991 - accuracy: 0.7474 - val_loss: 2.0563 - val_accuracy: 0.3445
# Epoch 88/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7892 - accuracy: 0.7554 - val_loss: 1.7002 - val_accuracy: 0.4153
# Epoch 89/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7776 - accuracy: 0.7567 - val_loss: 1.7316 - val_accuracy: 0.4088
# Epoch 90/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7662 - accuracy: 0.7627 - val_loss: 1.6827 - val_accuracy: 0.4214
# Epoch 91/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7567 - accuracy: 0.7648 - val_loss: 1.7210 - val_accuracy: 0.4038
# Epoch 92/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7383 - accuracy: 0.7734 - val_loss: 1.7817 - val_accuracy: 0.3942
# Epoch 93/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7373 - accuracy: 0.7717 - val_loss: 1.7472 - val_accuracy: 0.4165
# Epoch 94/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7053 - accuracy: 0.7871 - val_loss: 1.8179 - val_accuracy: 0.3843
# Epoch 95/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.7044 - accuracy: 0.7870 - val_loss: 1.7595 - val_accuracy: 0.4125
# Epoch 96/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.6772 - accuracy: 0.7990 - val_loss: 1.8007 - val_accuracy: 0.4147
# Epoch 97/100
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6740 - accuracy: 0.7999 - val_loss: 1.7340 - val_accuracy: 0.4153
# Epoch 98/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.6654 - accuracy: 0.8030 - val_loss: 1.7964 - val_accuracy: 0.4018
# Epoch 99/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.6540 - accuracy: 0.8085 - val_loss: 1.9291 - val_accuracy: 0.3782
# Epoch 100/100
# 90/90 [==============================] - 1s 6ms/step - loss: 0.6444 - accuracy: 0.8083 - val_loss: 1.7872 - val_accuracy: 0.4057

# %%
fig = plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.plot(MLP_relu_history.history['loss'], label='loss', color='red')
plt.plot(MLP_relu_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(MLP_relu_history.history['accuracy'], label='accuracy', color='red')
plt.plot(MLP_relu_history.history['val_accuracy'], label='val_accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(MLP_relu_history.history['loss'], label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(MLP_relu_history.history['accuracy'], label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(MLP_relu_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(MLP_relu_history.history['val_accuracy'], label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(MLP_relu_history.history)
hist['epoch'] = MLP_relu_history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 95  0.677193  0.798981  1.800674      0.414736     95
# 96  0.673995  0.799939  1.733956      0.415259     96
# 97  0.665446  0.803030  1.796398      0.401846     97
# 98  0.654042  0.808516  1.929096      0.378157     98
# 99  0.644416  0.808342  1.787207      0.405678     99

# %%
print("Max train acc: ", max(hist['accuracy']))
print("Max val acc: ", max(hist['val_accuracy']))

print("Min train loss: ", min(hist['loss']))
print("Min val loss: ", min(hist['val_loss']))
# Out:
# Max train acc:  0.8085162043571472
# Max val acc:  0.42135515809059143
# Min train loss:  0.6444162726402283
# Min val loss:  1.551701545715332

# %%
# Min val loss:  1.5517104864120483
