# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# To: /content/FER-2013.zip
# 100% 63.3M/63.3M [00:00<00:00, 247MB/s]

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/FER-2013.zip"

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng tf.data

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %%
import os
import pathlib
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
tf.keras.utils.set_random_seed(1)
tf.config.experimental.enable_op_determinism()

# %%
batch_size = 256
img_height = 48
img_width = 48
image_count = 28709 
train_dir = pathlib.Path("/content/train") 
test_dir = pathlib.Path("/content/test")

# %%
list_ds = tf.data.Dataset.list_files(str(train_dir/'*/*'), shuffle=False)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

# %%
for f in list_ds.take(7):
  print(f.numpy())
# Out:
# b'/content/train/neutral/Training_40464326.jpg'
# b'/content/train/fear/Training_89575609.jpg'
# b'/content/train/neutral/Training_94342256.jpg'
# b'/content/train/sad/Training_39660363.jpg'
# b'/content/train/sad/Training_70583207.jpg'
# b'/content/train/happy/Training_34322110.jpg'
# b'/content/train/happy/Training_96376941.jpg'

# %%
class_names = np.array(sorted([item.name for item in train_dir.glob('*')]))
print(class_names)
# Out:
# ['angry' 'disgust' 'fear' 'happy' 'neutral' 'sad' 'surprise']

# %%
val_size = int(image_count * 0.2)
train_ds = list_ds.skip(val_size)
val_ds = list_ds.take(val_size)

normalized_train_ds = list_ds.skip(val_size)
normalized_val_ds = list_ds.take(val_size)

# %%
# number of data
print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
# Out:
# 22968
# 5741

# %%
a = '/content/train/neutral/Training_79965780.jpg'
tf.strings.split(a, os.path.sep)
# Out:
# <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'', b'content', b'train', b'neutral', b'Training_79965780.jpg'],
#       dtype=object)>

# %%
np.array(["neutral"]) == np.array(['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise'])
# Out:
# array([False, False, False, False,  True, False, False])

# %%
def get_label(file_path):
  # Convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

# %%
def decode_img(img, norm):
  # Convert the compressed string to a 3D uint8 tensor
  img = tf.io.decode_jpeg(img, channels=1)
  # Resize the image to the desired size
  img = tf.image.resize(img, [img_height, img_width])
  # normalize
  if norm:
    img = img/127.5 - 1
  return img

# %%
def process_path(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img, norm=False)
  return img, label

def process_path_with_norm(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img, norm=True)
  return img, label

# %%
# for f in list_ds.take(7):
#   print(f.numpy())
#   print(process_path(f.numpy())[1])

# %%
AUTOTUNE = tf.data.AUTOTUNE
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=AUTOTUNE)

normalized_train_ds = normalized_train_ds.map(process_path_with_norm, num_parallel_calls=AUTOTUNE)
normalized_val_ds = normalized_val_ds.map(process_path_with_norm, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (48, 48, 1)
# Label:  3

# %%
def configure_for_performance(ds, train):
  ds = ds.cache()
  if train:
    ds = ds.shuffle(buffer_size=512)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

train_ds2 = configure_for_performance(train_ds, train=True)
val_ds2 = configure_for_performance(val_ds, train=False)

normalized_train_ds2 = configure_for_performance(normalized_train_ds, train=True)
normalized_val_ds2 = configure_for_performance(normalized_val_ds, train=False)

# %%
image_batch, label_batch = next(iter(train_ds2))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  minv = image_batch[i].numpy().min()
  maxv = image_batch[i].numpy().max()
  plt.imshow(np.squeeze(image_batch[i].numpy()), vmin=minv, vmax=maxv, cmap="gray")
  label = label_batch[i]
  plt.title(class_names[label])
  plt.axis("off")

# %% [markdown]
# ##### Softmax Regression Norm

# %%
num_class = 7

#
FER_SRN_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(48,48,1)),
    tf.keras.layers.Dense(units=num_class)
])
FER_SRN_model.summary()
#
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
opt = tf.keras.optimizers.SGD(learning_rate=0.006)
# metric = tf.keras.metrics.SparseCategoricalAccuracy()
FER_SRN_model.compile(optimizer=opt,loss=loss, metrics=['accuracy'])

#
FER_SRN_history = FER_SRN_model.fit(normalized_train_ds2, validation_data=normalized_val_ds2, epochs=100)

# Epoch 100/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.5474 - accuracy: 0.4147 - val_loss: 1.6431 - val_accuracy: 0.3726

# Epoch 100/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.5486 - accuracy: 0.4133 - val_loss: 1.6417 - val_accuracy: 0.3637
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 7)                 16135
#
# =================================================================
# Total params: 16,135
# Trainable params: 16,135
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 90/90 [==============================] - 18s 148ms/step - loss: 1.9043 - accuracy: 0.2276 - val_loss: 1.8340 - val_accuracy: 0.2691
# Epoch 2/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.8059 - accuracy: 0.2766 - val_loss: 1.7867 - val_accuracy: 0.3008
# Epoch 3/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.7652 - accuracy: 0.2997 - val_loss: 1.7603 - val_accuracy: 0.3153
# Epoch 4/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.7399 - accuracy: 0.3176 - val_loss: 1.7430 - val_accuracy: 0.3215
# Epoch 5/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.7222 - accuracy: 0.3292 - val_loss: 1.7308 - val_accuracy: 0.3276
# Epoch 6/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.7093 - accuracy: 0.3374 - val_loss: 1.7221 - val_accuracy: 0.3303
# Epoch 7/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6991 - accuracy: 0.3421 - val_loss: 1.7150 - val_accuracy: 0.3364
# Epoch 8/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6906 - accuracy: 0.3460 - val_loss: 1.7098 - val_accuracy: 0.3372
# Epoch 9/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6835 - accuracy: 0.3497 - val_loss: 1.7045 - val_accuracy: 0.3405
# Epoch 10/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6775 - accuracy: 0.3523 - val_loss: 1.7010 - val_accuracy: 0.3412
# Epoch 11/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6722 - accuracy: 0.3563 - val_loss: 1.6958 - val_accuracy: 0.3437
# Epoch 12/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6669 - accuracy: 0.3585 - val_loss: 1.6931 - val_accuracy: 0.3466
# Epoch 13/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6625 - accuracy: 0.3608 - val_loss: 1.6903 - val_accuracy: 0.3480
# Epoch 14/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6586 - accuracy: 0.3633 - val_loss: 1.6874 - val_accuracy: 0.3494
# Epoch 15/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6546 - accuracy: 0.3649 - val_loss: 1.6850 - val_accuracy: 0.3520
# Epoch 16/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6507 - accuracy: 0.3663 - val_loss: 1.6832 - val_accuracy: 0.3505
# Epoch 17/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6476 - accuracy: 0.3676 - val_loss: 1.6806 - val_accuracy: 0.3517
# Epoch 18/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6446 - accuracy: 0.3689 - val_loss: 1.6786 - val_accuracy: 0.3532
# Epoch 19/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6413 - accuracy: 0.3689 - val_loss: 1.6765 - val_accuracy: 0.3524
# Epoch 20/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6385 - accuracy: 0.3715 - val_loss: 1.6754 - val_accuracy: 0.3555
# Epoch 21/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6362 - accuracy: 0.3723 - val_loss: 1.6739 - val_accuracy: 0.3574
# Epoch 22/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6334 - accuracy: 0.3740 - val_loss: 1.6727 - val_accuracy: 0.3581
# Epoch 23/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6310 - accuracy: 0.3744 - val_loss: 1.6708 - val_accuracy: 0.3583
# Epoch 24/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6284 - accuracy: 0.3760 - val_loss: 1.6698 - val_accuracy: 0.3583
# Epoch 25/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6264 - accuracy: 0.3766 - val_loss: 1.6682 - val_accuracy: 0.3586
# Epoch 26/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6242 - accuracy: 0.3783 - val_loss: 1.6671 - val_accuracy: 0.3581
# Epoch 27/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6220 - accuracy: 0.3783 - val_loss: 1.6663 - val_accuracy: 0.3609
# Epoch 28/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6199 - accuracy: 0.3804 - val_loss: 1.6648 - val_accuracy: 0.3585
# Epoch 29/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6181 - accuracy: 0.3816 - val_loss: 1.6637 - val_accuracy: 0.3607
# Epoch 30/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6162 - accuracy: 0.3808 - val_loss: 1.6627 - val_accuracy: 0.3602
# Epoch 31/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6143 - accuracy: 0.3824 - val_loss: 1.6619 - val_accuracy: 0.3611
# Epoch 32/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6126 - accuracy: 0.3819 - val_loss: 1.6609 - val_accuracy: 0.3593
# Epoch 33/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6107 - accuracy: 0.3842 - val_loss: 1.6610 - val_accuracy: 0.3614
# Epoch 34/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6090 - accuracy: 0.3850 - val_loss: 1.6591 - val_accuracy: 0.3602
# Epoch 35/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6075 - accuracy: 0.3856 - val_loss: 1.6584 - val_accuracy: 0.3606
# Epoch 36/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6059 - accuracy: 0.3866 - val_loss: 1.6584 - val_accuracy: 0.3607
# Epoch 37/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6045 - accuracy: 0.3868 - val_loss: 1.6568 - val_accuracy: 0.3613
# Epoch 38/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6031 - accuracy: 0.3872 - val_loss: 1.6566 - val_accuracy: 0.3623
# Epoch 39/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6014 - accuracy: 0.3890 - val_loss: 1.6553 - val_accuracy: 0.3639
# Epoch 40/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5999 - accuracy: 0.3880 - val_loss: 1.6555 - val_accuracy: 0.3635
# Epoch 41/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5985 - accuracy: 0.3912 - val_loss: 1.6550 - val_accuracy: 0.3634
# Epoch 42/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5972 - accuracy: 0.3904 - val_loss: 1.6545 - val_accuracy: 0.3628
# Epoch 43/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5960 - accuracy: 0.3910 - val_loss: 1.6535 - val_accuracy: 0.3625
# Epoch 44/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5943 - accuracy: 0.3920 - val_loss: 1.6529 - val_accuracy: 0.3637
# Epoch 45/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5932 - accuracy: 0.3917 - val_loss: 1.6525 - val_accuracy: 0.3639
# Epoch 46/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5923 - accuracy: 0.3930 - val_loss: 1.6518 - val_accuracy: 0.3627
# Epoch 47/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5910 - accuracy: 0.3929 - val_loss: 1.6514 - val_accuracy: 0.3640
# Epoch 48/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5898 - accuracy: 0.3940 - val_loss: 1.6513 - val_accuracy: 0.3644
# Epoch 49/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5886 - accuracy: 0.3949 - val_loss: 1.6510 - val_accuracy: 0.3625
# Epoch 50/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5874 - accuracy: 0.3962 - val_loss: 1.6506 - val_accuracy: 0.3627
# Epoch 51/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5861 - accuracy: 0.3948 - val_loss: 1.6501 - val_accuracy: 0.3637
# Epoch 52/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5852 - accuracy: 0.3964 - val_loss: 1.6498 - val_accuracy: 0.3640
# Epoch 53/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5842 - accuracy: 0.3979 - val_loss: 1.6488 - val_accuracy: 0.3644
# Epoch 54/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5830 - accuracy: 0.3986 - val_loss: 1.6493 - val_accuracy: 0.3647
# Epoch 55/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5819 - accuracy: 0.3974 - val_loss: 1.6488 - val_accuracy: 0.3640
# Epoch 56/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5810 - accuracy: 0.3987 - val_loss: 1.6487 - val_accuracy: 0.3640
# Epoch 57/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5800 - accuracy: 0.3981 - val_loss: 1.6480 - val_accuracy: 0.3644
# Epoch 58/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5791 - accuracy: 0.3997 - val_loss: 1.6471 - val_accuracy: 0.3647
# Epoch 59/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5781 - accuracy: 0.3997 - val_loss: 1.6477 - val_accuracy: 0.3642
# Epoch 60/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5771 - accuracy: 0.4005 - val_loss: 1.6475 - val_accuracy: 0.3635
# Epoch 61/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5764 - accuracy: 0.4004 - val_loss: 1.6470 - val_accuracy: 0.3642
# Epoch 62/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5750 - accuracy: 0.4010 - val_loss: 1.6465 - val_accuracy: 0.3654
# Epoch 63/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5743 - accuracy: 0.4015 - val_loss: 1.6466 - val_accuracy: 0.3654
# Epoch 64/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5735 - accuracy: 0.4015 - val_loss: 1.6458 - val_accuracy: 0.3647
# Epoch 65/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5725 - accuracy: 0.4013 - val_loss: 1.6455 - val_accuracy: 0.3639
# Epoch 66/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5716 - accuracy: 0.4016 - val_loss: 1.6453 - val_accuracy: 0.3647
# Epoch 67/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5710 - accuracy: 0.4033 - val_loss: 1.6451 - val_accuracy: 0.3651
# Epoch 68/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5700 - accuracy: 0.4026 - val_loss: 1.6455 - val_accuracy: 0.3644
# Epoch 69/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5692 - accuracy: 0.4035 - val_loss: 1.6451 - val_accuracy: 0.3649
# Epoch 70/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5683 - accuracy: 0.4033 - val_loss: 1.6447 - val_accuracy: 0.3654
# Epoch 71/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5676 - accuracy: 0.4043 - val_loss: 1.6447 - val_accuracy: 0.3653
# Epoch 72/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5669 - accuracy: 0.4043 - val_loss: 1.6448 - val_accuracy: 0.3661
# Epoch 73/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5662 - accuracy: 0.4047 - val_loss: 1.6440 - val_accuracy: 0.3654
# Epoch 74/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5654 - accuracy: 0.4071 - val_loss: 1.6440 - val_accuracy: 0.3635
# Epoch 75/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5645 - accuracy: 0.4046 - val_loss: 1.6439 - val_accuracy: 0.3653
# Epoch 76/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5640 - accuracy: 0.4062 - val_loss: 1.6434 - val_accuracy: 0.3647
# Epoch 77/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5630 - accuracy: 0.4063 - val_loss: 1.6433 - val_accuracy: 0.3634
# Epoch 78/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5623 - accuracy: 0.4070 - val_loss: 1.6430 - val_accuracy: 0.3656
# Epoch 79/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5617 - accuracy: 0.4082 - val_loss: 1.6432 - val_accuracy: 0.3668
# Epoch 80/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5610 - accuracy: 0.4078 - val_loss: 1.6429 - val_accuracy: 0.3654
# Epoch 81/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5604 - accuracy: 0.4070 - val_loss: 1.6427 - val_accuracy: 0.3656
# Epoch 82/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5595 - accuracy: 0.4077 - val_loss: 1.6427 - val_accuracy: 0.3651
# Epoch 83/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5589 - accuracy: 0.4080 - val_loss: 1.6431 - val_accuracy: 0.3665
# Epoch 84/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5582 - accuracy: 0.4090 - val_loss: 1.6426 - val_accuracy: 0.3658
# Epoch 85/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5576 - accuracy: 0.4092 - val_loss: 1.6422 - val_accuracy: 0.3660
# Epoch 86/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5569 - accuracy: 0.4095 - val_loss: 1.6418 - val_accuracy: 0.3647
# Epoch 87/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5561 - accuracy: 0.4094 - val_loss: 1.6424 - val_accuracy: 0.3639
# Epoch 88/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5557 - accuracy: 0.4095 - val_loss: 1.6419 - val_accuracy: 0.3647
# Epoch 89/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5549 - accuracy: 0.4098 - val_loss: 1.6421 - val_accuracy: 0.3665
# Epoch 90/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5545 - accuracy: 0.4101 - val_loss: 1.6419 - val_accuracy: 0.3644
# Epoch 91/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5538 - accuracy: 0.4103 - val_loss: 1.6414 - val_accuracy: 0.3651
# Epoch 92/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5531 - accuracy: 0.4104 - val_loss: 1.6415 - val_accuracy: 0.3653
# Epoch 93/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5525 - accuracy: 0.4104 - val_loss: 1.6419 - val_accuracy: 0.3647
# Epoch 94/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5520 - accuracy: 0.4115 - val_loss: 1.6418 - val_accuracy: 0.3635
# Epoch 95/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.5515 - accuracy: 0.4113 - val_loss: 1.6414 - val_accuracy: 0.3651
# Epoch 96/100
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5509 - accuracy: 0.4114 - val_loss: 1.6413 - val_accuracy: 0.3649
# Epoch 97/100
# 90/90 [==============================] - 1s 9ms/step - loss: 1.5503 - accuracy: 0.4113 - val_loss: 1.6412 - val_accuracy: 0.3630
# Epoch 98/100
# 90/90 [==============================] - 1s 8ms/step - loss: 1.5497 - accuracy: 0.4123 - val_loss: 1.6414 - val_accuracy: 0.3654
# Epoch 99/100
# 90/90 [==============================] - 1s 8ms/step - loss: 1.5491 - accuracy: 0.4134 - val_loss: 1.6410 - val_accuracy: 0.3658
# Epoch 100/100
# 90/90 [==============================] - 1s 7ms/step - loss: 1.5486 - accuracy: 0.4133 - val_loss: 1.6417 - val_accuracy: 0.3637

# %%
fig = plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.plot(FER_SRN_history.history['loss'], label='loss', color='red')
plt.plot(FER_SRN_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(FER_SRN_history.history['accuracy'], label='accuracy', color='red')
plt.plot(FER_SRN_history.history['val_accuracy'], label='val_accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(FER_SRN_history.history['loss'], label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(FER_SRN_history.history['accuracy'], label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(FER_SRN_history.history['val_loss'], label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(FER_SRN_history.history['val_accuracy'], label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(FER_SRN_history.history)
hist['epoch'] = FER_SRN_history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 95  1.550878  0.411442  1.641289      0.364919     95
# 96  1.550287  0.411311  1.641233      0.363003     96
# 97  1.549688  0.412269  1.641411      0.365442     97
# 98  1.549104  0.413401  1.640977      0.365790     98
# 99  1.548613  0.413271  1.641671      0.363700     99

# %%
print("Max train acc: ", max(hist['accuracy']))
print("Max val acc: ", max(hist['val_accuracy']))

print("Min train loss: ", min(hist['loss']))
print("Min val loss: ", min(hist['val_loss']))
# Out:
# Max train acc:  0.4134012460708618
# Max val acc:  0.3668350577354431
# Min train loss:  1.5486128330230713
# Min val loss:  1.6409765481948853
