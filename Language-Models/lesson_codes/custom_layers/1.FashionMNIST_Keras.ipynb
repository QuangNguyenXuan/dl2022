# %%
# fashion_mnist
import tensorflow as tf
from tensorflow import keras
import numpy as np

(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')

x_train = x_train.reshape(60000, -1)
x_test  = x_test.reshape(10000, -1)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)

# %%
# data normalization

mean = np.mean(x_train)
std  = np.std(x_train)

x_train = (x_train-mean)/std
x_test  = (x_test-mean)/std

# %%
# create model
model = keras.Sequential()
model.add(keras.Input(shape=(784,)))
model.add(keras.layers.Dense(256))
model.add(tf.keras.layers.ReLU())
model.add(keras.layers.Dense(10))
model.add(tf.keras.layers.Softmax())
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               200960
#
#  re_lu (ReLU)                (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
#  softmax (Softmax)           (None, 10)                0
#
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimizer and loss
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['sparse_categorical_accuracy'])

# training
history = model.fit(x_train, y_train, 
                    validation_data=(x_test, y_test), 
                    batch_size=256, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 235/235 - 1s - loss: 0.8410 - sparse_categorical_accuracy: 0.7132 - val_loss: 0.6327 - val_sparse_categorical_accuracy: 0.7802 - 1s/epoch - 6ms/step
# Epoch 2/100
# 235/235 - 1s - loss: 0.5608 - sparse_categorical_accuracy: 0.8048 - val_loss: 0.5522 - val_sparse_categorical_accuracy: 0.8070 - 1s/epoch - 5ms/step
# Epoch 3/100
# 235/235 - 1s - loss: 0.5021 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.5157 - val_sparse_categorical_accuracy: 0.8166 - 1s/epoch - 5ms/step
# Epoch 4/100
# 235/235 - 1s - loss: 0.4703 - sparse_categorical_accuracy: 0.8352 - val_loss: 0.4923 - val_sparse_categorical_accuracy: 0.8258 - 1s/epoch - 5ms/step
# Epoch 5/100
# 235/235 - 1s - loss: 0.4487 - sparse_categorical_accuracy: 0.8431 - val_loss: 0.4878 - val_sparse_categorical_accuracy: 0.8245 - 1s/epoch - 5ms/step
# Epoch 6/100
# 235/235 - 1s - loss: 0.4330 - sparse_categorical_accuracy: 0.8485 - val_loss: 0.4636 - val_sparse_categorical_accuracy: 0.8342 - 1s/epoch - 5ms/step
# Epoch 7/100
# 235/235 - 1s - loss: 0.4202 - sparse_categorical_accuracy: 0.8526 - val_loss: 0.4614 - val_sparse_categorical_accuracy: 0.8372 - 1s/epoch - 5ms/step
# Epoch 8/100
# 235/235 - 1s - loss: 0.4093 - sparse_categorical_accuracy: 0.8564 - val_loss: 0.4526 - val_sparse_categorical_accuracy: 0.8364 - 1s/epoch - 5ms/step
# Epoch 9/100
# 235/235 - 1s - loss: 0.4008 - sparse_categorical_accuracy: 0.8584 - val_loss: 0.4418 - val_sparse_categorical_accuracy: 0.8403 - 1s/epoch - 5ms/step
# Epoch 10/100
# 235/235 - 1s - loss: 0.3927 - sparse_categorical_accuracy: 0.8620 - val_loss: 0.4353 - val_sparse_categorical_accuracy: 0.8444 - 1s/epoch - 5ms/step
# Epoch 11/100
# 235/235 - 1s - loss: 0.3857 - sparse_categorical_accuracy: 0.8634 - val_loss: 0.4311 - val_sparse_categorical_accuracy: 0.8457 - 1s/epoch - 5ms/step
# Epoch 12/100
# 235/235 - 1s - loss: 0.3799 - sparse_categorical_accuracy: 0.8662 - val_loss: 0.4230 - val_sparse_categorical_accuracy: 0.8476 - 1s/epoch - 5ms/step
# Epoch 13/100
# 235/235 - 1s - loss: 0.3741 - sparse_categorical_accuracy: 0.8688 - val_loss: 0.4196 - val_sparse_categorical_accuracy: 0.8491 - 1s/epoch - 5ms/step
# Epoch 14/100
# 235/235 - 1s - loss: 0.3692 - sparse_categorical_accuracy: 0.8704 - val_loss: 0.4135 - val_sparse_categorical_accuracy: 0.8507 - 1s/epoch - 4ms/step
# Epoch 15/100
# 235/235 - 1s - loss: 0.3640 - sparse_categorical_accuracy: 0.8711 - val_loss: 0.4130 - val_sparse_categorical_accuracy: 0.8532 - 1s/epoch - 4ms/step
# Epoch 16/100
# 235/235 - 1s - loss: 0.3598 - sparse_categorical_accuracy: 0.8734 - val_loss: 0.4152 - val_sparse_categorical_accuracy: 0.8521 - 1s/epoch - 4ms/step
# Epoch 17/100
# 235/235 - 1s - loss: 0.3559 - sparse_categorical_accuracy: 0.8744 - val_loss: 0.4076 - val_sparse_categorical_accuracy: 0.8506 - 1s/epoch - 5ms/step
# Epoch 18/100
# 235/235 - 1s - loss: 0.3518 - sparse_categorical_accuracy: 0.8755 - val_loss: 0.4010 - val_sparse_categorical_accuracy: 0.8576 - 1s/epoch - 5ms/step
# Epoch 19/100
# 235/235 - 1s - loss: 0.3481 - sparse_categorical_accuracy: 0.8764 - val_loss: 0.4069 - val_sparse_categorical_accuracy: 0.8505 - 1s/epoch - 5ms/step
# Epoch 20/100
# 235/235 - 1s - loss: 0.3447 - sparse_categorical_accuracy: 0.8778 - val_loss: 0.3962 - val_sparse_categorical_accuracy: 0.8572 - 1s/epoch - 5ms/step
# Epoch 21/100
# 235/235 - 1s - loss: 0.3414 - sparse_categorical_accuracy: 0.8792 - val_loss: 0.3953 - val_sparse_categorical_accuracy: 0.8577 - 1s/epoch - 4ms/step
# Epoch 22/100
# 235/235 - 1s - loss: 0.3381 - sparse_categorical_accuracy: 0.8807 - val_loss: 0.3907 - val_sparse_categorical_accuracy: 0.8614 - 1s/epoch - 5ms/step
# Epoch 23/100
# 235/235 - 1s - loss: 0.3351 - sparse_categorical_accuracy: 0.8805 - val_loss: 0.3895 - val_sparse_categorical_accuracy: 0.8597 - 1s/epoch - 5ms/step
# Epoch 24/100
# 235/235 - 1s - loss: 0.3325 - sparse_categorical_accuracy: 0.8821 - val_loss: 0.3871 - val_sparse_categorical_accuracy: 0.8604 - 1s/epoch - 5ms/step
# Epoch 25/100
# 235/235 - 1s - loss: 0.3294 - sparse_categorical_accuracy: 0.8827 - val_loss: 0.3856 - val_sparse_categorical_accuracy: 0.8597 - 1s/epoch - 5ms/step
# Epoch 26/100
# 235/235 - 1s - loss: 0.3269 - sparse_categorical_accuracy: 0.8847 - val_loss: 0.3833 - val_sparse_categorical_accuracy: 0.8611 - 1s/epoch - 5ms/step
# Epoch 27/100
# 235/235 - 1s - loss: 0.3242 - sparse_categorical_accuracy: 0.8849 - val_loss: 0.3830 - val_sparse_categorical_accuracy: 0.8633 - 1s/epoch - 5ms/step
# Epoch 28/100
# 235/235 - 1s - loss: 0.3219 - sparse_categorical_accuracy: 0.8860 - val_loss: 0.3820 - val_sparse_categorical_accuracy: 0.8616 - 1s/epoch - 5ms/step
# Epoch 29/100
# 235/235 - 1s - loss: 0.3195 - sparse_categorical_accuracy: 0.8863 - val_loss: 0.3787 - val_sparse_categorical_accuracy: 0.8656 - 1s/epoch - 5ms/step
# Epoch 30/100
# 235/235 - 1s - loss: 0.3170 - sparse_categorical_accuracy: 0.8874 - val_loss: 0.3768 - val_sparse_categorical_accuracy: 0.8641 - 1s/epoch - 5ms/step
# Epoch 31/100
# 235/235 - 1s - loss: 0.3147 - sparse_categorical_accuracy: 0.8883 - val_loss: 0.3772 - val_sparse_categorical_accuracy: 0.8644 - 1s/epoch - 5ms/step
# Epoch 32/100
# 235/235 - 1s - loss: 0.3122 - sparse_categorical_accuracy: 0.8889 - val_loss: 0.3738 - val_sparse_categorical_accuracy: 0.8645 - 1s/epoch - 5ms/step
# Epoch 33/100
# 235/235 - 1s - loss: 0.3101 - sparse_categorical_accuracy: 0.8900 - val_loss: 0.3766 - val_sparse_categorical_accuracy: 0.8642 - 1s/epoch - 5ms/step
# Epoch 34/100
# 235/235 - 1s - loss: 0.3086 - sparse_categorical_accuracy: 0.8908 - val_loss: 0.3704 - val_sparse_categorical_accuracy: 0.8670 - 1s/epoch - 5ms/step
# Epoch 35/100
# 235/235 - 1s - loss: 0.3064 - sparse_categorical_accuracy: 0.8910 - val_loss: 0.3691 - val_sparse_categorical_accuracy: 0.8679 - 1s/epoch - 5ms/step
# Epoch 36/100
# 235/235 - 1s - loss: 0.3042 - sparse_categorical_accuracy: 0.8916 - val_loss: 0.3674 - val_sparse_categorical_accuracy: 0.8674 - 1s/epoch - 5ms/step
# Epoch 37/100
# 235/235 - 1s - loss: 0.3025 - sparse_categorical_accuracy: 0.8931 - val_loss: 0.3681 - val_sparse_categorical_accuracy: 0.8662 - 1s/epoch - 4ms/step
# Epoch 38/100
# 235/235 - 1s - loss: 0.3003 - sparse_categorical_accuracy: 0.8939 - val_loss: 0.3661 - val_sparse_categorical_accuracy: 0.8673 - 1s/epoch - 5ms/step
# Epoch 39/100
# 235/235 - 1s - loss: 0.2983 - sparse_categorical_accuracy: 0.8942 - val_loss: 0.3661 - val_sparse_categorical_accuracy: 0.8700 - 1s/epoch - 4ms/step
# Epoch 40/100
# 235/235 - 1s - loss: 0.2967 - sparse_categorical_accuracy: 0.8950 - val_loss: 0.3640 - val_sparse_categorical_accuracy: 0.8679 - 1s/epoch - 5ms/step
# Epoch 41/100
# 235/235 - 1s - loss: 0.2947 - sparse_categorical_accuracy: 0.8956 - val_loss: 0.3691 - val_sparse_categorical_accuracy: 0.8652 - 1s/epoch - 4ms/step
# Epoch 42/100
# 235/235 - 1s - loss: 0.2931 - sparse_categorical_accuracy: 0.8968 - val_loss: 0.3655 - val_sparse_categorical_accuracy: 0.8659 - 1s/epoch - 5ms/step
# Epoch 43/100
# 235/235 - 1s - loss: 0.2909 - sparse_categorical_accuracy: 0.8978 - val_loss: 0.3644 - val_sparse_categorical_accuracy: 0.8696 - 1s/epoch - 5ms/step
# Epoch 44/100
# 235/235 - 1s - loss: 0.2895 - sparse_categorical_accuracy: 0.8982 - val_loss: 0.3614 - val_sparse_categorical_accuracy: 0.8714 - 1s/epoch - 5ms/step
# Epoch 45/100
# 235/235 - 1s - loss: 0.2878 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.3590 - val_sparse_categorical_accuracy: 0.8714 - 1s/epoch - 5ms/step
# Epoch 46/100
# 235/235 - 1s - loss: 0.2860 - sparse_categorical_accuracy: 0.8993 - val_loss: 0.3612 - val_sparse_categorical_accuracy: 0.8700 - 1s/epoch - 5ms/step
# Epoch 47/100
# 235/235 - 1s - loss: 0.2845 - sparse_categorical_accuracy: 0.9004 - val_loss: 0.3564 - val_sparse_categorical_accuracy: 0.8731 - 1s/epoch - 5ms/step
# Epoch 48/100
# 235/235 - 1s - loss: 0.2829 - sparse_categorical_accuracy: 0.9006 - val_loss: 0.3600 - val_sparse_categorical_accuracy: 0.8705 - 1s/epoch - 5ms/step
# Epoch 49/100
# 235/235 - 1s - loss: 0.2812 - sparse_categorical_accuracy: 0.9005 - val_loss: 0.3560 - val_sparse_categorical_accuracy: 0.8728 - 1s/epoch - 5ms/step
# Epoch 50/100
# 235/235 - 1s - loss: 0.2801 - sparse_categorical_accuracy: 0.9022 - val_loss: 0.3563 - val_sparse_categorical_accuracy: 0.8726 - 1s/epoch - 5ms/step
# Epoch 51/100
# 235/235 - 1s - loss: 0.2786 - sparse_categorical_accuracy: 0.9016 - val_loss: 0.3580 - val_sparse_categorical_accuracy: 0.8720 - 1s/epoch - 5ms/step
# Epoch 52/100
# 235/235 - 1s - loss: 0.2767 - sparse_categorical_accuracy: 0.9026 - val_loss: 0.3595 - val_sparse_categorical_accuracy: 0.8711 - 1s/epoch - 5ms/step
# Epoch 53/100
# 235/235 - 1s - loss: 0.2752 - sparse_categorical_accuracy: 0.9028 - val_loss: 0.3523 - val_sparse_categorical_accuracy: 0.8724 - 1s/epoch - 5ms/step
# Epoch 54/100
# 235/235 - 1s - loss: 0.2738 - sparse_categorical_accuracy: 0.9038 - val_loss: 0.3529 - val_sparse_categorical_accuracy: 0.8727 - 1s/epoch - 5ms/step
# Epoch 55/100
# 235/235 - 1s - loss: 0.2723 - sparse_categorical_accuracy: 0.9043 - val_loss: 0.3491 - val_sparse_categorical_accuracy: 0.8754 - 1s/epoch - 5ms/step
# Epoch 56/100
# 235/235 - 1s - loss: 0.2710 - sparse_categorical_accuracy: 0.9046 - val_loss: 0.3490 - val_sparse_categorical_accuracy: 0.8749 - 1s/epoch - 5ms/step
# Epoch 57/100
# 235/235 - 1s - loss: 0.2695 - sparse_categorical_accuracy: 0.9054 - val_loss: 0.3492 - val_sparse_categorical_accuracy: 0.8749 - 1s/epoch - 5ms/step
# Epoch 58/100
# 235/235 - 1s - loss: 0.2682 - sparse_categorical_accuracy: 0.9054 - val_loss: 0.3486 - val_sparse_categorical_accuracy: 0.8766 - 1s/epoch - 5ms/step
# Epoch 59/100
# 235/235 - 1s - loss: 0.2668 - sparse_categorical_accuracy: 0.9058 - val_loss: 0.3480 - val_sparse_categorical_accuracy: 0.8769 - 1s/epoch - 5ms/step
# Epoch 60/100
# 235/235 - 1s - loss: 0.2654 - sparse_categorical_accuracy: 0.9071 - val_loss: 0.3461 - val_sparse_categorical_accuracy: 0.8776 - 1s/epoch - 5ms/step
# Epoch 61/100
# 235/235 - 1s - loss: 0.2641 - sparse_categorical_accuracy: 0.9077 - val_loss: 0.3460 - val_sparse_categorical_accuracy: 0.8764 - 1s/epoch - 5ms/step
# Epoch 62/100
# 235/235 - 1s - loss: 0.2627 - sparse_categorical_accuracy: 0.9079 - val_loss: 0.3452 - val_sparse_categorical_accuracy: 0.8759 - 1s/epoch - 5ms/step
# Epoch 63/100
# 235/235 - 1s - loss: 0.2615 - sparse_categorical_accuracy: 0.9088 - val_loss: 0.3437 - val_sparse_categorical_accuracy: 0.8771 - 1s/epoch - 5ms/step
# Epoch 64/100
# 235/235 - 1s - loss: 0.2599 - sparse_categorical_accuracy: 0.9093 - val_loss: 0.3434 - val_sparse_categorical_accuracy: 0.8783 - 1s/epoch - 5ms/step
# Epoch 65/100
# 235/235 - 1s - loss: 0.2589 - sparse_categorical_accuracy: 0.9092 - val_loss: 0.3451 - val_sparse_categorical_accuracy: 0.8756 - 1s/epoch - 5ms/step
# Epoch 66/100
# 235/235 - 1s - loss: 0.2579 - sparse_categorical_accuracy: 0.9100 - val_loss: 0.3419 - val_sparse_categorical_accuracy: 0.8775 - 1s/epoch - 4ms/step
# Epoch 67/100
# 235/235 - 1s - loss: 0.2565 - sparse_categorical_accuracy: 0.9104 - val_loss: 0.3487 - val_sparse_categorical_accuracy: 0.8738 - 1s/epoch - 5ms/step
# Epoch 68/100
# 235/235 - 1s - loss: 0.2553 - sparse_categorical_accuracy: 0.9111 - val_loss: 0.3427 - val_sparse_categorical_accuracy: 0.8775 - 1s/epoch - 5ms/step
# Epoch 69/100
# 235/235 - 1s - loss: 0.2542 - sparse_categorical_accuracy: 0.9107 - val_loss: 0.3443 - val_sparse_categorical_accuracy: 0.8776 - 1s/epoch - 5ms/step
# Epoch 70/100
# 235/235 - 1s - loss: 0.2529 - sparse_categorical_accuracy: 0.9115 - val_loss: 0.3425 - val_sparse_categorical_accuracy: 0.8775 - 1s/epoch - 5ms/step
# Epoch 71/100
# 235/235 - 1s - loss: 0.2515 - sparse_categorical_accuracy: 0.9123 - val_loss: 0.3427 - val_sparse_categorical_accuracy: 0.8762 - 1s/epoch - 5ms/step
# Epoch 72/100
# 235/235 - 1s - loss: 0.2503 - sparse_categorical_accuracy: 0.9129 - val_loss: 0.3420 - val_sparse_categorical_accuracy: 0.8789 - 1s/epoch - 5ms/step
# Epoch 73/100
# 235/235 - 1s - loss: 0.2497 - sparse_categorical_accuracy: 0.9122 - val_loss: 0.3393 - val_sparse_categorical_accuracy: 0.8794 - 1s/epoch - 5ms/step
# Epoch 74/100
# 235/235 - 1s - loss: 0.2482 - sparse_categorical_accuracy: 0.9136 - val_loss: 0.3415 - val_sparse_categorical_accuracy: 0.8759 - 1s/epoch - 5ms/step
# Epoch 75/100
# 235/235 - 1s - loss: 0.2472 - sparse_categorical_accuracy: 0.9131 - val_loss: 0.3371 - val_sparse_categorical_accuracy: 0.8786 - 1s/epoch - 5ms/step
# Epoch 76/100
# 235/235 - 1s - loss: 0.2460 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.3375 - val_sparse_categorical_accuracy: 0.8791 - 1s/epoch - 5ms/step
# Epoch 77/100
# 235/235 - 1s - loss: 0.2447 - sparse_categorical_accuracy: 0.9150 - val_loss: 0.3425 - val_sparse_categorical_accuracy: 0.8770 - 1s/epoch - 4ms/step
# Epoch 78/100
# 235/235 - 1s - loss: 0.2437 - sparse_categorical_accuracy: 0.9149 - val_loss: 0.3355 - val_sparse_categorical_accuracy: 0.8801 - 1s/epoch - 5ms/step
# Epoch 79/100
# 235/235 - 1s - loss: 0.2423 - sparse_categorical_accuracy: 0.9158 - val_loss: 0.3377 - val_sparse_categorical_accuracy: 0.8815 - 1s/epoch - 5ms/step
# Epoch 80/100
# 235/235 - 1s - loss: 0.2414 - sparse_categorical_accuracy: 0.9151 - val_loss: 0.3372 - val_sparse_categorical_accuracy: 0.8787 - 1s/epoch - 5ms/step
# Epoch 81/100
# 235/235 - 1s - loss: 0.2405 - sparse_categorical_accuracy: 0.9160 - val_loss: 0.3343 - val_sparse_categorical_accuracy: 0.8799 - 1s/epoch - 5ms/step
# Epoch 82/100
# 235/235 - 1s - loss: 0.2394 - sparse_categorical_accuracy: 0.9163 - val_loss: 0.3338 - val_sparse_categorical_accuracy: 0.8808 - 1s/epoch - 5ms/step
# Epoch 83/100
# 235/235 - 1s - loss: 0.2381 - sparse_categorical_accuracy: 0.9173 - val_loss: 0.3374 - val_sparse_categorical_accuracy: 0.8792 - 1s/epoch - 5ms/step
# Epoch 84/100
# 235/235 - 1s - loss: 0.2371 - sparse_categorical_accuracy: 0.9173 - val_loss: 0.3350 - val_sparse_categorical_accuracy: 0.8817 - 1s/epoch - 5ms/step
# Epoch 85/100
# 235/235 - 1s - loss: 0.2359 - sparse_categorical_accuracy: 0.9181 - val_loss: 0.3356 - val_sparse_categorical_accuracy: 0.8799 - 1s/epoch - 5ms/step
# Epoch 86/100
# 235/235 - 1s - loss: 0.2351 - sparse_categorical_accuracy: 0.9179 - val_loss: 0.3374 - val_sparse_categorical_accuracy: 0.8795 - 1s/epoch - 5ms/step
# Epoch 87/100
# 235/235 - 1s - loss: 0.2339 - sparse_categorical_accuracy: 0.9185 - val_loss: 0.3379 - val_sparse_categorical_accuracy: 0.8769 - 1s/epoch - 5ms/step
# Epoch 88/100
# 235/235 - 1s - loss: 0.2330 - sparse_categorical_accuracy: 0.9195 - val_loss: 0.3346 - val_sparse_categorical_accuracy: 0.8816 - 1s/epoch - 5ms/step
# Epoch 89/100
# 235/235 - 1s - loss: 0.2319 - sparse_categorical_accuracy: 0.9201 - val_loss: 0.3421 - val_sparse_categorical_accuracy: 0.8777 - 1s/epoch - 5ms/step
# Epoch 90/100
# 235/235 - 1s - loss: 0.2308 - sparse_categorical_accuracy: 0.9198 - val_loss: 0.3323 - val_sparse_categorical_accuracy: 0.8809 - 1s/epoch - 5ms/step
# Epoch 91/100
# 235/235 - 1s - loss: 0.2300 - sparse_categorical_accuracy: 0.9204 - val_loss: 0.3329 - val_sparse_categorical_accuracy: 0.8823 - 1s/epoch - 5ms/step
# Epoch 92/100
# 235/235 - 1s - loss: 0.2289 - sparse_categorical_accuracy: 0.9211 - val_loss: 0.3317 - val_sparse_categorical_accuracy: 0.8812 - 1s/epoch - 5ms/step
# Epoch 93/100
# 235/235 - 1s - loss: 0.2282 - sparse_categorical_accuracy: 0.9213 - val_loss: 0.3306 - val_sparse_categorical_accuracy: 0.8819 - 1s/epoch - 5ms/step
# Epoch 94/100
# 235/235 - 1s - loss: 0.2270 - sparse_categorical_accuracy: 0.9212 - val_loss: 0.3346 - val_sparse_categorical_accuracy: 0.8808 - 1s/epoch - 5ms/step
# Epoch 95/100
# 235/235 - 1s - loss: 0.2265 - sparse_categorical_accuracy: 0.9220 - val_loss: 0.3306 - val_sparse_categorical_accuracy: 0.8814 - 1s/epoch - 5ms/step
# Epoch 96/100
# 235/235 - 1s - loss: 0.2250 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.3357 - val_sparse_categorical_accuracy: 0.8812 - 1s/epoch - 5ms/step
# Epoch 97/100
# 235/235 - 1s - loss: 0.2242 - sparse_categorical_accuracy: 0.9226 - val_loss: 0.3352 - val_sparse_categorical_accuracy: 0.8810 - 1s/epoch - 5ms/step
# Epoch 98/100
# 235/235 - 1s - loss: 0.2230 - sparse_categorical_accuracy: 0.9233 - val_loss: 0.3311 - val_sparse_categorical_accuracy: 0.8820 - 1s/epoch - 5ms/step
# Epoch 99/100
# 235/235 - 1s - loss: 0.2222 - sparse_categorical_accuracy: 0.9236 - val_loss: 0.3354 - val_sparse_categorical_accuracy: 0.8796 - 1s/epoch - 5ms/step
# Epoch 100/100
# 235/235 - 1s - loss: 0.2213 - sparse_categorical_accuracy: 0.9240 - val_loss: 0.3385 - val_sparse_categorical_accuracy: 0.8797 - 1s/epoch - 5ms/step

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %%
model.evaluate(X_test, y_test, batch_size)
