# %%
# fashion_mnist
import tensorflow as tf
from tensorflow import keras
import numpy as np

(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')

x_train = x_train.reshape(60000, -1)
x_test  = x_test.reshape(10000, -1)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)

# %%
# data normalization

mean = np.mean(x_train)
std  = np.std(x_train)

x_train = (x_train-mean)/std
x_test  = (x_test-mean)/std

# %%
class MyDenseLayer(tf.keras.layers.Layer):
    def __init__(self, num_outputs):
        super(MyDenseLayer, self).__init__()
        self.num_outputs = num_outputs

    def build(self, input_shape):
        self.kernel = self.add_weight("kernel",
                                      shape=[int(input_shape[-1]), self.num_outputs])
        self.bias   = self.add_weight("bias",
                                      shape=[self.num_outputs])

    def call(self, inputs):
        return tf.matmul(inputs, self.kernel) + self.bias

# %%
# create model
model = keras.Sequential()
model.add(keras.Input(shape=(784,)))
model.add(MyDenseLayer(256))
model.add(tf.keras.layers.ReLU())
model.add(MyDenseLayer(10))
model.add(tf.keras.layers.Softmax())
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  my_dense_layer (MyDenseLaye  (None, 256)              200960
#  r)
#
#  re_lu (ReLU)                (None, 256)               0
#
#  my_dense_layer_1 (MyDenseLa  (None, 10)               2570
#  yer)
#
#  softmax (Softmax)           (None, 10)                0
#
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimizer and loss
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['sparse_categorical_accuracy'])

# training
history = model.fit(x_train, y_train, 
                    validation_data=(x_test, y_test), 
                    batch_size=256, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 235/235 - 1s - loss: 0.8065 - sparse_categorical_accuracy: 0.7300 - val_loss: 0.6164 - val_sparse_categorical_accuracy: 0.7818 - 1s/epoch - 6ms/step
# Epoch 2/100
# 235/235 - 1s - loss: 0.5493 - sparse_categorical_accuracy: 0.8114 - val_loss: 0.5449 - val_sparse_categorical_accuracy: 0.8080 - 1s/epoch - 5ms/step
# Epoch 3/100
# 235/235 - 1s - loss: 0.4964 - sparse_categorical_accuracy: 0.8278 - val_loss: 0.5074 - val_sparse_categorical_accuracy: 0.8192 - 1s/epoch - 5ms/step
# Epoch 4/100
# 235/235 - 1s - loss: 0.4662 - sparse_categorical_accuracy: 0.8385 - val_loss: 0.4862 - val_sparse_categorical_accuracy: 0.8281 - 1s/epoch - 5ms/step
# Epoch 5/100
# 235/235 - 1s - loss: 0.4460 - sparse_categorical_accuracy: 0.8443 - val_loss: 0.4716 - val_sparse_categorical_accuracy: 0.8314 - 1s/epoch - 5ms/step
# Epoch 6/100
# 235/235 - 1s - loss: 0.4307 - sparse_categorical_accuracy: 0.8494 - val_loss: 0.4598 - val_sparse_categorical_accuracy: 0.8379 - 1s/epoch - 5ms/step
# Epoch 7/100
# 235/235 - 1s - loss: 0.4185 - sparse_categorical_accuracy: 0.8537 - val_loss: 0.4506 - val_sparse_categorical_accuracy: 0.8399 - 1s/epoch - 5ms/step
# Epoch 8/100
# 235/235 - 1s - loss: 0.4082 - sparse_categorical_accuracy: 0.8569 - val_loss: 0.4428 - val_sparse_categorical_accuracy: 0.8433 - 1s/epoch - 5ms/step
# Epoch 9/100
# 235/235 - 1s - loss: 0.3990 - sparse_categorical_accuracy: 0.8609 - val_loss: 0.4353 - val_sparse_categorical_accuracy: 0.8454 - 1s/epoch - 5ms/step
# Epoch 10/100
# 235/235 - 1s - loss: 0.3916 - sparse_categorical_accuracy: 0.8621 - val_loss: 0.4319 - val_sparse_categorical_accuracy: 0.8462 - 1s/epoch - 5ms/step
# Epoch 11/100
# 235/235 - 1s - loss: 0.3849 - sparse_categorical_accuracy: 0.8653 - val_loss: 0.4287 - val_sparse_categorical_accuracy: 0.8452 - 1s/epoch - 5ms/step
# Epoch 12/100
# 235/235 - 1s - loss: 0.3788 - sparse_categorical_accuracy: 0.8673 - val_loss: 0.4297 - val_sparse_categorical_accuracy: 0.8442 - 1s/epoch - 5ms/step
# Epoch 13/100
# 235/235 - 1s - loss: 0.3732 - sparse_categorical_accuracy: 0.8692 - val_loss: 0.4187 - val_sparse_categorical_accuracy: 0.8523 - 1s/epoch - 5ms/step
# Epoch 14/100
# 235/235 - 1s - loss: 0.3680 - sparse_categorical_accuracy: 0.8702 - val_loss: 0.4142 - val_sparse_categorical_accuracy: 0.8539 - 1s/epoch - 5ms/step
# Epoch 15/100
# 235/235 - 1s - loss: 0.3633 - sparse_categorical_accuracy: 0.8719 - val_loss: 0.4098 - val_sparse_categorical_accuracy: 0.8551 - 1s/epoch - 5ms/step
# Epoch 16/100
# 235/235 - 1s - loss: 0.3586 - sparse_categorical_accuracy: 0.8731 - val_loss: 0.4093 - val_sparse_categorical_accuracy: 0.8560 - 1s/epoch - 5ms/step
# Epoch 17/100
# 235/235 - 1s - loss: 0.3548 - sparse_categorical_accuracy: 0.8745 - val_loss: 0.4063 - val_sparse_categorical_accuracy: 0.8559 - 1s/epoch - 5ms/step
# Epoch 18/100
# 235/235 - 1s - loss: 0.3510 - sparse_categorical_accuracy: 0.8760 - val_loss: 0.3993 - val_sparse_categorical_accuracy: 0.8563 - 1s/epoch - 5ms/step
# Epoch 19/100
# 235/235 - 1s - loss: 0.3470 - sparse_categorical_accuracy: 0.8774 - val_loss: 0.3970 - val_sparse_categorical_accuracy: 0.8587 - 1s/epoch - 5ms/step
# Epoch 20/100
# 235/235 - 1s - loss: 0.3435 - sparse_categorical_accuracy: 0.8792 - val_loss: 0.3937 - val_sparse_categorical_accuracy: 0.8615 - 1s/epoch - 5ms/step
# Epoch 21/100
# 235/235 - 1s - loss: 0.3402 - sparse_categorical_accuracy: 0.8800 - val_loss: 0.3928 - val_sparse_categorical_accuracy: 0.8596 - 1s/epoch - 5ms/step
# Epoch 22/100
# 235/235 - 1s - loss: 0.3371 - sparse_categorical_accuracy: 0.8812 - val_loss: 0.3959 - val_sparse_categorical_accuracy: 0.8569 - 1s/epoch - 5ms/step
# Epoch 23/100
# 235/235 - 1s - loss: 0.3341 - sparse_categorical_accuracy: 0.8820 - val_loss: 0.3903 - val_sparse_categorical_accuracy: 0.8623 - 1s/epoch - 5ms/step
# Epoch 24/100
# 235/235 - 1s - loss: 0.3312 - sparse_categorical_accuracy: 0.8838 - val_loss: 0.3863 - val_sparse_categorical_accuracy: 0.8611 - 1s/epoch - 5ms/step
# Epoch 25/100
# 235/235 - 1s - loss: 0.3278 - sparse_categorical_accuracy: 0.8842 - val_loss: 0.3841 - val_sparse_categorical_accuracy: 0.8622 - 1s/epoch - 5ms/step
# Epoch 26/100
# 235/235 - 1s - loss: 0.3257 - sparse_categorical_accuracy: 0.8849 - val_loss: 0.3827 - val_sparse_categorical_accuracy: 0.8632 - 1s/epoch - 5ms/step
# Epoch 27/100
# 235/235 - 1s - loss: 0.3227 - sparse_categorical_accuracy: 0.8855 - val_loss: 0.3836 - val_sparse_categorical_accuracy: 0.8633 - 1s/epoch - 5ms/step
# Epoch 28/100
# 235/235 - 1s - loss: 0.3205 - sparse_categorical_accuracy: 0.8864 - val_loss: 0.3840 - val_sparse_categorical_accuracy: 0.8616 - 1s/epoch - 5ms/step
# Epoch 29/100
# 235/235 - 1s - loss: 0.3179 - sparse_categorical_accuracy: 0.8872 - val_loss: 0.3859 - val_sparse_categorical_accuracy: 0.8619 - 1s/epoch - 5ms/step
# Epoch 30/100
# 235/235 - 1s - loss: 0.3158 - sparse_categorical_accuracy: 0.8884 - val_loss: 0.3748 - val_sparse_categorical_accuracy: 0.8666 - 1s/epoch - 5ms/step
# Epoch 31/100
# 235/235 - 1s - loss: 0.3130 - sparse_categorical_accuracy: 0.8892 - val_loss: 0.3753 - val_sparse_categorical_accuracy: 0.8664 - 1s/epoch - 5ms/step
# Epoch 32/100
# 235/235 - 1s - loss: 0.3113 - sparse_categorical_accuracy: 0.8898 - val_loss: 0.3737 - val_sparse_categorical_accuracy: 0.8650 - 1s/epoch - 5ms/step
# Epoch 33/100
# 235/235 - 1s - loss: 0.3089 - sparse_categorical_accuracy: 0.8907 - val_loss: 0.3737 - val_sparse_categorical_accuracy: 0.8686 - 1s/epoch - 5ms/step
# Epoch 34/100
# 235/235 - 1s - loss: 0.3069 - sparse_categorical_accuracy: 0.8917 - val_loss: 0.3702 - val_sparse_categorical_accuracy: 0.8704 - 1s/epoch - 5ms/step
# Epoch 35/100
# 235/235 - 1s - loss: 0.3043 - sparse_categorical_accuracy: 0.8925 - val_loss: 0.3711 - val_sparse_categorical_accuracy: 0.8685 - 1s/epoch - 5ms/step
# Epoch 36/100
# 235/235 - 1s - loss: 0.3026 - sparse_categorical_accuracy: 0.8925 - val_loss: 0.3677 - val_sparse_categorical_accuracy: 0.8686 - 1s/epoch - 5ms/step
# Epoch 37/100
# 235/235 - 1s - loss: 0.3005 - sparse_categorical_accuracy: 0.8931 - val_loss: 0.3688 - val_sparse_categorical_accuracy: 0.8694 - 1s/epoch - 5ms/step
# Epoch 38/100
# 235/235 - 1s - loss: 0.2987 - sparse_categorical_accuracy: 0.8939 - val_loss: 0.3656 - val_sparse_categorical_accuracy: 0.8709 - 1s/epoch - 5ms/step
# Epoch 39/100
# 235/235 - 1s - loss: 0.2968 - sparse_categorical_accuracy: 0.8945 - val_loss: 0.3628 - val_sparse_categorical_accuracy: 0.8707 - 1s/epoch - 5ms/step
# Epoch 40/100
# 235/235 - 1s - loss: 0.2945 - sparse_categorical_accuracy: 0.8956 - val_loss: 0.3631 - val_sparse_categorical_accuracy: 0.8693 - 1s/epoch - 5ms/step
# Epoch 41/100
# 235/235 - 1s - loss: 0.2929 - sparse_categorical_accuracy: 0.8966 - val_loss: 0.3633 - val_sparse_categorical_accuracy: 0.8718 - 1s/epoch - 5ms/step
# Epoch 42/100
# 235/235 - 1s - loss: 0.2908 - sparse_categorical_accuracy: 0.8968 - val_loss: 0.3606 - val_sparse_categorical_accuracy: 0.8717 - 1s/epoch - 5ms/step
# Epoch 43/100
# 235/235 - 1s - loss: 0.2894 - sparse_categorical_accuracy: 0.8975 - val_loss: 0.3694 - val_sparse_categorical_accuracy: 0.8693 - 1s/epoch - 5ms/step
# Epoch 44/100
# 235/235 - 1s - loss: 0.2876 - sparse_categorical_accuracy: 0.8991 - val_loss: 0.3585 - val_sparse_categorical_accuracy: 0.8719 - 1s/epoch - 5ms/step
# Epoch 45/100
# 235/235 - 1s - loss: 0.2861 - sparse_categorical_accuracy: 0.8987 - val_loss: 0.3581 - val_sparse_categorical_accuracy: 0.8741 - 1s/epoch - 5ms/step
# Epoch 46/100
# 235/235 - 1s - loss: 0.2843 - sparse_categorical_accuracy: 0.9000 - val_loss: 0.3590 - val_sparse_categorical_accuracy: 0.8719 - 1s/epoch - 5ms/step
# Epoch 47/100
# 235/235 - 1s - loss: 0.2825 - sparse_categorical_accuracy: 0.9003 - val_loss: 0.3578 - val_sparse_categorical_accuracy: 0.8728 - 1s/epoch - 5ms/step
# Epoch 48/100
# 235/235 - 1s - loss: 0.2810 - sparse_categorical_accuracy: 0.9003 - val_loss: 0.3564 - val_sparse_categorical_accuracy: 0.8714 - 1s/epoch - 5ms/step
# Epoch 49/100
# 235/235 - 1s - loss: 0.2791 - sparse_categorical_accuracy: 0.9015 - val_loss: 0.3553 - val_sparse_categorical_accuracy: 0.8736 - 1s/epoch - 5ms/step
# Epoch 50/100
# 235/235 - 1s - loss: 0.2776 - sparse_categorical_accuracy: 0.9020 - val_loss: 0.3542 - val_sparse_categorical_accuracy: 0.8735 - 1s/epoch - 5ms/step
# Epoch 51/100
# 235/235 - 1s - loss: 0.2762 - sparse_categorical_accuracy: 0.9027 - val_loss: 0.3519 - val_sparse_categorical_accuracy: 0.8747 - 1s/epoch - 5ms/step
# Epoch 52/100
# 235/235 - 1s - loss: 0.2745 - sparse_categorical_accuracy: 0.9028 - val_loss: 0.3540 - val_sparse_categorical_accuracy: 0.8750 - 1s/epoch - 5ms/step
# Epoch 53/100
# 235/235 - 1s - loss: 0.2732 - sparse_categorical_accuracy: 0.9034 - val_loss: 0.3533 - val_sparse_categorical_accuracy: 0.8752 - 1s/epoch - 5ms/step
# Epoch 54/100
# 235/235 - 1s - loss: 0.2719 - sparse_categorical_accuracy: 0.9040 - val_loss: 0.3539 - val_sparse_categorical_accuracy: 0.8737 - 1s/epoch - 5ms/step
# Epoch 55/100
# 235/235 - 1s - loss: 0.2704 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.3493 - val_sparse_categorical_accuracy: 0.8763 - 1s/epoch - 5ms/step
# Epoch 56/100
# 235/235 - 1s - loss: 0.2689 - sparse_categorical_accuracy: 0.9051 - val_loss: 0.3494 - val_sparse_categorical_accuracy: 0.8766 - 1s/epoch - 5ms/step
# Epoch 57/100
# 235/235 - 1s - loss: 0.2676 - sparse_categorical_accuracy: 0.9056 - val_loss: 0.3524 - val_sparse_categorical_accuracy: 0.8739 - 1s/epoch - 5ms/step
# Epoch 58/100
# 235/235 - 1s - loss: 0.2663 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.3515 - val_sparse_categorical_accuracy: 0.8744 - 1s/epoch - 5ms/step
# Epoch 59/100
# 235/235 - 1s - loss: 0.2648 - sparse_categorical_accuracy: 0.9065 - val_loss: 0.3480 - val_sparse_categorical_accuracy: 0.8763 - 1s/epoch - 5ms/step
# Epoch 60/100
# 235/235 - 1s - loss: 0.2633 - sparse_categorical_accuracy: 0.9077 - val_loss: 0.3504 - val_sparse_categorical_accuracy: 0.8750 - 1s/epoch - 5ms/step
# Epoch 61/100
# 235/235 - 1s - loss: 0.2621 - sparse_categorical_accuracy: 0.9078 - val_loss: 0.3510 - val_sparse_categorical_accuracy: 0.8755 - 1s/epoch - 5ms/step
# Epoch 62/100
# 235/235 - 1s - loss: 0.2605 - sparse_categorical_accuracy: 0.9080 - val_loss: 0.3470 - val_sparse_categorical_accuracy: 0.8754 - 1s/epoch - 5ms/step
# Epoch 63/100
# 235/235 - 1s - loss: 0.2592 - sparse_categorical_accuracy: 0.9088 - val_loss: 0.3456 - val_sparse_categorical_accuracy: 0.8780 - 1s/epoch - 5ms/step
# Epoch 64/100
# 235/235 - 1s - loss: 0.2578 - sparse_categorical_accuracy: 0.9090 - val_loss: 0.3492 - val_sparse_categorical_accuracy: 0.8758 - 1s/epoch - 5ms/step
# Epoch 65/100
# 235/235 - 1s - loss: 0.2567 - sparse_categorical_accuracy: 0.9097 - val_loss: 0.3506 - val_sparse_categorical_accuracy: 0.8751 - 1s/epoch - 5ms/step
# Epoch 66/100
# 235/235 - 1s - loss: 0.2554 - sparse_categorical_accuracy: 0.9101 - val_loss: 0.3471 - val_sparse_categorical_accuracy: 0.8762 - 1s/epoch - 5ms/step
# Epoch 67/100
# 235/235 - 1s - loss: 0.2542 - sparse_categorical_accuracy: 0.9108 - val_loss: 0.3455 - val_sparse_categorical_accuracy: 0.8769 - 1s/epoch - 5ms/step
# Epoch 68/100
# 235/235 - 1s - loss: 0.2531 - sparse_categorical_accuracy: 0.9113 - val_loss: 0.3464 - val_sparse_categorical_accuracy: 0.8773 - 1s/epoch - 5ms/step
# Epoch 69/100
# 235/235 - 1s - loss: 0.2520 - sparse_categorical_accuracy: 0.9115 - val_loss: 0.3412 - val_sparse_categorical_accuracy: 0.8812 - 1s/epoch - 5ms/step
# Epoch 70/100
# 235/235 - 1s - loss: 0.2503 - sparse_categorical_accuracy: 0.9119 - val_loss: 0.3404 - val_sparse_categorical_accuracy: 0.8785 - 1s/epoch - 5ms/step
# Epoch 71/100
# 235/235 - 1s - loss: 0.2493 - sparse_categorical_accuracy: 0.9126 - val_loss: 0.3423 - val_sparse_categorical_accuracy: 0.8778 - 1s/epoch - 5ms/step
# Epoch 72/100
# 235/235 - 1s - loss: 0.2480 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.3405 - val_sparse_categorical_accuracy: 0.8789 - 1s/epoch - 5ms/step
# Epoch 73/100
# 235/235 - 1s - loss: 0.2470 - sparse_categorical_accuracy: 0.9136 - val_loss: 0.3411 - val_sparse_categorical_accuracy: 0.8786 - 1s/epoch - 5ms/step
# Epoch 74/100
# 235/235 - 1s - loss: 0.2456 - sparse_categorical_accuracy: 0.9143 - val_loss: 0.3392 - val_sparse_categorical_accuracy: 0.8787 - 1s/epoch - 5ms/step
# Epoch 75/100
# 235/235 - 1s - loss: 0.2445 - sparse_categorical_accuracy: 0.9143 - val_loss: 0.3448 - val_sparse_categorical_accuracy: 0.8766 - 1s/epoch - 5ms/step
# Epoch 76/100
# 235/235 - 1s - loss: 0.2431 - sparse_categorical_accuracy: 0.9154 - val_loss: 0.3413 - val_sparse_categorical_accuracy: 0.8777 - 1s/epoch - 5ms/step
# Epoch 77/100
# 235/235 - 1s - loss: 0.2421 - sparse_categorical_accuracy: 0.9155 - val_loss: 0.3388 - val_sparse_categorical_accuracy: 0.8800 - 1s/epoch - 5ms/step
# Epoch 78/100
# 235/235 - 1s - loss: 0.2415 - sparse_categorical_accuracy: 0.9157 - val_loss: 0.3399 - val_sparse_categorical_accuracy: 0.8799 - 1s/epoch - 5ms/step
# Epoch 79/100
# 235/235 - 1s - loss: 0.2402 - sparse_categorical_accuracy: 0.9156 - val_loss: 0.3400 - val_sparse_categorical_accuracy: 0.8804 - 1s/epoch - 5ms/step
# Epoch 80/100
# 235/235 - 1s - loss: 0.2391 - sparse_categorical_accuracy: 0.9165 - val_loss: 0.3415 - val_sparse_categorical_accuracy: 0.8795 - 1s/epoch - 5ms/step
# Epoch 81/100
# 235/235 - 1s - loss: 0.2378 - sparse_categorical_accuracy: 0.9173 - val_loss: 0.3410 - val_sparse_categorical_accuracy: 0.8782 - 1s/epoch - 5ms/step
# Epoch 82/100
# 235/235 - 1s - loss: 0.2368 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.3373 - val_sparse_categorical_accuracy: 0.8791 - 1s/epoch - 5ms/step
# Epoch 83/100
# 235/235 - 1s - loss: 0.2356 - sparse_categorical_accuracy: 0.9180 - val_loss: 0.3378 - val_sparse_categorical_accuracy: 0.8809 - 1s/epoch - 5ms/step
# Epoch 84/100
# 235/235 - 1s - loss: 0.2348 - sparse_categorical_accuracy: 0.9188 - val_loss: 0.3370 - val_sparse_categorical_accuracy: 0.8802 - 1s/epoch - 5ms/step
# Epoch 85/100
# 235/235 - 1s - loss: 0.2336 - sparse_categorical_accuracy: 0.9185 - val_loss: 0.3387 - val_sparse_categorical_accuracy: 0.8794 - 1s/epoch - 5ms/step
# Epoch 86/100
# 235/235 - 1s - loss: 0.2329 - sparse_categorical_accuracy: 0.9193 - val_loss: 0.3402 - val_sparse_categorical_accuracy: 0.8796 - 1s/epoch - 5ms/step
# Epoch 87/100
# 235/235 - 1s - loss: 0.2313 - sparse_categorical_accuracy: 0.9199 - val_loss: 0.3352 - val_sparse_categorical_accuracy: 0.8809 - 1s/epoch - 5ms/step
# Epoch 88/100
# 235/235 - 1s - loss: 0.2303 - sparse_categorical_accuracy: 0.9201 - val_loss: 0.3388 - val_sparse_categorical_accuracy: 0.8792 - 1s/epoch - 5ms/step
# Epoch 89/100
# 235/235 - 1s - loss: 0.2296 - sparse_categorical_accuracy: 0.9202 - val_loss: 0.3366 - val_sparse_categorical_accuracy: 0.8818 - 1s/epoch - 5ms/step
# Epoch 90/100
# 235/235 - 1s - loss: 0.2286 - sparse_categorical_accuracy: 0.9206 - val_loss: 0.3393 - val_sparse_categorical_accuracy: 0.8803 - 1s/epoch - 5ms/step
# Epoch 91/100
# 235/235 - 1s - loss: 0.2277 - sparse_categorical_accuracy: 0.9205 - val_loss: 0.3339 - val_sparse_categorical_accuracy: 0.8820 - 1s/epoch - 6ms/step
# Epoch 92/100
# 235/235 - 1s - loss: 0.2262 - sparse_categorical_accuracy: 0.9218 - val_loss: 0.3418 - val_sparse_categorical_accuracy: 0.8785 - 1s/epoch - 5ms/step
# Epoch 93/100
# 235/235 - 1s - loss: 0.2255 - sparse_categorical_accuracy: 0.9218 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8818 - 1s/epoch - 5ms/step
# Epoch 94/100
# 235/235 - 1s - loss: 0.2248 - sparse_categorical_accuracy: 0.9216 - val_loss: 0.3332 - val_sparse_categorical_accuracy: 0.8835 - 1s/epoch - 6ms/step
# Epoch 95/100
# 235/235 - 1s - loss: 0.2235 - sparse_categorical_accuracy: 0.9222 - val_loss: 0.3421 - val_sparse_categorical_accuracy: 0.8761 - 1s/epoch - 6ms/step
# Epoch 96/100
# 235/235 - 1s - loss: 0.2227 - sparse_categorical_accuracy: 0.9230 - val_loss: 0.3335 - val_sparse_categorical_accuracy: 0.8818 - 1s/epoch - 5ms/step
# Epoch 97/100
# 235/235 - 1s - loss: 0.2215 - sparse_categorical_accuracy: 0.9226 - val_loss: 0.3418 - val_sparse_categorical_accuracy: 0.8762 - 1s/epoch - 5ms/step
# Epoch 98/100
# 235/235 - 1s - loss: 0.2205 - sparse_categorical_accuracy: 0.9240 - val_loss: 0.3398 - val_sparse_categorical_accuracy: 0.8795 - 1s/epoch - 5ms/step
# Epoch 99/100
# 235/235 - 1s - loss: 0.2199 - sparse_categorical_accuracy: 0.9236 - val_loss: 0.3318 - val_sparse_categorical_accuracy: 0.8838 - 1s/epoch - 5ms/step
# Epoch 100/100
# 235/235 - 1s - loss: 0.2188 - sparse_categorical_accuracy: 0.9241 - val_loss: 0.3327 - val_sparse_categorical_accuracy: 0.8830 - 1s/epoch - 5ms/step

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()
