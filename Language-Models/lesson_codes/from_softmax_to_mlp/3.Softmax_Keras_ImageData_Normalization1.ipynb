# %%
import numpy as np
import gzip

# load training images
with gzip.open('data_fashion_mnist/train-images-idx3-ubyte.gz', 'rb') as f:
    X_train = np.frombuffer(f.read(), np.uint8, offset=16).reshape(-1, 28*28)

# load testing images
with gzip.open('data_fashion_mnist/t10k-images-idx3-ubyte.gz', 'rb') as f:
    X_test = np.frombuffer(f.read(), np.uint8, offset=16).reshape(-1, 28*28)

# load training labels
with gzip.open('data_fashion_mnist/train-labels-idx1-ubyte.gz', 'rb') as f:
    y_train = np.frombuffer(f.read(), np.uint8, offset=8)
    
# load testing labels
with gzip.open('data_fashion_mnist/t10k-labels-idx1-ubyte.gz', 'rb') as f:
    y_test = np.frombuffer(f.read(), np.uint8, offset=8)
    

# check data
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)

# %%
# data normalization

X_train = X_train/255.0
X_test  = X_test/255.0

# %%
import tensorflow as tf
import tensorflow.keras as keras

# create model
model = keras.Sequential()
model.add(keras.Input(shape=(784,)))
model.add(keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                7850
#
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimizer and loss
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['sparse_categorical_accuracy'])

# training
history = model.fit(X_train, y_train, 
                    validation_data=(X_test, y_test), 
                    batch_size=256, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 235/235 - 2s - loss: 1.3743 - sparse_categorical_accuracy: 0.6131 - val_loss: 1.0263 - val_sparse_categorical_accuracy: 0.6795 - 2s/epoch - 9ms/step
# Epoch 2/100
# 235/235 - 1s - loss: 0.9172 - sparse_categorical_accuracy: 0.7126 - val_loss: 0.8606 - val_sparse_categorical_accuracy: 0.7182 - 789ms/epoch - 3ms/step
# Epoch 3/100
# 235/235 - 1s - loss: 0.8044 - sparse_categorical_accuracy: 0.7435 - val_loss: 0.7858 - val_sparse_categorical_accuracy: 0.7433 - 799ms/epoch - 3ms/step
# Epoch 4/100
# 235/235 - 1s - loss: 0.7443 - sparse_categorical_accuracy: 0.7635 - val_loss: 0.7391 - val_sparse_categorical_accuracy: 0.7582 - 821ms/epoch - 3ms/step
# Epoch 5/100
# 235/235 - 1s - loss: 0.7044 - sparse_categorical_accuracy: 0.7774 - val_loss: 0.7077 - val_sparse_categorical_accuracy: 0.7678 - 772ms/epoch - 3ms/step
# Epoch 6/100
# 235/235 - 1s - loss: 0.6754 - sparse_categorical_accuracy: 0.7853 - val_loss: 0.6826 - val_sparse_categorical_accuracy: 0.7769 - 801ms/epoch - 3ms/step
# Epoch 7/100
# 235/235 - 1s - loss: 0.6528 - sparse_categorical_accuracy: 0.7922 - val_loss: 0.6632 - val_sparse_categorical_accuracy: 0.7828 - 786ms/epoch - 3ms/step
# Epoch 8/100
# 235/235 - 1s - loss: 0.6349 - sparse_categorical_accuracy: 0.7972 - val_loss: 0.6483 - val_sparse_categorical_accuracy: 0.7874 - 787ms/epoch - 3ms/step
# Epoch 9/100
# 235/235 - 1s - loss: 0.6200 - sparse_categorical_accuracy: 0.8011 - val_loss: 0.6341 - val_sparse_categorical_accuracy: 0.7914 - 801ms/epoch - 3ms/step
# Epoch 10/100
# 235/235 - 1s - loss: 0.6073 - sparse_categorical_accuracy: 0.8056 - val_loss: 0.6231 - val_sparse_categorical_accuracy: 0.7951 - 792ms/epoch - 3ms/step
# Epoch 11/100
# 235/235 - 1s - loss: 0.5964 - sparse_categorical_accuracy: 0.8078 - val_loss: 0.6139 - val_sparse_categorical_accuracy: 0.7957 - 795ms/epoch - 3ms/step
# Epoch 12/100
# 235/235 - 1s - loss: 0.5868 - sparse_categorical_accuracy: 0.8108 - val_loss: 0.6066 - val_sparse_categorical_accuracy: 0.7974 - 790ms/epoch - 3ms/step
# Epoch 13/100
# 235/235 - 1s - loss: 0.5785 - sparse_categorical_accuracy: 0.8125 - val_loss: 0.5970 - val_sparse_categorical_accuracy: 0.8033 - 781ms/epoch - 3ms/step
# Epoch 14/100
# 235/235 - 1s - loss: 0.5709 - sparse_categorical_accuracy: 0.8147 - val_loss: 0.5908 - val_sparse_categorical_accuracy: 0.8040 - 795ms/epoch - 3ms/step
# Epoch 15/100
# 235/235 - 1s - loss: 0.5642 - sparse_categorical_accuracy: 0.8173 - val_loss: 0.5843 - val_sparse_categorical_accuracy: 0.8066 - 812ms/epoch - 3ms/step
# Epoch 16/100
# 235/235 - 1s - loss: 0.5580 - sparse_categorical_accuracy: 0.8187 - val_loss: 0.5788 - val_sparse_categorical_accuracy: 0.8076 - 769ms/epoch - 3ms/step
# Epoch 17/100
# 235/235 - 1s - loss: 0.5524 - sparse_categorical_accuracy: 0.8205 - val_loss: 0.5740 - val_sparse_categorical_accuracy: 0.8079 - 798ms/epoch - 3ms/step
# Epoch 18/100
# 235/235 - 1s - loss: 0.5474 - sparse_categorical_accuracy: 0.8217 - val_loss: 0.5691 - val_sparse_categorical_accuracy: 0.8107 - 803ms/epoch - 3ms/step
# Epoch 19/100
# 235/235 - 1s - loss: 0.5425 - sparse_categorical_accuracy: 0.8226 - val_loss: 0.5656 - val_sparse_categorical_accuracy: 0.8103 - 790ms/epoch - 3ms/step
# Epoch 20/100
# 235/235 - 1s - loss: 0.5381 - sparse_categorical_accuracy: 0.8240 - val_loss: 0.5610 - val_sparse_categorical_accuracy: 0.8132 - 794ms/epoch - 3ms/step
# Epoch 21/100
# 235/235 - 1s - loss: 0.5342 - sparse_categorical_accuracy: 0.8255 - val_loss: 0.5575 - val_sparse_categorical_accuracy: 0.8142 - 790ms/epoch - 3ms/step
# Epoch 22/100
# 235/235 - 1s - loss: 0.5303 - sparse_categorical_accuracy: 0.8260 - val_loss: 0.5548 - val_sparse_categorical_accuracy: 0.8118 - 796ms/epoch - 3ms/step
# Epoch 23/100
# 235/235 - 1s - loss: 0.5267 - sparse_categorical_accuracy: 0.8266 - val_loss: 0.5505 - val_sparse_categorical_accuracy: 0.8151 - 789ms/epoch - 3ms/step
# Epoch 24/100
# 235/235 - 1s - loss: 0.5234 - sparse_categorical_accuracy: 0.8278 - val_loss: 0.5478 - val_sparse_categorical_accuracy: 0.8162 - 799ms/epoch - 3ms/step
# Epoch 25/100
# 235/235 - 1s - loss: 0.5203 - sparse_categorical_accuracy: 0.8285 - val_loss: 0.5450 - val_sparse_categorical_accuracy: 0.8158 - 792ms/epoch - 3ms/step
# Epoch 26/100
# 235/235 - 1s - loss: 0.5173 - sparse_categorical_accuracy: 0.8295 - val_loss: 0.5424 - val_sparse_categorical_accuracy: 0.8174 - 794ms/epoch - 3ms/step
# Epoch 27/100
# 235/235 - 1s - loss: 0.5144 - sparse_categorical_accuracy: 0.8303 - val_loss: 0.5396 - val_sparse_categorical_accuracy: 0.8185 - 795ms/epoch - 3ms/step
# Epoch 28/100
# 235/235 - 1s - loss: 0.5118 - sparse_categorical_accuracy: 0.8308 - val_loss: 0.5373 - val_sparse_categorical_accuracy: 0.8171 - 793ms/epoch - 3ms/step
# Epoch 29/100
# 235/235 - 1s - loss: 0.5093 - sparse_categorical_accuracy: 0.8321 - val_loss: 0.5352 - val_sparse_categorical_accuracy: 0.8195 - 801ms/epoch - 3ms/step
# Epoch 30/100
# 235/235 - 1s - loss: 0.5069 - sparse_categorical_accuracy: 0.8324 - val_loss: 0.5329 - val_sparse_categorical_accuracy: 0.8188 - 798ms/epoch - 3ms/step
# Epoch 31/100
# 235/235 - 1s - loss: 0.5046 - sparse_categorical_accuracy: 0.8336 - val_loss: 0.5309 - val_sparse_categorical_accuracy: 0.8198 - 797ms/epoch - 3ms/step
# Epoch 32/100
# 235/235 - 1s - loss: 0.5024 - sparse_categorical_accuracy: 0.8335 - val_loss: 0.5286 - val_sparse_categorical_accuracy: 0.8220 - 801ms/epoch - 3ms/step
# Epoch 33/100
# 235/235 - 1s - loss: 0.5004 - sparse_categorical_accuracy: 0.8340 - val_loss: 0.5267 - val_sparse_categorical_accuracy: 0.8228 - 800ms/epoch - 3ms/step
# Epoch 34/100
# 235/235 - 1s - loss: 0.4982 - sparse_categorical_accuracy: 0.8344 - val_loss: 0.5259 - val_sparse_categorical_accuracy: 0.8205 - 798ms/epoch - 3ms/step
# Epoch 35/100
# 235/235 - 1s - loss: 0.4963 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.5236 - val_sparse_categorical_accuracy: 0.8213 - 813ms/epoch - 3ms/step
# Epoch 36/100
# 235/235 - 1s - loss: 0.4945 - sparse_categorical_accuracy: 0.8355 - val_loss: 0.5220 - val_sparse_categorical_accuracy: 0.8222 - 793ms/epoch - 3ms/step
# Epoch 37/100
# 235/235 - 1s - loss: 0.4928 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.5203 - val_sparse_categorical_accuracy: 0.8245 - 804ms/epoch - 3ms/step
# Epoch 38/100
# 235/235 - 1s - loss: 0.4911 - sparse_categorical_accuracy: 0.8366 - val_loss: 0.5189 - val_sparse_categorical_accuracy: 0.8230 - 799ms/epoch - 3ms/step
# Epoch 39/100
# 235/235 - 1s - loss: 0.4894 - sparse_categorical_accuracy: 0.8373 - val_loss: 0.5170 - val_sparse_categorical_accuracy: 0.8248 - 816ms/epoch - 3ms/step
# Epoch 40/100
# 235/235 - 1s - loss: 0.4878 - sparse_categorical_accuracy: 0.8382 - val_loss: 0.5165 - val_sparse_categorical_accuracy: 0.8248 - 903ms/epoch - 4ms/step
# Epoch 41/100
# 235/235 - 1s - loss: 0.4863 - sparse_categorical_accuracy: 0.8382 - val_loss: 0.5141 - val_sparse_categorical_accuracy: 0.8257 - 883ms/epoch - 4ms/step
# Epoch 42/100
# 235/235 - 1s - loss: 0.4847 - sparse_categorical_accuracy: 0.8387 - val_loss: 0.5131 - val_sparse_categorical_accuracy: 0.8238 - 897ms/epoch - 4ms/step
# Epoch 43/100
# 235/235 - 1s - loss: 0.4835 - sparse_categorical_accuracy: 0.8388 - val_loss: 0.5120 - val_sparse_categorical_accuracy: 0.8252 - 833ms/epoch - 4ms/step
# Epoch 44/100
# 235/235 - 1s - loss: 0.4820 - sparse_categorical_accuracy: 0.8392 - val_loss: 0.5106 - val_sparse_categorical_accuracy: 0.8259 - 807ms/epoch - 3ms/step
# Epoch 45/100
# 235/235 - 1s - loss: 0.4807 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.5092 - val_sparse_categorical_accuracy: 0.8268 - 796ms/epoch - 3ms/step
# Epoch 46/100
# 235/235 - 1s - loss: 0.4793 - sparse_categorical_accuracy: 0.8402 - val_loss: 0.5083 - val_sparse_categorical_accuracy: 0.8266 - 796ms/epoch - 3ms/step
# Epoch 47/100
# 235/235 - 1s - loss: 0.4781 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.5076 - val_sparse_categorical_accuracy: 0.8264 - 793ms/epoch - 3ms/step
# Epoch 48/100
# 235/235 - 1s - loss: 0.4770 - sparse_categorical_accuracy: 0.8413 - val_loss: 0.5060 - val_sparse_categorical_accuracy: 0.8271 - 804ms/epoch - 3ms/step
# Epoch 49/100
# 235/235 - 1s - loss: 0.4758 - sparse_categorical_accuracy: 0.8411 - val_loss: 0.5051 - val_sparse_categorical_accuracy: 0.8275 - 794ms/epoch - 3ms/step
# Epoch 50/100
# 235/235 - 1s - loss: 0.4746 - sparse_categorical_accuracy: 0.8419 - val_loss: 0.5046 - val_sparse_categorical_accuracy: 0.8273 - 795ms/epoch - 3ms/step
# Epoch 51/100
# 235/235 - 1s - loss: 0.4736 - sparse_categorical_accuracy: 0.8421 - val_loss: 0.5027 - val_sparse_categorical_accuracy: 0.8275 - 796ms/epoch - 3ms/step
# Epoch 52/100
# 235/235 - 1s - loss: 0.4725 - sparse_categorical_accuracy: 0.8423 - val_loss: 0.5017 - val_sparse_categorical_accuracy: 0.8283 - 792ms/epoch - 3ms/step
# Epoch 53/100
# 235/235 - 1s - loss: 0.4714 - sparse_categorical_accuracy: 0.8419 - val_loss: 0.5007 - val_sparse_categorical_accuracy: 0.8279 - 788ms/epoch - 3ms/step
# Epoch 54/100
# 235/235 - 1s - loss: 0.4703 - sparse_categorical_accuracy: 0.8432 - val_loss: 0.5008 - val_sparse_categorical_accuracy: 0.8283 - 794ms/epoch - 3ms/step
# Epoch 55/100
# 235/235 - 1s - loss: 0.4694 - sparse_categorical_accuracy: 0.8432 - val_loss: 0.4991 - val_sparse_categorical_accuracy: 0.8285 - 792ms/epoch - 3ms/step
# Epoch 56/100
# 235/235 - 1s - loss: 0.4684 - sparse_categorical_accuracy: 0.8432 - val_loss: 0.4986 - val_sparse_categorical_accuracy: 0.8286 - 794ms/epoch - 3ms/step
# Epoch 57/100
# 235/235 - 1s - loss: 0.4674 - sparse_categorical_accuracy: 0.8439 - val_loss: 0.4980 - val_sparse_categorical_accuracy: 0.8287 - 788ms/epoch - 3ms/step
# Epoch 58/100
# 235/235 - 1s - loss: 0.4665 - sparse_categorical_accuracy: 0.8438 - val_loss: 0.4966 - val_sparse_categorical_accuracy: 0.8295 - 800ms/epoch - 3ms/step
# Epoch 59/100
# 235/235 - 1s - loss: 0.4655 - sparse_categorical_accuracy: 0.8445 - val_loss: 0.4968 - val_sparse_categorical_accuracy: 0.8295 - 792ms/epoch - 3ms/step
# Epoch 60/100
# 235/235 - 1s - loss: 0.4647 - sparse_categorical_accuracy: 0.8445 - val_loss: 0.4953 - val_sparse_categorical_accuracy: 0.8286 - 791ms/epoch - 3ms/step
# Epoch 61/100
# 235/235 - 1s - loss: 0.4639 - sparse_categorical_accuracy: 0.8445 - val_loss: 0.4943 - val_sparse_categorical_accuracy: 0.8296 - 791ms/epoch - 3ms/step
# Epoch 62/100
# 235/235 - 1s - loss: 0.4630 - sparse_categorical_accuracy: 0.8449 - val_loss: 0.4935 - val_sparse_categorical_accuracy: 0.8300 - 790ms/epoch - 3ms/step
# Epoch 63/100
# 235/235 - 1s - loss: 0.4622 - sparse_categorical_accuracy: 0.8451 - val_loss: 0.4928 - val_sparse_categorical_accuracy: 0.8304 - 793ms/epoch - 3ms/step
# Epoch 64/100
# 235/235 - 1s - loss: 0.4613 - sparse_categorical_accuracy: 0.8458 - val_loss: 0.4926 - val_sparse_categorical_accuracy: 0.8297 - 797ms/epoch - 3ms/step
# Epoch 65/100
# 235/235 - 1s - loss: 0.4605 - sparse_categorical_accuracy: 0.8460 - val_loss: 0.4917 - val_sparse_categorical_accuracy: 0.8301 - 793ms/epoch - 3ms/step
# Epoch 66/100
# 235/235 - 1s - loss: 0.4598 - sparse_categorical_accuracy: 0.8457 - val_loss: 0.4910 - val_sparse_categorical_accuracy: 0.8308 - 796ms/epoch - 3ms/step
# Epoch 67/100
# 235/235 - 1s - loss: 0.4591 - sparse_categorical_accuracy: 0.8457 - val_loss: 0.4906 - val_sparse_categorical_accuracy: 0.8309 - 805ms/epoch - 3ms/step
# Epoch 68/100
# 235/235 - 1s - loss: 0.4583 - sparse_categorical_accuracy: 0.8467 - val_loss: 0.4895 - val_sparse_categorical_accuracy: 0.8310 - 792ms/epoch - 3ms/step
# Epoch 69/100
# 235/235 - 1s - loss: 0.4577 - sparse_categorical_accuracy: 0.8467 - val_loss: 0.4890 - val_sparse_categorical_accuracy: 0.8308 - 796ms/epoch - 3ms/step
# Epoch 70/100
# 235/235 - 1s - loss: 0.4569 - sparse_categorical_accuracy: 0.8467 - val_loss: 0.4882 - val_sparse_categorical_accuracy: 0.8301 - 794ms/epoch - 3ms/step
# Epoch 71/100
# 235/235 - 1s - loss: 0.4561 - sparse_categorical_accuracy: 0.8463 - val_loss: 0.4883 - val_sparse_categorical_accuracy: 0.8304 - 795ms/epoch - 3ms/step
# Epoch 72/100
# 235/235 - 1s - loss: 0.4555 - sparse_categorical_accuracy: 0.8468 - val_loss: 0.4876 - val_sparse_categorical_accuracy: 0.8298 - 799ms/epoch - 3ms/step
# Epoch 73/100
# 235/235 - 1s - loss: 0.4549 - sparse_categorical_accuracy: 0.8473 - val_loss: 0.4867 - val_sparse_categorical_accuracy: 0.8316 - 799ms/epoch - 3ms/step
# Epoch 74/100
# 235/235 - 1s - loss: 0.4543 - sparse_categorical_accuracy: 0.8476 - val_loss: 0.4860 - val_sparse_categorical_accuracy: 0.8314 - 847ms/epoch - 4ms/step
# Epoch 75/100
# 235/235 - 1s - loss: 0.4535 - sparse_categorical_accuracy: 0.8479 - val_loss: 0.4855 - val_sparse_categorical_accuracy: 0.8311 - 816ms/epoch - 3ms/step
# Epoch 76/100
# 235/235 - 1s - loss: 0.4529 - sparse_categorical_accuracy: 0.8477 - val_loss: 0.4851 - val_sparse_categorical_accuracy: 0.8316 - 815ms/epoch - 3ms/step
# Epoch 77/100
# 235/235 - 1s - loss: 0.4523 - sparse_categorical_accuracy: 0.8479 - val_loss: 0.4843 - val_sparse_categorical_accuracy: 0.8316 - 801ms/epoch - 3ms/step
# Epoch 78/100
# 235/235 - 1s - loss: 0.4517 - sparse_categorical_accuracy: 0.8486 - val_loss: 0.4839 - val_sparse_categorical_accuracy: 0.8319 - 799ms/epoch - 3ms/step
# Epoch 79/100
# 235/235 - 1s - loss: 0.4511 - sparse_categorical_accuracy: 0.8482 - val_loss: 0.4835 - val_sparse_categorical_accuracy: 0.8321 - 816ms/epoch - 3ms/step
# Epoch 80/100
# 235/235 - 1s - loss: 0.4505 - sparse_categorical_accuracy: 0.8485 - val_loss: 0.4831 - val_sparse_categorical_accuracy: 0.8319 - 801ms/epoch - 3ms/step
# Epoch 81/100
# 235/235 - 1s - loss: 0.4499 - sparse_categorical_accuracy: 0.8483 - val_loss: 0.4824 - val_sparse_categorical_accuracy: 0.8330 - 795ms/epoch - 3ms/step
# Epoch 82/100
# 235/235 - 1s - loss: 0.4493 - sparse_categorical_accuracy: 0.8488 - val_loss: 0.4818 - val_sparse_categorical_accuracy: 0.8321 - 800ms/epoch - 3ms/step
# Epoch 83/100
# 235/235 - 1s - loss: 0.4488 - sparse_categorical_accuracy: 0.8487 - val_loss: 0.4814 - val_sparse_categorical_accuracy: 0.8328 - 789ms/epoch - 3ms/step
# Epoch 84/100
# 235/235 - 1s - loss: 0.4483 - sparse_categorical_accuracy: 0.8492 - val_loss: 0.4809 - val_sparse_categorical_accuracy: 0.8326 - 786ms/epoch - 3ms/step
# Epoch 85/100
# 235/235 - 1s - loss: 0.4477 - sparse_categorical_accuracy: 0.8494 - val_loss: 0.4805 - val_sparse_categorical_accuracy: 0.8327 - 783ms/epoch - 3ms/step
# Epoch 86/100
# 235/235 - 1s - loss: 0.4472 - sparse_categorical_accuracy: 0.8493 - val_loss: 0.4801 - val_sparse_categorical_accuracy: 0.8335 - 799ms/epoch - 3ms/step
# Epoch 87/100
# 235/235 - 1s - loss: 0.4467 - sparse_categorical_accuracy: 0.8494 - val_loss: 0.4798 - val_sparse_categorical_accuracy: 0.8328 - 788ms/epoch - 3ms/step
# Epoch 88/100
# 235/235 - 1s - loss: 0.4462 - sparse_categorical_accuracy: 0.8495 - val_loss: 0.4792 - val_sparse_categorical_accuracy: 0.8325 - 787ms/epoch - 3ms/step
# Epoch 89/100
# 235/235 - 1s - loss: 0.4456 - sparse_categorical_accuracy: 0.8498 - val_loss: 0.4786 - val_sparse_categorical_accuracy: 0.8341 - 788ms/epoch - 3ms/step
# Epoch 90/100
# 235/235 - 1s - loss: 0.4453 - sparse_categorical_accuracy: 0.8500 - val_loss: 0.4784 - val_sparse_categorical_accuracy: 0.8335 - 783ms/epoch - 3ms/step
# Epoch 91/100
# 235/235 - 1s - loss: 0.4447 - sparse_categorical_accuracy: 0.8506 - val_loss: 0.4778 - val_sparse_categorical_accuracy: 0.8333 - 798ms/epoch - 3ms/step
# Epoch 92/100
# 235/235 - 1s - loss: 0.4442 - sparse_categorical_accuracy: 0.8504 - val_loss: 0.4773 - val_sparse_categorical_accuracy: 0.8340 - 798ms/epoch - 3ms/step
# Epoch 93/100
# 235/235 - 1s - loss: 0.4438 - sparse_categorical_accuracy: 0.8504 - val_loss: 0.4773 - val_sparse_categorical_accuracy: 0.8334 - 791ms/epoch - 3ms/step
# Epoch 94/100
# 235/235 - 1s - loss: 0.4433 - sparse_categorical_accuracy: 0.8503 - val_loss: 0.4768 - val_sparse_categorical_accuracy: 0.8336 - 788ms/epoch - 3ms/step
# Epoch 95/100
# 235/235 - 1s - loss: 0.4428 - sparse_categorical_accuracy: 0.8508 - val_loss: 0.4765 - val_sparse_categorical_accuracy: 0.8347 - 785ms/epoch - 3ms/step
# Epoch 96/100
# 235/235 - 1s - loss: 0.4424 - sparse_categorical_accuracy: 0.8504 - val_loss: 0.4764 - val_sparse_categorical_accuracy: 0.8339 - 801ms/epoch - 3ms/step
# Epoch 97/100
# 235/235 - 1s - loss: 0.4419 - sparse_categorical_accuracy: 0.8508 - val_loss: 0.4756 - val_sparse_categorical_accuracy: 0.8343 - 810ms/epoch - 3ms/step
# Epoch 98/100
# 235/235 - 1s - loss: 0.4414 - sparse_categorical_accuracy: 0.8514 - val_loss: 0.4752 - val_sparse_categorical_accuracy: 0.8342 - 799ms/epoch - 3ms/step
# Epoch 99/100
# 235/235 - 1s - loss: 0.4411 - sparse_categorical_accuracy: 0.8510 - val_loss: 0.4752 - val_sparse_categorical_accuracy: 0.8349 - 786ms/epoch - 3ms/step
# Epoch 100/100
# 235/235 - 1s - loss: 0.4407 - sparse_categorical_accuracy: 0.8506 - val_loss: 0.4747 - val_sparse_categorical_accuracy: 0.8337 - 784ms/epoch - 3ms/step

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()
