# %%
# fashion_mnist
import tensorflow as tf
from tensorflow import keras
import numpy as np

(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
# data normalization

mean = np.mean(x_train)
std  = np.std(x_train)

x_train = (x_train-mean)/std
x_test  = (x_test-mean)/std

# %%
import tensorflow as tf
import tensorflow.keras as keras

# create model
model = keras.Sequential()
model.add(keras.Input(shape=(28,28)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimizer and loss
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['sparse_categorical_accuracy'])

# training
history = model.fit(x_train, y_train, 
                    validation_data=(x_test, y_test), 
                    batch_size=256, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 235/235 - 1s - loss: 0.7950 - sparse_categorical_accuracy: 0.7316 - val_loss: 0.6097 - val_sparse_categorical_accuracy: 0.7865 - 1s/epoch - 6ms/step
# Epoch 2/100
# 235/235 - 1s - loss: 0.5438 - sparse_categorical_accuracy: 0.8110 - val_loss: 0.5388 - val_sparse_categorical_accuracy: 0.8100 - 1s/epoch - 5ms/step
# Epoch 3/100
# 235/235 - 1s - loss: 0.4911 - sparse_categorical_accuracy: 0.8293 - val_loss: 0.5077 - val_sparse_categorical_accuracy: 0.8178 - 1s/epoch - 5ms/step
# Epoch 4/100
# 235/235 - 1s - loss: 0.4616 - sparse_categorical_accuracy: 0.8389 - val_loss: 0.4874 - val_sparse_categorical_accuracy: 0.8242 - 1s/epoch - 5ms/step
# Epoch 5/100
# 235/235 - 1s - loss: 0.4416 - sparse_categorical_accuracy: 0.8460 - val_loss: 0.4692 - val_sparse_categorical_accuracy: 0.8331 - 1s/epoch - 5ms/step
# Epoch 6/100
# 235/235 - 1s - loss: 0.4268 - sparse_categorical_accuracy: 0.8508 - val_loss: 0.4564 - val_sparse_categorical_accuracy: 0.8378 - 1s/epoch - 5ms/step
# Epoch 7/100
# 235/235 - 1s - loss: 0.4144 - sparse_categorical_accuracy: 0.8561 - val_loss: 0.4448 - val_sparse_categorical_accuracy: 0.8420 - 1s/epoch - 5ms/step
# Epoch 8/100
# 235/235 - 1s - loss: 0.4048 - sparse_categorical_accuracy: 0.8589 - val_loss: 0.4417 - val_sparse_categorical_accuracy: 0.8412 - 1s/epoch - 5ms/step
# Epoch 9/100
# 235/235 - 1s - loss: 0.3958 - sparse_categorical_accuracy: 0.8618 - val_loss: 0.4309 - val_sparse_categorical_accuracy: 0.8452 - 1s/epoch - 5ms/step
# Epoch 10/100
# 235/235 - 1s - loss: 0.3885 - sparse_categorical_accuracy: 0.8645 - val_loss: 0.4291 - val_sparse_categorical_accuracy: 0.8477 - 1s/epoch - 5ms/step
# Epoch 11/100
# 235/235 - 1s - loss: 0.3819 - sparse_categorical_accuracy: 0.8663 - val_loss: 0.4230 - val_sparse_categorical_accuracy: 0.8485 - 1s/epoch - 5ms/step
# Epoch 12/100
# 235/235 - 1s - loss: 0.3761 - sparse_categorical_accuracy: 0.8686 - val_loss: 0.4157 - val_sparse_categorical_accuracy: 0.8508 - 1s/epoch - 5ms/step
# Epoch 13/100
# 235/235 - 1s - loss: 0.3708 - sparse_categorical_accuracy: 0.8697 - val_loss: 0.4134 - val_sparse_categorical_accuracy: 0.8510 - 1s/epoch - 5ms/step
# Epoch 14/100
# 235/235 - 1s - loss: 0.3658 - sparse_categorical_accuracy: 0.8712 - val_loss: 0.4087 - val_sparse_categorical_accuracy: 0.8538 - 1s/epoch - 5ms/step
# Epoch 15/100
# 235/235 - 1s - loss: 0.3614 - sparse_categorical_accuracy: 0.8724 - val_loss: 0.4054 - val_sparse_categorical_accuracy: 0.8543 - 1s/epoch - 4ms/step
# Epoch 16/100
# 235/235 - 1s - loss: 0.3566 - sparse_categorical_accuracy: 0.8751 - val_loss: 0.4053 - val_sparse_categorical_accuracy: 0.8517 - 1s/epoch - 4ms/step
# Epoch 17/100
# 235/235 - 1s - loss: 0.3529 - sparse_categorical_accuracy: 0.8760 - val_loss: 0.3984 - val_sparse_categorical_accuracy: 0.8553 - 1s/epoch - 5ms/step
# Epoch 18/100
# 235/235 - 1s - loss: 0.3493 - sparse_categorical_accuracy: 0.8774 - val_loss: 0.4035 - val_sparse_categorical_accuracy: 0.8547 - 1s/epoch - 5ms/step
# Epoch 19/100
# 235/235 - 1s - loss: 0.3454 - sparse_categorical_accuracy: 0.8784 - val_loss: 0.3923 - val_sparse_categorical_accuracy: 0.8576 - 1s/epoch - 4ms/step
# Epoch 20/100
# 235/235 - 1s - loss: 0.3423 - sparse_categorical_accuracy: 0.8789 - val_loss: 0.3925 - val_sparse_categorical_accuracy: 0.8581 - 1s/epoch - 5ms/step
# Epoch 21/100
# 235/235 - 1s - loss: 0.3387 - sparse_categorical_accuracy: 0.8808 - val_loss: 0.3890 - val_sparse_categorical_accuracy: 0.8608 - 1s/epoch - 4ms/step
# Epoch 22/100
# 235/235 - 1s - loss: 0.3355 - sparse_categorical_accuracy: 0.8815 - val_loss: 0.3878 - val_sparse_categorical_accuracy: 0.8615 - 1s/epoch - 5ms/step
# Epoch 23/100
# 235/235 - 1s - loss: 0.3328 - sparse_categorical_accuracy: 0.8823 - val_loss: 0.3867 - val_sparse_categorical_accuracy: 0.8635 - 1s/epoch - 4ms/step
# Epoch 24/100
# 235/235 - 1s - loss: 0.3298 - sparse_categorical_accuracy: 0.8833 - val_loss: 0.3834 - val_sparse_categorical_accuracy: 0.8629 - 1s/epoch - 5ms/step
# Epoch 25/100
# 235/235 - 1s - loss: 0.3272 - sparse_categorical_accuracy: 0.8847 - val_loss: 0.3808 - val_sparse_categorical_accuracy: 0.8624 - 1s/epoch - 5ms/step
# Epoch 26/100
# 235/235 - 1s - loss: 0.3248 - sparse_categorical_accuracy: 0.8852 - val_loss: 0.3813 - val_sparse_categorical_accuracy: 0.8640 - 1s/epoch - 4ms/step
# Epoch 27/100
# 235/235 - 1s - loss: 0.3223 - sparse_categorical_accuracy: 0.8862 - val_loss: 0.3839 - val_sparse_categorical_accuracy: 0.8647 - 1s/epoch - 5ms/step
# Epoch 28/100
# 235/235 - 1s - loss: 0.3199 - sparse_categorical_accuracy: 0.8873 - val_loss: 0.3762 - val_sparse_categorical_accuracy: 0.8654 - 1s/epoch - 5ms/step
# Epoch 29/100
# 235/235 - 1s - loss: 0.3174 - sparse_categorical_accuracy: 0.8878 - val_loss: 0.3746 - val_sparse_categorical_accuracy: 0.8656 - 1s/epoch - 5ms/step
# Epoch 30/100
# 235/235 - 1s - loss: 0.3150 - sparse_categorical_accuracy: 0.8886 - val_loss: 0.3754 - val_sparse_categorical_accuracy: 0.8654 - 1s/epoch - 5ms/step
# Epoch 31/100
# 235/235 - 1s - loss: 0.3128 - sparse_categorical_accuracy: 0.8895 - val_loss: 0.3759 - val_sparse_categorical_accuracy: 0.8640 - 1s/epoch - 5ms/step
# Epoch 32/100
# 235/235 - 1s - loss: 0.3107 - sparse_categorical_accuracy: 0.8896 - val_loss: 0.3748 - val_sparse_categorical_accuracy: 0.8672 - 1s/epoch - 5ms/step
# Epoch 33/100
# 235/235 - 1s - loss: 0.3086 - sparse_categorical_accuracy: 0.8909 - val_loss: 0.3720 - val_sparse_categorical_accuracy: 0.8648 - 1s/epoch - 5ms/step
# Epoch 34/100
# 235/235 - 1s - loss: 0.3062 - sparse_categorical_accuracy: 0.8918 - val_loss: 0.3689 - val_sparse_categorical_accuracy: 0.8684 - 1s/epoch - 5ms/step
# Epoch 35/100
# 235/235 - 1s - loss: 0.3044 - sparse_categorical_accuracy: 0.8924 - val_loss: 0.3687 - val_sparse_categorical_accuracy: 0.8689 - 1s/epoch - 5ms/step
# Epoch 36/100
# 235/235 - 1s - loss: 0.3024 - sparse_categorical_accuracy: 0.8925 - val_loss: 0.3736 - val_sparse_categorical_accuracy: 0.8663 - 1s/epoch - 5ms/step
# Epoch 37/100
# 235/235 - 1s - loss: 0.3005 - sparse_categorical_accuracy: 0.8938 - val_loss: 0.3647 - val_sparse_categorical_accuracy: 0.8690 - 1s/epoch - 5ms/step
# Epoch 38/100
# 235/235 - 1s - loss: 0.2991 - sparse_categorical_accuracy: 0.8940 - val_loss: 0.3648 - val_sparse_categorical_accuracy: 0.8692 - 1s/epoch - 5ms/step
# Epoch 39/100
# 235/235 - 1s - loss: 0.2966 - sparse_categorical_accuracy: 0.8953 - val_loss: 0.3619 - val_sparse_categorical_accuracy: 0.8694 - 1s/epoch - 4ms/step
# Epoch 40/100
# 235/235 - 1s - loss: 0.2949 - sparse_categorical_accuracy: 0.8951 - val_loss: 0.3751 - val_sparse_categorical_accuracy: 0.8621 - 1s/epoch - 5ms/step
# Epoch 41/100
# 235/235 - 1s - loss: 0.2931 - sparse_categorical_accuracy: 0.8957 - val_loss: 0.3629 - val_sparse_categorical_accuracy: 0.8696 - 1s/epoch - 5ms/step
# Epoch 42/100
# 235/235 - 1s - loss: 0.2917 - sparse_categorical_accuracy: 0.8967 - val_loss: 0.3629 - val_sparse_categorical_accuracy: 0.8707 - 1s/epoch - 5ms/step
# Epoch 43/100
# 235/235 - 1s - loss: 0.2896 - sparse_categorical_accuracy: 0.8974 - val_loss: 0.3575 - val_sparse_categorical_accuracy: 0.8715 - 1s/epoch - 5ms/step
# Epoch 44/100
# 235/235 - 1s - loss: 0.2880 - sparse_categorical_accuracy: 0.8986 - val_loss: 0.3560 - val_sparse_categorical_accuracy: 0.8722 - 1s/epoch - 5ms/step
# Epoch 45/100
# 235/235 - 1s - loss: 0.2861 - sparse_categorical_accuracy: 0.8987 - val_loss: 0.3572 - val_sparse_categorical_accuracy: 0.8726 - 1s/epoch - 5ms/step
# Epoch 46/100
# 235/235 - 1s - loss: 0.2845 - sparse_categorical_accuracy: 0.8995 - val_loss: 0.3569 - val_sparse_categorical_accuracy: 0.8727 - 1s/epoch - 5ms/step
# Epoch 47/100
# 235/235 - 1s - loss: 0.2830 - sparse_categorical_accuracy: 0.8997 - val_loss: 0.3580 - val_sparse_categorical_accuracy: 0.8720 - 1s/epoch - 5ms/step
# Epoch 48/100
# 235/235 - 1s - loss: 0.2814 - sparse_categorical_accuracy: 0.9002 - val_loss: 0.3581 - val_sparse_categorical_accuracy: 0.8729 - 1s/epoch - 5ms/step
# Epoch 49/100
# 235/235 - 1s - loss: 0.2802 - sparse_categorical_accuracy: 0.9012 - val_loss: 0.3534 - val_sparse_categorical_accuracy: 0.8749 - 1s/epoch - 5ms/step
# Epoch 50/100
# 235/235 - 1s - loss: 0.2785 - sparse_categorical_accuracy: 0.9019 - val_loss: 0.3552 - val_sparse_categorical_accuracy: 0.8723 - 1s/epoch - 5ms/step
# Epoch 51/100
# 235/235 - 1s - loss: 0.2767 - sparse_categorical_accuracy: 0.9019 - val_loss: 0.3520 - val_sparse_categorical_accuracy: 0.8746 - 1s/epoch - 5ms/step
# Epoch 52/100
# 235/235 - 1s - loss: 0.2753 - sparse_categorical_accuracy: 0.9025 - val_loss: 0.3521 - val_sparse_categorical_accuracy: 0.8747 - 1s/epoch - 5ms/step
# Epoch 53/100
# 235/235 - 1s - loss: 0.2740 - sparse_categorical_accuracy: 0.9034 - val_loss: 0.3563 - val_sparse_categorical_accuracy: 0.8685 - 1s/epoch - 5ms/step
# Epoch 54/100
# 235/235 - 1s - loss: 0.2723 - sparse_categorical_accuracy: 0.9035 - val_loss: 0.3482 - val_sparse_categorical_accuracy: 0.8748 - 1s/epoch - 4ms/step
# Epoch 55/100
# 235/235 - 1s - loss: 0.2712 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.3487 - val_sparse_categorical_accuracy: 0.8750 - 1s/epoch - 5ms/step
# Epoch 56/100
# 235/235 - 1s - loss: 0.2698 - sparse_categorical_accuracy: 0.9049 - val_loss: 0.3480 - val_sparse_categorical_accuracy: 0.8758 - 1s/epoch - 4ms/step
# Epoch 57/100
# 235/235 - 1s - loss: 0.2681 - sparse_categorical_accuracy: 0.9054 - val_loss: 0.3530 - val_sparse_categorical_accuracy: 0.8741 - 1s/epoch - 5ms/step
# Epoch 58/100
# 235/235 - 1s - loss: 0.2670 - sparse_categorical_accuracy: 0.9061 - val_loss: 0.3451 - val_sparse_categorical_accuracy: 0.8764 - 1s/epoch - 4ms/step
# Epoch 59/100
# 235/235 - 1s - loss: 0.2655 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.3544 - val_sparse_categorical_accuracy: 0.8701 - 1s/epoch - 5ms/step
# Epoch 60/100
# 235/235 - 1s - loss: 0.2647 - sparse_categorical_accuracy: 0.9069 - val_loss: 0.3450 - val_sparse_categorical_accuracy: 0.8779 - 1s/epoch - 5ms/step
# Epoch 61/100
# 235/235 - 1s - loss: 0.2627 - sparse_categorical_accuracy: 0.9075 - val_loss: 0.3436 - val_sparse_categorical_accuracy: 0.8762 - 1s/epoch - 5ms/step
# Epoch 62/100
# 235/235 - 1s - loss: 0.2613 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.3447 - val_sparse_categorical_accuracy: 0.8769 - 1s/epoch - 5ms/step
# Epoch 63/100
# 235/235 - 1s - loss: 0.2602 - sparse_categorical_accuracy: 0.9090 - val_loss: 0.3449 - val_sparse_categorical_accuracy: 0.8768 - 1s/epoch - 5ms/step
# Epoch 64/100
# 235/235 - 1s - loss: 0.2591 - sparse_categorical_accuracy: 0.9088 - val_loss: 0.3409 - val_sparse_categorical_accuracy: 0.8789 - 1s/epoch - 5ms/step
# Epoch 65/100
# 235/235 - 1s - loss: 0.2579 - sparse_categorical_accuracy: 0.9095 - val_loss: 0.3440 - val_sparse_categorical_accuracy: 0.8776 - 1s/epoch - 5ms/step
# Epoch 66/100
# 235/235 - 1s - loss: 0.2566 - sparse_categorical_accuracy: 0.9102 - val_loss: 0.3423 - val_sparse_categorical_accuracy: 0.8767 - 1s/epoch - 5ms/step
# Epoch 67/100
# 235/235 - 1s - loss: 0.2555 - sparse_categorical_accuracy: 0.9100 - val_loss: 0.3453 - val_sparse_categorical_accuracy: 0.8762 - 1s/epoch - 5ms/step
# Epoch 68/100
# 235/235 - 1s - loss: 0.2539 - sparse_categorical_accuracy: 0.9107 - val_loss: 0.3410 - val_sparse_categorical_accuracy: 0.8783 - 1s/epoch - 4ms/step
# Epoch 69/100
# 235/235 - 1s - loss: 0.2531 - sparse_categorical_accuracy: 0.9116 - val_loss: 0.3451 - val_sparse_categorical_accuracy: 0.8764 - 1s/epoch - 5ms/step
# Epoch 70/100
# 235/235 - 1s - loss: 0.2514 - sparse_categorical_accuracy: 0.9121 - val_loss: 0.3487 - val_sparse_categorical_accuracy: 0.8735 - 1s/epoch - 5ms/step
# Epoch 71/100
# 235/235 - 1s - loss: 0.2504 - sparse_categorical_accuracy: 0.9129 - val_loss: 0.3458 - val_sparse_categorical_accuracy: 0.8763 - 1s/epoch - 5ms/step
# Epoch 72/100
# 235/235 - 1s - loss: 0.2491 - sparse_categorical_accuracy: 0.9131 - val_loss: 0.3386 - val_sparse_categorical_accuracy: 0.8783 - 1s/epoch - 5ms/step
# Epoch 73/100
# 235/235 - 1s - loss: 0.2482 - sparse_categorical_accuracy: 0.9132 - val_loss: 0.3390 - val_sparse_categorical_accuracy: 0.8786 - 1s/epoch - 5ms/step
# Epoch 74/100
# 235/235 - 1s - loss: 0.2471 - sparse_categorical_accuracy: 0.9130 - val_loss: 0.3399 - val_sparse_categorical_accuracy: 0.8765 - 1s/epoch - 5ms/step
# Epoch 75/100
# 235/235 - 1s - loss: 0.2459 - sparse_categorical_accuracy: 0.9140 - val_loss: 0.3388 - val_sparse_categorical_accuracy: 0.8784 - 1s/epoch - 5ms/step
# Epoch 76/100
# 235/235 - 1s - loss: 0.2448 - sparse_categorical_accuracy: 0.9144 - val_loss: 0.3427 - val_sparse_categorical_accuracy: 0.8773 - 1s/epoch - 5ms/step
# Epoch 77/100
# 235/235 - 1s - loss: 0.2435 - sparse_categorical_accuracy: 0.9151 - val_loss: 0.3484 - val_sparse_categorical_accuracy: 0.8759 - 1s/epoch - 5ms/step
# Epoch 78/100
# 235/235 - 1s - loss: 0.2426 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.3344 - val_sparse_categorical_accuracy: 0.8810 - 1s/epoch - 5ms/step
# Epoch 79/100
# 235/235 - 1s - loss: 0.2411 - sparse_categorical_accuracy: 0.9160 - val_loss: 0.3353 - val_sparse_categorical_accuracy: 0.8808 - 1s/epoch - 5ms/step
# Epoch 80/100
# 235/235 - 1s - loss: 0.2403 - sparse_categorical_accuracy: 0.9161 - val_loss: 0.3375 - val_sparse_categorical_accuracy: 0.8806 - 1s/epoch - 5ms/step
# Epoch 81/100
# 235/235 - 1s - loss: 0.2392 - sparse_categorical_accuracy: 0.9169 - val_loss: 0.3358 - val_sparse_categorical_accuracy: 0.8793 - 1s/epoch - 5ms/step
# Epoch 82/100
# 235/235 - 1s - loss: 0.2379 - sparse_categorical_accuracy: 0.9174 - val_loss: 0.3379 - val_sparse_categorical_accuracy: 0.8806 - 1s/epoch - 5ms/step
# Epoch 83/100
# 235/235 - 1s - loss: 0.2372 - sparse_categorical_accuracy: 0.9177 - val_loss: 0.3357 - val_sparse_categorical_accuracy: 0.8810 - 1s/epoch - 5ms/step
# Epoch 84/100
# 235/235 - 1s - loss: 0.2360 - sparse_categorical_accuracy: 0.9176 - val_loss: 0.3415 - val_sparse_categorical_accuracy: 0.8771 - 1s/epoch - 5ms/step
# Epoch 85/100
# 235/235 - 1s - loss: 0.2350 - sparse_categorical_accuracy: 0.9189 - val_loss: 0.3364 - val_sparse_categorical_accuracy: 0.8813 - 1s/epoch - 5ms/step
# Epoch 86/100
# 235/235 - 1s - loss: 0.2340 - sparse_categorical_accuracy: 0.9180 - val_loss: 0.3334 - val_sparse_categorical_accuracy: 0.8815 - 1s/epoch - 5ms/step
# Epoch 87/100
# 235/235 - 1s - loss: 0.2332 - sparse_categorical_accuracy: 0.9188 - val_loss: 0.3313 - val_sparse_categorical_accuracy: 0.8814 - 1s/epoch - 5ms/step
# Epoch 88/100
# 235/235 - 1s - loss: 0.2321 - sparse_categorical_accuracy: 0.9198 - val_loss: 0.3325 - val_sparse_categorical_accuracy: 0.8811 - 1s/epoch - 5ms/step
# Epoch 89/100
# 235/235 - 1s - loss: 0.2312 - sparse_categorical_accuracy: 0.9198 - val_loss: 0.3360 - val_sparse_categorical_accuracy: 0.8802 - 1s/epoch - 5ms/step
# Epoch 90/100
# 235/235 - 1s - loss: 0.2299 - sparse_categorical_accuracy: 0.9204 - val_loss: 0.3413 - val_sparse_categorical_accuracy: 0.8785 - 1s/epoch - 5ms/step
# Epoch 91/100
# 235/235 - 1s - loss: 0.2289 - sparse_categorical_accuracy: 0.9201 - val_loss: 0.3294 - val_sparse_categorical_accuracy: 0.8827 - 1s/epoch - 5ms/step
# Epoch 92/100
# 235/235 - 1s - loss: 0.2285 - sparse_categorical_accuracy: 0.9206 - val_loss: 0.3371 - val_sparse_categorical_accuracy: 0.8789 - 1s/epoch - 5ms/step
# Epoch 93/100
# 235/235 - 1s - loss: 0.2271 - sparse_categorical_accuracy: 0.9217 - val_loss: 0.3360 - val_sparse_categorical_accuracy: 0.8807 - 1s/epoch - 5ms/step
# Epoch 94/100
# 235/235 - 1s - loss: 0.2258 - sparse_categorical_accuracy: 0.9216 - val_loss: 0.3318 - val_sparse_categorical_accuracy: 0.8813 - 1s/epoch - 5ms/step
# Epoch 95/100
# 235/235 - 1s - loss: 0.2251 - sparse_categorical_accuracy: 0.9217 - val_loss: 0.3330 - val_sparse_categorical_accuracy: 0.8813 - 1s/epoch - 5ms/step
# Epoch 96/100
# 235/235 - 1s - loss: 0.2241 - sparse_categorical_accuracy: 0.9225 - val_loss: 0.3333 - val_sparse_categorical_accuracy: 0.8800 - 1s/epoch - 5ms/step
# Epoch 97/100
# 235/235 - 1s - loss: 0.2230 - sparse_categorical_accuracy: 0.9225 - val_loss: 0.3307 - val_sparse_categorical_accuracy: 0.8831 - 1s/epoch - 5ms/step
# Epoch 98/100
# 235/235 - 1s - loss: 0.2221 - sparse_categorical_accuracy: 0.9234 - val_loss: 0.3304 - val_sparse_categorical_accuracy: 0.8829 - 1s/epoch - 5ms/step
# Epoch 99/100
# 235/235 - 1s - loss: 0.2214 - sparse_categorical_accuracy: 0.9229 - val_loss: 0.3359 - val_sparse_categorical_accuracy: 0.8804 - 1s/epoch - 5ms/step
# Epoch 100/100
# 235/235 - 1s - loss: 0.2202 - sparse_categorical_accuracy: 0.9236 - val_loss: 0.3280 - val_sparse_categorical_accuracy: 0.8834 - 1s/epoch - 5ms/step

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()
