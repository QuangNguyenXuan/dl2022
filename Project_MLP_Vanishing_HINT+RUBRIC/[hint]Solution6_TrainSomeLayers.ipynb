# %% [markdown]
# ## Load Data

# %%
# fashion_mnist
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
tf.keras.utils.set_random_seed(1)
tf.config.experimental.enable_op_determinism()

(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %% [markdown]
# ## Reshape Data

# %%
X_train = X_train.reshape(60000, -1)
X_test  = X_test.reshape(10000, -1)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)

# %% [markdown]
# ## Train Some Layers

# %%
# solution 6: Train some layers

batch_size = 512
initializer = tf.keras.initializers.RandomNormal()

# Ví dụ sub model 1
first = keras.Sequential()
first.add(keras.layers.Dense(128, activation='sigmoid',
                             kernel_initializer=initializer))
first.add(keras.layers.Dense(128, activation='sigmoid',
                             kernel_initializer=initializer))

#################### YOUR CODE HERE ####################
# Các bạn thực hiện sub model 2 tương tự như cách thức của Ví dụ sub model 1
second = 
########################################################

#################### YOUR CODE HERE ####################
# Các bạn thực hiện sub model 2 tương tự như cách thức của Ví dụ sub model 1
third = 
########################################################

#################### YOUR CODE HERE ####################
# Các bạn thực hiện sub model 2 tương tự như cách thức của Ví dụ sub model 1
fourth =
########################################################

# %% [markdown]
# ### Train 1

# %%
# Ví dụ train lần 1 với sub model 1 (tạo model mới và thêm Input layer, sub model 1, Output layer)
first_model = keras.Sequential()
first_model.add(keras.Input(shape=(784,)))
first_model.add(first)
first_model.add(keras.layers.Dense(10))

first_model.compile(optimizer=tf.keras.optimizers.SGD(), 
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])

history = first_model.fit(X_train, y_train, batch_size,
                          validation_data=(X_test, y_test),
                          epochs=100, verbose=2)

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# ### Train 2

# %%
# Fix first and train second
#################### YOUR CODE HERE ####################
# Các bạn thực hiện tương tự như Ví dụ train lần 1 
# Train lần 2: Ghép sub mode 1 và 2 lại với nhau. Train với 100 epoch nhưng freeze (fix) weight của sub model 1 
# (tạo model mới và thêm Input layer, sub model 1, sub model 2, Output layer)
second_model = 

# freeze sub model 1

########################################################
second_model.compile(optimizer=tf.keras.optimizers.SGD(), 
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])

history = second_model.fit(X_train, y_train, batch_size,
                           validation_data=(X_test, y_test),
                           epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 118/118 - 1s - loss: 2.3249 - accuracy: 0.1186 - val_loss: 2.2997 - val_accuracy: 0.1000 - 1s/epoch - 10ms/step
# Epoch 2/100
# 118/118 - 0s - loss: 2.2984 - accuracy: 0.1321 - val_loss: 2.2970 - val_accuracy: 0.0999 - 479ms/epoch - 4ms/step
# Epoch 3/100
# 118/118 - 0s - loss: 2.2958 - accuracy: 0.1856 - val_loss: 2.2945 - val_accuracy: 0.1000 - 473ms/epoch - 4ms/step
# Epoch 4/100
# 118/118 - 0s - loss: 2.2931 - accuracy: 0.2069 - val_loss: 2.2917 - val_accuracy: 0.1943 - 466ms/epoch - 4ms/step
# Epoch 5/100
# 118/118 - 0s - loss: 2.2903 - accuracy: 0.2582 - val_loss: 2.2889 - val_accuracy: 0.2025 - 472ms/epoch - 4ms/step
# Epoch 6/100
# 118/118 - 0s - loss: 2.2874 - accuracy: 0.3302 - val_loss: 2.2859 - val_accuracy: 0.2068 - 481ms/epoch - 4ms/step
# Epoch 7/100
# 118/118 - 0s - loss: 2.2844 - accuracy: 0.3106 - val_loss: 2.2827 - val_accuracy: 0.4330 - 451ms/epoch - 4ms/step
# Epoch 8/100
# 118/118 - 0s - loss: 2.2812 - accuracy: 0.3829 - val_loss: 2.2794 - val_accuracy: 0.5430 - 473ms/epoch - 4ms/step
# Epoch 9/100
# 118/118 - 0s - loss: 2.2778 - accuracy: 0.3860 - val_loss: 2.2760 - val_accuracy: 0.4212 - 457ms/epoch - 4ms/step
# Epoch 10/100
# 118/118 - 0s - loss: 2.2741 - accuracy: 0.3744 - val_loss: 2.2723 - val_accuracy: 0.2627 - 484ms/epoch - 4ms/step
# Epoch 11/100
# 118/118 - 0s - loss: 2.2702 - accuracy: 0.4363 - val_loss: 2.2682 - val_accuracy: 0.3972 - 456ms/epoch - 4ms/step
# Epoch 12/100
# 118/118 - 0s - loss: 2.2658 - accuracy: 0.4474 - val_loss: 2.2638 - val_accuracy: 0.3700 - 483ms/epoch - 4ms/step
# Epoch 13/100
# 118/118 - 0s - loss: 2.2611 - accuracy: 0.4431 - val_loss: 2.2587 - val_accuracy: 0.5266 - 460ms/epoch - 4ms/step
# Epoch 14/100
# 118/118 - 0s - loss: 2.2559 - accuracy: 0.5555 - val_loss: 2.2533 - val_accuracy: 0.6364 - 481ms/epoch - 4ms/step
# Epoch 15/100
# 118/118 - 0s - loss: 2.2502 - accuracy: 0.5390 - val_loss: 2.2473 - val_accuracy: 0.4942 - 458ms/epoch - 4ms/step
# Epoch 16/100
# 118/118 - 0s - loss: 2.2437 - accuracy: 0.4969 - val_loss: 2.2407 - val_accuracy: 0.4598 - 478ms/epoch - 4ms/step
# Epoch 17/100
# 118/118 - 0s - loss: 2.2366 - accuracy: 0.4879 - val_loss: 2.2330 - val_accuracy: 0.5549 - 459ms/epoch - 4ms/step
# Epoch 18/100
# 118/118 - 0s - loss: 2.2285 - accuracy: 0.5189 - val_loss: 2.2245 - val_accuracy: 0.4078 - 470ms/epoch - 4ms/step
# Epoch 19/100
# 118/118 - 0s - loss: 2.2194 - accuracy: 0.5320 - val_loss: 2.2147 - val_accuracy: 0.5102 - 470ms/epoch - 4ms/step
# Epoch 20/100
# 118/118 - 0s - loss: 2.2090 - accuracy: 0.5564 - val_loss: 2.2036 - val_accuracy: 0.5994 - 449ms/epoch - 4ms/step
# Epoch 21/100
# 118/118 - 0s - loss: 2.1972 - accuracy: 0.5197 - val_loss: 2.1912 - val_accuracy: 0.6416 - 477ms/epoch - 4ms/step
# Epoch 22/100
# 118/118 - 0s - loss: 2.1837 - accuracy: 0.5596 - val_loss: 2.1766 - val_accuracy: 0.5187 - 461ms/epoch - 4ms/step
# Epoch 23/100
# 118/118 - 0s - loss: 2.1681 - accuracy: 0.5077 - val_loss: 2.1603 - val_accuracy: 0.4550 - 460ms/epoch - 4ms/step
# Epoch 24/100
# 118/118 - 0s - loss: 2.1505 - accuracy: 0.5092 - val_loss: 2.1413 - val_accuracy: 0.5456 - 457ms/epoch - 4ms/step
# Epoch 25/100
# 118/118 - 0s - loss: 2.1303 - accuracy: 0.5091 - val_loss: 2.1197 - val_accuracy: 0.5890 - 456ms/epoch - 4ms/step
# Epoch 26/100
# 118/118 - 0s - loss: 2.1072 - accuracy: 0.5113 - val_loss: 2.0954 - val_accuracy: 0.4424 - 446ms/epoch - 4ms/step
# Epoch 27/100
# 118/118 - 0s - loss: 2.0814 - accuracy: 0.5025 - val_loss: 2.0679 - val_accuracy: 0.5235 - 476ms/epoch - 4ms/step
# Epoch 28/100
# 118/118 - 0s - loss: 2.0524 - accuracy: 0.5239 - val_loss: 2.0378 - val_accuracy: 0.5088 - 455ms/epoch - 4ms/step
# Epoch 29/100
# 118/118 - 0s - loss: 2.0207 - accuracy: 0.5351 - val_loss: 2.0048 - val_accuracy: 0.4605 - 457ms/epoch - 4ms/step
# Epoch 30/100
# 118/118 - 0s - loss: 1.9864 - accuracy: 0.5137 - val_loss: 1.9695 - val_accuracy: 0.5542 - 452ms/epoch - 4ms/step
# Epoch 31/100
# 118/118 - 0s - loss: 1.9503 - accuracy: 0.5321 - val_loss: 1.9327 - val_accuracy: 0.6042 - 453ms/epoch - 4ms/step
# Epoch 32/100
# 118/118 - 0s - loss: 1.9130 - accuracy: 0.5671 - val_loss: 1.8953 - val_accuracy: 0.5852 - 479ms/epoch - 4ms/step
# Epoch 33/100
# 118/118 - 0s - loss: 1.8756 - accuracy: 0.5638 - val_loss: 1.8583 - val_accuracy: 0.5855 - 469ms/epoch - 4ms/step
# Epoch 34/100
# 118/118 - 0s - loss: 1.8388 - accuracy: 0.5829 - val_loss: 1.8224 - val_accuracy: 0.6088 - 479ms/epoch - 4ms/step
# Epoch 35/100
# 118/118 - 0s - loss: 1.8035 - accuracy: 0.6175 - val_loss: 1.7881 - val_accuracy: 0.5770 - 439ms/epoch - 4ms/step
# Epoch 36/100
# 118/118 - 0s - loss: 1.7701 - accuracy: 0.6253 - val_loss: 1.7560 - val_accuracy: 0.6004 - 455ms/epoch - 4ms/step
# Epoch 37/100
# 118/118 - 0s - loss: 1.7390 - accuracy: 0.6389 - val_loss: 1.7261 - val_accuracy: 0.6779 - 451ms/epoch - 4ms/step
# Epoch 38/100
# 118/118 - 0s - loss: 1.7100 - accuracy: 0.6553 - val_loss: 1.6984 - val_accuracy: 0.6809 - 477ms/epoch - 4ms/step
# Epoch 39/100
# 118/118 - 0s - loss: 1.6831 - accuracy: 0.6778 - val_loss: 1.6728 - val_accuracy: 0.6978 - 469ms/epoch - 4ms/step
# Epoch 40/100
# 118/118 - 0s - loss: 1.6581 - accuracy: 0.6895 - val_loss: 1.6488 - val_accuracy: 0.7060 - 453ms/epoch - 4ms/step
# Epoch 41/100
# 118/118 - 0s - loss: 1.6347 - accuracy: 0.6953 - val_loss: 1.6265 - val_accuracy: 0.7251 - 446ms/epoch - 4ms/step
# Epoch 42/100
# 118/118 - 0s - loss: 1.6127 - accuracy: 0.7083 - val_loss: 1.6051 - val_accuracy: 0.6663 - 483ms/epoch - 4ms/step
# Epoch 43/100
# 118/118 - 0s - loss: 1.5916 - accuracy: 0.7155 - val_loss: 1.5847 - val_accuracy: 0.6835 - 468ms/epoch - 4ms/step
# Epoch 44/100
# 118/118 - 0s - loss: 1.5714 - accuracy: 0.7130 - val_loss: 1.5649 - val_accuracy: 0.7203 - 455ms/epoch - 4ms/step
# Epoch 45/100
# 118/118 - 0s - loss: 1.5515 - accuracy: 0.7177 - val_loss: 1.5457 - val_accuracy: 0.7251 - 469ms/epoch - 4ms/step
# Epoch 46/100
# 118/118 - 0s - loss: 1.5322 - accuracy: 0.7398 - val_loss: 1.5265 - val_accuracy: 0.7310 - 481ms/epoch - 4ms/step
# Epoch 47/100
# 118/118 - 0s - loss: 1.5128 - accuracy: 0.7384 - val_loss: 1.5076 - val_accuracy: 0.7112 - 459ms/epoch - 4ms/step
# Epoch 48/100
# 118/118 - 0s - loss: 1.4934 - accuracy: 0.7480 - val_loss: 1.4884 - val_accuracy: 0.6908 - 443ms/epoch - 4ms/step
# Epoch 49/100
# 118/118 - 0s - loss: 1.4739 - accuracy: 0.7439 - val_loss: 1.4689 - val_accuracy: 0.7577 - 461ms/epoch - 4ms/step
# Epoch 50/100
# 118/118 - 0s - loss: 1.4539 - accuracy: 0.7583 - val_loss: 1.4491 - val_accuracy: 0.7086 - 451ms/epoch - 4ms/step
# Epoch 51/100
# 118/118 - 0s - loss: 1.4335 - accuracy: 0.7542 - val_loss: 1.4287 - val_accuracy: 0.7450 - 469ms/epoch - 4ms/step
# Epoch 52/100
# 118/118 - 0s - loss: 1.4127 - accuracy: 0.7682 - val_loss: 1.4080 - val_accuracy: 0.7369 - 460ms/epoch - 4ms/step
# Epoch 53/100
# 118/118 - 0s - loss: 1.3913 - accuracy: 0.7612 - val_loss: 1.3869 - val_accuracy: 0.7398 - 463ms/epoch - 4ms/step
# Epoch 54/100
# 118/118 - 0s - loss: 1.3693 - accuracy: 0.7580 - val_loss: 1.3651 - val_accuracy: 0.7583 - 445ms/epoch - 4ms/step
# Epoch 55/100
# 118/118 - 0s - loss: 1.3469 - accuracy: 0.7757 - val_loss: 1.3427 - val_accuracy: 0.7637 - 455ms/epoch - 4ms/step
# Epoch 56/100
# 118/118 - 0s - loss: 1.3239 - accuracy: 0.7774 - val_loss: 1.3199 - val_accuracy: 0.7686 - 450ms/epoch - 4ms/step
# Epoch 57/100
# 118/118 - 0s - loss: 1.3006 - accuracy: 0.7825 - val_loss: 1.2969 - val_accuracy: 0.7749 - 450ms/epoch - 4ms/step
# Epoch 58/100
# 118/118 - 0s - loss: 1.2770 - accuracy: 0.7871 - val_loss: 1.2737 - val_accuracy: 0.7693 - 460ms/epoch - 4ms/step
# Epoch 59/100
# 118/118 - 0s - loss: 1.2532 - accuracy: 0.7911 - val_loss: 1.2505 - val_accuracy: 0.7724 - 447ms/epoch - 4ms/step
# Epoch 60/100
# 118/118 - 0s - loss: 1.2295 - accuracy: 0.7889 - val_loss: 1.2274 - val_accuracy: 0.7820 - 482ms/epoch - 4ms/step
# Epoch 61/100
# 118/118 - 0s - loss: 1.2059 - accuracy: 0.7949 - val_loss: 1.2045 - val_accuracy: 0.7882 - 449ms/epoch - 4ms/step
# Epoch 62/100
# 118/118 - 1s - loss: 1.1825 - accuracy: 0.7991 - val_loss: 1.1819 - val_accuracy: 0.7811 - 671ms/epoch - 6ms/step
# Epoch 63/100
# 118/118 - 0s - loss: 1.1595 - accuracy: 0.8036 - val_loss: 1.1598 - val_accuracy: 0.7796 - 452ms/epoch - 4ms/step
# Epoch 64/100
# 118/118 - 1s - loss: 1.1369 - accuracy: 0.8025 - val_loss: 1.1383 - val_accuracy: 0.7849 - 723ms/epoch - 6ms/step
# Epoch 65/100
# 118/118 - 1s - loss: 1.1150 - accuracy: 0.8056 - val_loss: 1.1172 - val_accuracy: 0.7919 - 595ms/epoch - 5ms/step
# Epoch 66/100
# 118/118 - 1s - loss: 1.0935 - accuracy: 0.8089 - val_loss: 1.0968 - val_accuracy: 0.7809 - 542ms/epoch - 5ms/step
# Epoch 67/100
# 118/118 - 0s - loss: 1.0727 - accuracy: 0.8132 - val_loss: 1.0769 - val_accuracy: 0.7864 - 457ms/epoch - 4ms/step
# Epoch 68/100
# 118/118 - 0s - loss: 1.0524 - accuracy: 0.8128 - val_loss: 1.0577 - val_accuracy: 0.7909 - 452ms/epoch - 4ms/step
# Epoch 69/100
# 118/118 - 0s - loss: 1.0328 - accuracy: 0.8116 - val_loss: 1.0392 - val_accuracy: 0.7960 - 442ms/epoch - 4ms/step
# Epoch 70/100
# 118/118 - 0s - loss: 1.0138 - accuracy: 0.8159 - val_loss: 1.0211 - val_accuracy: 0.7885 - 458ms/epoch - 4ms/step
# Epoch 71/100
# 118/118 - 0s - loss: 0.9954 - accuracy: 0.8173 - val_loss: 1.0035 - val_accuracy: 0.8025 - 454ms/epoch - 4ms/step
# Epoch 72/100
# 118/118 - 0s - loss: 0.9774 - accuracy: 0.8197 - val_loss: 0.9867 - val_accuracy: 0.8011 - 465ms/epoch - 4ms/step
# Epoch 73/100
# 118/118 - 0s - loss: 0.9601 - accuracy: 0.8235 - val_loss: 0.9702 - val_accuracy: 0.8039 - 454ms/epoch - 4ms/step
# Epoch 74/100
# 118/118 - 0s - loss: 0.9432 - accuracy: 0.8243 - val_loss: 0.9545 - val_accuracy: 0.8021 - 461ms/epoch - 4ms/step
# Epoch 75/100
# 118/118 - 0s - loss: 0.9267 - accuracy: 0.8256 - val_loss: 0.9388 - val_accuracy: 0.8053 - 453ms/epoch - 4ms/step
# Epoch 76/100
# 118/118 - 0s - loss: 0.9108 - accuracy: 0.8264 - val_loss: 0.9238 - val_accuracy: 0.8085 - 469ms/epoch - 4ms/step
# Epoch 77/100
# 118/118 - 0s - loss: 0.8952 - accuracy: 0.8277 - val_loss: 0.9091 - val_accuracy: 0.8060 - 458ms/epoch - 4ms/step
# Epoch 78/100
# 118/118 - 0s - loss: 0.8800 - accuracy: 0.8284 - val_loss: 0.8949 - val_accuracy: 0.8073 - 458ms/epoch - 4ms/step
# Epoch 79/100
# 118/118 - 0s - loss: 0.8652 - accuracy: 0.8295 - val_loss: 0.8811 - val_accuracy: 0.8062 - 451ms/epoch - 4ms/step
# Epoch 80/100
# 118/118 - 0s - loss: 0.8508 - accuracy: 0.8302 - val_loss: 0.8676 - val_accuracy: 0.8107 - 471ms/epoch - 4ms/step
# Epoch 81/100
# 118/118 - 0s - loss: 0.8368 - accuracy: 0.8318 - val_loss: 0.8543 - val_accuracy: 0.8116 - 451ms/epoch - 4ms/step
# Epoch 82/100
# 118/118 - 0s - loss: 0.8231 - accuracy: 0.8327 - val_loss: 0.8414 - val_accuracy: 0.8092 - 444ms/epoch - 4ms/step
# Epoch 83/100
# 118/118 - 0s - loss: 0.8096 - accuracy: 0.8323 - val_loss: 0.8290 - val_accuracy: 0.8110 - 464ms/epoch - 4ms/step
# Epoch 84/100
# 118/118 - 0s - loss: 0.7966 - accuracy: 0.8342 - val_loss: 0.8167 - val_accuracy: 0.8121 - 445ms/epoch - 4ms/step
# Epoch 85/100
# 118/118 - 0s - loss: 0.7838 - accuracy: 0.8349 - val_loss: 0.8049 - val_accuracy: 0.8124 - 464ms/epoch - 4ms/step
# Epoch 86/100
# 118/118 - 0s - loss: 0.7713 - accuracy: 0.8350 - val_loss: 0.7932 - val_accuracy: 0.8122 - 462ms/epoch - 4ms/step
# Epoch 87/100
# 118/118 - 0s - loss: 0.7592 - accuracy: 0.8360 - val_loss: 0.7820 - val_accuracy: 0.8132 - 461ms/epoch - 4ms/step
# Epoch 88/100
# 118/118 - 0s - loss: 0.7474 - accuracy: 0.8365 - val_loss: 0.7710 - val_accuracy: 0.8120 - 469ms/epoch - 4ms/step
# Epoch 89/100
# 118/118 - 0s - loss: 0.7359 - accuracy: 0.8365 - val_loss: 0.7604 - val_accuracy: 0.8137 - 472ms/epoch - 4ms/step
# Epoch 90/100
# 118/118 - 0s - loss: 0.7247 - accuracy: 0.8382 - val_loss: 0.7500 - val_accuracy: 0.8138 - 480ms/epoch - 4ms/step
# Epoch 91/100
# 118/118 - 1s - loss: 0.7137 - accuracy: 0.8375 - val_loss: 0.7398 - val_accuracy: 0.8151 - 739ms/epoch - 6ms/step
# Epoch 92/100
# 118/118 - 1s - loss: 0.7031 - accuracy: 0.8395 - val_loss: 0.7300 - val_accuracy: 0.8160 - 673ms/epoch - 6ms/step
# Epoch 93/100
# 118/118 - 1s - loss: 0.6928 - accuracy: 0.8401 - val_loss: 0.7206 - val_accuracy: 0.8152 - 767ms/epoch - 6ms/step
# Epoch 94/100
# 118/118 - 0s - loss: 0.6829 - accuracy: 0.8401 - val_loss: 0.7114 - val_accuracy: 0.8154 - 489ms/epoch - 4ms/step
# Epoch 95/100
# 118/118 - 0s - loss: 0.6732 - accuracy: 0.8407 - val_loss: 0.7025 - val_accuracy: 0.8154 - 458ms/epoch - 4ms/step
# Epoch 96/100
# 118/118 - 0s - loss: 0.6638 - accuracy: 0.8411 - val_loss: 0.6938 - val_accuracy: 0.8174 - 460ms/epoch - 4ms/step
# Epoch 97/100
# 118/118 - 0s - loss: 0.6547 - accuracy: 0.8414 - val_loss: 0.6857 - val_accuracy: 0.8156 - 445ms/epoch - 4ms/step
# Epoch 98/100
# 118/118 - 0s - loss: 0.6460 - accuracy: 0.8420 - val_loss: 0.6776 - val_accuracy: 0.8191 - 448ms/epoch - 4ms/step
# Epoch 99/100
# 118/118 - 0s - loss: 0.6375 - accuracy: 0.8422 - val_loss: 0.6698 - val_accuracy: 0.8187 - 469ms/epoch - 4ms/step
# Epoch 100/100
# 118/118 - 0s - loss: 0.6293 - accuracy: 0.8421 - val_loss: 0.6626 - val_accuracy: 0.8186 - 480ms/epoch - 4ms/step

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# ### Train 3

# %%
# train first and second
#################### YOUR CODE HERE ####################
# Các bạn thực hiện tương tự như Ví dụ train lần 1 
# Train lần 3: Tiếp tục train thêm 100 epoch nhưng lần này không fix weight của sub model 1
# (tạo model mới và thêm Input layer, sub model 1, sub model 2, Output layer)
second_model = 

# unfreeze sub model 1

########################################################

second_model.compile(optimizer=tf.keras.optimizers.SGD(), 
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])

history = second_model.fit(X_train, y_train, batch_size,
                          validation_data=(X_test, y_test),
                          epochs=100, verbose=2)

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# ### Train 4

# %%
# fix first and second, train third
#################### YOUR CODE HERE ####################
# Các bạn thực hiện tương tự như Ví dụ train lần 1 
# Train lần 4: Ghép sub mode 1, 2 và 3 lại với nhau. Train với 100 epoch nhưng fix weight của sub model 1 và 2
# (tạo model mới và thêm Input layer, sub model 1, sub model 2, sub model 3, Output layer)
third_model = 

# freeze sub model 1 và sub model 2

########################################################


third_model.compile(optimizer=tf.keras.optimizers.SGD(), 
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])

history = third_model.fit(X_train, y_train, batch_size,
                          validation_data=(X_test, y_test),
                          epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 118/118 - 1s - loss: 2.3086 - accuracy: 0.1160 - val_loss: 2.2981 - val_accuracy: 0.0999 - 1s/epoch - 10ms/step
# Epoch 2/100
# 118/118 - 0s - loss: 2.2964 - accuracy: 0.1671 - val_loss: 2.2949 - val_accuracy: 0.1000 - 467ms/epoch - 4ms/step
# Epoch 3/100
# 118/118 - 0s - loss: 2.2931 - accuracy: 0.2259 - val_loss: 2.2917 - val_accuracy: 0.1000 - 479ms/epoch - 4ms/step
# Epoch 4/100
# 118/118 - 0s - loss: 2.2897 - accuracy: 0.2279 - val_loss: 2.2882 - val_accuracy: 0.1725 - 456ms/epoch - 4ms/step
# Epoch 5/100
# 118/118 - 0s - loss: 2.2861 - accuracy: 0.2967 - val_loss: 2.2846 - val_accuracy: 0.2361 - 487ms/epoch - 4ms/step
# Epoch 6/100
# 118/118 - 0s - loss: 2.2824 - accuracy: 0.4147 - val_loss: 2.2807 - val_accuracy: 0.2950 - 456ms/epoch - 4ms/step
# Epoch 7/100
# 118/118 - 0s - loss: 2.2783 - accuracy: 0.4112 - val_loss: 2.2764 - val_accuracy: 0.4650 - 489ms/epoch - 4ms/step
# Epoch 8/100
# 118/118 - 0s - loss: 2.2739 - accuracy: 0.4531 - val_loss: 2.2719 - val_accuracy: 0.5188 - 475ms/epoch - 4ms/step
# Epoch 9/100
# 118/118 - 0s - loss: 2.2692 - accuracy: 0.4657 - val_loss: 2.2670 - val_accuracy: 0.5612 - 496ms/epoch - 4ms/step
# Epoch 10/100
# 118/118 - 0s - loss: 2.2639 - accuracy: 0.4787 - val_loss: 2.2617 - val_accuracy: 0.5560 - 482ms/epoch - 4ms/step
# Epoch 11/100
# 118/118 - 0s - loss: 2.2582 - accuracy: 0.5192 - val_loss: 2.2556 - val_accuracy: 0.6799 - 493ms/epoch - 4ms/step
# Epoch 12/100
# 118/118 - 0s - loss: 2.2517 - accuracy: 0.5705 - val_loss: 2.2489 - val_accuracy: 0.5114 - 500ms/epoch - 4ms/step
# Epoch 13/100
# 118/118 - 0s - loss: 2.2444 - accuracy: 0.5711 - val_loss: 2.2411 - val_accuracy: 0.6435 - 496ms/epoch - 4ms/step
# Epoch 14/100
# 118/118 - 0s - loss: 2.2362 - accuracy: 0.6317 - val_loss: 2.2325 - val_accuracy: 0.6006 - 476ms/epoch - 4ms/step
# Epoch 15/100
# 118/118 - 0s - loss: 2.2269 - accuracy: 0.6101 - val_loss: 2.2226 - val_accuracy: 0.6070 - 493ms/epoch - 4ms/step
# Epoch 16/100
# 118/118 - 0s - loss: 2.2162 - accuracy: 0.5938 - val_loss: 2.2116 - val_accuracy: 0.5407 - 466ms/epoch - 4ms/step
# Epoch 17/100
# 118/118 - 0s - loss: 2.2041 - accuracy: 0.5990 - val_loss: 2.1984 - val_accuracy: 0.5182 - 488ms/epoch - 4ms/step
# Epoch 18/100
# 118/118 - 0s - loss: 2.1900 - accuracy: 0.6127 - val_loss: 2.1835 - val_accuracy: 0.6043 - 486ms/epoch - 4ms/step
# Epoch 19/100
# 118/118 - 0s - loss: 2.1738 - accuracy: 0.6469 - val_loss: 2.1661 - val_accuracy: 0.6717 - 490ms/epoch - 4ms/step
# Epoch 20/100
# 118/118 - 0s - loss: 2.1550 - accuracy: 0.6361 - val_loss: 2.1460 - val_accuracy: 0.6815 - 475ms/epoch - 4ms/step
# Epoch 21/100
# 118/118 - 1s - loss: 2.1331 - accuracy: 0.6107 - val_loss: 2.1228 - val_accuracy: 0.6976 - 521ms/epoch - 4ms/step
# Epoch 22/100
# 118/118 - 0s - loss: 2.1078 - accuracy: 0.6571 - val_loss: 2.0956 - val_accuracy: 0.5439 - 477ms/epoch - 4ms/step
# Epoch 23/100
# 118/118 - 0s - loss: 2.0785 - accuracy: 0.6266 - val_loss: 2.0646 - val_accuracy: 0.5655 - 492ms/epoch - 4ms/step
# Epoch 24/100
# 118/118 - 0s - loss: 2.0448 - accuracy: 0.5928 - val_loss: 2.0287 - val_accuracy: 0.6001 - 482ms/epoch - 4ms/step
# Epoch 25/100
# 118/118 - 0s - loss: 2.0065 - accuracy: 0.6231 - val_loss: 1.9883 - val_accuracy: 0.6018 - 496ms/epoch - 4ms/step
# Epoch 26/100
# 118/118 - 0s - loss: 1.9633 - accuracy: 0.6097 - val_loss: 1.9432 - val_accuracy: 0.6610 - 462ms/epoch - 4ms/step
# Epoch 27/100
# 118/118 - 0s - loss: 1.9155 - accuracy: 0.6347 - val_loss: 1.8935 - val_accuracy: 0.6044 - 454ms/epoch - 4ms/step
# Epoch 28/100
# 118/118 - 0s - loss: 1.8636 - accuracy: 0.6221 - val_loss: 1.8406 - val_accuracy: 0.6398 - 465ms/epoch - 4ms/step
# Epoch 29/100
# 118/118 - 0s - loss: 1.8085 - accuracy: 0.6497 - val_loss: 1.7846 - val_accuracy: 0.6315 - 478ms/epoch - 4ms/step
# Epoch 30/100
# 118/118 - 0s - loss: 1.7511 - accuracy: 0.6553 - val_loss: 1.7272 - val_accuracy: 0.6018 - 490ms/epoch - 4ms/step
# Epoch 31/100
# 118/118 - 0s - loss: 1.6925 - accuracy: 0.6520 - val_loss: 1.6691 - val_accuracy: 0.6714 - 498ms/epoch - 4ms/step
# Epoch 32/100
# 118/118 - 0s - loss: 1.6338 - accuracy: 0.6858 - val_loss: 1.6115 - val_accuracy: 0.6996 - 487ms/epoch - 4ms/step
# Epoch 33/100
# 118/118 - 0s - loss: 1.5759 - accuracy: 0.6996 - val_loss: 1.5551 - val_accuracy: 0.7088 - 494ms/epoch - 4ms/step
# Epoch 34/100
# 118/118 - 0s - loss: 1.5191 - accuracy: 0.7171 - val_loss: 1.5004 - val_accuracy: 0.7283 - 485ms/epoch - 4ms/step
# Epoch 35/100
# 118/118 - 0s - loss: 1.4643 - accuracy: 0.7363 - val_loss: 1.4475 - val_accuracy: 0.7243 - 487ms/epoch - 4ms/step
# Epoch 36/100
# 118/118 - 0s - loss: 1.4115 - accuracy: 0.7463 - val_loss: 1.3971 - val_accuracy: 0.7394 - 487ms/epoch - 4ms/step
# Epoch 37/100
# 118/118 - 0s - loss: 1.3612 - accuracy: 0.7608 - val_loss: 1.3490 - val_accuracy: 0.7535 - 474ms/epoch - 4ms/step
# Epoch 38/100
# 118/118 - 1s - loss: 1.3132 - accuracy: 0.7710 - val_loss: 1.3036 - val_accuracy: 0.7612 - 508ms/epoch - 4ms/step
# Epoch 39/100
# 118/118 - 0s - loss: 1.2678 - accuracy: 0.7822 - val_loss: 1.2607 - val_accuracy: 0.7605 - 470ms/epoch - 4ms/step
# Epoch 40/100
# 118/118 - 0s - loss: 1.2249 - accuracy: 0.7887 - val_loss: 1.2204 - val_accuracy: 0.7639 - 485ms/epoch - 4ms/step
# Epoch 41/100
# 118/118 - 0s - loss: 1.1844 - accuracy: 0.7922 - val_loss: 1.1824 - val_accuracy: 0.7761 - 473ms/epoch - 4ms/step
# Epoch 42/100
# 118/118 - 0s - loss: 1.1462 - accuracy: 0.7995 - val_loss: 1.1466 - val_accuracy: 0.7837 - 491ms/epoch - 4ms/step
# Epoch 43/100
# 118/118 - 0s - loss: 1.1101 - accuracy: 0.8049 - val_loss: 1.1128 - val_accuracy: 0.7799 - 488ms/epoch - 4ms/step
# Epoch 44/100
# 118/118 - 1s - loss: 1.0761 - accuracy: 0.8084 - val_loss: 1.0810 - val_accuracy: 0.7834 - 504ms/epoch - 4ms/step
# Epoch 45/100
# 118/118 - 0s - loss: 1.0437 - accuracy: 0.8125 - val_loss: 1.0509 - val_accuracy: 0.7839 - 475ms/epoch - 4ms/step
# Epoch 46/100
# 118/118 - 0s - loss: 1.0132 - accuracy: 0.8133 - val_loss: 1.0224 - val_accuracy: 0.7926 - 495ms/epoch - 4ms/step
# Epoch 47/100
# 118/118 - 0s - loss: 0.9841 - accuracy: 0.8192 - val_loss: 0.9954 - val_accuracy: 0.7877 - 489ms/epoch - 4ms/step
# Epoch 48/100
# 118/118 - 0s - loss: 0.9564 - accuracy: 0.8210 - val_loss: 0.9696 - val_accuracy: 0.7869 - 499ms/epoch - 4ms/step
# Epoch 49/100
# 118/118 - 0s - loss: 0.9299 - accuracy: 0.8214 - val_loss: 0.9451 - val_accuracy: 0.7963 - 481ms/epoch - 4ms/step
# Epoch 50/100
# 118/118 - 0s - loss: 0.9046 - accuracy: 0.8240 - val_loss: 0.9217 - val_accuracy: 0.8080 - 487ms/epoch - 4ms/step
# Epoch 51/100
# 118/118 - 0s - loss: 0.8804 - accuracy: 0.8291 - val_loss: 0.8992 - val_accuracy: 0.8057 - 499ms/epoch - 4ms/step
# Epoch 52/100
# 118/118 - 1s - loss: 0.8572 - accuracy: 0.8313 - val_loss: 0.8779 - val_accuracy: 0.8080 - 571ms/epoch - 5ms/step
# Epoch 53/100
# 118/118 - 0s - loss: 0.8350 - accuracy: 0.8338 - val_loss: 0.8576 - val_accuracy: 0.8068 - 480ms/epoch - 4ms/step
# Epoch 54/100
# 118/118 - 0s - loss: 0.8137 - accuracy: 0.8337 - val_loss: 0.8382 - val_accuracy: 0.8123 - 486ms/epoch - 4ms/step
# Epoch 55/100
# 118/118 - 0s - loss: 0.7933 - accuracy: 0.8377 - val_loss: 0.8194 - val_accuracy: 0.8105 - 483ms/epoch - 4ms/step
# Epoch 56/100
# 118/118 - 1s - loss: 0.7738 - accuracy: 0.8390 - val_loss: 0.8014 - val_accuracy: 0.8153 - 566ms/epoch - 5ms/step
# Epoch 57/100
# 118/118 - 0s - loss: 0.7551 - accuracy: 0.8414 - val_loss: 0.7845 - val_accuracy: 0.8147 - 479ms/epoch - 4ms/step
# Epoch 58/100
# 118/118 - 0s - loss: 0.7373 - accuracy: 0.8433 - val_loss: 0.7682 - val_accuracy: 0.8216 - 477ms/epoch - 4ms/step
# Epoch 59/100
# 118/118 - 1s - loss: 0.7203 - accuracy: 0.8463 - val_loss: 0.7529 - val_accuracy: 0.8184 - 514ms/epoch - 4ms/step
# Epoch 60/100
# 118/118 - 0s - loss: 0.7041 - accuracy: 0.8455 - val_loss: 0.7382 - val_accuracy: 0.8228 - 475ms/epoch - 4ms/step
# Epoch 61/100
# 118/118 - 0s - loss: 0.6886 - accuracy: 0.8492 - val_loss: 0.7244 - val_accuracy: 0.8230 - 477ms/epoch - 4ms/step
# Epoch 62/100
# 118/118 - 0s - loss: 0.6739 - accuracy: 0.8496 - val_loss: 0.7112 - val_accuracy: 0.8255 - 490ms/epoch - 4ms/step
# Epoch 63/100
# 118/118 - 0s - loss: 0.6600 - accuracy: 0.8518 - val_loss: 0.6987 - val_accuracy: 0.8261 - 466ms/epoch - 4ms/step
# Epoch 64/100
# 118/118 - 0s - loss: 0.6468 - accuracy: 0.8531 - val_loss: 0.6870 - val_accuracy: 0.8260 - 476ms/epoch - 4ms/step
# Epoch 65/100
# 118/118 - 0s - loss: 0.6343 - accuracy: 0.8544 - val_loss: 0.6760 - val_accuracy: 0.8258 - 474ms/epoch - 4ms/step
# Epoch 66/100
# 118/118 - 0s - loss: 0.6224 - accuracy: 0.8546 - val_loss: 0.6656 - val_accuracy: 0.8280 - 484ms/epoch - 4ms/step
# Epoch 67/100
# 118/118 - 1s - loss: 0.6112 - accuracy: 0.8569 - val_loss: 0.6557 - val_accuracy: 0.8277 - 502ms/epoch - 4ms/step
# Epoch 68/100
# 118/118 - 0s - loss: 0.6006 - accuracy: 0.8575 - val_loss: 0.6463 - val_accuracy: 0.8287 - 493ms/epoch - 4ms/step
# Epoch 69/100
# 118/118 - 0s - loss: 0.5906 - accuracy: 0.8588 - val_loss: 0.6378 - val_accuracy: 0.8269 - 498ms/epoch - 4ms/step
# Epoch 70/100
# 118/118 - 0s - loss: 0.5811 - accuracy: 0.8574 - val_loss: 0.6295 - val_accuracy: 0.8311 - 478ms/epoch - 4ms/step
# Epoch 71/100
# 118/118 - 0s - loss: 0.5723 - accuracy: 0.8598 - val_loss: 0.6218 - val_accuracy: 0.8291 - 473ms/epoch - 4ms/step
# Epoch 72/100
# 118/118 - 0s - loss: 0.5638 - accuracy: 0.8603 - val_loss: 0.6146 - val_accuracy: 0.8296 - 472ms/epoch - 4ms/step
# Epoch 73/100
# 118/118 - 0s - loss: 0.5559 - accuracy: 0.8605 - val_loss: 0.6078 - val_accuracy: 0.8324 - 479ms/epoch - 4ms/step
# Epoch 74/100
# 118/118 - 0s - loss: 0.5484 - accuracy: 0.8614 - val_loss: 0.6014 - val_accuracy: 0.8321 - 470ms/epoch - 4ms/step
# Epoch 75/100
# 118/118 - 0s - loss: 0.5413 - accuracy: 0.8615 - val_loss: 0.5954 - val_accuracy: 0.8331 - 476ms/epoch - 4ms/step
# Epoch 76/100
# 118/118 - 0s - loss: 0.5346 - accuracy: 0.8624 - val_loss: 0.5897 - val_accuracy: 0.8325 - 475ms/epoch - 4ms/step
# Epoch 77/100
# 118/118 - 0s - loss: 0.5283 - accuracy: 0.8625 - val_loss: 0.5843 - val_accuracy: 0.8342 - 479ms/epoch - 4ms/step
# Epoch 78/100
# 118/118 - 0s - loss: 0.5223 - accuracy: 0.8631 - val_loss: 0.5794 - val_accuracy: 0.8335 - 480ms/epoch - 4ms/step
# Epoch 79/100
# 118/118 - 0s - loss: 0.5166 - accuracy: 0.8629 - val_loss: 0.5747 - val_accuracy: 0.8348 - 486ms/epoch - 4ms/step
# Epoch 80/100
# 118/118 - 0s - loss: 0.5113 - accuracy: 0.8641 - val_loss: 0.5701 - val_accuracy: 0.8340 - 467ms/epoch - 4ms/step
# Epoch 81/100
# 118/118 - 0s - loss: 0.5062 - accuracy: 0.8640 - val_loss: 0.5659 - val_accuracy: 0.8356 - 489ms/epoch - 4ms/step
# Epoch 82/100
# 118/118 - 0s - loss: 0.5014 - accuracy: 0.8643 - val_loss: 0.5618 - val_accuracy: 0.8355 - 478ms/epoch - 4ms/step
# Epoch 83/100
# 118/118 - 1s - loss: 0.4968 - accuracy: 0.8647 - val_loss: 0.5581 - val_accuracy: 0.8362 - 507ms/epoch - 4ms/step
# Epoch 84/100
# 118/118 - 0s - loss: 0.4924 - accuracy: 0.8650 - val_loss: 0.5546 - val_accuracy: 0.8366 - 495ms/epoch - 4ms/step
# Epoch 85/100
# 118/118 - 0s - loss: 0.4883 - accuracy: 0.8651 - val_loss: 0.5512 - val_accuracy: 0.8373 - 474ms/epoch - 4ms/step
# Epoch 86/100
# 118/118 - 0s - loss: 0.4843 - accuracy: 0.8651 - val_loss: 0.5481 - val_accuracy: 0.8367 - 475ms/epoch - 4ms/step
# Epoch 87/100
# 118/118 - 0s - loss: 0.4806 - accuracy: 0.8653 - val_loss: 0.5449 - val_accuracy: 0.8367 - 472ms/epoch - 4ms/step
# Epoch 88/100
# 118/118 - 1s - loss: 0.4770 - accuracy: 0.8653 - val_loss: 0.5422 - val_accuracy: 0.8368 - 507ms/epoch - 4ms/step
# Epoch 89/100
# 118/118 - 0s - loss: 0.4737 - accuracy: 0.8658 - val_loss: 0.5395 - val_accuracy: 0.8367 - 486ms/epoch - 4ms/step
# Epoch 90/100
# 118/118 - 0s - loss: 0.4704 - accuracy: 0.8652 - val_loss: 0.5370 - val_accuracy: 0.8375 - 486ms/epoch - 4ms/step
# Epoch 91/100
# 118/118 - 0s - loss: 0.4673 - accuracy: 0.8658 - val_loss: 0.5344 - val_accuracy: 0.8376 - 469ms/epoch - 4ms/step
# Epoch 92/100
# 118/118 - 0s - loss: 0.4644 - accuracy: 0.8658 - val_loss: 0.5320 - val_accuracy: 0.8379 - 499ms/epoch - 4ms/step
# Epoch 93/100
# 118/118 - 0s - loss: 0.4616 - accuracy: 0.8664 - val_loss: 0.5299 - val_accuracy: 0.8370 - 460ms/epoch - 4ms/step
# Epoch 94/100
# 118/118 - 0s - loss: 0.4590 - accuracy: 0.8662 - val_loss: 0.5278 - val_accuracy: 0.8376 - 495ms/epoch - 4ms/step
# Epoch 95/100
# 118/118 - 0s - loss: 0.4564 - accuracy: 0.8659 - val_loss: 0.5257 - val_accuracy: 0.8381 - 472ms/epoch - 4ms/step
# Epoch 96/100
# 118/118 - 0s - loss: 0.4539 - accuracy: 0.8665 - val_loss: 0.5238 - val_accuracy: 0.8377 - 476ms/epoch - 4ms/step
# Epoch 97/100
# 118/118 - 0s - loss: 0.4516 - accuracy: 0.8663 - val_loss: 0.5221 - val_accuracy: 0.8378 - 481ms/epoch - 4ms/step
# Epoch 98/100
# 118/118 - 0s - loss: 0.4494 - accuracy: 0.8666 - val_loss: 0.5203 - val_accuracy: 0.8387 - 491ms/epoch - 4ms/step
# Epoch 99/100
# 118/118 - 0s - loss: 0.4472 - accuracy: 0.8669 - val_loss: 0.5187 - val_accuracy: 0.8386 - 491ms/epoch - 4ms/step
# Epoch 100/100
# 118/118 - 1s - loss: 0.4452 - accuracy: 0.8668 - val_loss: 0.5172 - val_accuracy: 0.8390 - 605ms/epoch - 5ms/step

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# ### Train 5

# %%
# train first, second, and third
#################### YOUR CODE HERE ####################
# Các bạn thực hiện tương tự như Ví dụ train lần 1 
# Train lần 5: Tiếp tục train thêm 100 epoch nhưng lần này không fix weight của sub model 1 và sub model 2
# (tạo model mới và thêm Input layer, sub model 1, sub model 2, sub model 3, Output layer)
third_model = 

# unfreeze sub model 1 và sub model 2

########################################################


third_model.compile(optimizer=tf.keras.optimizers.SGD(), 
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])

history = third_model.fit(X_train, y_train, batch_size,
                          validation_data=(X_test, y_test),
                          epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 118/118 - 1s - loss: 1.9850 - accuracy: 0.4230 - val_loss: 1.7443 - val_accuracy: 0.6593 - 1s/epoch - 11ms/step
# Epoch 2/100
# 118/118 - 1s - loss: 1.5919 - accuracy: 0.7018 - val_loss: 1.4724 - val_accuracy: 0.7052 - 513ms/epoch - 4ms/step
# Epoch 3/100
# 118/118 - 1s - loss: 1.3642 - accuracy: 0.7422 - val_loss: 1.2900 - val_accuracy: 0.7444 - 502ms/epoch - 4ms/step
# Epoch 4/100
# 118/118 - 1s - loss: 1.2024 - accuracy: 0.7791 - val_loss: 1.1550 - val_accuracy: 0.7683 - 505ms/epoch - 4ms/step
# Epoch 5/100
# 118/118 - 1s - loss: 1.0784 - accuracy: 0.8126 - val_loss: 1.0508 - val_accuracy: 0.8007 - 507ms/epoch - 4ms/step
# Epoch 6/100
# 118/118 - 0s - loss: 0.9808 - accuracy: 0.8379 - val_loss: 0.9678 - val_accuracy: 0.8114 - 495ms/epoch - 4ms/step
# Epoch 7/100
# 118/118 - 1s - loss: 0.9030 - accuracy: 0.8442 - val_loss: 0.9033 - val_accuracy: 0.8206 - 516ms/epoch - 4ms/step
# Epoch 8/100
# 118/118 - 1s - loss: 0.8396 - accuracy: 0.8504 - val_loss: 0.8504 - val_accuracy: 0.8230 - 513ms/epoch - 4ms/step
# Epoch 9/100
# 118/118 - 1s - loss: 0.7869 - accuracy: 0.8551 - val_loss: 0.8045 - val_accuracy: 0.8286 - 527ms/epoch - 4ms/step
# Epoch 10/100
# 118/118 - 0s - loss: 0.7434 - accuracy: 0.8585 - val_loss: 0.7685 - val_accuracy: 0.8297 - 500ms/epoch - 4ms/step
# Epoch 11/100
# 118/118 - 1s - loss: 0.7066 - accuracy: 0.8596 - val_loss: 0.7363 - val_accuracy: 0.8290 - 521ms/epoch - 4ms/step
# Epoch 12/100
# 118/118 - 1s - loss: 0.6746 - accuracy: 0.8615 - val_loss: 0.7112 - val_accuracy: 0.8296 - 506ms/epoch - 4ms/step
# Epoch 13/100
# 118/118 - 1s - loss: 0.6470 - accuracy: 0.8633 - val_loss: 0.6869 - val_accuracy: 0.8317 - 514ms/epoch - 4ms/step
# Epoch 14/100
# 118/118 - 1s - loss: 0.6242 - accuracy: 0.8648 - val_loss: 0.6698 - val_accuracy: 0.8314 - 508ms/epoch - 4ms/step
# Epoch 15/100
# 118/118 - 1s - loss: 0.6032 - accuracy: 0.8656 - val_loss: 0.6517 - val_accuracy: 0.8348 - 528ms/epoch - 4ms/step
# Epoch 16/100
# 118/118 - 1s - loss: 0.5861 - accuracy: 0.8655 - val_loss: 0.6391 - val_accuracy: 0.8326 - 503ms/epoch - 4ms/step
# Epoch 17/100
# 118/118 - 1s - loss: 0.5709 - accuracy: 0.8655 - val_loss: 0.6269 - val_accuracy: 0.8362 - 507ms/epoch - 4ms/step
# Epoch 18/100
# 118/118 - 1s - loss: 0.5558 - accuracy: 0.8673 - val_loss: 0.6119 - val_accuracy: 0.8340 - 518ms/epoch - 4ms/step
# Epoch 19/100
# 118/118 - 1s - loss: 0.5419 - accuracy: 0.8680 - val_loss: 0.6042 - val_accuracy: 0.8363 - 515ms/epoch - 4ms/step
# Epoch 20/100
# 118/118 - 0s - loss: 0.5305 - accuracy: 0.8691 - val_loss: 0.5917 - val_accuracy: 0.8355 - 494ms/epoch - 4ms/step
# Epoch 21/100
# 118/118 - 1s - loss: 0.5194 - accuracy: 0.8698 - val_loss: 0.5857 - val_accuracy: 0.8341 - 516ms/epoch - 4ms/step
# Epoch 22/100
# 118/118 - 1s - loss: 0.5113 - accuracy: 0.8696 - val_loss: 0.5787 - val_accuracy: 0.8360 - 510ms/epoch - 4ms/step
# Epoch 23/100
# 118/118 - 1s - loss: 0.5005 - accuracy: 0.8708 - val_loss: 0.5697 - val_accuracy: 0.8351 - 524ms/epoch - 4ms/step
# Epoch 24/100
# 118/118 - 1s - loss: 0.4914 - accuracy: 0.8718 - val_loss: 0.5617 - val_accuracy: 0.8395 - 508ms/epoch - 4ms/step
# Epoch 25/100
# 118/118 - 1s - loss: 0.4850 - accuracy: 0.8702 - val_loss: 0.5610 - val_accuracy: 0.8334 - 511ms/epoch - 4ms/step
# Epoch 26/100
# 118/118 - 1s - loss: 0.4844 - accuracy: 0.8688 - val_loss: 0.5539 - val_accuracy: 0.8348 - 500ms/epoch - 4ms/step
# Epoch 27/100
# 118/118 - 1s - loss: 0.4775 - accuracy: 0.8695 - val_loss: 0.5505 - val_accuracy: 0.8358 - 524ms/epoch - 4ms/step
# Epoch 28/100
# 118/118 - 1s - loss: 0.4664 - accuracy: 0.8715 - val_loss: 0.5406 - val_accuracy: 0.8377 - 511ms/epoch - 4ms/step
# Epoch 29/100
# 118/118 - 1s - loss: 0.4613 - accuracy: 0.8704 - val_loss: 0.5423 - val_accuracy: 0.8358 - 519ms/epoch - 4ms/step
# Epoch 30/100
# 118/118 - 1s - loss: 0.4578 - accuracy: 0.8713 - val_loss: 0.5363 - val_accuracy: 0.8366 - 510ms/epoch - 4ms/step
# Epoch 31/100
# 118/118 - 1s - loss: 0.4545 - accuracy: 0.8716 - val_loss: 0.5369 - val_accuracy: 0.8327 - 524ms/epoch - 4ms/step
# Epoch 32/100
# 118/118 - 0s - loss: 0.4489 - accuracy: 0.8716 - val_loss: 0.5337 - val_accuracy: 0.8396 - 499ms/epoch - 4ms/step
# Epoch 33/100
# 118/118 - 1s - loss: 0.4452 - accuracy: 0.8728 - val_loss: 0.5253 - val_accuracy: 0.8359 - 512ms/epoch - 4ms/step
# Epoch 34/100
# 118/118 - 1s - loss: 0.4439 - accuracy: 0.8706 - val_loss: 0.5273 - val_accuracy: 0.8351 - 517ms/epoch - 4ms/step
# Epoch 35/100
# 118/118 - 1s - loss: 0.4366 - accuracy: 0.8734 - val_loss: 0.5303 - val_accuracy: 0.8354 - 516ms/epoch - 4ms/step
# Epoch 36/100
# 118/118 - 1s - loss: 0.4320 - accuracy: 0.8741 - val_loss: 0.5152 - val_accuracy: 0.8396 - 502ms/epoch - 4ms/step
# Epoch 37/100
# 118/118 - 1s - loss: 0.4287 - accuracy: 0.8748 - val_loss: 0.5189 - val_accuracy: 0.8357 - 505ms/epoch - 4ms/step
# Epoch 38/100
# 118/118 - 1s - loss: 0.4304 - accuracy: 0.8734 - val_loss: 0.5137 - val_accuracy: 0.8390 - 517ms/epoch - 4ms/step
# Epoch 39/100
# 118/118 - 1s - loss: 0.4285 - accuracy: 0.8743 - val_loss: 0.5116 - val_accuracy: 0.8371 - 511ms/epoch - 4ms/step
# Epoch 40/100
# 118/118 - 1s - loss: 0.4227 - accuracy: 0.8746 - val_loss: 0.5198 - val_accuracy: 0.8329 - 529ms/epoch - 4ms/step
# Epoch 41/100
# 118/118 - 1s - loss: 0.4239 - accuracy: 0.8728 - val_loss: 0.5064 - val_accuracy: 0.8422 - 537ms/epoch - 5ms/step
# Epoch 42/100
# 118/118 - 1s - loss: 0.4206 - accuracy: 0.8744 - val_loss: 0.5135 - val_accuracy: 0.8349 - 550ms/epoch - 5ms/step
# Epoch 43/100
# 118/118 - 1s - loss: 0.4188 - accuracy: 0.8742 - val_loss: 0.5076 - val_accuracy: 0.8382 - 514ms/epoch - 4ms/step
# Epoch 44/100
# 118/118 - 1s - loss: 0.4175 - accuracy: 0.8738 - val_loss: 0.5101 - val_accuracy: 0.8372 - 550ms/epoch - 5ms/step
# Epoch 45/100
# 118/118 - 1s - loss: 0.4158 - accuracy: 0.8739 - val_loss: 0.5210 - val_accuracy: 0.8329 - 516ms/epoch - 4ms/step
# Epoch 46/100
# 118/118 - 1s - loss: 0.4193 - accuracy: 0.8712 - val_loss: 0.5033 - val_accuracy: 0.8387 - 522ms/epoch - 4ms/step
# Epoch 47/100
# 118/118 - 1s - loss: 0.4124 - accuracy: 0.8736 - val_loss: 0.5021 - val_accuracy: 0.8365 - 518ms/epoch - 4ms/step
# Epoch 48/100
# 118/118 - 1s - loss: 0.4101 - accuracy: 0.8739 - val_loss: 0.5007 - val_accuracy: 0.8434 - 516ms/epoch - 4ms/step
# Epoch 49/100
# 118/118 - 1s - loss: 0.4113 - accuracy: 0.8734 - val_loss: 0.4930 - val_accuracy: 0.8427 - 518ms/epoch - 4ms/step
# Epoch 50/100
# 118/118 - 1s - loss: 0.4112 - accuracy: 0.8715 - val_loss: 0.4994 - val_accuracy: 0.8379 - 515ms/epoch - 4ms/step
# Epoch 51/100
# 118/118 - 1s - loss: 0.4021 - accuracy: 0.8769 - val_loss: 0.4959 - val_accuracy: 0.8400 - 514ms/epoch - 4ms/step
# Epoch 52/100
# 118/118 - 1s - loss: 0.4030 - accuracy: 0.8751 - val_loss: 0.4904 - val_accuracy: 0.8397 - 514ms/epoch - 4ms/step
# Epoch 53/100
# 118/118 - 1s - loss: 0.3988 - accuracy: 0.8751 - val_loss: 0.4879 - val_accuracy: 0.8408 - 507ms/epoch - 4ms/step
# Epoch 54/100
# 118/118 - 1s - loss: 0.3963 - accuracy: 0.8769 - val_loss: 0.5061 - val_accuracy: 0.8352 - 520ms/epoch - 4ms/step
# Epoch 55/100
# 118/118 - 1s - loss: 0.4002 - accuracy: 0.8752 - val_loss: 0.4985 - val_accuracy: 0.8387 - 508ms/epoch - 4ms/step
# Epoch 56/100
# 118/118 - 1s - loss: 0.3972 - accuracy: 0.8749 - val_loss: 0.4962 - val_accuracy: 0.8381 - 524ms/epoch - 4ms/step
# Epoch 57/100
# 118/118 - 1s - loss: 0.4017 - accuracy: 0.8727 - val_loss: 0.4932 - val_accuracy: 0.8388 - 505ms/epoch - 4ms/step
# Epoch 58/100
# 118/118 - 1s - loss: 0.3989 - accuracy: 0.8740 - val_loss: 0.4864 - val_accuracy: 0.8455 - 518ms/epoch - 4ms/step
# Epoch 59/100
# 118/118 - 1s - loss: 0.3944 - accuracy: 0.8760 - val_loss: 0.4887 - val_accuracy: 0.8423 - 531ms/epoch - 4ms/step
# Epoch 60/100
# 118/118 - 1s - loss: 0.3979 - accuracy: 0.8733 - val_loss: 0.5282 - val_accuracy: 0.8207 - 539ms/epoch - 5ms/step
# Epoch 61/100
# 118/118 - 1s - loss: 0.3986 - accuracy: 0.8733 - val_loss: 0.4924 - val_accuracy: 0.8396 - 509ms/epoch - 4ms/step
# Epoch 62/100
# 118/118 - 1s - loss: 0.3958 - accuracy: 0.8748 - val_loss: 0.4914 - val_accuracy: 0.8383 - 537ms/epoch - 5ms/step
# Epoch 63/100
# 118/118 - 1s - loss: 0.3946 - accuracy: 0.8736 - val_loss: 0.4908 - val_accuracy: 0.8382 - 551ms/epoch - 5ms/step
# Epoch 64/100
# 118/118 - 1s - loss: 0.3910 - accuracy: 0.8736 - val_loss: 0.4856 - val_accuracy: 0.8383 - 610ms/epoch - 5ms/step
# Epoch 65/100
# 118/118 - 1s - loss: 0.3864 - accuracy: 0.8764 - val_loss: 0.4831 - val_accuracy: 0.8426 - 802ms/epoch - 7ms/step
# Epoch 66/100
# 118/118 - 1s - loss: 0.3875 - accuracy: 0.8762 - val_loss: 0.4814 - val_accuracy: 0.8438 - 734ms/epoch - 6ms/step
# Epoch 67/100
# 118/118 - 1s - loss: 0.3894 - accuracy: 0.8753 - val_loss: 0.4860 - val_accuracy: 0.8479 - 674ms/epoch - 6ms/step
# Epoch 68/100
# 118/118 - 1s - loss: 0.3892 - accuracy: 0.8751 - val_loss: 0.4862 - val_accuracy: 0.8410 - 507ms/epoch - 4ms/step
# Epoch 69/100
# 118/118 - 1s - loss: 0.3861 - accuracy: 0.8756 - val_loss: 0.4792 - val_accuracy: 0.8441 - 511ms/epoch - 4ms/step
# Epoch 70/100
# 118/118 - 1s - loss: 0.3824 - accuracy: 0.8768 - val_loss: 0.4952 - val_accuracy: 0.8361 - 506ms/epoch - 4ms/step
# Epoch 71/100
# 118/118 - 1s - loss: 0.3914 - accuracy: 0.8741 - val_loss: 0.4915 - val_accuracy: 0.8395 - 525ms/epoch - 4ms/step
# Epoch 72/100
# 118/118 - 1s - loss: 0.3857 - accuracy: 0.8755 - val_loss: 0.4850 - val_accuracy: 0.8414 - 516ms/epoch - 4ms/step
# Epoch 73/100
# 118/118 - 1s - loss: 0.3867 - accuracy: 0.8747 - val_loss: 0.4800 - val_accuracy: 0.8435 - 514ms/epoch - 4ms/step
# Epoch 74/100
# 118/118 - 1s - loss: 0.3824 - accuracy: 0.8766 - val_loss: 0.4862 - val_accuracy: 0.8402 - 514ms/epoch - 4ms/step
# Epoch 75/100
# 118/118 - 1s - loss: 0.3826 - accuracy: 0.8761 - val_loss: 0.4741 - val_accuracy: 0.8460 - 504ms/epoch - 4ms/step
# Epoch 76/100
# 118/118 - 1s - loss: 0.3857 - accuracy: 0.8740 - val_loss: 0.4837 - val_accuracy: 0.8421 - 527ms/epoch - 4ms/step
# Epoch 77/100
# 118/118 - 1s - loss: 0.3835 - accuracy: 0.8755 - val_loss: 0.4842 - val_accuracy: 0.8429 - 504ms/epoch - 4ms/step
# Epoch 78/100
# 118/118 - 1s - loss: 0.3806 - accuracy: 0.8763 - val_loss: 0.4870 - val_accuracy: 0.8410 - 535ms/epoch - 5ms/step
# Epoch 79/100
# 118/118 - 1s - loss: 0.3826 - accuracy: 0.8747 - val_loss: 0.4844 - val_accuracy: 0.8383 - 521ms/epoch - 4ms/step
# Epoch 80/100
# 118/118 - 1s - loss: 0.3810 - accuracy: 0.8763 - val_loss: 0.4932 - val_accuracy: 0.8377 - 538ms/epoch - 5ms/step
# Epoch 81/100
# 118/118 - 1s - loss: 0.3837 - accuracy: 0.8757 - val_loss: 0.5036 - val_accuracy: 0.8315 - 506ms/epoch - 4ms/step
# Epoch 82/100
# 118/118 - 1s - loss: 0.3825 - accuracy: 0.8740 - val_loss: 0.4949 - val_accuracy: 0.8347 - 529ms/epoch - 4ms/step
# Epoch 83/100
# 118/118 - 1s - loss: 0.3779 - accuracy: 0.8771 - val_loss: 0.4733 - val_accuracy: 0.8427 - 536ms/epoch - 5ms/step
# Epoch 84/100
# 118/118 - 1s - loss: 0.3755 - accuracy: 0.8774 - val_loss: 0.4793 - val_accuracy: 0.8407 - 504ms/epoch - 4ms/step
# Epoch 85/100
# 118/118 - 1s - loss: 0.3740 - accuracy: 0.8794 - val_loss: 0.4758 - val_accuracy: 0.8414 - 510ms/epoch - 4ms/step
# Epoch 86/100
# 118/118 - 1s - loss: 0.3724 - accuracy: 0.8794 - val_loss: 0.4934 - val_accuracy: 0.8367 - 518ms/epoch - 4ms/step
# Epoch 87/100
# 118/118 - 1s - loss: 0.3818 - accuracy: 0.8753 - val_loss: 0.4810 - val_accuracy: 0.8409 - 517ms/epoch - 4ms/step
# Epoch 88/100
# 118/118 - 1s - loss: 0.3803 - accuracy: 0.8749 - val_loss: 0.4774 - val_accuracy: 0.8411 - 508ms/epoch - 4ms/step
# Epoch 89/100
# 118/118 - 1s - loss: 0.3764 - accuracy: 0.8759 - val_loss: 0.4746 - val_accuracy: 0.8441 - 516ms/epoch - 4ms/step
# Epoch 90/100
# 118/118 - 1s - loss: 0.3717 - accuracy: 0.8782 - val_loss: 0.4839 - val_accuracy: 0.8394 - 506ms/epoch - 4ms/step
# Epoch 91/100
# 118/118 - 1s - loss: 0.3685 - accuracy: 0.8802 - val_loss: 0.4790 - val_accuracy: 0.8408 - 506ms/epoch - 4ms/step
# Epoch 92/100
# 118/118 - 1s - loss: 0.3757 - accuracy: 0.8760 - val_loss: 0.4811 - val_accuracy: 0.8428 - 501ms/epoch - 4ms/step
# Epoch 93/100
# 118/118 - 1s - loss: 0.3705 - accuracy: 0.8788 - val_loss: 0.4902 - val_accuracy: 0.8387 - 510ms/epoch - 4ms/step
# Epoch 94/100
# 118/118 - 0s - loss: 0.3769 - accuracy: 0.8754 - val_loss: 0.4900 - val_accuracy: 0.8394 - 492ms/epoch - 4ms/step
# Epoch 95/100
# 118/118 - 1s - loss: 0.3859 - accuracy: 0.8725 - val_loss: 0.4904 - val_accuracy: 0.8368 - 507ms/epoch - 4ms/step
# Epoch 96/100
# 118/118 - 1s - loss: 0.3825 - accuracy: 0.8731 - val_loss: 0.4835 - val_accuracy: 0.8382 - 511ms/epoch - 4ms/step
# Epoch 97/100
# 118/118 - 1s - loss: 0.3793 - accuracy: 0.8748 - val_loss: 0.4755 - val_accuracy: 0.8419 - 523ms/epoch - 4ms/step
# Epoch 98/100
# 118/118 - 1s - loss: 0.3672 - accuracy: 0.8793 - val_loss: 0.4984 - val_accuracy: 0.8322 - 543ms/epoch - 5ms/step
# Epoch 99/100
# 118/118 - 1s - loss: 0.3821 - accuracy: 0.8741 - val_loss: 0.4876 - val_accuracy: 0.8388 - 522ms/epoch - 4ms/step
# Epoch 100/100
# 118/118 - 1s - loss: 0.3833 - accuracy: 0.8744 - val_loss: 0.4772 - val_accuracy: 0.8396 - 512ms/epoch - 4ms/step

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# ### Train 6

# %%
# fix first, second and third, and train fourth
#################### YOUR CODE HERE ####################
# Các bạn thực hiện tương tự như Ví dụ train lần 1 
# Train lần 6:  Ghép sub mode 1, 2, 3 và 4 lại với nhau. Train với 100 epoch nhưng fix weight của sub model 1, sub model 2 và sub model 3
# (tạo model mới và thêm Input layer, sub model 1, sub model 2, sub model 3, sub model 4 , Output layer)
fourth_model = 

# freeze sub model 1 ,sub model 2 và sub model 3

########################################################


fourth_model.compile(optimizer=tf.keras.optimizers.SGD(), 
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])

history = fourth_model.fit(X_train, y_train, batch_size,
                          validation_data=(X_test, y_test),
                          epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 118/118 - 1s - loss: 2.2660 - accuracy: 0.2481 - val_loss: 2.1905 - val_accuracy: 0.4866 - 1s/epoch - 10ms/step
# Epoch 2/100
# 118/118 - 0s - loss: 2.1262 - accuracy: 0.5928 - val_loss: 2.0653 - val_accuracy: 0.6526 - 455ms/epoch - 4ms/step
# Epoch 3/100
# 118/118 - 0s - loss: 2.0011 - accuracy: 0.7236 - val_loss: 1.9434 - val_accuracy: 0.7707 - 495ms/epoch - 4ms/step
# Epoch 4/100
# 118/118 - 0s - loss: 1.8781 - accuracy: 0.8110 - val_loss: 1.8231 - val_accuracy: 0.8002 - 466ms/epoch - 4ms/step
# Epoch 5/100
# 118/118 - 0s - loss: 1.7573 - accuracy: 0.8254 - val_loss: 1.7059 - val_accuracy: 0.7947 - 491ms/epoch - 4ms/step
# Epoch 6/100
# 118/118 - 0s - loss: 1.6405 - accuracy: 0.8340 - val_loss: 1.5942 - val_accuracy: 0.8071 - 470ms/epoch - 4ms/step
# Epoch 7/100
# 118/118 - 0s - loss: 1.5298 - accuracy: 0.8435 - val_loss: 1.4893 - val_accuracy: 0.8160 - 472ms/epoch - 4ms/step
# Epoch 8/100
# 118/118 - 0s - loss: 1.4264 - accuracy: 0.8499 - val_loss: 1.3925 - val_accuracy: 0.8228 - 464ms/epoch - 4ms/step
# Epoch 9/100
# 118/118 - 0s - loss: 1.3312 - accuracy: 0.8543 - val_loss: 1.3040 - val_accuracy: 0.8267 - 477ms/epoch - 4ms/step
# Epoch 10/100
# 118/118 - 0s - loss: 1.2442 - accuracy: 0.8601 - val_loss: 1.2238 - val_accuracy: 0.8253 - 474ms/epoch - 4ms/step
# Epoch 11/100
# 118/118 - 0s - loss: 1.1652 - accuracy: 0.8609 - val_loss: 1.1513 - val_accuracy: 0.8300 - 470ms/epoch - 4ms/step
# Epoch 12/100
# 118/118 - 0s - loss: 1.0938 - accuracy: 0.8623 - val_loss: 1.0864 - val_accuracy: 0.8331 - 475ms/epoch - 4ms/step
# Epoch 13/100
# 118/118 - 0s - loss: 1.0295 - accuracy: 0.8662 - val_loss: 1.0278 - val_accuracy: 0.8310 - 484ms/epoch - 4ms/step
# Epoch 14/100
# 118/118 - 0s - loss: 0.9716 - accuracy: 0.8661 - val_loss: 0.9755 - val_accuracy: 0.8320 - 484ms/epoch - 4ms/step
# Epoch 15/100
# 118/118 - 0s - loss: 0.9196 - accuracy: 0.8674 - val_loss: 0.9289 - val_accuracy: 0.8332 - 477ms/epoch - 4ms/step
# Epoch 16/100
# 118/118 - 0s - loss: 0.8729 - accuracy: 0.8687 - val_loss: 0.8873 - val_accuracy: 0.8328 - 460ms/epoch - 4ms/step
# Epoch 17/100
# 118/118 - 0s - loss: 0.8311 - accuracy: 0.8690 - val_loss: 0.8500 - val_accuracy: 0.8344 - 468ms/epoch - 4ms/step
# Epoch 18/100
# 118/118 - 0s - loss: 0.7936 - accuracy: 0.8692 - val_loss: 0.8168 - val_accuracy: 0.8343 - 478ms/epoch - 4ms/step
# Epoch 19/100
# 118/118 - 0s - loss: 0.7599 - accuracy: 0.8708 - val_loss: 0.7871 - val_accuracy: 0.8345 - 476ms/epoch - 4ms/step
# Epoch 20/100
# 118/118 - 0s - loss: 0.7296 - accuracy: 0.8706 - val_loss: 0.7605 - val_accuracy: 0.8348 - 488ms/epoch - 4ms/step
# Epoch 21/100
# 118/118 - 0s - loss: 0.7024 - accuracy: 0.8711 - val_loss: 0.7369 - val_accuracy: 0.8352 - 479ms/epoch - 4ms/step
# Epoch 22/100
# 118/118 - 0s - loss: 0.6779 - accuracy: 0.8712 - val_loss: 0.7155 - val_accuracy: 0.8347 - 468ms/epoch - 4ms/step
# Epoch 23/100
# 118/118 - 0s - loss: 0.6557 - accuracy: 0.8714 - val_loss: 0.6966 - val_accuracy: 0.8369 - 461ms/epoch - 4ms/step
# Epoch 24/100
# 118/118 - 0s - loss: 0.6357 - accuracy: 0.8720 - val_loss: 0.6793 - val_accuracy: 0.8365 - 482ms/epoch - 4ms/step
# Epoch 25/100
# 118/118 - 0s - loss: 0.6175 - accuracy: 0.8718 - val_loss: 0.6637 - val_accuracy: 0.8360 - 475ms/epoch - 4ms/step
# Epoch 26/100
# 118/118 - 0s - loss: 0.6010 - accuracy: 0.8720 - val_loss: 0.6498 - val_accuracy: 0.8356 - 477ms/epoch - 4ms/step
# Epoch 27/100
# 118/118 - 0s - loss: 0.5859 - accuracy: 0.8723 - val_loss: 0.6370 - val_accuracy: 0.8370 - 468ms/epoch - 4ms/step
# Epoch 28/100
# 118/118 - 0s - loss: 0.5722 - accuracy: 0.8727 - val_loss: 0.6255 - val_accuracy: 0.8370 - 473ms/epoch - 4ms/step
# Epoch 29/100
# 118/118 - 0s - loss: 0.5597 - accuracy: 0.8727 - val_loss: 0.6150 - val_accuracy: 0.8369 - 479ms/epoch - 4ms/step
# Epoch 30/100
# 118/118 - 0s - loss: 0.5481 - accuracy: 0.8728 - val_loss: 0.6057 - val_accuracy: 0.8387 - 483ms/epoch - 4ms/step
# Epoch 31/100
# 118/118 - 0s - loss: 0.5376 - accuracy: 0.8733 - val_loss: 0.5969 - val_accuracy: 0.8374 - 488ms/epoch - 4ms/step
# Epoch 32/100
# 118/118 - 0s - loss: 0.5278 - accuracy: 0.8735 - val_loss: 0.5889 - val_accuracy: 0.8377 - 473ms/epoch - 4ms/step
# Epoch 33/100
# 118/118 - 0s - loss: 0.5188 - accuracy: 0.8735 - val_loss: 0.5816 - val_accuracy: 0.8374 - 463ms/epoch - 4ms/step
# Epoch 34/100
# 118/118 - 0s - loss: 0.5105 - accuracy: 0.8739 - val_loss: 0.5750 - val_accuracy: 0.8386 - 458ms/epoch - 4ms/step
# Epoch 35/100
# 118/118 - 0s - loss: 0.5029 - accuracy: 0.8736 - val_loss: 0.5688 - val_accuracy: 0.8384 - 485ms/epoch - 4ms/step
# Epoch 36/100
# 118/118 - 0s - loss: 0.4957 - accuracy: 0.8737 - val_loss: 0.5633 - val_accuracy: 0.8391 - 470ms/epoch - 4ms/step
# Epoch 37/100
# 118/118 - 0s - loss: 0.4891 - accuracy: 0.8741 - val_loss: 0.5579 - val_accuracy: 0.8382 - 482ms/epoch - 4ms/step
# Epoch 38/100
# 118/118 - 0s - loss: 0.4830 - accuracy: 0.8738 - val_loss: 0.5532 - val_accuracy: 0.8384 - 460ms/epoch - 4ms/step
# Epoch 39/100
# 118/118 - 0s - loss: 0.4772 - accuracy: 0.8741 - val_loss: 0.5487 - val_accuracy: 0.8381 - 461ms/epoch - 4ms/step
# Epoch 40/100
# 118/118 - 0s - loss: 0.4719 - accuracy: 0.8741 - val_loss: 0.5447 - val_accuracy: 0.8386 - 457ms/epoch - 4ms/step
# Epoch 41/100
# 118/118 - 0s - loss: 0.4669 - accuracy: 0.8741 - val_loss: 0.5408 - val_accuracy: 0.8387 - 464ms/epoch - 4ms/step
# Epoch 42/100
# 118/118 - 0s - loss: 0.4623 - accuracy: 0.8740 - val_loss: 0.5373 - val_accuracy: 0.8389 - 476ms/epoch - 4ms/step
# Epoch 43/100
# 118/118 - 0s - loss: 0.4579 - accuracy: 0.8741 - val_loss: 0.5340 - val_accuracy: 0.8383 - 482ms/epoch - 4ms/step
# Epoch 44/100
# 118/118 - 0s - loss: 0.4538 - accuracy: 0.8745 - val_loss: 0.5310 - val_accuracy: 0.8386 - 465ms/epoch - 4ms/step
# Epoch 45/100
# 118/118 - 0s - loss: 0.4499 - accuracy: 0.8742 - val_loss: 0.5282 - val_accuracy: 0.8384 - 471ms/epoch - 4ms/step
# Epoch 46/100
# 118/118 - 0s - loss: 0.4463 - accuracy: 0.8745 - val_loss: 0.5256 - val_accuracy: 0.8383 - 459ms/epoch - 4ms/step
# Epoch 47/100
# 118/118 - 0s - loss: 0.4429 - accuracy: 0.8743 - val_loss: 0.5231 - val_accuracy: 0.8387 - 481ms/epoch - 4ms/step
# Epoch 48/100
# 118/118 - 0s - loss: 0.4398 - accuracy: 0.8745 - val_loss: 0.5209 - val_accuracy: 0.8381 - 475ms/epoch - 4ms/step
# Epoch 49/100
# 118/118 - 0s - loss: 0.4367 - accuracy: 0.8745 - val_loss: 0.5186 - val_accuracy: 0.8384 - 476ms/epoch - 4ms/step
# Epoch 50/100
# 118/118 - 0s - loss: 0.4339 - accuracy: 0.8742 - val_loss: 0.5167 - val_accuracy: 0.8386 - 473ms/epoch - 4ms/step
# Epoch 51/100
# 118/118 - 0s - loss: 0.4312 - accuracy: 0.8748 - val_loss: 0.5148 - val_accuracy: 0.8381 - 477ms/epoch - 4ms/step
# Epoch 52/100
# 118/118 - 0s - loss: 0.4287 - accuracy: 0.8748 - val_loss: 0.5131 - val_accuracy: 0.8382 - 494ms/epoch - 4ms/step
# Epoch 53/100
# 118/118 - 0s - loss: 0.4262 - accuracy: 0.8748 - val_loss: 0.5114 - val_accuracy: 0.8383 - 476ms/epoch - 4ms/step
# Epoch 54/100
# 118/118 - 0s - loss: 0.4240 - accuracy: 0.8749 - val_loss: 0.5101 - val_accuracy: 0.8382 - 473ms/epoch - 4ms/step
# Epoch 55/100
# 118/118 - 0s - loss: 0.4218 - accuracy: 0.8749 - val_loss: 0.5085 - val_accuracy: 0.8383 - 461ms/epoch - 4ms/step
# Epoch 56/100
# 118/118 - 0s - loss: 0.4198 - accuracy: 0.8747 - val_loss: 0.5072 - val_accuracy: 0.8386 - 479ms/epoch - 4ms/step
# Epoch 57/100
# 118/118 - 0s - loss: 0.4178 - accuracy: 0.8750 - val_loss: 0.5058 - val_accuracy: 0.8384 - 474ms/epoch - 4ms/step
# Epoch 58/100
# 118/118 - 0s - loss: 0.4160 - accuracy: 0.8751 - val_loss: 0.5047 - val_accuracy: 0.8389 - 495ms/epoch - 4ms/step
# Epoch 59/100
# 118/118 - 0s - loss: 0.4142 - accuracy: 0.8752 - val_loss: 0.5035 - val_accuracy: 0.8384 - 485ms/epoch - 4ms/step
# Epoch 60/100
# 118/118 - 1s - loss: 0.4125 - accuracy: 0.8749 - val_loss: 0.5025 - val_accuracy: 0.8386 - 505ms/epoch - 4ms/step
# Epoch 61/100
# 118/118 - 0s - loss: 0.4110 - accuracy: 0.8752 - val_loss: 0.5015 - val_accuracy: 0.8383 - 456ms/epoch - 4ms/step
# Epoch 62/100
# 118/118 - 0s - loss: 0.4094 - accuracy: 0.8752 - val_loss: 0.5006 - val_accuracy: 0.8388 - 473ms/epoch - 4ms/step
# Epoch 63/100
# 118/118 - 0s - loss: 0.4080 - accuracy: 0.8751 - val_loss: 0.4997 - val_accuracy: 0.8384 - 468ms/epoch - 4ms/step
# Epoch 64/100
# 118/118 - 0s - loss: 0.4066 - accuracy: 0.8751 - val_loss: 0.4989 - val_accuracy: 0.8385 - 482ms/epoch - 4ms/step
# Epoch 65/100
# 118/118 - 0s - loss: 0.4053 - accuracy: 0.8752 - val_loss: 0.4981 - val_accuracy: 0.8390 - 472ms/epoch - 4ms/step
# Epoch 66/100
# 118/118 - 0s - loss: 0.4040 - accuracy: 0.8753 - val_loss: 0.4974 - val_accuracy: 0.8386 - 456ms/epoch - 4ms/step
# Epoch 67/100
# 118/118 - 0s - loss: 0.4028 - accuracy: 0.8755 - val_loss: 0.4967 - val_accuracy: 0.8383 - 455ms/epoch - 4ms/step
# Epoch 68/100
# 118/118 - 0s - loss: 0.4017 - accuracy: 0.8754 - val_loss: 0.4959 - val_accuracy: 0.8385 - 474ms/epoch - 4ms/step
# Epoch 69/100
# 118/118 - 0s - loss: 0.4005 - accuracy: 0.8753 - val_loss: 0.4955 - val_accuracy: 0.8383 - 479ms/epoch - 4ms/step
# Epoch 70/100
# 118/118 - 0s - loss: 0.3995 - accuracy: 0.8751 - val_loss: 0.4948 - val_accuracy: 0.8388 - 463ms/epoch - 4ms/step
# Epoch 71/100
# 118/118 - 0s - loss: 0.3985 - accuracy: 0.8755 - val_loss: 0.4942 - val_accuracy: 0.8385 - 476ms/epoch - 4ms/step
# Epoch 72/100
# 118/118 - 0s - loss: 0.3975 - accuracy: 0.8753 - val_loss: 0.4937 - val_accuracy: 0.8383 - 477ms/epoch - 4ms/step
# Epoch 73/100
# 118/118 - 0s - loss: 0.3966 - accuracy: 0.8756 - val_loss: 0.4932 - val_accuracy: 0.8385 - 463ms/epoch - 4ms/step
# Epoch 74/100
# 118/118 - 0s - loss: 0.3957 - accuracy: 0.8754 - val_loss: 0.4927 - val_accuracy: 0.8388 - 456ms/epoch - 4ms/step
# Epoch 75/100
# 118/118 - 0s - loss: 0.3948 - accuracy: 0.8754 - val_loss: 0.4922 - val_accuracy: 0.8386 - 482ms/epoch - 4ms/step
# Epoch 76/100
# 118/118 - 0s - loss: 0.3940 - accuracy: 0.8753 - val_loss: 0.4919 - val_accuracy: 0.8383 - 462ms/epoch - 4ms/step
# Epoch 77/100
# 118/118 - 0s - loss: 0.3932 - accuracy: 0.8754 - val_loss: 0.4913 - val_accuracy: 0.8387 - 465ms/epoch - 4ms/step
# Epoch 78/100
# 118/118 - 0s - loss: 0.3924 - accuracy: 0.8754 - val_loss: 0.4910 - val_accuracy: 0.8386 - 488ms/epoch - 4ms/step
# Epoch 79/100
# 118/118 - 0s - loss: 0.3917 - accuracy: 0.8754 - val_loss: 0.4907 - val_accuracy: 0.8382 - 474ms/epoch - 4ms/step
# Epoch 80/100
# 118/118 - 0s - loss: 0.3910 - accuracy: 0.8754 - val_loss: 0.4904 - val_accuracy: 0.8385 - 476ms/epoch - 4ms/step
# Epoch 81/100
# 118/118 - 0s - loss: 0.3903 - accuracy: 0.8755 - val_loss: 0.4901 - val_accuracy: 0.8382 - 487ms/epoch - 4ms/step
# Epoch 82/100
# 118/118 - 0s - loss: 0.3897 - accuracy: 0.8756 - val_loss: 0.4896 - val_accuracy: 0.8389 - 475ms/epoch - 4ms/step
# Epoch 83/100
# 118/118 - 0s - loss: 0.3890 - accuracy: 0.8755 - val_loss: 0.4894 - val_accuracy: 0.8386 - 464ms/epoch - 4ms/step
# Epoch 84/100
# 118/118 - 0s - loss: 0.3884 - accuracy: 0.8752 - val_loss: 0.4891 - val_accuracy: 0.8384 - 471ms/epoch - 4ms/step
# Epoch 85/100
# 118/118 - 0s - loss: 0.3878 - accuracy: 0.8753 - val_loss: 0.4888 - val_accuracy: 0.8382 - 460ms/epoch - 4ms/step
# Epoch 86/100
# 118/118 - 0s - loss: 0.3872 - accuracy: 0.8758 - val_loss: 0.4886 - val_accuracy: 0.8389 - 472ms/epoch - 4ms/step
# Epoch 87/100
# 118/118 - 0s - loss: 0.3867 - accuracy: 0.8755 - val_loss: 0.4882 - val_accuracy: 0.8389 - 468ms/epoch - 4ms/step
# Epoch 88/100
# 118/118 - 0s - loss: 0.3861 - accuracy: 0.8755 - val_loss: 0.4881 - val_accuracy: 0.8392 - 472ms/epoch - 4ms/step
# Epoch 89/100
# 118/118 - 0s - loss: 0.3856 - accuracy: 0.8757 - val_loss: 0.4878 - val_accuracy: 0.8388 - 472ms/epoch - 4ms/step
# Epoch 90/100
# 118/118 - 0s - loss: 0.3851 - accuracy: 0.8752 - val_loss: 0.4877 - val_accuracy: 0.8387 - 492ms/epoch - 4ms/step
# Epoch 91/100
# 118/118 - 0s - loss: 0.3846 - accuracy: 0.8755 - val_loss: 0.4875 - val_accuracy: 0.8388 - 473ms/epoch - 4ms/step
# Epoch 92/100
# 118/118 - 0s - loss: 0.3841 - accuracy: 0.8755 - val_loss: 0.4872 - val_accuracy: 0.8391 - 490ms/epoch - 4ms/step
# Epoch 93/100
# 118/118 - 0s - loss: 0.3837 - accuracy: 0.8758 - val_loss: 0.4870 - val_accuracy: 0.8389 - 473ms/epoch - 4ms/step
# Epoch 94/100
# 118/118 - 0s - loss: 0.3833 - accuracy: 0.8757 - val_loss: 0.4869 - val_accuracy: 0.8389 - 486ms/epoch - 4ms/step
# Epoch 95/100
# 118/118 - 0s - loss: 0.3828 - accuracy: 0.8754 - val_loss: 0.4867 - val_accuracy: 0.8393 - 456ms/epoch - 4ms/step
# Epoch 96/100
# 118/118 - 0s - loss: 0.3824 - accuracy: 0.8755 - val_loss: 0.4864 - val_accuracy: 0.8389 - 462ms/epoch - 4ms/step
# Epoch 97/100
# 118/118 - 0s - loss: 0.3820 - accuracy: 0.8758 - val_loss: 0.4863 - val_accuracy: 0.8390 - 453ms/epoch - 4ms/step
# Epoch 98/100
# 118/118 - 0s - loss: 0.3816 - accuracy: 0.8756 - val_loss: 0.4862 - val_accuracy: 0.8386 - 474ms/epoch - 4ms/step
# Epoch 99/100
# 118/118 - 0s - loss: 0.3812 - accuracy: 0.8754 - val_loss: 0.4860 - val_accuracy: 0.8390 - 483ms/epoch - 4ms/step
# Epoch 100/100
# 118/118 - 0s - loss: 0.3809 - accuracy: 0.8755 - val_loss: 0.4859 - val_accuracy: 0.8394 - 473ms/epoch - 4ms/step

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# ### Train 7

# %%
# first, second, third, and fourth
#################### YOUR CODE HERE ####################
# Các bạn thực hiện tương tự như Ví dụ train lần 1 
# Train lần 7:  Tiếp tục train thêm 300 epoch nhưng lần này không fix weight của sub model 1, sub model 2 và sub model 3
# (tạo model mới và thêm Input layer, sub model 1, sub model 2, sub model 3, sub model 4 , Output layer)
fourth_model = 

# unfreeze sub model 1 ,sub model 2 và sub model 3

########################################################

fourth_model.compile(optimizer=tf.keras.optimizers.SGD(), 
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])

history = fourth_model.fit(X_train, y_train, batch_size,
                          validation_data=(X_test, y_test),
                          epochs=300, verbose=2)

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()
