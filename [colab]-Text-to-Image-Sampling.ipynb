# %%
# !cp -r /kaggle/input/sd-text2imagetraining/celebhq /kaggle/working/celebhq
# !cp /kaggle/input/sd-text2imagetraining/blocks.py /kaggle/working/blocks.py

# %%
# !pip install gdown
# to upgrade
# !pip install --upgrade gdown
# Out:
# Collecting gdown
#   Downloading gdown-5.1.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.1.0-py3-none-any.whl (17 kB)
# Installing collected packages: gdown
# Successfully installed gdown-5.1.0
# Requirement already satisfied: gdown in /opt/conda/lib/python3.10/site-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)

# %%
# Tạo thư mục data
# !mkdir data
# %cd data

# !mkdir CelebAMask-HQ
# %cd CelebAMask-HQ

# Tải file ảnh
# !gdown 1jlQ8umhpJo8lVgC9q4_1q_t_Frv1kZ3f
# !unzip image.zip

# Tải file mô tả của ảnh
# !gdown 1X1EFCyralNN2Bg3LhelL_lShrSrmTitW
# !unzip text.zip

# Tải file train và test
# !gdown 1GdeTdBpi_IV7AuBpJAhLElqjswRmOy-7 -O train.pickle
# !gdown 1JNxgdvPMI_HHUq2-JUuJp8L7cD-74OAf -O test.pickle

# !mv images CelebA-HQ-img
# !rm image.zip text.zip

# %cd /kaggle/working/
# Out:
# /kaggle/working/data
# /kaggle/working/data/CelebAMask-HQ
# Downloading...
# From (original): https://drive.google.com/uc?id=1jlQ8umhpJo8lVgC9q4_1q_t_Frv1kZ3f
# From (redirected): https://drive.google.com/uc?id=1jlQ8umhpJo8lVgC9q4_1q_t_Frv1kZ3f&confirm=t&uuid=0faa1f37-f42f-4856-8806-a0c2ff10b986
# To: /kaggle/working/data/CelebAMask-HQ/image.zip
# 100%|██████████████████████████████████████| 2.05G/2.05G [00:22<00:00, 91.4MB/s]
# Archive:  image.zip
#    creating: images/
#   inflating: images/26346.jpg
#   inflating: images/18939.jpg
#   inflating: images/27155.jpg
#   inflating: images/2579.jpg
#   inflating: images/9638.jpg
#   inflating: images/20667.jpg
#   inflating: images/11561.jpg
#   inflating: images/18396.jpg
#   inflating: images/12253.jpg
#   inflating: images/27599.jpg
#   inflating: images/6199.jpg
#   inflating: images/9861.jpg
#   inflating: images/9567.jpg
#   inflating: images/25139.jpg
#   inflating: images/26025.jpg
#   inflating: images/2435.jpg
#   inflating: images/23554.jpg
#   inflating: images/29624.jpg
#   inflating: images/8655.jpg
#   inflating: images/26680.jpg
#   inflating: images/19589.jpg
#   inflating: images/16950.jpg
#   inflating: images/5183.jpg
#   inflating: images/6886.jpg
#   inflating: images/12225.jpg
#   inflating: images/22382.jpg
#   inflating: images/22435.jpg
#   inflating: images/18638.jpg
#   inflating: images/16958.jpg
#   inflating: images/7137.jpg
#   inflating: images/16008.jpg
#   inflating: images/17739.jpg
#   inflating: images/23240.jpg
#   inflating: images/5205.jpg
#   inflating: images/9970.jpg
#   inflating: images/5176.jpg
#   inflating: images/3376.jpg
#   inflating: images/4456.jpg
#   inflating: images/28188.jpg
#   inflating: images/21802.jpg
#   inflating: images/7196.jpg
#   inflating: images/19144.jpg
#   inflating: images/11063.jpg
#   inflating: images/24308.jpg
#   inflating: images/6288.jpg
#   inflating: images/18886.jpg
#   inflating: images/28979.jpg
#   inflating: images/4516.jpg
#   inflating: images/13889.jpg
#   inflating: images/6962.jpg
#   inflating: images/5500.jpg
#   inflating: images/718.jpg
#   inflating: images/19895.jpg
#   inflating: images/700.jpg
#   inflating: images/18715.jpg
#   inflating: images/6513.jpg
#   inflating: images/17334.jpg
#   inflating: images/9766.jpg
#   inflating: images/21463.jpg
#   inflating: images/5599.jpg
#   inflating: images/5739.jpg
#   inflating: images/29592.jpg
#   inflating: images/3752.jpg
#   inflating: images/26367.jpg
#   inflating: images/939.jpg
#   inflating: images/24769.jpg
#   inflating: images/13815.jpg
#   inflating: images/8558.jpg
#   inflating: images/22855.jpg
#   inflating: images/1554.jpg
#   inflating: images/21867.jpg
#   inflating: images/18619.jpg
#   inflating: images/1128.jpg
#   inflating: images/27594.jpg
#   inflating: images/18358.jpg
#   inflating: images/25518.jpg
#   inflating: images/18114.jpg
#   inflating: images/16790.jpg
#   inflating: images/24041.jpg
#   inflating: images/27090.jpg
#   inflating: images/3557.jpg
#   inflating: images/25316.jpg
#   inflating: images/20986.jpg
#   inflating: images/7760.jpg
#   inflating: images/14457.jpg
#   inflating: images/5925.jpg
#   inflating: images/18218.jpg
#   inflating: images/6805.jpg
#   inflating: images/24313.jpg
#   inflating: images/11892.jpg
#   inflating: images/15001.jpg
#   inflating: images/576.jpg
#   inflating: images/3224.jpg
#   inflating: images/28251.jpg
#   inflating: images/11015.jpg
#   inflating: images/11181.jpg
#   inflating: images/7520.jpg
#   inflating: images/19229.jpg
#   inflating: images/9124.jpg
#   inflating: images/11139.jpg
#   inflating: images/18585.jpg
#   inflating: images/10379.jpg
#   inflating: images/16849.jpg
#   inflating: images/8836.jpg
#   inflating: images/24967.jpg
#   inflating: images/12583.jpg
#   inflating: images/18365.jpg
#   inflating: images/10713.jpg
#   inflating: images/18325.jpg
#   inflating: images/9029.jpg
#   inflating: images/3698.jpg
#   inflating: images/130.jpg
#   inflating: images/3837.jpg
#   inflating: images/13026.jpg
#   inflating: images/3743.jpg
#   inflating: images/3600.jpg
#   inflating: images/14490.jpg
#   inflating: images/22871.jpg
#   inflating: images/27990.jpg
#   inflating: images/11639.jpg
#   inflating: images/13686.jpg
#   inflating: images/4002.jpg
#   inflating: images/26970.jpg
#   inflating: images/1922.jpg
#   inflating: images/15215.jpg
#   inflating: images/23983.jpg
#   inflating: images/19301.jpg
#   inflating: images/1612.jpg
#   inflating: images/23585.jpg
#   inflating: images/29795.jpg
#   inflating: images/20989.jpg
#   inflating: images/11555.jpg
#   inflating: images/20071.jpg
#   inflating: images/3209.jpg
#   inflating: images/18150.jpg
#   inflating: images/21943.jpg
#   inflating: images/14177.jpg
#   inflating: images/6450.jpg
#   inflating: images/14330.jpg
#   inflating: images/20643.jpg
#   inflating: images/2691.jpg
#   inflating: images/17394.jpg
#   inflating: images/22271.jpg
#   inflating: images/7984.jpg
#   inflating: images/29677.jpg
#   inflating: images/15292.jpg
#   inflating: images/2212.jpg
#   inflating: images/13258.jpg
#   inflating: images/19532.jpg
#   inflating: images/24495.jpg
#   inflating: images/26438.jpg
#   inflating: images/10182.jpg
#   inflating: images/6926.jpg
#   inflating: images/14965.jpg
#   inflating: images/26892.jpg
#   inflating: images/13034.jpg
#   inflating: images/8075.jpg
#   inflating: images/5975.jpg
#   inflating: images/12374.jpg
#   inflating: images/10901.jpg
#   inflating: images/28804.jpg
#   inflating: images/10309.jpg
#   inflating: images/14030.jpg
#   inflating: images/3044.jpg
#   inflating: images/19364.jpg
#   inflating: images/19265.jpg
#   inflating: images/24420.jpg
#   inflating: images/13639.jpg
#   inflating: images/24231.jpg
#   inflating: images/17715.jpg
#   inflating: images/28561.jpg
#   inflating: images/4659.jpg
#   inflating: images/17976.jpg
#   inflating: images/2019.jpg
#   inflating: images/10897.jpg
#   inflating: images/7630.jpg
#   inflating: images/5488.jpg
#   inflating: images/1803.jpg
#   inflating: images/27642.jpg
#   inflating: images/25484.jpg
#   inflating: images/12118.jpg
#   inflating: images/21738.jpg
#   inflating: images/4921.jpg
#   inflating: images/24605.jpg
#   inflating: images/25772.jpg
#   inflating: images/22319.jpg
#   inflating: images/18370.jpg
#   inflating: images/2805.jpg
#   inflating: images/13403.jpg
#   inflating: images/18483.jpg
#   inflating: images/21892.jpg
#   inflating: images/29971.jpg
#   inflating: images/15646.jpg
#   inflating: images/9459.jpg
#   inflating: images/29759.jpg
#   inflating: images/12752.jpg
#   inflating: images/6842.jpg
#   inflating: images/22699.jpg
#   inflating: images/16660.jpg
#   inflating: images/16285.jpg
#   inflating: images/15870.jpg
#   inflating: images/14523.jpg
#   inflating: images/21141.jpg
#   inflating: images/18592.jpg
#   inflating: images/16548.jpg
#   inflating: images/4253.jpg
#   inflating: images/7447.jpg
#   inflating: images/28261.jpg
#   inflating: images/23978.jpg
#   inflating: images/20891.jpg
#   inflating: images/27357.jpg
#   inflating: images/17337.jpg
#   inflating: images/19404.jpg
#   inflating: images/23051.jpg
#   inflating: images/23222.jpg
#   inflating: images/2727.jpg
#   inflating: images/2590.jpg
#   inflating: images/28073.jpg
#   inflating: images/18805.jpg
#   inflating: images/21821.jpg
#   inflating: images/8609.jpg
#   inflating: images/14322.jpg
#   inflating: images/19594.jpg
#   inflating: images/28633.jpg
#   inflating: images/25171.jpg
#   inflating: images/1166.jpg
#   inflating: images/928.jpg
#   inflating: images/6027.jpg
#   inflating: images/11014.jpg
#   inflating: images/7488.jpg
#   inflating: images/29788.jpg
#   inflating: images/12236.jpg
#   inflating: images/8934.jpg
#   inflating: images/18906.jpg
#   inflating: images/10025.jpg
#   inflating: images/5892.jpg
#   inflating: images/26971.jpg
#   inflating: images/24232.jpg
#   inflating: images/3231.jpg
#   inflating: images/25722.jpg
#   inflating: images/7058.jpg
#   inflating: images/22018.jpg
#   inflating: images/2961.jpg
#   inflating: images/11120.jpg
#   inflating: images/8320.jpg
#   inflating: images/13869.jpg
#   inflating: images/8092.jpg
#   inflating: images/23315.jpg
#   inflating: images/14390.jpg
#   inflating: images/8751.jpg
#   inflating: images/4752.jpg
#   inflating: images/21101.jpg
#   inflating: images/9911.jpg
#   inflating: images/10435.jpg
#   inflating: images/8680.jpg
#   inflating: images/1759.jpg
#   inflating: images/752.jpg
#   inflating: images/10006.jpg
#   inflating: images/26355.jpg
#   inflating: images/21920.jpg
#   inflating: images/14113.jpg
#   inflating: images/23677.jpg
#   inflating: images/18546.jpg
#   inflating: images/3312.jpg
#   inflating: images/24897.jpg
#   inflating: images/28304.jpg
#   inflating: images/12329.jpg
#   inflating: images/3096.jpg
#   inflating: images/19742.jpg
#   inflating: images/20661.jpg
#   inflating: images/16351.jpg
#   inflating: images/4732.jpg
#   inflating: images/19127.jpg
#   inflating: images/6202.jpg
#   inflating: images/3184.jpg
#   inflating: images/17878.jpg
#   inflating: images/8570.jpg
#   inflating: images/7535.jpg
#   inflating: images/25703.jpg
#   inflating: images/6867.jpg
#   inflating: images/25481.jpg
#   inflating: images/22523.jpg
#   inflating: images/27935.jpg
#   inflating: images/26173.jpg
#   inflating: images/27652.jpg
#   inflating: images/6206.jpg
#   inflating: images/15789.jpg
#   inflating: images/16971.jpg
#   inflating: images/11438.jpg
#   inflating: images/19228.jpg
#   inflating: images/10491.jpg
#   inflating: images/11604.jpg
#   inflating: images/28374.jpg
#   inflating: images/23007.jpg
#   inflating: images/6764.jpg
#   inflating: images/19167.jpg
#   inflating: images/19910.jpg
#   inflating: images/13912.jpg
#   inflating: images/4171.jpg
#   inflating: images/14282.jpg
#   inflating: images/9682.jpg
#   inflating: images/13778.jpg
#   inflating: images/19243.jpg
#   inflating: images/27518.jpg
#   inflating: images/6287.jpg
#   inflating: images/4830.jpg
#   inflating: images/22747.jpg
#   inflating: images/16919.jpg
#   inflating: images/15757.jpg
#   inflating: images/12787.jpg
#   inflating: images/28659.jpg
#   inflating: images/16561.jpg
#   inflating: images/2960.jpg
#   inflating: images/28179.jpg
#   inflating: images/5603.jpg
#   inflating: images/10216.jpg
#   inflating: images/2678.jpg
#   inflating: images/14985.jpg
#   inflating: images/13422.jpg
#   inflating: images/29186.jpg
#   inflating: images/7840.jpg
#   inflating: images/4082.jpg
#   inflating: images/15876.jpg
#   inflating: images/12592.jpg
#   inflating: images/2365.jpg
#   inflating: images/18065.jpg
#   inflating: images/9491.jpg
#   inflating: images/3320.jpg
#   inflating: images/4291.jpg
#   inflating: images/28557.jpg
#   inflating: images/24302.jpg
#   inflating: images/28604.jpg
#   inflating: images/9492.jpg
#   inflating: images/26050.jpg
#   inflating: images/1672.jpg
#   inflating: images/1975.jpg
#   inflating: images/21173.jpg
#   inflating: images/26299.jpg
#   inflating: images/17085.jpg
#   inflating: images/13638.jpg
#   inflating: images/21555.jpg
#   inflating: images/1165.jpg
#   inflating: images/27033.jpg
#   inflating: images/15626.jpg
#   inflating: images/10404.jpg
#   inflating: images/14375.jpg
#   inflating: images/11843.jpg
#   inflating: images/14235.jpg
#   inflating: images/7442.jpg
#   inflating: images/23415.jpg
#   inflating: images/16087.jpg
#   inflating: images/8104.jpg
#   inflating: images/12759.jpg
#   inflating: images/27618.jpg
#   inflating: images/18153.jpg
#   inflating: images/5699.jpg
#   inflating: images/9758.jpg
#   inflating: images/12264.jpg
#   inflating: images/14801.jpg
#   inflating: images/8170.jpg
#   inflating: images/24471.jpg
#   inflating: images/20807.jpg
#   inflating: images/24407.jpg
#   inflating: images/8041.jpg
#   inflating: images/23010.jpg
#   inflating: images/18778.jpg
#   inflating: images/21967.jpg
#   inflating: images/6758.jpg
#   inflating: images/29002.jpg
#   inflating: images/8876.jpg
#   inflating: images/7512.jpg
#   inflating: images/86.jpg
#   inflating: images/6808.jpg
#   inflating: images/10454.jpg
#   inflating: images/3068.jpg
#   inflating: images/23430.jpg
#   inflating: images/26428.jpg
#   inflating: images/10642.jpg
#   inflating: images/15041.jpg
#   inflating: images/5369.jpg
#   inflating: images/21049.jpg
#   inflating: images/15058.jpg
#   inflating: images/2930.jpg
#   inflating: images/5799.jpg
#   inflating: images/14576.jpg
#   inflating: images/22872.jpg
#   inflating: images/22436.jpg
#   inflating: images/26085.jpg
#   inflating: images/28176.jpg
#   inflating: images/19098.jpg
#   inflating: images/8767.jpg
#   inflating: images/10125.jpg
#   inflating: images/15365.jpg
#   inflating: images/4822.jpg
#   inflating: images/21896.jpg
#   inflating: images/6124.jpg
#   inflating: images/23801.jpg
#   inflating: images/12885.jpg
#   inflating: images/15289.jpg
#   inflating: images/22966.jpg
#   inflating: images/3821.jpg
#   inflating: images/29455.jpg
#   inflating: images/16273.jpg
#   inflating: images/4371.jpg
#   inflating: images/29696.jpg
#   inflating: images/19998.jpg
#   inflating: images/2769.jpg
#   inflating: images/29697.jpg
#   inflating: images/4315.jpg
#   inflating: images/9166.jpg
#   inflating: images/15638.jpg
#   inflating: images/5673.jpg
#   inflating: images/3091.jpg
#   inflating: images/19604.jpg
#   inflating: images/28051.jpg
#   inflating: images/4700.jpg
#   inflating: images/5230.jpg
#   inflating: images/5819.jpg
#   inflating: images/16916.jpg
#   inflating: images/7388.jpg
#   inflating: images/14498.jpg
#   inflating: images/3080.jpg
#   inflating: images/19595.jpg
#   inflating: images/29803.jpg
#   inflating: images/4529.jpg
#   inflating: images/10442.jpg
#   inflating: images/3244.jpg
#   inflating: images/17463.jpg
#   inflating: images/26726.jpg
#   inflating: images/7437.jpg
#   inflating: images/5376.jpg
#   inflating: images/29837.jpg
#   inflating: images/2698.jpg
#   inflating: images/7096.jpg
#   inflating: images/24043.jpg
#   inflating: images/21595.jpg
#   inflating: images/14894.jpg
#   inflating: images/12332.jpg
#   inflating: images/11223.jpg
#   inflating: images/14314.jpg
#   inflating: images/6443.jpg
#   inflating: images/23760.jpg
#   inflating: images/8904.jpg
#   inflating: images/1778.jpg
#   inflating: images/23330.jpg
#   inflating: images/16.jpg
#   inflating: images/24227.jpg
#   inflating: images/28069.jpg
#   inflating: images/16101.jpg
#   inflating: images/21648.jpg
#   inflating: images/24924.jpg
#   inflating: images/6897.jpg
#   inflating: images/19355.jpg
#   inflating: images/27296.jpg
#   inflating: images/28602.jpg
#   inflating: images/9705.jpg
#   inflating: images/25226.jpg
#   inflating: images/2300.jpg
#   inflating: images/24189.jpg
#   inflating: images/2197.jpg
#   inflating: images/25834.jpg
#   inflating: images/24532.jpg
#   inflating: images/18188.jpg
#   inflating: images/26156.jpg
#   inflating: images/21794.jpg
#   inflating: images/6991.jpg
#   inflating: images/15838.jpg
#   inflating: images/22771.jpg
#   inflating: images/5260.jpg
#   inflating: images/5719.jpg
#   inflating: images/24010.jpg
#   inflating: images/14382.jpg
#   inflating: images/28397.jpg
#   inflating: images/9923.jpg
#   inflating: images/5084.jpg
#   inflating: images/25490.jpg
#   inflating: images/3500.jpg
#   inflating: images/21823.jpg
#   inflating: images/21669.jpg
#   inflating: images/2175.jpg
#   inflating: images/63.jpg
#   inflating: images/10196.jpg
#   inflating: images/21442.jpg
#   inflating: images/7017.jpg
#   inflating: images/18550.jpg
#   inflating: images/22610.jpg
#   inflating: images/4790.jpg
#   inflating: images/9358.jpg
#   inflating: images/28238.jpg
#   inflating: images/12654.jpg
#   inflating: images/14557.jpg
#   inflating: images/9659.jpg
#   inflating: images/7267.jpg
#   inflating: images/7151.jpg
#   inflating: images/14814.jpg
#   inflating: images/10540.jpg
#   inflating: images/10191.jpg
#   inflating: images/10759.jpg
#   inflating: images/18098.jpg
#   inflating: images/27116.jpg
#   inflating: images/6024.jpg
#   inflating: images/20037.jpg
#   inflating: images/22306.jpg
#   inflating: images/27702.jpg
#   inflating: images/16249.jpg
#   inflating: images/16397.jpg
#   inflating: images/3833.jpg
#   inflating: images/19635.jpg
#   inflating: images/18561.jpg
#   inflating: images/17191.jpg
#   inflating: images/21300.jpg
#   inflating: images/10184.jpg
#   inflating: images/20915.jpg
#   inflating: images/11138.jpg
#   inflating: images/9323.jpg
#   inflating: images/8842.jpg
#   inflating: images/29601.jpg
#   inflating: images/7124.jpg
#   inflating: images/25039.jpg
#   inflating: images/8126.jpg
#   inflating: images/422.jpg
#   inflating: images/12081.jpg
#   inflating: images/2883.jpg
#   inflating: images/7886.jpg
#   inflating: images/26548.jpg
#   inflating: images/24178.jpg
#   inflating: images/4383.jpg
#   inflating: images/8711.jpg
#   inflating: images/21905.jpg
#   inflating: images/15737.jpg
#   inflating: images/12206.jpg
#   inflating: images/9475.jpg
#   inflating: images/22189.jpg
#   inflating: images/17246.jpg
#   inflating: images/21296.jpg
#   inflating: images/12465.jpg
#   inflating: images/355.jpg
#   inflating: images/9376.jpg
#   inflating: images/27847.jpg
#   inflating: images/24821.jpg
#   inflating: images/14812.jpg
#   inflating: images/16212.jpg
#   inflating: images/3116.jpg
#   inflating: images/223.jpg
#   inflating: images/19872.jpg
#   inflating: images/1572.jpg
#   inflating: images/13730.jpg
#   inflating: images/12829.jpg
#   inflating: images/19315.jpg
#   inflating: images/2848.jpg
#   inflating: images/8418.jpg
#   inflating: images/23504.jpg
#   inflating: images/14075.jpg
#   inflating: images/11047.jpg
#   inflating: images/12826.jpg
#   inflating: images/19304.jpg
#   inflating: images/2997.jpg
#   inflating: images/2915.jpg
#   inflating: images/3672.jpg
#   inflating: images/26037.jpg
#   inflating: images/4359.jpg
#   inflating: images/314.jpg
#   inflating: images/27438.jpg
#   inflating: images/8421.jpg
#   inflating: images/4437.jpg
#   inflating: images/11135.jpg
#   inflating: images/12708.jpg
#   inflating: images/27105.jpg
#   inflating: images/1401.jpg
#   inflating: images/17783.jpg
#   inflating: images/19801.jpg
#   inflating: images/29023.jpg
#   inflating: images/959.jpg
#   inflating: images/21055.jpg
#   inflating: images/10371.jpg
#   inflating: images/25347.jpg
#   inflating: images/3108.jpg
#   inflating: images/22215.jpg
#   inflating: images/9004.jpg
#   inflating: images/5521.jpg
#   inflating: images/21515.jpg
#   inflating: images/21393.jpg
#   inflating: images/29889.jpg
#   inflating: images/15606.jpg
#   inflating: images/28837.jpg
#   inflating: images/16441.jpg
#   inflating: images/21311.jpg
#   inflating: images/4275.jpg
#   inflating: images/15345.jpg
#   inflating: images/20936.jpg
#   inflating: images/22332.jpg
#   inflating: images/25552.jpg
#   inflating: images/22012.jpg
#   inflating: images/21592.jpg
#   inflating: images/12991.jpg
#   inflating: images/21541.jpg
#   inflating: images/21054.jpg
#   inflating: images/22393.jpg
#   inflating: images/1154.jpg
#   inflating: images/13519.jpg
#   inflating: images/11637.jpg
#   inflating: images/14561.jpg
#   inflating: images/24060.jpg
#   inflating: images/20875.jpg
#   inflating: images/2296.jpg
#   inflating: images/28472.jpg
#   inflating: images/13503.jpg
#   inflating: images/2453.jpg
#   inflating: images/25418.jpg
#   inflating: images/29293.jpg
#   inflating: images/21932.jpg
#   inflating: images/9395.jpg
#   inflating: images/9401.jpg
#   inflating: images/11973.jpg
#   inflating: images/19181.jpg
#   inflating: images/18067.jpg
#   inflating: images/29196.jpg
#   inflating: images/7070.jpg
#   inflating: images/10821.jpg
#   inflating: images/1997.jpg
#   inflating: images/17424.jpg
#   inflating: images/24816.jpg
#   inflating: images/15530.jpg
#   inflating: images/22516.jpg
#   inflating: images/3750.jpg
#   inflating: images/29273.jpg
#   inflating: images/6321.jpg
#   inflating: images/26965.jpg
#   inflating: images/4765.jpg
#   inflating: images/28707.jpg
#   inflating: images/6520.jpg
#   inflating: images/29515.jpg
#   inflating: images/24205.jpg
#   inflating: images/28355.jpg
#   inflating: images/26646.jpg
#   inflating: images/25810.jpg
#   inflating: images/26100.jpg
#   inflating: images/13323.jpg
#   inflating: images/4873.jpg
#   inflating: images/28970.jpg
#   inflating: images/17746.jpg
#   inflating: images/12550.jpg
#   inflating: images/804.jpg
#   inflating: images/16272.jpg
#   inflating: images/20595.jpg
#   inflating: images/23710.jpg
#   inflating: images/2388.jpg
#   inflating: images/1978.jpg
#   inflating: images/3791.jpg
#   inflating: images/20752.jpg
#   inflating: images/28774.jpg
#   inflating: images/417.jpg
#   inflating: images/25320.jpg
#   inflating: images/12895.jpg
#   inflating: images/22236.jpg
#   inflating: images/18832.jpg
#   inflating: images/10349.jpg
#   inflating: images/1676.jpg
#   inflating: images/5228.jpg
#   inflating: images/5755.jpg
#   inflating: images/2307.jpg
#   inflating: images/16791.jpg
#   inflating: images/9026.jpg
#   inflating: images/15598.jpg
#   inflating: images/22485.jpg
#   inflating: images/23835.jpg
#   inflating: images/24932.jpg
#   inflating: images/13395.jpg
#   inflating: images/13299.jpg
#   inflating: images/2760.jpg
#   inflating: images/18078.jpg
#   inflating: images/7861.jpg
#   inflating: images/18562.jpg
#   inflating: images/15204.jpg
#   inflating: images/21159.jpg
#   inflating: images/16862.jpg
#   inflating: images/17429.jpg
#   inflating: images/24150.jpg
#   inflating: images/7443.jpg
#   inflating: images/28398.jpg
#   inflating: images/24004.jpg
#   inflating: images/3736.jpg
#   inflating: images/27671.jpg
#   inflating: images/24392.jpg
#   inflating: images/23284.jpg
#   inflating: images/16291.jpg
#   inflating: images/17102.jpg
#   inflating: images/20375.jpg
#   inflating: images/16823.jpg
#   inflating: images/1636.jpg
#   inflating: images/8499.jpg
#   inflating: images/15718.jpg
#   inflating: images/29824.jpg
#   inflating: images/15229.jpg
#   inflating: images/9598.jpg
#   inflating: images/7723.jpg
#   inflating: images/29320.jpg
#   inflating: images/4479.jpg
#   inflating: images/26895.jpg
#   inflating: images/12425.jpg
#   inflating: images/6110.jpg
#   inflating: images/2355.jpg
#   inflating: images/13983.jpg
#   inflating: images/561.jpg
#   inflating: images/23433.jpg
#   inflating: images/7997.jpg
#   inflating: images/3556.jpg
#   inflating: images/25394.jpg
#   inflating: images/785.jpg
#   inflating: images/3372.jpg
#   inflating: images/29172.jpg
#   inflating: images/15366.jpg
#   inflating: images/16511.jpg
#   inflating: images/12974.jpg
#   inflating: images/25995.jpg
#   inflating: images/8672.jpg
#   inflating: images/27883.jpg
#   inflating: images/2231.jpg
#   inflating: images/27951.jpg
#   inflating: images/17268.jpg
#   inflating: images/14537.jpg
#   inflating: images/19925.jpg
#   inflating: images/13336.jpg
#   inflating: images/26174.jpg
#   inflating: images/26959.jpg
#   inflating: images/2608.jpg
#   inflating: images/19609.jpg
#   inflating: images/19286.jpg
#   inflating: images/3041.jpg
#   inflating: images/26652.jpg
#   inflating: images/23840.jpg
#   inflating: images/10779.jpg
#   inflating: images/20575.jpg
#   inflating: images/2575.jpg
#   inflating: images/7976.jpg
#   inflating: images/12181.jpg
#   inflating: images/20046.jpg
#   inflating: images/11242.jpg
#   inflating: images/6267.jpg
#   inflating: images/2694.jpg
#   inflating: images/2627.jpg
#   inflating: images/9053.jpg
#   inflating: images/4266.jpg
#   inflating: images/15081.jpg
#   inflating: images/16067.jpg
#   inflating: images/2118.jpg
#   inflating: images/25806.jpg
#   inflating: images/19732.jpg
#   inflating: images/3222.jpg
#   inflating: images/14949.jpg
#   inflating: images/16865.jpg
#   inflating: images/14265.jpg
#   inflating: images/22670.jpg
#   inflating: images/26914.jpg
#   inflating: images/357.jpg
#   inflating: images/17588.jpg
#   inflating: images/15097.jpg
#   inflating: images/21398.jpg
#   inflating: images/13311.jpg
#   inflating: images/21859.jpg
#   inflating: images/13866.jpg
#   inflating: images/870.jpg
#   inflating: images/14690.jpg
#   inflating: images/3647.jpg
#   inflating: images/22373.jpg
#   inflating: images/15449.jpg
#   inflating: images/12331.jpg
#   inflating: images/1590.jpg
#   inflating: images/23131.jpg
#   inflating: images/27682.jpg
#   inflating: images/13046.jpg
#   inflating: images/26063.jpg
#   inflating: images/19646.jpg
#   inflating: images/13060.jpg
#   inflating: images/10023.jpg
#   inflating: images/10978.jpg
#   inflating: images/674.jpg
#   inflating: images/18729.jpg
#   inflating: images/29991.jpg
#   inflating: images/21930.jpg
#   inflating: images/26229.jpg
#   inflating: images/19357.jpg
#   inflating: images/2500.jpg
#   inflating: images/12962.jpg
#   inflating: images/5890.jpg
#   inflating: images/14779.jpg
#   inflating: images/24633.jpg
#   inflating: images/3933.jpg
#   inflating: images/3756.jpg
#   inflating: images/11465.jpg
#   inflating: images/20305.jpg
#   inflating: images/1617.jpg
#   inflating: images/26158.jpg
#   inflating: images/8222.jpg
#   inflating: images/8285.jpg
#   inflating: images/369.jpg
#   inflating: images/26758.jpg
#   inflating: images/4152.jpg
#   inflating: images/21799.jpg
#   inflating: images/28042.jpg
#   inflating: images/10896.jpg
#   inflating: images/10235.jpg
#   inflating: images/20450.jpg
#   inflating: images/15396.jpg
#   inflating: images/15269.jpg
#   inflating: images/756.jpg
#   inflating: images/21729.jpg
#   inflating: images/14471.jpg
#   inflating: images/23313.jpg
#   inflating: images/6096.jpg
#   inflating: images/4492.jpg
#   inflating: images/16074.jpg
#   inflating: images/17554.jpg
#   inflating: images/9775.jpg
#   inflating: images/18444.jpg
#   inflating: images/1344.jpg
#   inflating: images/7136.jpg
#   inflating: images/28547.jpg
#   inflating: images/17104.jpg
#   inflating: images/9333.jpg
#   inflating: images/29537.jpg
#   inflating: images/24946.jpg
#   inflating: images/27904.jpg
#   inflating: images/767.jpg
#   inflating: images/15683.jpg
#   inflating: images/28305.jpg
#   inflating: images/29500.jpg
#   inflating: images/25451.jpg
#   inflating: images/17726.jpg
#   inflating: images/12979.jpg
#   inflating: images/2285.jpg
#   inflating: images/18841.jpg
#   inflating: images/27468.jpg
#   inflating: images/19851.jpg
#   inflating: images/5120.jpg
#   inflating: images/518.jpg
#   inflating: images/345.jpg
#   inflating: images/17402.jpg
#   inflating: images/29254.jpg
#   inflating: images/2101.jpg
#   inflating: images/2459.jpg
#   inflating: images/1618.jpg
#   inflating: images/19658.jpg
#   inflating: images/27541.jpg
#   inflating: images/16788.jpg
#   inflating: images/17082.jpg
#   inflating: images/4337.jpg
#   inflating: images/11282.jpg
#   inflating: images/23090.jpg
#   inflating: images/23449.jpg
#   inflating: images/6594.jpg
#   inflating: images/24006.jpg
#   inflating: images/15722.jpg
#   inflating: images/11427.jpg
#   inflating: images/19180.jpg
#   inflating: images/16762.jpg
#   inflating: images/8443.jpg
#   inflating: images/24869.jpg
#   inflating: images/4578.jpg
#   inflating: images/24200.jpg
#   inflating: images/6178.jpg
#   inflating: images/17280.jpg
#   inflating: images/9579.jpg
#   inflating: images/25960.jpg
#   inflating: images/8279.jpg
#   inflating: images/25169.jpg
#   inflating: images/14155.jpg
#   inflating: images/5851.jpg
#   inflating: images/27525.jpg
#   inflating: images/18.jpg
#   inflating: images/6410.jpg
#   inflating: images/4701.jpg
#   inflating: images/22940.jpg
#   inflating: images/10716.jpg
#   inflating: images/27784.jpg
#   inflating: images/4007.jpg
#   inflating: images/3838.jpg
#   inflating: images/18955.jpg
#   inflating: images/6239.jpg
#   inflating: images/28038.jpg
#   inflating: images/22939.jpg
#   inflating: images/18944.jpg
#   inflating: images/10326.jpg
#   inflating: images/13125.jpg
#   inflating: images/19270.jpg
#   inflating: images/26116.jpg
#   inflating: images/10985.jpg
#   inflating: images/18414.jpg
#   inflating: images/5713.jpg
#   inflating: images/29156.jpg
#   inflating: images/8946.jpg
#   inflating: images/17722.jpg
#   inflating: images/9437.jpg
#   inflating: images/5845.jpg
#   inflating: images/13124.jpg
#   inflating: images/13486.jpg
#   inflating: images/3607.jpg
#   inflating: images/8220.jpg
#   inflating: images/10114.jpg
#   inflating: images/10041.jpg
#   inflating: images/489.jpg
#   inflating: images/9306.jpg
#   inflating: images/1696.jpg
#   inflating: images/22554.jpg
#   inflating: images/10930.jpg
#   inflating: images/3809.jpg
#   inflating: images/22259.jpg
#   inflating: images/4711.jpg
#   inflating: images/1100.jpg
#   inflating: images/13533.jpg
#   inflating: images/17059.jpg
#   inflating: images/402.jpg
#   inflating: images/2113.jpg
#   inflating: images/9189.jpg
#   inflating: images/9517.jpg
#   inflating: images/28635.jpg
#   inflating: images/29526.jpg
#   inflating: images/3593.jpg
#   inflating: images/23434.jpg
#   inflating: images/1764.jpg
#   inflating: images/10820.jpg
#   inflating: images/21330.jpg
#   inflating: images/25406.jpg
#   inflating: images/13099.jpg
#   inflating: images/22582.jpg
#   inflating: images/6620.jpg
#   inflating: images/7965.jpg
#   inflating: images/19531.jpg
#   inflating: images/25822.jpg
#   inflating: images/15294.jpg
#   inflating: images/22879.jpg
#   inflating: images/7298.jpg
#   inflating: images/818.jpg
#   inflating: images/20394.jpg
#   inflating: images/3150.jpg
#   inflating: images/25151.jpg
#   inflating: images/12088.jpg
#   inflating: images/23071.jpg
#   inflating: images/1918.jpg
#   inflating: images/17586.jpg
#   inflating: images/10802.jpg
#   inflating: images/27421.jpg
#   inflating: images/9079.jpg
#   inflating: images/2851.jpg
#   inflating: images/2845.jpg
#   inflating: images/21243.jpg
#   inflating: images/18037.jpg
#   inflating: images/8356.jpg
#   inflating: images/1242.jpg
#   inflating: images/29507.jpg
#   inflating: images/25835.jpg
#   inflating: images/29467.jpg
#   inflating: images/18010.jpg
#   inflating: images/6327.jpg
#   inflating: images/19975.jpg
#   inflating: images/11922.jpg
#   inflating: images/9411.jpg
#   inflating: images/3772.jpg
#   inflating: images/28584.jpg
#   inflating: images/5695.jpg
#   inflating: images/3040.jpg
#   inflating: images/10519.jpg
#   inflating: images/8197.jpg
#   inflating: images/2362.jpg
#   inflating: images/21038.jpg
#   inflating: images/13183.jpg
#   inflating: images/23207.jpg
#   inflating: images/9810.jpg
#   inflating: images/3208.jpg
#   inflating: images/5115.jpg
#   inflating: images/7857.jpg
#   inflating: images/3081.jpg
#   inflating: images/23407.jpg
#   inflating: images/22842.jpg
#   inflating: images/18260.jpg
#   inflating: images/23477.jpg
#   inflating: images/20384.jpg
#   inflating: images/3535.jpg
#   inflating: images/3059.jpg
#   inflating: images/21365.jpg
#   inflating: images/765.jpg
#   inflating: images/19452.jpg
#   inflating: images/10710.jpg
#   inflating: images/23215.jpg
#   inflating: images/5736.jpg
#   inflating: images/21044.jpg
#   inflating: images/21546.jpg
#   inflating: images/24095.jpg
#   inflating: images/18907.jpg
#   inflating: images/15115.jpg
#   inflating: images/6707.jpg
#   inflating: images/26056.jpg
#   inflating: images/24303.jpg
#   inflating: images/11226.jpg
#   inflating: images/4980.jpg
#   inflating: images/13288.jpg
#   inflating: images/28938.jpg
#   inflating: images/10669.jpg
#   inflating: images/12240.jpg
#   inflating: images/26234.jpg
#   inflating: images/15241.jpg
#   inflating: images/17731.jpg
#   inflating: images/29615.jpg
#   inflating: images/2020.jpg
#   inflating: images/21524.jpg
#   inflating: images/20415.jpg
#   inflating: images/27014.jpg
#   inflating: images/19113.jpg
#   inflating: images/21539.jpg
#   inflating: images/7364.jpg
#   inflating: images/5825.jpg
#   inflating: images/23088.jpg
#   inflating: images/12463.jpg
#   inflating: images/3107.jpg
#   inflating: images/15329.jpg
#   inflating: images/25046.jpg
#   inflating: images/11573.jpg
#   inflating: images/4858.jpg
#   inflating: images/28350.jpg
#   inflating: images/25911.jpg
#   inflating: images/1860.jpg
#   inflating: images/8755.jpg
#   inflating: images/18524.jpg
#   inflating: images/20888.jpg
#   inflating: images/377.jpg
#   inflating: images/11538.jpg
#   inflating: images/20214.jpg
#   inflating: images/17621.jpg
#   inflating: images/13049.jpg
#   inflating: images/27625.jpg
#   inflating: images/29888.jpg
#   inflating: images/24487.jpg
#   inflating: images/9500.jpg
#   inflating: images/25312.jpg
#   inflating: images/13230.jpg
#   inflating: images/19486.jpg
#   inflating: images/13739.jpg
#   inflating: images/18210.jpg
#   inflating: images/10051.jpg
#   inflating: images/12410.jpg
#   inflating: images/20340.jpg
#   inflating: images/13103.jpg
#   inflating: images/12265.jpg
#   inflating: images/17943.jpg
#   inflating: images/28674.jpg
#   inflating: images/12361.jpg
#   inflating: images/12558.jpg
#   inflating: images/2427.jpg
#   inflating: images/17677.jpg
#   inflating: images/13962.jpg
#   inflating: images/29951.jpg
#   inflating: images/3608.jpg
#   inflating: images/29502.jpg
#   inflating: images/17803.jpg
#   inflating: images/14388.jpg
#   inflating: images/1887.jpg
#   inflating: images/15138.jpg
#   inflating: images/17780.jpg
#   inflating: images/12645.jpg
#   inflating: images/19344.jpg
#   inflating: images/17005.jpg
#   inflating: images/8295.jpg
#   inflating: images/18701.jpg
#   inflating: images/17764.jpg
#   inflating: images/15868.jpg
#   inflating: images/8804.jpg
#   inflating: images/8784.jpg
#   inflating: images/16997.jpg
#   inflating: images/23114.jpg
#   inflating: images/21713.jpg
#   inflating: images/13565.jpg
#   inflating: images/1173.jpg
#   inflating: images/26973.jpg
#   inflating: images/27261.jpg
#   inflating: images/27950.jpg
#   inflating: images/24421.jpg
#   inflating: images/17925.jpg
#   inflating: images/20645.jpg
#   inflating: images/17852.jpg
#   inflating: images/3290.jpg
#   inflating: images/18400.jpg
#   inflating: images/6324.jpg
#   inflating: images/2010.jpg
#   inflating: images/1753.jpg
#   inflating: images/25398.jpg
#   inflating: images/16616.jpg
#   inflating: images/27236.jpg
#   inflating: images/25875.jpg
#   inflating: images/4613.jpg
#   inflating: images/7246.jpg
#   inflating: images/14706.jpg
#   inflating: images/15670.jpg
#   inflating: images/2105.jpg
#   inflating: images/4191.jpg
#   inflating: images/26864.jpg
#   inflating: images/22412.jpg
#   inflating: images/18003.jpg
#   inflating: images/24399.jpg
#   inflating: images/9117.jpg
#   inflating: images/1127.jpg
#   inflating: images/8298.jpg
#   inflating: images/25719.jpg
#   inflating: images/28792.jpg
#   inflating: images/844.jpg
#   inflating: images/7919.jpg
#   inflating: images/15291.jpg
#   inflating: images/12692.jpg
#   inflating: images/10397.jpg
#   inflating: images/1718.jpg
#   inflating: images/17017.jpg
#   inflating: images/20903.jpg
#   inflating: images/23204.jpg
#   inflating: images/13513.jpg
#   inflating: images/28302.jpg
#   inflating: images/27056.jpg
#   inflating: images/19994.jpg
#   inflating: images/21085.jpg
#   inflating: images/27293.jpg
#   inflating: images/11830.jpg
#   inflating: images/29665.jpg
#   inflating: images/25047.jpg
#   inflating: images/3060.jpg
#   inflating: images/9681.jpg
#   inflating: images/9202.jpg
#   inflating: images/6849.jpg
#   inflating: images/22304.jpg
#   inflating: images/5954.jpg
#   inflating: images/28435.jpg
#   inflating: images/26497.jpg
#   inflating: images/6821.jpg
#   inflating: images/24174.jpg
#   inflating: images/7027.jpg
#   inflating: images/11157.jpg
#   inflating: images/14256.jpg
#   inflating: images/7853.jpg
#   inflating: images/15413.jpg
#   inflating: images/28097.jpg
#   inflating: images/359.jpg
#   inflating: images/14512.jpg
#   inflating: images/13849.jpg
#   inflating: images/2183.jpg
#   inflating: images/27994.jpg
#   inflating: images/25366.jpg
#   inflating: images/16659.jpg
#   inflating: images/14708.jpg
#   inflating: images/7498.jpg
#   inflating: images/16798.jpg
#   inflating: images/25749.jpg
#   inflating: images/4039.jpg
#   inflating: images/7278.jpg
#   inflating: images/5321.jpg
#   inflating: images/21609.jpg
#   inflating: images/13408.jpg
#   inflating: images/3601.jpg
#   inflating: images/13979.jpg
#   inflating: images/15180.jpg
#   inflating: images/4423.jpg
#   inflating: images/23678.jpg
#   inflating: images/13443.jpg
#   inflating: images/7790.jpg
#   inflating: images/25885.jpg
#   inflating: images/17200.jpg
#   inflating: images/23001.jpg
#   inflating: images/14993.jpg
#   inflating: images/12342.jpg
#   inflating: images/23363.jpg
#   inflating: images/1219.jpg
#   inflating: images/11451.jpg
#   inflating: images/9497.jpg
#   inflating: images/15666.jpg
#   inflating: images/77.jpg
#   inflating: images/12643.jpg
#   inflating: images/16763.jpg
#   inflating: images/2067.jpg
#   inflating: images/24974.jpg
#   inflating: images/4603.jpg
#   inflating: images/626.jpg
#   inflating: images/12794.jpg
#   inflating: images/19661.jpg
#   inflating: images/10559.jpg
#   inflating: images/729.jpg
#   inflating: images/14825.jpg
#   inflating: images/14130.jpg
#   inflating: images/13085.jpg
#   inflating: images/19490.jpg
#   inflating: images/9387.jpg
#   inflating: images/15116.jpg
#   inflating: images/16024.jpg
#   inflating: images/10475.jpg
#   inflating: images/21951.jpg
#   inflating: images/20977.jpg
#   inflating: images/3135.jpg
#   inflating: images/11212.jpg
#   inflating: images/28391.jpg
#   inflating: images/8284.jpg
#   inflating: images/1689.jpg
#   inflating: images/22374.jpg
#   inflating: images/12180.jpg
#   inflating: images/17966.jpg
#   inflating: images/20066.jpg
#   inflating: images/25231.jpg
#   inflating: images/29485.jpg
#   inflating: images/26451.jpg
#   inflating: images/20120.jpg
#   inflating: images/22206.jpg
#   inflating: images/16122.jpg
#   inflating: images/4044.jpg
#   inflating: images/24219.jpg
#   inflating: images/555.jpg
#   inflating: images/29427.jpg
#   inflating: images/26467.jpg
#   inflating: images/26352.jpg
#   inflating: images/14849.jpg
#   inflating: images/7594.jpg
#   inflating: images/371.jpg
#   inflating: images/19864.jpg
#   inflating: images/27906.jpg
#   inflating: images/27678.jpg
#   inflating: images/18022.jpg
#   inflating: images/2094.jpg
#   inflating: images/16682.jpg
#   inflating: images/12631.jpg
#   inflating: images/27655.jpg
#   inflating: images/5049.jpg
#   inflating: images/23198.jpg
#   inflating: images/2892.jpg
#   inflating: images/1504.jpg
#   inflating: images/24847.jpg
#   inflating: images/17263.jpg
#   inflating: images/20325.jpg
#   inflating: images/27242.jpg
#   inflating: images/28194.jpg
#   inflating: images/11999.jpg
#   inflating: images/29664.jpg
#   inflating: images/19032.jpg
#   inflating: images/19781.jpg
#   inflating: images/595.jpg
#   inflating: images/18012.jpg
#   inflating: images/6892.jpg
#   inflating: images/26125.jpg
#   inflating: images/458.jpg
#   inflating: images/13817.jpg
#   inflating: images/24809.jpg
#   inflating: images/4412.jpg
#   inflating: images/4445.jpg
#   inflating: images/27417.jpg
#   inflating: images/25348.jpg
#   inflating: images/3137.jpg
#   inflating: images/2754.jpg
#   inflating: images/14869.jpg
#   inflating: images/16129.jpg
# ...
#   inflating: celeba-caption/1345.txt
#   inflating: celeba-caption/28603.txt
#   inflating: celeba-caption/11291.txt
#   inflating: celeba-caption/29499.txt
#   inflating: celeba-caption/29234.txt
#   inflating: celeba-caption/3211.txt
#   inflating: celeba-caption/4244.txt
#   inflating: celeba-caption/8014.txt
#   inflating: celeba-caption/23304.txt
#   inflating: celeba-caption/11842.txt
#   inflating: celeba-caption/25608.txt
#   inflating: celeba-caption/24328.txt
#   inflating: celeba-caption/27267.txt
#   inflating: celeba-caption/18761.txt
#   inflating: celeba-caption/805.txt
#   inflating: celeba-caption/3681.txt
#   inflating: celeba-caption/20321.txt
#   inflating: celeba-caption/6987.txt
#   inflating: celeba-caption/22823.txt
#   inflating: celeba-caption/21877.txt
#   inflating: celeba-caption/15146.txt
#   inflating: celeba-caption/27827.txt
#   inflating: celeba-caption/1018.txt
#   inflating: celeba-caption/12420.txt
#   inflating: celeba-caption/16381.txt
#   inflating: celeba-caption/24233.txt
#   inflating: celeba-caption/12928.txt
#   inflating: celeba-caption/13851.txt
#   inflating: celeba-caption/26009.txt
#   inflating: celeba-caption/23061.txt
#   inflating: celeba-caption/563.txt
#   inflating: celeba-caption/27079.txt
#   inflating: celeba-caption/22752.txt
#   inflating: celeba-caption/25925.txt
#   inflating: celeba-caption/11772.txt
#   inflating: celeba-caption/3658.txt
#   inflating: celeba-caption/24137.txt
#   inflating: celeba-caption/1574.txt
#   inflating: celeba-caption/17682.txt
#   inflating: celeba-caption/27764.txt
#   inflating: celeba-caption/8336.txt
#   inflating: celeba-caption/17054.txt
#   inflating: celeba-caption/24969.txt
#   inflating: celeba-caption/25123.txt
#   inflating: celeba-caption/22554.txt
#   inflating: celeba-caption/26267.txt
#   inflating: celeba-caption/4961.txt
#   inflating: celeba-caption/28817.txt
#   inflating: celeba-caption/23489.txt
#   inflating: celeba-caption/15211.txt
#   inflating: celeba-caption/619.txt
#   inflating: celeba-caption/19948.txt
#   inflating: celeba-caption/15637.txt
#   inflating: celeba-caption/11698.txt
#   inflating: celeba-caption/2823.txt
#   inflating: celeba-caption/384.txt
#   inflating: celeba-caption/3351.txt
#   inflating: celeba-caption/23375.txt
#   inflating: celeba-caption/18159.txt
#   inflating: celeba-caption/5521.txt
#   inflating: celeba-caption/6759.txt
#   inflating: celeba-caption/25145.txt
#   inflating: celeba-caption/3350.txt
#   inflating: celeba-caption/6574.txt
#   inflating: celeba-caption/12285.txt
#   inflating: celeba-caption/14216.txt
#   inflating: celeba-caption/26636.txt
#   inflating: celeba-caption/11510.txt
#   inflating: celeba-caption/4606.txt
#   inflating: celeba-caption/22755.txt
#   inflating: celeba-caption/3640.txt
#   inflating: celeba-caption/11270.txt
#   inflating: celeba-caption/29459.txt
#   inflating: celeba-caption/8326.txt
#   inflating: celeba-caption/7296.txt
#   inflating: celeba-caption/18728.txt
#   inflating: celeba-caption/24472.txt
#   inflating: celeba-caption/17060.txt
#   inflating: celeba-caption/1546.txt
#   inflating: celeba-caption/718.txt
#   inflating: celeba-caption/7053.txt
#   inflating: celeba-caption/11985.txt
#   inflating: celeba-caption/26844.txt
#   inflating: celeba-caption/2840.txt
#   inflating: celeba-caption/24129.txt
#   inflating: celeba-caption/8654.txt
#   inflating: celeba-caption/8568.txt
#   inflating: celeba-caption/14206.txt
#   inflating: celeba-caption/12625.txt
#   inflating: celeba-caption/18895.txt
#   inflating: celeba-caption/21004.txt
#   inflating: celeba-caption/29332.txt
#   inflating: celeba-caption/6979.txt
#   inflating: celeba-caption/21395.txt
#   inflating: celeba-caption/6547.txt
#   inflating: celeba-caption/4920.txt
#   inflating: celeba-caption/24930.txt
#   inflating: celeba-caption/29076.txt
#   inflating: celeba-caption/4474.txt
#   inflating: celeba-caption/23031.txt
#   inflating: celeba-caption/21822.txt
#   inflating: celeba-caption/19669.txt
#   inflating: celeba-caption/14873.txt
#   inflating: celeba-caption/23410.txt
#   inflating: celeba-caption/24057.txt
#   inflating: celeba-caption/589.txt
#   inflating: celeba-caption/13407.txt
#   inflating: celeba-caption/5891.txt
#   inflating: celeba-caption/20486.txt
#   inflating: celeba-caption/11363.txt
#   inflating: celeba-caption/10033.txt
#   inflating: celeba-caption/1919.txt
#   inflating: celeba-caption/26379.txt
#   inflating: celeba-caption/7410.txt
#   inflating: celeba-caption/24532.txt
#   inflating: celeba-caption/3045.txt
#   inflating: celeba-caption/18650.txt
#   inflating: celeba-caption/15.txt
#   inflating: celeba-caption/6569.txt
#   inflating: celeba-caption/27526.txt
#   inflating: celeba-caption/5535.txt
#   inflating: celeba-caption/20247.txt
#   inflating: celeba-caption/2964.txt
#   inflating: celeba-caption/20781.txt
#   inflating: celeba-caption/15782.txt
#   inflating: celeba-caption/5505.txt
#   inflating: celeba-caption/13264.txt
#   inflating: celeba-caption/23957.txt
#   inflating: celeba-caption/17103.txt
#   inflating: celeba-caption/10639.txt
#   inflating: celeba-caption/17491.txt
#   inflating: celeba-caption/17123.txt
#   inflating: celeba-caption/5116.txt
#   inflating: celeba-caption/5586.txt
#   inflating: celeba-caption/24584.txt
#   inflating: celeba-caption/24741.txt
#   inflating: celeba-caption/23766.txt
#   inflating: celeba-caption/14366.txt
#   inflating: celeba-caption/13722.txt
#   inflating: celeba-caption/5618.txt
#   inflating: celeba-caption/2172.txt
#   inflating: celeba-caption/12028.txt
#   inflating: celeba-caption/7974.txt
#   inflating: celeba-caption/1705.txt
#   inflating: celeba-caption/3726.txt
#   inflating: celeba-caption/19462.txt
#   inflating: celeba-caption/7251.txt
#   inflating: celeba-caption/16775.txt
#   inflating: celeba-caption/11285.txt
#   inflating: celeba-caption/29728.txt
#   inflating: celeba-caption/18593.txt
#   inflating: celeba-caption/22461.txt
#   inflating: celeba-caption/21308.txt
#   inflating: celeba-caption/15608.txt
#   inflating: celeba-caption/28734.txt
#   inflating: celeba-caption/5120.txt
#   inflating: celeba-caption/12434.txt
#   inflating: celeba-caption/7338.txt
#   inflating: celeba-caption/5447.txt
#   inflating: celeba-caption/11520.txt
#   inflating: celeba-caption/27612.txt
#   inflating: celeba-caption/11225.txt
#   inflating: celeba-caption/22449.txt
#   inflating: celeba-caption/7206.txt
#   inflating: celeba-caption/25757.txt
#   inflating: celeba-caption/17132.txt
#   inflating: celeba-caption/29014.txt
#   inflating: celeba-caption/20963.txt
#   inflating: celeba-caption/28613.txt
#   inflating: celeba-caption/6491.txt
#   inflating: celeba-caption/17273.txt
#   inflating: celeba-caption/27933.txt
#   inflating: celeba-caption/9728.txt
#   inflating: celeba-caption/8430.txt
#   inflating: celeba-caption/18558.txt
#   inflating: celeba-caption/11961.txt
#   inflating: celeba-caption/6447.txt
#   inflating: celeba-caption/1169.txt
#   inflating: celeba-caption/15143.txt
#   inflating: celeba-caption/26250.txt
#   inflating: celeba-caption/20903.txt
#   inflating: celeba-caption/5458.txt
#   inflating: celeba-caption/7065.txt
#   inflating: celeba-caption/6917.txt
#   inflating: celeba-caption/29829.txt
#   inflating: celeba-caption/13474.txt
#   inflating: celeba-caption/20999.txt
#   inflating: celeba-caption/21992.txt
#   inflating: celeba-caption/12893.txt
#   inflating: celeba-caption/9491.txt
#   inflating: celeba-caption/5907.txt
#   inflating: celeba-caption/23388.txt
#   inflating: celeba-caption/10750.txt
#   inflating: celeba-caption/17651.txt
#   inflating: celeba-caption/19689.txt
#   inflating: celeba-caption/24501.txt
#   inflating: celeba-caption/4197.txt
#   inflating: celeba-caption/23603.txt
#   inflating: celeba-caption/23611.txt
#   inflating: celeba-caption/779.txt
#   inflating: celeba-caption/22846.txt
#   inflating: celeba-caption/23956.txt
#   inflating: celeba-caption/15876.txt
#   inflating: celeba-caption/15043.txt
#   inflating: celeba-caption/28030.txt
#   inflating: celeba-caption/29382.txt
#   inflating: celeba-caption/7477.txt
#   inflating: celeba-caption/5604.txt
#   inflating: celeba-caption/18606.txt
#   inflating: celeba-caption/22743.txt
#   inflating: celeba-caption/13933.txt
#   inflating: celeba-caption/24937.txt
#   inflating: celeba-caption/18622.txt
#   inflating: celeba-caption/5992.txt
#   inflating: celeba-caption/1508.txt
#   inflating: celeba-caption/15206.txt
#   inflating: celeba-caption/18802.txt
#   inflating: celeba-caption/5117.txt
#   inflating: celeba-caption/11311.txt
#   inflating: celeba-caption/6361.txt
#   inflating: celeba-caption/11789.txt
#   inflating: celeba-caption/3879.txt
#   inflating: celeba-caption/10489.txt
#   inflating: celeba-caption/28758.txt
#   inflating: celeba-caption/9695.txt
#   inflating: celeba-caption/10376.txt
#   inflating: celeba-caption/1016.txt
#   inflating: celeba-caption/7309.txt
#   inflating: celeba-caption/9962.txt
#   inflating: celeba-caption/13919.txt
#   inflating: celeba-caption/4390.txt
#   inflating: celeba-caption/14599.txt
#   inflating: celeba-caption/4040.txt
#   inflating: celeba-caption/17057.txt
#   inflating: celeba-caption/9967.txt
#   inflating: celeba-caption/21252.txt
#   inflating: celeba-caption/3288.txt
#   inflating: celeba-caption/11384.txt
#   inflating: celeba-caption/1135.txt
#   inflating: celeba-caption/24418.txt
#   inflating: celeba-caption/14796.txt
#   inflating: celeba-caption/20410.txt
#   inflating: celeba-caption/7030.txt
#   inflating: celeba-caption/13302.txt
#   inflating: celeba-caption/29876.txt
#   inflating: celeba-caption/5377.txt
#   inflating: celeba-caption/825.txt
#   inflating: celeba-caption/1671.txt
#   inflating: celeba-caption/10261.txt
#   inflating: celeba-caption/15609.txt
#   inflating: celeba-caption/10117.txt
#   inflating: celeba-caption/6305.txt
#   inflating: celeba-caption/27324.txt
#   inflating: celeba-caption/16948.txt
#   inflating: celeba-caption/29756.txt
#   inflating: celeba-caption/7184.txt
#   inflating: celeba-caption/5464.txt
#   inflating: celeba-caption/19959.txt
#   inflating: celeba-caption/11299.txt
#   inflating: celeba-caption/1460.txt
#   inflating: celeba-caption/6110.txt
#   inflating: celeba-caption/17334.txt
#   inflating: celeba-caption/15712.txt
#   inflating: celeba-caption/16486.txt
#   inflating: celeba-caption/7768.txt
#   inflating: celeba-caption/2956.txt
#   inflating: celeba-caption/29818.txt
#   inflating: celeba-caption/21211.txt
#   inflating: celeba-caption/317.txt
#   inflating: celeba-caption/12099.txt
#   inflating: celeba-caption/2235.txt
#   inflating: celeba-caption/19849.txt
#   inflating: celeba-caption/19393.txt
#   inflating: celeba-caption/595.txt
#   inflating: celeba-caption/26285.txt
#   inflating: celeba-caption/8696.txt
#   inflating: celeba-caption/5356.txt
#   inflating: celeba-caption/24784.txt
#   inflating: celeba-caption/21566.txt
#   inflating: celeba-caption/26539.txt
#   inflating: celeba-caption/8827.txt
#   inflating: celeba-caption/18769.txt
#   inflating: celeba-caption/26942.txt
#   inflating: celeba-caption/1117.txt
#   inflating: celeba-caption/17689.txt
#   inflating: celeba-caption/12517.txt
#   inflating: celeba-caption/6339.txt
#   inflating: celeba-caption/12204.txt
#   inflating: celeba-caption/6997.txt
#   inflating: celeba-caption/11768.txt
#   inflating: celeba-caption/18627.txt
#   inflating: celeba-caption/19955.txt
#   inflating: celeba-caption/19729.txt
#   inflating: celeba-caption/13107.txt
#   inflating: celeba-caption/12809.txt
#   inflating: celeba-caption/13392.txt
#   inflating: celeba-caption/6063.txt
#   inflating: celeba-caption/21305.txt
#   inflating: celeba-caption/9994.txt
#   inflating: celeba-caption/28784.txt
#   inflating: celeba-caption/6894.txt
#   inflating: celeba-caption/8463.txt
#   inflating: celeba-caption/9039.txt
#   inflating: celeba-caption/12370.txt
#   inflating: celeba-caption/27941.txt
#   inflating: celeba-caption/7475.txt
#   inflating: celeba-caption/18813.txt
#   inflating: celeba-caption/19282.txt
#   inflating: celeba-caption/6896.txt
#   inflating: celeba-caption/16222.txt
#   inflating: celeba-caption/18590.txt
#   inflating: celeba-caption/28621.txt
#   inflating: celeba-caption/12078.txt
#   inflating: celeba-caption/20715.txt
#   inflating: celeba-caption/16848.txt
#   inflating: celeba-caption/15478.txt
#   inflating: celeba-caption/16319.txt
#   inflating: celeba-caption/9686.txt
#   inflating: celeba-caption/21937.txt
#   inflating: celeba-caption/18310.txt
#   inflating: celeba-caption/27635.txt
#   inflating: celeba-caption/23023.txt
#   inflating: celeba-caption/9120.txt
#   inflating: celeba-caption/25246.txt
#   inflating: celeba-caption/5923.txt
#   inflating: celeba-caption/9055.txt
#   inflating: celeba-caption/20608.txt
#   inflating: celeba-caption/28311.txt
#   inflating: celeba-caption/10516.txt
#   inflating: celeba-caption/26957.txt
#   inflating: celeba-caption/29481.txt
#   inflating: celeba-caption/7046.txt
#   inflating: celeba-caption/26720.txt
#   inflating: celeba-caption/12391.txt
#   inflating: celeba-caption/20433.txt
#   inflating: celeba-caption/29085.txt
#   inflating: celeba-caption/5345.txt
#   inflating: celeba-caption/5731.txt
#   inflating: celeba-caption/903.txt
#   inflating: celeba-caption/17031.txt
#   inflating: celeba-caption/29765.txt
#   inflating: celeba-caption/6308.txt
#   inflating: celeba-caption/7238.txt
#   inflating: celeba-caption/16312.txt
#   inflating: celeba-caption/13390.txt
#   inflating: celeba-caption/23952.txt
#   inflating: celeba-caption/29359.txt
#   inflating: celeba-caption/18822.txt
#   inflating: celeba-caption/22079.txt
#   inflating: celeba-caption/10083.txt
#   inflating: celeba-caption/18497.txt
#   inflating: celeba-caption/5744.txt
#   inflating: celeba-caption/7265.txt
#   inflating: celeba-caption/14921.txt
#   inflating: celeba-caption/28618.txt
#   inflating: celeba-caption/3331.txt
#   inflating: celeba-caption/5663.txt
#   inflating: celeba-caption/22729.txt
#   inflating: celeba-caption/2432.txt
#   inflating: celeba-caption/14852.txt
#   inflating: celeba-caption/15420.txt
#   inflating: celeba-caption/13348.txt
#   inflating: celeba-caption/6449.txt
#   inflating: celeba-caption/1564.txt
#   inflating: celeba-caption/28852.txt
#   inflating: celeba-caption/16463.txt
#   inflating: celeba-caption/8536.txt
#   inflating: celeba-caption/14870.txt
#   inflating: celeba-caption/16246.txt
#   inflating: celeba-caption/10158.txt
#   inflating: celeba-caption/23133.txt
#   inflating: celeba-caption/7703.txt
#   inflating: celeba-caption/3166.txt
#   inflating: celeba-caption/8061.txt
#   inflating: celeba-caption/27570.txt
#   inflating: celeba-caption/20910.txt
#   inflating: celeba-caption/311.txt
#   inflating: celeba-caption/16181.txt
#   inflating: celeba-caption/23042.txt
#   inflating: celeba-caption/12636.txt
#   inflating: celeba-caption/27527.txt
#   inflating: celeba-caption/20900.txt
#   inflating: celeba-caption/25728.txt
#   inflating: celeba-caption/21889.txt
#   inflating: celeba-caption/1422.txt
#   inflating: celeba-caption/17412.txt
#   inflating: celeba-caption/29047.txt
#   inflating: celeba-caption/10834.txt
#   inflating: celeba-caption/22613.txt
#   inflating: celeba-caption/12094.txt
#   inflating: celeba-caption/11879.txt
#   inflating: celeba-caption/6042.txt
# Downloading...
# From: https://drive.google.com/uc?id=1GdeTdBpi_IV7AuBpJAhLElqjswRmOy-7
# To: /kaggle/working/data/CelebAMask-HQ/train.pickle
# 100%|█████████████████████████████████████████| 355k/355k [00:00<00:00, 107MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1JNxgdvPMI_HHUq2-JUuJp8L7cD-74OAf
# To: /kaggle/working/data/CelebAMask-HQ/test.pickle
# 100%|██████████████████████████████████████| 82.6k/82.6k [00:00<00:00, 78.5MB/s]
# /kaggle/working

# %% [markdown]
# # Import thư viện cần thiết

# %%
# !pip install einops
# !pip install diffusers
# !pip install accelerate
# Out:
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.7.0
# Collecting diffusers
#   Downloading diffusers-0.27.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.10/site-packages (from diffusers) (6.11.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from diffusers) (3.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.2 in /opt/conda/lib/python3.10/site-packages (from diffusers) (0.21.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from diffusers) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from diffusers) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from diffusers) (0.4.2)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from diffusers) (9.5.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.2->diffusers) (2024.3.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.2->diffusers) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.2->diffusers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.2->diffusers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.2->diffusers) (21.3)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata->diffusers) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers) (2024.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.20.2->diffusers) (3.1.1)
# Downloading diffusers-0.27.2-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 46.1 MB/s eta 0:00:0000:01
# Installing collected packages: diffusers
# Successfully installed diffusers-0.27.2
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.28.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (2.1.2)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.21.4)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.1.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2024.3.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
import torch
import pickle
import torchvision
import numpy as np
import torch.nn as nn
from torch.optim import Adam

from einops import einsum
from blocks import get_time_embedding
from blocks import DownBlock, MidBlock, UpBlockUnet

from diffusers import VQModel
from transformers import CLIPTokenizer, CLIPTextModel

import os
import glob
import random
from PIL import Image
from tqdm.notebook import tqdm
from torchvision.utils import make_grid
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset

# %% [markdown]
# # Dataset

# %%
def load_latents(latent_path):
    r"""
    Simple utility to save latents to speed up ldm training
    :param latent_path:
    :return:
    """
    latent_maps = {}
    for fname in glob.glob(os.path.join(latent_path, '*.pkl')):
        s = pickle.load(open(fname, 'rb'))
        for k, v in s.items():
            latent_maps[k] = v[0]
    return latent_maps

# %%
class CelebDataset(Dataset):
    r"""
    Celeb dataset will by default centre crop and resize the images.
    This can be replaced by any other dataset. As long as all the images
    are under one directory.
    """

    def __init__(self, split, im_path, im_size=256, im_channels=3, im_ext='jpg',
                 use_latents=False, latent_path=None, condition_config=None):
        self.split = split
        if self.split != 'all':
          self.split_filter = pickle.load(open(f'/kaggle/working/data/CelebAMask-HQ/{self.split}.pickle', 'rb'))

        self.im_size = im_size
        self.im_channels = im_channels
        self.im_ext = im_ext
        self.im_path = im_path
        self.latent_maps = None
        self.use_latents = False

        self.condition_types = [] if condition_config is None else condition_config['condition_types']
        self.images, self.texts = self.load_images(im_path)

        # Whether to load images or to load latents
        if use_latents and latent_path is not None:
            latent_maps = load_latents(latent_path)
            if len(latent_maps) >= len(self.images):
                self.use_latents = True
                self.latent_maps = latent_maps
                print('Found {} latents'.format(len(self.latent_maps)))
            else:
                print('Latents not found')

    def load_images(self, im_path):
        r"""
        Gets all images from the path specified
        and stacks them all up
        """
        assert os.path.exists(im_path), "images path {} does not exist".format(im_path)
        ims = []
        fnames = glob.glob(os.path.join(im_path, 'CelebA-HQ-img/*.{}'.format('png')))
        fnames += glob.glob(os.path.join(im_path, 'CelebA-HQ-img/*.{}'.format('jpg')))
        fnames += glob.glob(os.path.join(im_path, 'CelebA-HQ-img/*.{}'.format('jpeg')))
        texts = []

        for fname in tqdm(fnames):
            im_name = os.path.split(fname)[1].split('.')[0]

            if self.split != 'all':
              if im_name not in self.split_filter:
                continue

            ims.append(fname)

            if 'text' in self.condition_types:
                captions_im = []
                with open(os.path.join(im_path, 'celeba-caption/{}.txt'.format(im_name))) as f:
                    for line in f.readlines():
                        captions_im.append(line.strip())
                texts.append(captions_im)

        if 'text' in self.condition_types:
            assert len(texts) == len(ims), "Condition Type Text but could not find captions for all images"

        print('Found {} images'.format(len(ims)))
        print('Found {} captions'.format(len(texts)))

        return ims, texts

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        ######## Set Conditioning Info ########
        cond_inputs = {}
        if 'text' in self.condition_types:
            cond_inputs['text'] = random.sample(self.texts[index], k=1)[0]
        #######################################

        if self.use_latents:
            latent = self.latent_maps[self.images[index]]
            if len(self.condition_types) == 0:
                return latent
            else:
                return latent, cond_inputs
        else:
            im = Image.open(self.images[index])
            im_tensor = torchvision.transforms.Compose([
                torchvision.transforms.Resize(self.im_size),
                torchvision.transforms.CenterCrop(self.im_size),
                torchvision.transforms.ToTensor(),
            ])(im)
            im.close()

            # Convert input to -1 to 1 range.
            im_tensor = (2 * im_tensor) - 1
            if len(self.condition_types) == 0:
                return im_tensor
            else:
                return im_tensor, cond_inputs

# %% [markdown]
# # Xây dựng Noise Scheduler

# %%
class LinearNoiseScheduler:
    """
    Linear noise scheduler được sử dụng trong DDPM
    """

    def __init__(self, num_timesteps, beta_start, beta_end):
        self.num_timesteps = num_timesteps
        self.beta_start = beta_start
        self.beta_end = beta_end

        # Mimicking how compvis repo creates schedule
        # Test later
        self.betas = (
                torch.linspace(beta_start ** 0.5, beta_end ** 0.5, num_timesteps) ** 2
        )


        self.alphas = 1. - self.betas
        self.alpha_cum_prod = torch.cumprod(self.alphas, dim=0)
        self.sqrt_alpha_cum_prod = torch.sqrt(self.alpha_cum_prod)
        self.sqrt_one_minus_alpha_cum_prod = torch.sqrt(1 - self.alpha_cum_prod)

    def add_noise(self, original, noise, t):
        """
        Hàm forward cho quá trình diffusion
        :param original: Image on which noise is to be applied
        :param noise: Random Noise Tensor (from normal dist)
        :param t: timestep of the forward process of shape -> (B,)
        :return:
        """
        original_shape = original.shape
        batch_size = original_shape[0]

        sqrt_alpha_cum_prod = self.sqrt_alpha_cum_prod.to(original.device)[t].reshape(batch_size)
        sqrt_one_minus_alpha_cum_prod = self.sqrt_one_minus_alpha_cum_prod.to(original.device)[t].reshape(batch_size)

        # Reshape till (B,) becomes (B,1,1,1) if image is (B,C,H,W)
        for _ in range(len(original_shape) - 1):
            sqrt_alpha_cum_prod = sqrt_alpha_cum_prod.unsqueeze(-1)
        for _ in range(len(original_shape) - 1):
            sqrt_one_minus_alpha_cum_prod = sqrt_one_minus_alpha_cum_prod.unsqueeze(-1)

        # Apply and Return Forward process equation
        return (sqrt_alpha_cum_prod.to(original.device) * original
                + sqrt_one_minus_alpha_cum_prod.to(original.device) * noise)

    def sample_prev_timestep(self, xt, noise_pred, t):
        r"""
            Use the noise prediction by model to get
            xt-1 using xt and the nosie predicted
        :param xt: current timestep sample
        :param noise_pred: model noise prediction
        :param t: current timestep we are at
        :return:
        """
        x0 = ((xt - (self.sqrt_one_minus_alpha_cum_prod.to(xt.device)[t] * noise_pred)) /
              torch.sqrt(self.alpha_cum_prod.to(xt.device)[t]))
        x0 = torch.clamp(x0, -1., 1.)

        mean = xt - ((self.betas.to(xt.device)[t]) * noise_pred) / (self.sqrt_one_minus_alpha_cum_prod.to(xt.device)[t])
        mean = mean / torch.sqrt(self.alphas.to(xt.device)[t])

        if t == 0:
            return mean, x0
        else:
            variance = (1 - self.alpha_cum_prod.to(xt.device)[t - 1]) / (1.0 - self.alpha_cum_prod.to(xt.device)[t])
            variance = variance * self.betas.to(xt.device)[t]
            sigma = variance ** 0.5
            z = torch.randn(xt.shape).to(xt.device)
            return mean + sigma * z, x0

# %% [markdown]
# # Mô hình UNet

# %%
class Unet(nn.Module):
    r"""
    Unet model comprising
    Down blocks, Midblocks and Uplocks
    """

    def __init__(self, im_channels, model_config):
        super().__init__()
        self.down_channels = model_config['down_channels']
        self.mid_channels = model_config['mid_channels']
        self.t_emb_dim = model_config['time_emb_dim']
        self.down_sample = model_config['down_sample']
        self.num_down_layers = model_config['num_down_layers']
        self.num_mid_layers = model_config['num_mid_layers']
        self.num_up_layers = model_config['num_up_layers']
        self.attns = model_config['attn_down']
        self.norm_channels = model_config['norm_channels']
        self.num_heads = model_config['num_heads']
        self.conv_out_channels = model_config['conv_out_channels']

        # Validating Unet Model configurations
        assert self.mid_channels[0] == self.down_channels[-1]
        assert self.mid_channels[-1] == self.down_channels[-2]
        assert len(self.down_sample) == len(self.down_channels) - 1
        assert len(self.attns) == len(self.down_channels) - 1

        ######## Class, Mask and Text Conditioning Config #####
        self.condition_config = model_config['condition_config']
        self.text_cond = True
        self.text_embed_dim = self.condition_config['text_condition_config']['text_embed_dim']
        self.cond = self.text_cond
        ###################################
        self.conv_in = nn.Conv2d(im_channels, self.down_channels[0], kernel_size=3, padding=1)

        # Initial projection from sinusoidal time embedding
        self.t_proj = nn.Sequential(
            nn.Linear(self.t_emb_dim, self.t_emb_dim),
            nn.SiLU(),
            nn.Linear(self.t_emb_dim, self.t_emb_dim)
        )

        self.up_sample = list(reversed(self.down_sample))
        self.downs = nn.ModuleList([])

        # Build the Downblocks
        for i in range(len(self.down_channels) - 1):
            # Cross Attention and Context Dim only needed if text condition is present
            self.downs.append(DownBlock(self.down_channels[i], self.down_channels[i + 1], self.t_emb_dim,
                                        down_sample=self.down_sample[i],
                                        num_heads=self.num_heads,
                                        num_layers=self.num_down_layers,
                                        attn=self.attns[i], norm_channels=self.norm_channels,
                                        cross_attn=self.text_cond,
                                        context_dim=self.text_embed_dim))

        self.mids = nn.ModuleList([])
        # Build the Midblocks
        for i in range(len(self.mid_channels) - 1):
            self.mids.append(MidBlock(self.mid_channels[i], self.mid_channels[i + 1], self.t_emb_dim,
                                      num_heads=self.num_heads,
                                      num_layers=self.num_mid_layers,
                                      norm_channels=self.norm_channels,
                                      cross_attn=self.text_cond,
                                      context_dim=self.text_embed_dim))

        self.ups = nn.ModuleList([])
        # Build the Upblocks
        for i in reversed(range(len(self.down_channels) - 1)):
            self.ups.append(
                UpBlockUnet(self.down_channels[i] * 2, self.down_channels[i - 1] if i != 0 else self.conv_out_channels,
                            self.t_emb_dim, up_sample=self.down_sample[i],
                            num_heads=self.num_heads,
                            num_layers=self.num_up_layers,
                            norm_channels=self.norm_channels,
                            cross_attn=self.text_cond,
                            context_dim=self.text_embed_dim))

        self.norm_out = nn.GroupNorm(self.norm_channels, self.conv_out_channels)
        self.conv_out = nn.Conv2d(self.conv_out_channels, im_channels, kernel_size=3, padding=1)

    def forward(self, x, t, cond_input=None):
        # Shapes assuming downblocks are [C1, C2, C3, C4]
        # Shapes assuming midblocks are [C4, C4, C3]

        # B x C x H x W -> # B x C1 x H x W
        out = self.conv_in(x)

        # t_emb -> B x t_emb_dim
        t_emb = get_time_embedding(torch.as_tensor(t).long(), self.t_emb_dim)
        t_emb = self.t_proj(t_emb)

        context_hidden_states = None
        context_hidden_states = cond_input['text']
        down_outs = []

        for idx, down in enumerate(self.downs):
            down_outs.append(out)
            out = down(out, t_emb, context_hidden_states)
        # down_outs  [B x C1 x H x W, B x C2 x H/2 x W/2, B x C3 x H/4 x W/4]
        # out B x C4 x H/4 x W/4

        for mid in self.mids:
            out = mid(out, t_emb, context_hidden_states)
        # out B x C3 x H/4 x W/4

        for up in self.ups:
            down_out = down_outs.pop()
            out = up(out, down_out, t_emb, context_hidden_states)
            # out [B x C2 x H/4 x W/4, B x C1 x H/2 x W/2, B x 16 x H x W]
        out = self.norm_out(out)
        out = nn.SiLU()(out)
        out = self.conv_out(out)
        # out B x C x H x W
        return out

# %% [markdown]
# # Model Config

# %%
config = {
    "dataset_params": {
        "im_path": "data/CelebAMask-HQ",
        "im_channels": 3,
        "im_size": 256,
        "name": "celebhq"
    },
    "diffusion_params": {
        "num_timesteps": 1000,
        "beta_start": 0.00085,
        "beta_end": 0.012
    },
    "ldm_params": {
        "down_channels": [128, 256, 384, 512],
        "mid_channels": [512, 384],
        "down_sample": [True, True, True],
        "attn_down": [True, True, True],
        "time_emb_dim": 512,
        "norm_channels": 32,
        "num_heads": 16,
        "conv_out_channels": 128,
        "num_down_layers": 2,
        "num_mid_layers": 2,
        "num_up_layers": 2,
        "condition_config": {
            "condition_types": ["text"],
            "text_condition_config": {
                "text_embed_model": "clip",
                "train_text_embed_model": False,
                "text_embed_dim": 512,
                "cond_drop_prob": 0.1
            }
        }
    },
    "train_params": {
        "seed": 1111,
        "task_name": "celebhq",
        "ldm_batch_size": 1,
        "ldm_epochs": 30,
        "num_samples": 1,
        "num_grid_rows": 1,
        "ldm_lr": 0.000005,
        "save_latents": True,
        "vqvae_latent_dir_name": 'vqvae_latents',
        "cf_guidance_scale": 1.0,
        "ldm_ckpt_name": "ddpm_ckpt_text_cond_clip.pth",
    }
}

# %%
def get_text_representation(text, text_tokenizer, text_model, device,
                            truncation=True,
                            padding='max_length',
                            max_length=77):
    token_output = text_tokenizer(text,
                                  truncation=truncation,
                                  padding=padding,
                                  return_attention_mask=True,
                                  max_length=max_length)
    indexed_tokens = token_output['input_ids']
    att_masks = token_output['attention_mask']
    tokens_tensor = torch.tensor(indexed_tokens).to(device)
    mask_tensor = torch.tensor(att_masks).to(device)
    text_embed = text_model(tokens_tensor, attention_mask=mask_tensor).last_hidden_state
    return text_embed

# %%
def drop_text_condition(text_embed, im, empty_text_embed, text_drop_prob):
    if text_drop_prob > 0:
        text_drop_mask = torch.zeros((im.shape[0]), device=im.device).float().uniform_(0,
                                                                                       1) < text_drop_prob
        assert empty_text_embed is not None, ("Text Conditioning required as well as"
                                        " text dropping but empty text representation not created")
        text_embed[text_drop_mask, :, :] = empty_text_embed[0]
    return text_embed

# %% [markdown]
# # Sample

# %%
diffusion_config = config['diffusion_params']
dataset_config = config['dataset_params']
diffusion_model_config = config['ldm_params']
train_config = config['train_params']
latents_channel = 3
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Create the noise scheduler
scheduler = LinearNoiseScheduler(num_timesteps=diffusion_config['num_timesteps'],
                                  beta_start=diffusion_config['beta_start'],
                                  beta_end=diffusion_config['beta_end'])

# Instantiate Condition related components
text_tokenizer = None
text_model = None
empty_text_embed = None
condition_config = diffusion_model_config['condition_config']
condition_types = condition_config['condition_types']

with torch.no_grad():
    # Load tokenizer and text model based on config
    text_tokenizer = CLIPTokenizer.from_pretrained('openai/clip-vit-base-patch16')
    text_model = CLIPTextModel.from_pretrained('openai/clip-vit-base-patch16').to(device)
    text_model.eval()

    empty_text_embed = get_text_representation([''], text_tokenizer, text_model, device)

im_dataset = CelebDataset(split='train',
                          im_path=dataset_config['im_path'],
                          im_size=dataset_config['im_size'],
                          im_channels=dataset_config['im_channels'],
                          use_latents=True,
                          latent_path=os.path.join(train_config['task_name'],
                                                   train_config['vqvae_latent_dir_name']),
                          condition_config=condition_config)

filters = list(range(0, len(im_dataset), 10))
im_dataset = torch.utils.data.Subset(im_dataset, filters)

data_loader = DataLoader(im_dataset,
                         batch_size=train_config['ldm_batch_size'],
                         shuffle=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.10k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/599M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# 100%|██████████| 30000/30000 [00:10<00:00, 2934.15it/s]
# Found 24000 images
# Found 24000 captions
# Found 30000 latents

# %%
model = Unet(im_channels=latents_channel,
             model_config=diffusion_model_config).to(device)
model.eval()
if os.path.exists(os.path.join(train_config['task_name'],
                               train_config['ldm_ckpt_name'])):
    print('Loaded unet checkpoint')
    model.load_state_dict(torch.load(os.path.join(train_config['task_name'],
                                                  train_config['ldm_ckpt_name']),
                                     map_location=device))
else:
    raise Exception('Model checkpoint {} not found'.format(os.path.join(train_config['task_name'],
                                                          train_config['ldm_ckpt_name'])))
    
vae = VQModel.from_pretrained("CompVis/ldm-celebahq-256", subfolder="vqvae")
vae.eval()
vae = vae.to(device)
# Out:
# Loaded unet checkpoint
# vqvae/config.json:   0%|          | 0.00/486 [00:00<?, ?B/s]
# vqvae/diffusion_pytorch_model.bin:   0%|          | 0.00/221M [00:00<?, ?B/s]

# %%
img_list = []
text_list = []

for data in tqdm(data_loader):
    cond_input = None
    if condition_config is not None:
        im, cond_input = data
    else:
        im = data
    
    text_list.append(cond_input['text'])
    
    with torch.no_grad():
        xt = torch.randn((train_config['ldm_batch_size'], latents_channel, 64, 64)).to(device)
        empty_prompt = ['']
        text_prompt_embed = get_text_representation(cond_input['text'],
                                                    text_tokenizer,
                                                    text_model,
                                                    device)
        
        # Can replace empty prompt with negative prompt
        empty_text_embed = get_text_representation(empty_prompt, text_tokenizer, text_model, device)
        assert empty_text_embed.shape == text_prompt_embed.shape

        uncond_input = {
            'text': empty_text_embed
        }
        cond_input = {
            'text': text_prompt_embed
        }
        ###############################################

        # By default classifier free guidance is disabled
        # Change value in config or change default value here to enable it
        cf_guidance_scale = train_config['cf_guidance_scale']

        ims = None
        ################# Sampling Loop ########################
        for i in tqdm(reversed(range(diffusion_config['num_timesteps']))):
            # Get prediction of noise
            t = (torch.ones((xt.shape[0],)) * i).long().to(device)
            noise_pred_cond = model(xt, t, cond_input)

            if cf_guidance_scale > 1:
                noise_pred_uncond = model(xt, t, uncond_input)
                noise_pred = noise_pred_uncond + cf_guidance_scale * (noise_pred_cond - noise_pred_uncond)
            else:
                noise_pred = noise_pred_cond

            # Use scheduler to get x0 and xt-1
            xt, x0_pred = scheduler.sample_prev_timestep(xt, noise_pred, torch.as_tensor(i).to(device))

            # Save x0
            # ims = torch.clamp(xt, -1., 1.).detach().cpu()
            if i == 0:
                # Decode ONLY the final iamge to save time
                ims = vae.decode(xt).sample
            else:
                ims = x0_pred

            ims = torch.clamp(ims, -1., 1.).detach().cpu()
            ims = (ims + 1) / 2        
        img_list.append(ims)
    
    if len(img_list) == 4:
        break
# Out:
#   0%|          | 0/2400 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
grid = make_grid(torch.cat(img_list, dim=0), nrow=2)
img = torchvision.transforms.ToPILImage()(grid)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=518x518>

# %%
print(text_list)
# Out:
# [['The woman has mouth slightly open, and big lips and wears lipstick.'], ['She is wearing lipstick. She has arched eyebrows, and high cheekbones. She is young.'], ['This man is wearing necktie. He has eyeglasses, big nose, and gray hair. He.'], ['This person is wearing lipstick, earrings. She has arched eyebrows, high cheekbones, and big lips.']]
