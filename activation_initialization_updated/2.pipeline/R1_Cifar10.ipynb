# %% [markdown]
# # training

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras import layers, losses
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Model

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')

x_train = tf.reshape(x_train, (-1, 32*32*3))
x_test  = tf.reshape(x_test, (-1, 32*32*3))

x_train = x_train/255.0
x_test  = x_test/255.0

print(x_train.shape)
print(x_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (50000, 3072)
# (10000, 3072)
# (50000, 1)
# (10000, 1)

# %%
# create model
model = keras.Sequential()
model.add(keras.Input(shape=(3072,)))
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 256)               786688
#
#  dense_3 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 789,258
# Trainable params: 789,258
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimizer and loss
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['sparse_categorical_accuracy'])

# training
history = model.fit(x_train, y_train, 
                    validation_data=(x_test, y_test), 
                    batch_size=2048, epochs=200, verbose=2)
# Out:
# Epoch 1/200
# 25/25 - 2s - loss: 2.5748 - sparse_categorical_accuracy: 0.1684 - val_loss: 2.1007 - val_sparse_categorical_accuracy: 0.2191 - 2s/epoch - 67ms/step
# Epoch 2/200
# 25/25 - 1s - loss: 2.0118 - sparse_categorical_accuracy: 0.2741 - val_loss: 1.9559 - val_sparse_categorical_accuracy: 0.3152 - 1s/epoch - 46ms/step
# Epoch 3/200
# 25/25 - 1s - loss: 1.9190 - sparse_categorical_accuracy: 0.3275 - val_loss: 1.8892 - val_sparse_categorical_accuracy: 0.3449 - 1s/epoch - 45ms/step
# Epoch 4/200
# 25/25 - 1s - loss: 1.8627 - sparse_categorical_accuracy: 0.3512 - val_loss: 1.8417 - val_sparse_categorical_accuracy: 0.3586 - 1s/epoch - 47ms/step
# Epoch 5/200
# 25/25 - 1s - loss: 1.8209 - sparse_categorical_accuracy: 0.3682 - val_loss: 1.8108 - val_sparse_categorical_accuracy: 0.3721 - 1s/epoch - 45ms/step
# Epoch 6/200
# 25/25 - 1s - loss: 1.7874 - sparse_categorical_accuracy: 0.3816 - val_loss: 1.7896 - val_sparse_categorical_accuracy: 0.3799 - 1s/epoch - 45ms/step
# Epoch 7/200
# 25/25 - 1s - loss: 1.7629 - sparse_categorical_accuracy: 0.3899 - val_loss: 1.7645 - val_sparse_categorical_accuracy: 0.3872 - 1s/epoch - 48ms/step
# Epoch 8/200
# 25/25 - 1s - loss: 1.7414 - sparse_categorical_accuracy: 0.3971 - val_loss: 1.7478 - val_sparse_categorical_accuracy: 0.3986 - 1s/epoch - 48ms/step
# Epoch 9/200
# 25/25 - 1s - loss: 1.7233 - sparse_categorical_accuracy: 0.4042 - val_loss: 1.7243 - val_sparse_categorical_accuracy: 0.3939 - 1s/epoch - 49ms/step
# Epoch 10/200
# 25/25 - 2s - loss: 1.7109 - sparse_categorical_accuracy: 0.4056 - val_loss: 1.7089 - val_sparse_categorical_accuracy: 0.4082 - 2s/epoch - 61ms/step
# Epoch 11/200
# 25/25 - 2s - loss: 1.6912 - sparse_categorical_accuracy: 0.4141 - val_loss: 1.6929 - val_sparse_categorical_accuracy: 0.4084 - 2s/epoch - 63ms/step
# Epoch 12/200
# 25/25 - 2s - loss: 1.6814 - sparse_categorical_accuracy: 0.4166 - val_loss: 1.6876 - val_sparse_categorical_accuracy: 0.4108 - 2s/epoch - 63ms/step
# Epoch 13/200
# 25/25 - 1s - loss: 1.6704 - sparse_categorical_accuracy: 0.4200 - val_loss: 1.6734 - val_sparse_categorical_accuracy: 0.4173 - 1s/epoch - 49ms/step
# Epoch 14/200
# 25/25 - 1s - loss: 1.6577 - sparse_categorical_accuracy: 0.4246 - val_loss: 1.6654 - val_sparse_categorical_accuracy: 0.4172 - 1s/epoch - 60ms/step
# Epoch 15/200
# 25/25 - 1s - loss: 1.6474 - sparse_categorical_accuracy: 0.4264 - val_loss: 1.6556 - val_sparse_categorical_accuracy: 0.4232 - 1s/epoch - 53ms/step
# Epoch 16/200
# 25/25 - 1s - loss: 1.6383 - sparse_categorical_accuracy: 0.4303 - val_loss: 1.6514 - val_sparse_categorical_accuracy: 0.4189 - 1s/epoch - 59ms/step
# Epoch 17/200
# 25/25 - 1s - loss: 1.6263 - sparse_categorical_accuracy: 0.4368 - val_loss: 1.6409 - val_sparse_categorical_accuracy: 0.4264 - 1s/epoch - 58ms/step
# Epoch 18/200
# 25/25 - 1s - loss: 1.6185 - sparse_categorical_accuracy: 0.4362 - val_loss: 1.6324 - val_sparse_categorical_accuracy: 0.4289 - 1s/epoch - 58ms/step
# Epoch 19/200
# 25/25 - 1s - loss: 1.6029 - sparse_categorical_accuracy: 0.4452 - val_loss: 1.6217 - val_sparse_categorical_accuracy: 0.4355 - 1s/epoch - 53ms/step
# Epoch 20/200
# 25/25 - 1s - loss: 1.5957 - sparse_categorical_accuracy: 0.4456 - val_loss: 1.6326 - val_sparse_categorical_accuracy: 0.4314 - 1s/epoch - 53ms/step
# Epoch 21/200
# 25/25 - 1s - loss: 1.5851 - sparse_categorical_accuracy: 0.4504 - val_loss: 1.6064 - val_sparse_categorical_accuracy: 0.4390 - 1s/epoch - 55ms/step
# Epoch 22/200
# 25/25 - 2s - loss: 1.5749 - sparse_categorical_accuracy: 0.4556 - val_loss: 1.5976 - val_sparse_categorical_accuracy: 0.4420 - 2s/epoch - 63ms/step
# Epoch 23/200
# 25/25 - 1s - loss: 1.5682 - sparse_categorical_accuracy: 0.4565 - val_loss: 1.6010 - val_sparse_categorical_accuracy: 0.4382 - 1s/epoch - 54ms/step
# Epoch 24/200
# 25/25 - 1s - loss: 1.5627 - sparse_categorical_accuracy: 0.4571 - val_loss: 1.6012 - val_sparse_categorical_accuracy: 0.4349 - 1s/epoch - 53ms/step
# Epoch 25/200
# 25/25 - 1s - loss: 1.5588 - sparse_categorical_accuracy: 0.4581 - val_loss: 1.5805 - val_sparse_categorical_accuracy: 0.4436 - 1s/epoch - 52ms/step
# Epoch 26/200
# 25/25 - 1s - loss: 1.5438 - sparse_categorical_accuracy: 0.4662 - val_loss: 1.5812 - val_sparse_categorical_accuracy: 0.4450 - 1s/epoch - 52ms/step
# Epoch 27/200
# 25/25 - 1s - loss: 1.5415 - sparse_categorical_accuracy: 0.4646 - val_loss: 1.5759 - val_sparse_categorical_accuracy: 0.4478 - 1s/epoch - 53ms/step
# Epoch 28/200
# 25/25 - 1s - loss: 1.5362 - sparse_categorical_accuracy: 0.4670 - val_loss: 1.5709 - val_sparse_categorical_accuracy: 0.4482 - 1s/epoch - 54ms/step
# Epoch 29/200
# 25/25 - 2s - loss: 1.5251 - sparse_categorical_accuracy: 0.4709 - val_loss: 1.5662 - val_sparse_categorical_accuracy: 0.4542 - 2s/epoch - 61ms/step
# Epoch 30/200
# 25/25 - 1s - loss: 1.5261 - sparse_categorical_accuracy: 0.4715 - val_loss: 1.5585 - val_sparse_categorical_accuracy: 0.4521 - 1s/epoch - 59ms/step
# Epoch 31/200
# 25/25 - 1s - loss: 1.5143 - sparse_categorical_accuracy: 0.4743 - val_loss: 1.5564 - val_sparse_categorical_accuracy: 0.4545 - 1s/epoch - 53ms/step
# Epoch 32/200
# 25/25 - 1s - loss: 1.5088 - sparse_categorical_accuracy: 0.4762 - val_loss: 1.5533 - val_sparse_categorical_accuracy: 0.4514 - 1s/epoch - 52ms/step
# Epoch 33/200
# 25/25 - 1s - loss: 1.5092 - sparse_categorical_accuracy: 0.4726 - val_loss: 1.5449 - val_sparse_categorical_accuracy: 0.4587 - 1s/epoch - 53ms/step
# Epoch 34/200
# 25/25 - 1s - loss: 1.5021 - sparse_categorical_accuracy: 0.4786 - val_loss: 1.5456 - val_sparse_categorical_accuracy: 0.4559 - 1s/epoch - 54ms/step
# Epoch 35/200
# 25/25 - 1s - loss: 1.4930 - sparse_categorical_accuracy: 0.4805 - val_loss: 1.5392 - val_sparse_categorical_accuracy: 0.4583 - 1s/epoch - 51ms/step
# Epoch 36/200
# 25/25 - 1s - loss: 1.4994 - sparse_categorical_accuracy: 0.4770 - val_loss: 1.5644 - val_sparse_categorical_accuracy: 0.4405 - 1s/epoch - 52ms/step
# Epoch 37/200
# 25/25 - 1s - loss: 1.5101 - sparse_categorical_accuracy: 0.4720 - val_loss: 1.5397 - val_sparse_categorical_accuracy: 0.4527 - 1s/epoch - 52ms/step
# Epoch 38/200
# 25/25 - 1s - loss: 1.4817 - sparse_categorical_accuracy: 0.4830 - val_loss: 1.5354 - val_sparse_categorical_accuracy: 0.4626 - 1s/epoch - 51ms/step
# Epoch 39/200
# 25/25 - 1s - loss: 1.4771 - sparse_categorical_accuracy: 0.4859 - val_loss: 1.5259 - val_sparse_categorical_accuracy: 0.4616 - 1s/epoch - 52ms/step
# Epoch 40/200
# 25/25 - 1s - loss: 1.4788 - sparse_categorical_accuracy: 0.4844 - val_loss: 1.5304 - val_sparse_categorical_accuracy: 0.4627 - 1s/epoch - 51ms/step
# Epoch 41/200
# 25/25 - 1s - loss: 1.4786 - sparse_categorical_accuracy: 0.4871 - val_loss: 1.5328 - val_sparse_categorical_accuracy: 0.4627 - 1s/epoch - 53ms/step
# Epoch 42/200
# 25/25 - 1s - loss: 1.4757 - sparse_categorical_accuracy: 0.4844 - val_loss: 1.5284 - val_sparse_categorical_accuracy: 0.4678 - 1s/epoch - 53ms/step
# Epoch 43/200
# 25/25 - 1s - loss: 1.4643 - sparse_categorical_accuracy: 0.4895 - val_loss: 1.5256 - val_sparse_categorical_accuracy: 0.4611 - 1s/epoch - 52ms/step
# Epoch 44/200
# 25/25 - 1s - loss: 1.4630 - sparse_categorical_accuracy: 0.4892 - val_loss: 1.5191 - val_sparse_categorical_accuracy: 0.4678 - 1s/epoch - 52ms/step
# Epoch 45/200
# 25/25 - 1s - loss: 1.4578 - sparse_categorical_accuracy: 0.4898 - val_loss: 1.5235 - val_sparse_categorical_accuracy: 0.4617 - 1s/epoch - 53ms/step
# Epoch 46/200
# 25/25 - 1s - loss: 1.4507 - sparse_categorical_accuracy: 0.4944 - val_loss: 1.5188 - val_sparse_categorical_accuracy: 0.4634 - 1s/epoch - 52ms/step
# Epoch 47/200
# 25/25 - 1s - loss: 1.4473 - sparse_categorical_accuracy: 0.4961 - val_loss: 1.5190 - val_sparse_categorical_accuracy: 0.4609 - 1s/epoch - 53ms/step
# Epoch 48/200
# 25/25 - 1s - loss: 1.4487 - sparse_categorical_accuracy: 0.4951 - val_loss: 1.5052 - val_sparse_categorical_accuracy: 0.4653 - 1s/epoch - 53ms/step
# Epoch 49/200
# 25/25 - 1s - loss: 1.4416 - sparse_categorical_accuracy: 0.4959 - val_loss: 1.5141 - val_sparse_categorical_accuracy: 0.4604 - 1s/epoch - 52ms/step
# Epoch 50/200
# 25/25 - 1s - loss: 1.4344 - sparse_categorical_accuracy: 0.4994 - val_loss: 1.5002 - val_sparse_categorical_accuracy: 0.4718 - 1s/epoch - 54ms/step
# Epoch 51/200
# 25/25 - 1s - loss: 1.4323 - sparse_categorical_accuracy: 0.5000 - val_loss: 1.5223 - val_sparse_categorical_accuracy: 0.4639 - 1s/epoch - 52ms/step
# Epoch 52/200
# 25/25 - 1s - loss: 1.4388 - sparse_categorical_accuracy: 0.4971 - val_loss: 1.5168 - val_sparse_categorical_accuracy: 0.4592 - 1s/epoch - 52ms/step
# Epoch 53/200
# 25/25 - 1s - loss: 1.4297 - sparse_categorical_accuracy: 0.5014 - val_loss: 1.5019 - val_sparse_categorical_accuracy: 0.4669 - 1s/epoch - 52ms/step
# Epoch 54/200
# 25/25 - 1s - loss: 1.4220 - sparse_categorical_accuracy: 0.5044 - val_loss: 1.5004 - val_sparse_categorical_accuracy: 0.4677 - 1s/epoch - 52ms/step
# Epoch 55/200
# 25/25 - 1s - loss: 1.4293 - sparse_categorical_accuracy: 0.4998 - val_loss: 1.5085 - val_sparse_categorical_accuracy: 0.4654 - 1s/epoch - 52ms/step
# Epoch 56/200
# 25/25 - 1s - loss: 1.4200 - sparse_categorical_accuracy: 0.5047 - val_loss: 1.4903 - val_sparse_categorical_accuracy: 0.4719 - 1s/epoch - 52ms/step
# Epoch 57/200
# 25/25 - 1s - loss: 1.4149 - sparse_categorical_accuracy: 0.5067 - val_loss: 1.5002 - val_sparse_categorical_accuracy: 0.4697 - 1s/epoch - 53ms/step
# Epoch 58/200
# 25/25 - 1s - loss: 1.4090 - sparse_categorical_accuracy: 0.5081 - val_loss: 1.4875 - val_sparse_categorical_accuracy: 0.4786 - 1s/epoch - 52ms/step
# Epoch 59/200
# 25/25 - 1s - loss: 1.4068 - sparse_categorical_accuracy: 0.5096 - val_loss: 1.4983 - val_sparse_categorical_accuracy: 0.4679 - 1s/epoch - 52ms/step
# Epoch 60/200
# 25/25 - 1s - loss: 1.4035 - sparse_categorical_accuracy: 0.5111 - val_loss: 1.4882 - val_sparse_categorical_accuracy: 0.4734 - 1s/epoch - 53ms/step
# Epoch 61/200
# 25/25 - 1s - loss: 1.4017 - sparse_categorical_accuracy: 0.5106 - val_loss: 1.4833 - val_sparse_categorical_accuracy: 0.4770 - 1s/epoch - 52ms/step
# Epoch 62/200
# 25/25 - 1s - loss: 1.3988 - sparse_categorical_accuracy: 0.5132 - val_loss: 1.4994 - val_sparse_categorical_accuracy: 0.4725 - 1s/epoch - 52ms/step
# Epoch 63/200
# 25/25 - 1s - loss: 1.4043 - sparse_categorical_accuracy: 0.5072 - val_loss: 1.4774 - val_sparse_categorical_accuracy: 0.4803 - 1s/epoch - 52ms/step
# Epoch 64/200
# 25/25 - 1s - loss: 1.4026 - sparse_categorical_accuracy: 0.5076 - val_loss: 1.4809 - val_sparse_categorical_accuracy: 0.4762 - 1s/epoch - 53ms/step
# Epoch 65/200
# 25/25 - 1s - loss: 1.3937 - sparse_categorical_accuracy: 0.5125 - val_loss: 1.4754 - val_sparse_categorical_accuracy: 0.4775 - 1s/epoch - 53ms/step
# Epoch 66/200
# 25/25 - 1s - loss: 1.3893 - sparse_categorical_accuracy: 0.5149 - val_loss: 1.4861 - val_sparse_categorical_accuracy: 0.4761 - 1s/epoch - 54ms/step
# Epoch 67/200
# 25/25 - 1s - loss: 1.3938 - sparse_categorical_accuracy: 0.5131 - val_loss: 1.4926 - val_sparse_categorical_accuracy: 0.4698 - 1s/epoch - 54ms/step
# Epoch 68/200
# 25/25 - 1s - loss: 1.3928 - sparse_categorical_accuracy: 0.5118 - val_loss: 1.4869 - val_sparse_categorical_accuracy: 0.4759 - 1s/epoch - 58ms/step
# Epoch 69/200
# 25/25 - 1s - loss: 1.3812 - sparse_categorical_accuracy: 0.5180 - val_loss: 1.4876 - val_sparse_categorical_accuracy: 0.4734 - 1s/epoch - 54ms/step
# Epoch 70/200
# 25/25 - 1s - loss: 1.3932 - sparse_categorical_accuracy: 0.5119 - val_loss: 1.5122 - val_sparse_categorical_accuracy: 0.4587 - 1s/epoch - 55ms/step
# Epoch 71/200
# 25/25 - 2s - loss: 1.3862 - sparse_categorical_accuracy: 0.5152 - val_loss: 1.4855 - val_sparse_categorical_accuracy: 0.4728 - 2s/epoch - 69ms/step
# Epoch 72/200
# 25/25 - 2s - loss: 1.3756 - sparse_categorical_accuracy: 0.5187 - val_loss: 1.4726 - val_sparse_categorical_accuracy: 0.4806 - 2s/epoch - 62ms/step
# Epoch 73/200
# 25/25 - 2s - loss: 1.3754 - sparse_categorical_accuracy: 0.5180 - val_loss: 1.4669 - val_sparse_categorical_accuracy: 0.4818 - 2s/epoch - 71ms/step
# Epoch 74/200
# 25/25 - 2s - loss: 1.3731 - sparse_categorical_accuracy: 0.5179 - val_loss: 1.4581 - val_sparse_categorical_accuracy: 0.4862 - 2s/epoch - 68ms/step
# Epoch 75/200
# 25/25 - 2s - loss: 1.3712 - sparse_categorical_accuracy: 0.5215 - val_loss: 1.4729 - val_sparse_categorical_accuracy: 0.4783 - 2s/epoch - 74ms/step
# Epoch 76/200
# 25/25 - 2s - loss: 1.3659 - sparse_categorical_accuracy: 0.5221 - val_loss: 1.5171 - val_sparse_categorical_accuracy: 0.4582 - 2s/epoch - 78ms/step
# Epoch 77/200
# 25/25 - 2s - loss: 1.3709 - sparse_categorical_accuracy: 0.5209 - val_loss: 1.4790 - val_sparse_categorical_accuracy: 0.4750 - 2s/epoch - 65ms/step
# Epoch 78/200
# 25/25 - 1s - loss: 1.3674 - sparse_categorical_accuracy: 0.5229 - val_loss: 1.4710 - val_sparse_categorical_accuracy: 0.4785 - 1s/epoch - 60ms/step
# Epoch 79/200
# 25/25 - 1s - loss: 1.3621 - sparse_categorical_accuracy: 0.5226 - val_loss: 1.4681 - val_sparse_categorical_accuracy: 0.4774 - 1s/epoch - 60ms/step
# Epoch 80/200
# 25/25 - 1s - loss: 1.3586 - sparse_categorical_accuracy: 0.5261 - val_loss: 1.4752 - val_sparse_categorical_accuracy: 0.4765 - 1s/epoch - 60ms/step
# Epoch 81/200
# 25/25 - 2s - loss: 1.3638 - sparse_categorical_accuracy: 0.5224 - val_loss: 1.4758 - val_sparse_categorical_accuracy: 0.4793 - 2s/epoch - 64ms/step
# Epoch 82/200
# 25/25 - 2s - loss: 1.3598 - sparse_categorical_accuracy: 0.5244 - val_loss: 1.4797 - val_sparse_categorical_accuracy: 0.4783 - 2s/epoch - 73ms/step
# Epoch 83/200
# 25/25 - 2s - loss: 1.3552 - sparse_categorical_accuracy: 0.5265 - val_loss: 1.4673 - val_sparse_categorical_accuracy: 0.4819 - 2s/epoch - 69ms/step
# Epoch 84/200
# 25/25 - 2s - loss: 1.3477 - sparse_categorical_accuracy: 0.5288 - val_loss: 1.4690 - val_sparse_categorical_accuracy: 0.4801 - 2s/epoch - 86ms/step
# Epoch 85/200
# 25/25 - 2s - loss: 1.3517 - sparse_categorical_accuracy: 0.5270 - val_loss: 1.4737 - val_sparse_categorical_accuracy: 0.4776 - 2s/epoch - 85ms/step
# Epoch 86/200
# 25/25 - 2s - loss: 1.3518 - sparse_categorical_accuracy: 0.5261 - val_loss: 1.4860 - val_sparse_categorical_accuracy: 0.4743 - 2s/epoch - 88ms/step
# Epoch 87/200
# 25/25 - 2s - loss: 1.3528 - sparse_categorical_accuracy: 0.5247 - val_loss: 1.4604 - val_sparse_categorical_accuracy: 0.4819 - 2s/epoch - 71ms/step
# Epoch 88/200
# 25/25 - 2s - loss: 1.3506 - sparse_categorical_accuracy: 0.5266 - val_loss: 1.4887 - val_sparse_categorical_accuracy: 0.4758 - 2s/epoch - 69ms/step
# Epoch 89/200
# 25/25 - 2s - loss: 1.3507 - sparse_categorical_accuracy: 0.5272 - val_loss: 1.4803 - val_sparse_categorical_accuracy: 0.4732 - 2s/epoch - 68ms/step
# Epoch 90/200
# 25/25 - 2s - loss: 1.3426 - sparse_categorical_accuracy: 0.5313 - val_loss: 1.4664 - val_sparse_categorical_accuracy: 0.4812 - 2s/epoch - 66ms/step
# Epoch 91/200
# 25/25 - 2s - loss: 1.3383 - sparse_categorical_accuracy: 0.5315 - val_loss: 1.4586 - val_sparse_categorical_accuracy: 0.4846 - 2s/epoch - 64ms/step
# Epoch 92/200
# 25/25 - 2s - loss: 1.3344 - sparse_categorical_accuracy: 0.5333 - val_loss: 1.4599 - val_sparse_categorical_accuracy: 0.4794 - 2s/epoch - 66ms/step
# Epoch 93/200
# 25/25 - 2s - loss: 1.3329 - sparse_categorical_accuracy: 0.5321 - val_loss: 1.4577 - val_sparse_categorical_accuracy: 0.4826 - 2s/epoch - 79ms/step
# Epoch 94/200
# 25/25 - 2s - loss: 1.3358 - sparse_categorical_accuracy: 0.5336 - val_loss: 1.4516 - val_sparse_categorical_accuracy: 0.4850 - 2s/epoch - 78ms/step
# Epoch 95/200
# 25/25 - 2s - loss: 1.3286 - sparse_categorical_accuracy: 0.5353 - val_loss: 1.4679 - val_sparse_categorical_accuracy: 0.4746 - 2s/epoch - 75ms/step
# Epoch 96/200
# 25/25 - 2s - loss: 1.3319 - sparse_categorical_accuracy: 0.5341 - val_loss: 1.4603 - val_sparse_categorical_accuracy: 0.4845 - 2s/epoch - 76ms/step
# Epoch 97/200
# 25/25 - 2s - loss: 1.3253 - sparse_categorical_accuracy: 0.5363 - val_loss: 1.4526 - val_sparse_categorical_accuracy: 0.4856 - 2s/epoch - 74ms/step
# Epoch 98/200
# 25/25 - 2s - loss: 1.3224 - sparse_categorical_accuracy: 0.5381 - val_loss: 1.4523 - val_sparse_categorical_accuracy: 0.4868 - 2s/epoch - 80ms/step
# Epoch 99/200
# 25/25 - 2s - loss: 1.3198 - sparse_categorical_accuracy: 0.5376 - val_loss: 1.4488 - val_sparse_categorical_accuracy: 0.4847 - 2s/epoch - 72ms/step
# Epoch 100/200
# 25/25 - 2s - loss: 1.3169 - sparse_categorical_accuracy: 0.5395 - val_loss: 1.4526 - val_sparse_categorical_accuracy: 0.4817 - 2s/epoch - 70ms/step
# Epoch 101/200
# 25/25 - 2s - loss: 1.3120 - sparse_categorical_accuracy: 0.5415 - val_loss: 1.4552 - val_sparse_categorical_accuracy: 0.4873 - 2s/epoch - 72ms/step
# Epoch 102/200
# 25/25 - 2s - loss: 1.3214 - sparse_categorical_accuracy: 0.5374 - val_loss: 1.4665 - val_sparse_categorical_accuracy: 0.4849 - 2s/epoch - 73ms/step
# Epoch 103/200
# 25/25 - 2s - loss: 1.3232 - sparse_categorical_accuracy: 0.5384 - val_loss: 1.4653 - val_sparse_categorical_accuracy: 0.4810 - 2s/epoch - 72ms/step
# Epoch 104/200
# 25/25 - 2s - loss: 1.3254 - sparse_categorical_accuracy: 0.5343 - val_loss: 1.4551 - val_sparse_categorical_accuracy: 0.4828 - 2s/epoch - 67ms/step
# Epoch 105/200
# 25/25 - 2s - loss: 1.3119 - sparse_categorical_accuracy: 0.5396 - val_loss: 1.4610 - val_sparse_categorical_accuracy: 0.4869 - 2s/epoch - 67ms/step
# Epoch 106/200
# 25/25 - 2s - loss: 1.3184 - sparse_categorical_accuracy: 0.5390 - val_loss: 1.4550 - val_sparse_categorical_accuracy: 0.4856 - 2s/epoch - 70ms/step
# Epoch 107/200
# 25/25 - 2s - loss: 1.3077 - sparse_categorical_accuracy: 0.5436 - val_loss: 1.4771 - val_sparse_categorical_accuracy: 0.4795 - 2s/epoch - 67ms/step
# Epoch 108/200
# 25/25 - 2s - loss: 1.3147 - sparse_categorical_accuracy: 0.5394 - val_loss: 1.4705 - val_sparse_categorical_accuracy: 0.4815 - 2s/epoch - 67ms/step
# Epoch 109/200
# 25/25 - 2s - loss: 1.3196 - sparse_categorical_accuracy: 0.5380 - val_loss: 1.4581 - val_sparse_categorical_accuracy: 0.4824 - 2s/epoch - 66ms/step
# Epoch 110/200
# 25/25 - 2s - loss: 1.3109 - sparse_categorical_accuracy: 0.5396 - val_loss: 1.4571 - val_sparse_categorical_accuracy: 0.4835 - 2s/epoch - 67ms/step
# Epoch 111/200
# 25/25 - 2s - loss: 1.3149 - sparse_categorical_accuracy: 0.5384 - val_loss: 1.4599 - val_sparse_categorical_accuracy: 0.4804 - 2s/epoch - 66ms/step
# Epoch 112/200
# 25/25 - 2s - loss: 1.3080 - sparse_categorical_accuracy: 0.5426 - val_loss: 1.4726 - val_sparse_categorical_accuracy: 0.4789 - 2s/epoch - 67ms/step
# Epoch 113/200
# 25/25 - 2s - loss: 1.3063 - sparse_categorical_accuracy: 0.5428 - val_loss: 1.4628 - val_sparse_categorical_accuracy: 0.4860 - 2s/epoch - 66ms/step
# Epoch 114/200
# 25/25 - 2s - loss: 1.2976 - sparse_categorical_accuracy: 0.5456 - val_loss: 1.4495 - val_sparse_categorical_accuracy: 0.4865 - 2s/epoch - 70ms/step
# Epoch 115/200
# 25/25 - 2s - loss: 1.2997 - sparse_categorical_accuracy: 0.5449 - val_loss: 1.4459 - val_sparse_categorical_accuracy: 0.4847 - 2s/epoch - 79ms/step
# Epoch 116/200
# 25/25 - 2s - loss: 1.2963 - sparse_categorical_accuracy: 0.5473 - val_loss: 1.4556 - val_sparse_categorical_accuracy: 0.4839 - 2s/epoch - 77ms/step
# Epoch 117/200
# 25/25 - 2s - loss: 1.2944 - sparse_categorical_accuracy: 0.5471 - val_loss: 1.4505 - val_sparse_categorical_accuracy: 0.4865 - 2s/epoch - 77ms/step
# Epoch 118/200
# 25/25 - 2s - loss: 1.3000 - sparse_categorical_accuracy: 0.5442 - val_loss: 1.4436 - val_sparse_categorical_accuracy: 0.4887 - 2s/epoch - 72ms/step
# Epoch 119/200
# 25/25 - 2s - loss: 1.2920 - sparse_categorical_accuracy: 0.5491 - val_loss: 1.4626 - val_sparse_categorical_accuracy: 0.4863 - 2s/epoch - 63ms/step
# Epoch 120/200
# 25/25 - 2s - loss: 1.2946 - sparse_categorical_accuracy: 0.5460 - val_loss: 1.4480 - val_sparse_categorical_accuracy: 0.4921 - 2s/epoch - 62ms/step
# Epoch 121/200
# 25/25 - 1s - loss: 1.2927 - sparse_categorical_accuracy: 0.5471 - val_loss: 1.4684 - val_sparse_categorical_accuracy: 0.4811 - 1s/epoch - 60ms/step
# Epoch 122/200
# 25/25 - 1s - loss: 1.2890 - sparse_categorical_accuracy: 0.5486 - val_loss: 1.4584 - val_sparse_categorical_accuracy: 0.4828 - 1s/epoch - 60ms/step
# Epoch 123/200
# 25/25 - 2s - loss: 1.2910 - sparse_categorical_accuracy: 0.5466 - val_loss: 1.4613 - val_sparse_categorical_accuracy: 0.4837 - 2s/epoch - 63ms/step
# Epoch 124/200
# 25/25 - 2s - loss: 1.2900 - sparse_categorical_accuracy: 0.5490 - val_loss: 1.4501 - val_sparse_categorical_accuracy: 0.4875 - 2s/epoch - 60ms/step
# Epoch 125/200
# 25/25 - 2s - loss: 1.2822 - sparse_categorical_accuracy: 0.5499 - val_loss: 1.4515 - val_sparse_categorical_accuracy: 0.4879 - 2s/epoch - 62ms/step
# Epoch 126/200
# 25/25 - 2s - loss: 1.2845 - sparse_categorical_accuracy: 0.5516 - val_loss: 1.4662 - val_sparse_categorical_accuracy: 0.4794 - 2s/epoch - 61ms/step
# Epoch 127/200
# 25/25 - 1s - loss: 1.2889 - sparse_categorical_accuracy: 0.5491 - val_loss: 1.4611 - val_sparse_categorical_accuracy: 0.4845 - 1s/epoch - 58ms/step
# Epoch 128/200
# 25/25 - 2s - loss: 1.2767 - sparse_categorical_accuracy: 0.5531 - val_loss: 1.4666 - val_sparse_categorical_accuracy: 0.4767 - 2s/epoch - 64ms/step
# Epoch 129/200
# 25/25 - 2s - loss: 1.2792 - sparse_categorical_accuracy: 0.5514 - val_loss: 1.4576 - val_sparse_categorical_accuracy: 0.4825 - 2s/epoch - 70ms/step
# Epoch 130/200
# 25/25 - 2s - loss: 1.2841 - sparse_categorical_accuracy: 0.5497 - val_loss: 1.4471 - val_sparse_categorical_accuracy: 0.4805 - 2s/epoch - 65ms/step
# Epoch 131/200
# 25/25 - 1s - loss: 1.2720 - sparse_categorical_accuracy: 0.5554 - val_loss: 1.4584 - val_sparse_categorical_accuracy: 0.4799 - 1s/epoch - 58ms/step
# Epoch 132/200
# 25/25 - 1s - loss: 1.2759 - sparse_categorical_accuracy: 0.5524 - val_loss: 1.4797 - val_sparse_categorical_accuracy: 0.4757 - 1s/epoch - 60ms/step
# Epoch 133/200
# 25/25 - 1s - loss: 1.2794 - sparse_categorical_accuracy: 0.5521 - val_loss: 1.4518 - val_sparse_categorical_accuracy: 0.4881 - 1s/epoch - 58ms/step
# Epoch 134/200
# 25/25 - 1s - loss: 1.2762 - sparse_categorical_accuracy: 0.5539 - val_loss: 1.4578 - val_sparse_categorical_accuracy: 0.4856 - 1s/epoch - 58ms/step
# Epoch 135/200
# 25/25 - 1s - loss: 1.2811 - sparse_categorical_accuracy: 0.5520 - val_loss: 1.4469 - val_sparse_categorical_accuracy: 0.4893 - 1s/epoch - 57ms/step
# Epoch 136/200
# 25/25 - 1s - loss: 1.2764 - sparse_categorical_accuracy: 0.5520 - val_loss: 1.4580 - val_sparse_categorical_accuracy: 0.4837 - 1s/epoch - 58ms/step
# Epoch 137/200
# 25/25 - 1s - loss: 1.2674 - sparse_categorical_accuracy: 0.5561 - val_loss: 1.4613 - val_sparse_categorical_accuracy: 0.4799 - 1s/epoch - 58ms/step
# Epoch 138/200
# 25/25 - 1s - loss: 1.2673 - sparse_categorical_accuracy: 0.5553 - val_loss: 1.4425 - val_sparse_categorical_accuracy: 0.4879 - 1s/epoch - 57ms/step
# Epoch 139/200
# 25/25 - 1s - loss: 1.2644 - sparse_categorical_accuracy: 0.5561 - val_loss: 1.4609 - val_sparse_categorical_accuracy: 0.4896 - 1s/epoch - 57ms/step
# Epoch 140/200
# 25/25 - 1s - loss: 1.2717 - sparse_categorical_accuracy: 0.5536 - val_loss: 1.4663 - val_sparse_categorical_accuracy: 0.4786 - 1s/epoch - 57ms/step
# Epoch 141/200
# 25/25 - 2s - loss: 1.2662 - sparse_categorical_accuracy: 0.5557 - val_loss: 1.4417 - val_sparse_categorical_accuracy: 0.4922 - 2s/epoch - 61ms/step
# Epoch 142/200
# 25/25 - 2s - loss: 1.2678 - sparse_categorical_accuracy: 0.5573 - val_loss: 1.4684 - val_sparse_categorical_accuracy: 0.4828 - 2s/epoch - 68ms/step
# Epoch 143/200
# 25/25 - 2s - loss: 1.2737 - sparse_categorical_accuracy: 0.5525 - val_loss: 1.4507 - val_sparse_categorical_accuracy: 0.4843 - 2s/epoch - 75ms/step
# Epoch 144/200
# 25/25 - 2s - loss: 1.2579 - sparse_categorical_accuracy: 0.5600 - val_loss: 1.4529 - val_sparse_categorical_accuracy: 0.4883 - 2s/epoch - 69ms/step
# Epoch 145/200
# 25/25 - 2s - loss: 1.2608 - sparse_categorical_accuracy: 0.5587 - val_loss: 1.4565 - val_sparse_categorical_accuracy: 0.4804 - 2s/epoch - 70ms/step
# Epoch 146/200
# 25/25 - 2s - loss: 1.2584 - sparse_categorical_accuracy: 0.5583 - val_loss: 1.4492 - val_sparse_categorical_accuracy: 0.4849 - 2s/epoch - 64ms/step
# Epoch 147/200
# 25/25 - 2s - loss: 1.2564 - sparse_categorical_accuracy: 0.5595 - val_loss: 1.4603 - val_sparse_categorical_accuracy: 0.4796 - 2s/epoch - 64ms/step
# Epoch 148/200
# 25/25 - 2s - loss: 1.2552 - sparse_categorical_accuracy: 0.5622 - val_loss: 1.4562 - val_sparse_categorical_accuracy: 0.4877 - 2s/epoch - 68ms/step
# Epoch 149/200
# 25/25 - 2s - loss: 1.2480 - sparse_categorical_accuracy: 0.5643 - val_loss: 1.4397 - val_sparse_categorical_accuracy: 0.4916 - 2s/epoch - 66ms/step
# Epoch 150/200
# 25/25 - 2s - loss: 1.2510 - sparse_categorical_accuracy: 0.5619 - val_loss: 1.4483 - val_sparse_categorical_accuracy: 0.4874 - 2s/epoch - 64ms/step
# Epoch 151/200
# 25/25 - 2s - loss: 1.2575 - sparse_categorical_accuracy: 0.5618 - val_loss: 1.4540 - val_sparse_categorical_accuracy: 0.4909 - 2s/epoch - 68ms/step
# Epoch 152/200
# 25/25 - 2s - loss: 1.2551 - sparse_categorical_accuracy: 0.5617 - val_loss: 1.4971 - val_sparse_categorical_accuracy: 0.4760 - 2s/epoch - 66ms/step
# Epoch 153/200
# 25/25 - 2s - loss: 1.2524 - sparse_categorical_accuracy: 0.5608 - val_loss: 1.4492 - val_sparse_categorical_accuracy: 0.4855 - 2s/epoch - 72ms/step
# Epoch 154/200
# 25/25 - 2s - loss: 1.2440 - sparse_categorical_accuracy: 0.5653 - val_loss: 1.4503 - val_sparse_categorical_accuracy: 0.4925 - 2s/epoch - 68ms/step
# Epoch 155/200
# 25/25 - 2s - loss: 1.2513 - sparse_categorical_accuracy: 0.5606 - val_loss: 1.4491 - val_sparse_categorical_accuracy: 0.4874 - 2s/epoch - 60ms/step
# Epoch 156/200
# 25/25 - 2s - loss: 1.2411 - sparse_categorical_accuracy: 0.5666 - val_loss: 1.4496 - val_sparse_categorical_accuracy: 0.4895 - 2s/epoch - 61ms/step
# Epoch 157/200
# 25/25 - 1s - loss: 1.2442 - sparse_categorical_accuracy: 0.5660 - val_loss: 1.4739 - val_sparse_categorical_accuracy: 0.4801 - 1s/epoch - 57ms/step
# Epoch 158/200
# 25/25 - 1s - loss: 1.2403 - sparse_categorical_accuracy: 0.5661 - val_loss: 1.4427 - val_sparse_categorical_accuracy: 0.4914 - 1s/epoch - 57ms/step
# Epoch 159/200
# 25/25 - 1s - loss: 1.2387 - sparse_categorical_accuracy: 0.5680 - val_loss: 1.4780 - val_sparse_categorical_accuracy: 0.4736 - 1s/epoch - 56ms/step
# Epoch 160/200
# 25/25 - 1s - loss: 1.2422 - sparse_categorical_accuracy: 0.5659 - val_loss: 1.4479 - val_sparse_categorical_accuracy: 0.4898 - 1s/epoch - 56ms/step
# Epoch 161/200
# 25/25 - 2s - loss: 1.2360 - sparse_categorical_accuracy: 0.5668 - val_loss: 1.4505 - val_sparse_categorical_accuracy: 0.4874 - 2s/epoch - 61ms/step
# Epoch 162/200
# 25/25 - 1s - loss: 1.2369 - sparse_categorical_accuracy: 0.5666 - val_loss: 1.4501 - val_sparse_categorical_accuracy: 0.4924 - 1s/epoch - 58ms/step
# Epoch 163/200
# 25/25 - 1s - loss: 1.2423 - sparse_categorical_accuracy: 0.5642 - val_loss: 1.4632 - val_sparse_categorical_accuracy: 0.4860 - 1s/epoch - 56ms/step
# Epoch 164/200
# 25/25 - 1s - loss: 1.2398 - sparse_categorical_accuracy: 0.5666 - val_loss: 1.4520 - val_sparse_categorical_accuracy: 0.4889 - 1s/epoch - 56ms/step
# Epoch 165/200
# 25/25 - 1s - loss: 1.2382 - sparse_categorical_accuracy: 0.5668 - val_loss: 1.4446 - val_sparse_categorical_accuracy: 0.4907 - 1s/epoch - 56ms/step
# Epoch 166/200
# 25/25 - 1s - loss: 1.2340 - sparse_categorical_accuracy: 0.5681 - val_loss: 1.4547 - val_sparse_categorical_accuracy: 0.4856 - 1s/epoch - 58ms/step
# Epoch 167/200
# 25/25 - 1s - loss: 1.2365 - sparse_categorical_accuracy: 0.5693 - val_loss: 1.4862 - val_sparse_categorical_accuracy: 0.4716 - 1s/epoch - 56ms/step
# Epoch 168/200
# 25/25 - 1s - loss: 1.2411 - sparse_categorical_accuracy: 0.5663 - val_loss: 1.4871 - val_sparse_categorical_accuracy: 0.4780 - 1s/epoch - 59ms/step
# Epoch 169/200
# 25/25 - 1s - loss: 1.2380 - sparse_categorical_accuracy: 0.5674 - val_loss: 1.4555 - val_sparse_categorical_accuracy: 0.4886 - 1s/epoch - 58ms/step
# Epoch 170/200
# 25/25 - 1s - loss: 1.2296 - sparse_categorical_accuracy: 0.5691 - val_loss: 1.4518 - val_sparse_categorical_accuracy: 0.4895 - 1s/epoch - 58ms/step
# Epoch 171/200
# 25/25 - 2s - loss: 1.2367 - sparse_categorical_accuracy: 0.5659 - val_loss: 1.4604 - val_sparse_categorical_accuracy: 0.4848 - 2s/epoch - 67ms/step
# Epoch 172/200
# 25/25 - 2s - loss: 1.2362 - sparse_categorical_accuracy: 0.5680 - val_loss: 1.4504 - val_sparse_categorical_accuracy: 0.4880 - 2s/epoch - 73ms/step
# Epoch 173/200
# 25/25 - 2s - loss: 1.2285 - sparse_categorical_accuracy: 0.5698 - val_loss: 1.4522 - val_sparse_categorical_accuracy: 0.4843 - 2s/epoch - 69ms/step
# Epoch 174/200
# 25/25 - 2s - loss: 1.2255 - sparse_categorical_accuracy: 0.5713 - val_loss: 1.4383 - val_sparse_categorical_accuracy: 0.4916 - 2s/epoch - 65ms/step
# Epoch 175/200
# 25/25 - 2s - loss: 1.2249 - sparse_categorical_accuracy: 0.5720 - val_loss: 1.4770 - val_sparse_categorical_accuracy: 0.4784 - 2s/epoch - 61ms/step
# Epoch 176/200
# 25/25 - 2s - loss: 1.2302 - sparse_categorical_accuracy: 0.5705 - val_loss: 1.4711 - val_sparse_categorical_accuracy: 0.4856 - 2s/epoch - 69ms/step
# Epoch 177/200
# 25/25 - 2s - loss: 1.2266 - sparse_categorical_accuracy: 0.5731 - val_loss: 1.4850 - val_sparse_categorical_accuracy: 0.4796 - 2s/epoch - 67ms/step
# Epoch 178/200
# 25/25 - 2s - loss: 1.2268 - sparse_categorical_accuracy: 0.5704 - val_loss: 1.4749 - val_sparse_categorical_accuracy: 0.4768 - 2s/epoch - 63ms/step
# Epoch 179/200
# 25/25 - 2s - loss: 1.2249 - sparse_categorical_accuracy: 0.5716 - val_loss: 1.4527 - val_sparse_categorical_accuracy: 0.4827 - 2s/epoch - 77ms/step
# Epoch 180/200
# 25/25 - 2s - loss: 1.2186 - sparse_categorical_accuracy: 0.5756 - val_loss: 1.4541 - val_sparse_categorical_accuracy: 0.4866 - 2s/epoch - 70ms/step
# Epoch 181/200
# 25/25 - 2s - loss: 1.2263 - sparse_categorical_accuracy: 0.5709 - val_loss: 1.4841 - val_sparse_categorical_accuracy: 0.4772 - 2s/epoch - 72ms/step
# Epoch 182/200
# 25/25 - 2s - loss: 1.2298 - sparse_categorical_accuracy: 0.5700 - val_loss: 1.4515 - val_sparse_categorical_accuracy: 0.4887 - 2s/epoch - 73ms/step
# Epoch 183/200
# 25/25 - 2s - loss: 1.2218 - sparse_categorical_accuracy: 0.5735 - val_loss: 1.4590 - val_sparse_categorical_accuracy: 0.4857 - 2s/epoch - 71ms/step
# Epoch 184/200
# 25/25 - 2s - loss: 1.2180 - sparse_categorical_accuracy: 0.5745 - val_loss: 1.4594 - val_sparse_categorical_accuracy: 0.4813 - 2s/epoch - 69ms/step
# Epoch 185/200
# 25/25 - 2s - loss: 1.2099 - sparse_categorical_accuracy: 0.5772 - val_loss: 1.4555 - val_sparse_categorical_accuracy: 0.4903 - 2s/epoch - 69ms/step
# Epoch 186/200
# 25/25 - 2s - loss: 1.2110 - sparse_categorical_accuracy: 0.5772 - val_loss: 1.4553 - val_sparse_categorical_accuracy: 0.4901 - 2s/epoch - 68ms/step
# Epoch 187/200
# 25/25 - 2s - loss: 1.2116 - sparse_categorical_accuracy: 0.5771 - val_loss: 1.4461 - val_sparse_categorical_accuracy: 0.4897 - 2s/epoch - 69ms/step
# Epoch 188/200
# 25/25 - 2s - loss: 1.2125 - sparse_categorical_accuracy: 0.5772 - val_loss: 1.4651 - val_sparse_categorical_accuracy: 0.4889 - 2s/epoch - 67ms/step
# Epoch 189/200
# 25/25 - 2s - loss: 1.2177 - sparse_categorical_accuracy: 0.5751 - val_loss: 1.4684 - val_sparse_categorical_accuracy: 0.4814 - 2s/epoch - 65ms/step
# Epoch 190/200
# 25/25 - 2s - loss: 1.2190 - sparse_categorical_accuracy: 0.5698 - val_loss: 1.4809 - val_sparse_categorical_accuracy: 0.4813 - 2s/epoch - 60ms/step
# Epoch 191/200
# 25/25 - 2s - loss: 1.2160 - sparse_categorical_accuracy: 0.5745 - val_loss: 1.4584 - val_sparse_categorical_accuracy: 0.4875 - 2s/epoch - 62ms/step
# Epoch 192/200
# 25/25 - 2s - loss: 1.2110 - sparse_categorical_accuracy: 0.5748 - val_loss: 1.4569 - val_sparse_categorical_accuracy: 0.4889 - 2s/epoch - 61ms/step
# Epoch 193/200
# 25/25 - 2s - loss: 1.2138 - sparse_categorical_accuracy: 0.5744 - val_loss: 1.4591 - val_sparse_categorical_accuracy: 0.4837 - 2s/epoch - 60ms/step
# Epoch 194/200
# 25/25 - 2s - loss: 1.2127 - sparse_categorical_accuracy: 0.5767 - val_loss: 1.4646 - val_sparse_categorical_accuracy: 0.4824 - 2s/epoch - 69ms/step
# Epoch 195/200
# 25/25 - 2s - loss: 1.2091 - sparse_categorical_accuracy: 0.5777 - val_loss: 1.4587 - val_sparse_categorical_accuracy: 0.4862 - 2s/epoch - 72ms/step
# Epoch 196/200
# 25/25 - 2s - loss: 1.2080 - sparse_categorical_accuracy: 0.5784 - val_loss: 1.4814 - val_sparse_categorical_accuracy: 0.4791 - 2s/epoch - 68ms/step
# Epoch 197/200
# 25/25 - 2s - loss: 1.2202 - sparse_categorical_accuracy: 0.5724 - val_loss: 1.4662 - val_sparse_categorical_accuracy: 0.4865 - 2s/epoch - 70ms/step
# Epoch 198/200
# 25/25 - 2s - loss: 1.2048 - sparse_categorical_accuracy: 0.5812 - val_loss: 1.4566 - val_sparse_categorical_accuracy: 0.4908 - 2s/epoch - 74ms/step
# Epoch 199/200
# 25/25 - 2s - loss: 1.2025 - sparse_categorical_accuracy: 0.5778 - val_loss: 1.4667 - val_sparse_categorical_accuracy: 0.4865 - 2s/epoch - 67ms/step
# Epoch 200/200
# 25/25 - 2s - loss: 1.2087 - sparse_categorical_accuracy: 0.5765 - val_loss: 1.4569 - val_sparse_categorical_accuracy: 0.4937 - 2s/epoch - 68ms/step

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()
