# %% [markdown]
# # training

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras import layers, losses
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Model

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')

x_train = tf.reshape(x_train, (-1, 28*28))
x_test  = tf.reshape(x_test, (-1, 28*28))

x_train = x_train/255.0
x_test  = x_test/255.0

print(x_train.shape)
print(x_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 784)
# (10000, 784)
# (60000,)
# (10000,)

# %%
# create model
model = keras.Sequential()
model.add(keras.Input(shape=(784,)))
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimizer and loss
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['sparse_categorical_accuracy'])

# training
history = model.fit(x_train, y_train, 
                    validation_data=(x_test, y_test), 
                    batch_size=2048, epochs=200, verbose=2)
# Out:
# Epoch 1/200
# 30/30 - 1s - loss: 0.9480 - sparse_categorical_accuracy: 0.6851 - val_loss: 0.6154 - val_sparse_categorical_accuracy: 0.7893 - 929ms/epoch - 31ms/step
# Epoch 2/200
# 30/30 - 0s - loss: 0.5336 - sparse_categorical_accuracy: 0.8208 - val_loss: 0.5200 - val_sparse_categorical_accuracy: 0.8237 - 481ms/epoch - 16ms/step
# Epoch 3/200
# 30/30 - 0s - loss: 0.4718 - sparse_categorical_accuracy: 0.8392 - val_loss: 0.4808 - val_sparse_categorical_accuracy: 0.8352 - 480ms/epoch - 16ms/step
# Epoch 4/200
# 30/30 - 0s - loss: 0.4356 - sparse_categorical_accuracy: 0.8510 - val_loss: 0.4581 - val_sparse_categorical_accuracy: 0.8412 - 487ms/epoch - 16ms/step
# Epoch 5/200
# 30/30 - 0s - loss: 0.4157 - sparse_categorical_accuracy: 0.8576 - val_loss: 0.4374 - val_sparse_categorical_accuracy: 0.8485 - 488ms/epoch - 16ms/step
# Epoch 6/200
# 30/30 - 0s - loss: 0.3979 - sparse_categorical_accuracy: 0.8630 - val_loss: 0.4258 - val_sparse_categorical_accuracy: 0.8513 - 471ms/epoch - 16ms/step
# Epoch 7/200
# 30/30 - 0s - loss: 0.3850 - sparse_categorical_accuracy: 0.8674 - val_loss: 0.4180 - val_sparse_categorical_accuracy: 0.8542 - 474ms/epoch - 16ms/step
# Epoch 8/200
# 30/30 - 0s - loss: 0.3701 - sparse_categorical_accuracy: 0.8718 - val_loss: 0.4141 - val_sparse_categorical_accuracy: 0.8560 - 472ms/epoch - 16ms/step
# Epoch 9/200
# 30/30 - 0s - loss: 0.3623 - sparse_categorical_accuracy: 0.8742 - val_loss: 0.4062 - val_sparse_categorical_accuracy: 0.8581 - 468ms/epoch - 16ms/step
# Epoch 10/200
# 30/30 - 0s - loss: 0.3508 - sparse_categorical_accuracy: 0.8787 - val_loss: 0.3918 - val_sparse_categorical_accuracy: 0.8629 - 468ms/epoch - 16ms/step
# Epoch 11/200
# 30/30 - 0s - loss: 0.3440 - sparse_categorical_accuracy: 0.8796 - val_loss: 0.3856 - val_sparse_categorical_accuracy: 0.8655 - 475ms/epoch - 16ms/step
# Epoch 12/200
# 30/30 - 0s - loss: 0.3328 - sparse_categorical_accuracy: 0.8845 - val_loss: 0.3837 - val_sparse_categorical_accuracy: 0.8652 - 482ms/epoch - 16ms/step
# Epoch 13/200
# 30/30 - 0s - loss: 0.3307 - sparse_categorical_accuracy: 0.8836 - val_loss: 0.3780 - val_sparse_categorical_accuracy: 0.8670 - 472ms/epoch - 16ms/step
# Epoch 14/200
# 30/30 - 0s - loss: 0.3239 - sparse_categorical_accuracy: 0.8859 - val_loss: 0.3796 - val_sparse_categorical_accuracy: 0.8685 - 471ms/epoch - 16ms/step
# Epoch 15/200
# 30/30 - 0s - loss: 0.3179 - sparse_categorical_accuracy: 0.8879 - val_loss: 0.3805 - val_sparse_categorical_accuracy: 0.8666 - 470ms/epoch - 16ms/step
# Epoch 16/200
# 30/30 - 0s - loss: 0.3115 - sparse_categorical_accuracy: 0.8912 - val_loss: 0.3682 - val_sparse_categorical_accuracy: 0.8714 - 482ms/epoch - 16ms/step
# Epoch 17/200
# 30/30 - 0s - loss: 0.3047 - sparse_categorical_accuracy: 0.8931 - val_loss: 0.3670 - val_sparse_categorical_accuracy: 0.8723 - 471ms/epoch - 16ms/step
# Epoch 18/200
# 30/30 - 0s - loss: 0.2998 - sparse_categorical_accuracy: 0.8941 - val_loss: 0.3539 - val_sparse_categorical_accuracy: 0.8742 - 476ms/epoch - 16ms/step
# Epoch 19/200
# 30/30 - 0s - loss: 0.2948 - sparse_categorical_accuracy: 0.8959 - val_loss: 0.3660 - val_sparse_categorical_accuracy: 0.8722 - 472ms/epoch - 16ms/step
# Epoch 20/200
# 30/30 - 0s - loss: 0.2911 - sparse_categorical_accuracy: 0.8978 - val_loss: 0.3509 - val_sparse_categorical_accuracy: 0.8784 - 475ms/epoch - 16ms/step
# Epoch 21/200
# 30/30 - 0s - loss: 0.2822 - sparse_categorical_accuracy: 0.9005 - val_loss: 0.3506 - val_sparse_categorical_accuracy: 0.8756 - 477ms/epoch - 16ms/step
# Epoch 22/200
# 30/30 - 0s - loss: 0.2788 - sparse_categorical_accuracy: 0.9023 - val_loss: 0.3541 - val_sparse_categorical_accuracy: 0.8752 - 477ms/epoch - 16ms/step
# Epoch 23/200
# 30/30 - 0s - loss: 0.2796 - sparse_categorical_accuracy: 0.9004 - val_loss: 0.3575 - val_sparse_categorical_accuracy: 0.8688 - 477ms/epoch - 16ms/step
# Epoch 24/200
# 30/30 - 0s - loss: 0.2762 - sparse_categorical_accuracy: 0.9018 - val_loss: 0.3420 - val_sparse_categorical_accuracy: 0.8764 - 478ms/epoch - 16ms/step
# Epoch 25/200
# 30/30 - 0s - loss: 0.2683 - sparse_categorical_accuracy: 0.9047 - val_loss: 0.3386 - val_sparse_categorical_accuracy: 0.8774 - 479ms/epoch - 16ms/step
# Epoch 26/200
# 30/30 - 0s - loss: 0.2639 - sparse_categorical_accuracy: 0.9072 - val_loss: 0.3368 - val_sparse_categorical_accuracy: 0.8789 - 479ms/epoch - 16ms/step
# Epoch 27/200
# 30/30 - 0s - loss: 0.2596 - sparse_categorical_accuracy: 0.9093 - val_loss: 0.3425 - val_sparse_categorical_accuracy: 0.8763 - 483ms/epoch - 16ms/step
# Epoch 28/200
# 30/30 - 0s - loss: 0.2592 - sparse_categorical_accuracy: 0.9082 - val_loss: 0.3354 - val_sparse_categorical_accuracy: 0.8821 - 483ms/epoch - 16ms/step
# Epoch 29/200
# 30/30 - 0s - loss: 0.2587 - sparse_categorical_accuracy: 0.9072 - val_loss: 0.3418 - val_sparse_categorical_accuracy: 0.8794 - 477ms/epoch - 16ms/step
# Epoch 30/200
# 30/30 - 0s - loss: 0.2507 - sparse_categorical_accuracy: 0.9111 - val_loss: 0.3362 - val_sparse_categorical_accuracy: 0.8801 - 480ms/epoch - 16ms/step
# Epoch 31/200
# 30/30 - 0s - loss: 0.2477 - sparse_categorical_accuracy: 0.9122 - val_loss: 0.3344 - val_sparse_categorical_accuracy: 0.8808 - 481ms/epoch - 16ms/step
# Epoch 32/200
# 30/30 - 0s - loss: 0.2468 - sparse_categorical_accuracy: 0.9125 - val_loss: 0.3318 - val_sparse_categorical_accuracy: 0.8827 - 479ms/epoch - 16ms/step
# Epoch 33/200
# 30/30 - 0s - loss: 0.2408 - sparse_categorical_accuracy: 0.9147 - val_loss: 0.3280 - val_sparse_categorical_accuracy: 0.8824 - 485ms/epoch - 16ms/step
# Epoch 34/200
# 30/30 - 0s - loss: 0.2376 - sparse_categorical_accuracy: 0.9161 - val_loss: 0.3306 - val_sparse_categorical_accuracy: 0.8827 - 485ms/epoch - 16ms/step
# Epoch 35/200
# 30/30 - 0s - loss: 0.2353 - sparse_categorical_accuracy: 0.9161 - val_loss: 0.3282 - val_sparse_categorical_accuracy: 0.8814 - 482ms/epoch - 16ms/step
# Epoch 36/200
# 30/30 - 0s - loss: 0.2327 - sparse_categorical_accuracy: 0.9176 - val_loss: 0.3312 - val_sparse_categorical_accuracy: 0.8834 - 490ms/epoch - 16ms/step
# Epoch 37/200
# 30/30 - 0s - loss: 0.2331 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.3210 - val_sparse_categorical_accuracy: 0.8862 - 480ms/epoch - 16ms/step
# Epoch 38/200
# 30/30 - 0s - loss: 0.2270 - sparse_categorical_accuracy: 0.9198 - val_loss: 0.3239 - val_sparse_categorical_accuracy: 0.8852 - 475ms/epoch - 16ms/step
# Epoch 39/200
# 30/30 - 0s - loss: 0.2246 - sparse_categorical_accuracy: 0.9209 - val_loss: 0.3211 - val_sparse_categorical_accuracy: 0.8857 - 485ms/epoch - 16ms/step
# Epoch 40/200
# 30/30 - 0s - loss: 0.2240 - sparse_categorical_accuracy: 0.9206 - val_loss: 0.3246 - val_sparse_categorical_accuracy: 0.8823 - 476ms/epoch - 16ms/step
# Epoch 41/200
# 30/30 - 0s - loss: 0.2231 - sparse_categorical_accuracy: 0.9206 - val_loss: 0.3466 - val_sparse_categorical_accuracy: 0.8741 - 482ms/epoch - 16ms/step
# Epoch 42/200
# 30/30 - 0s - loss: 0.2285 - sparse_categorical_accuracy: 0.9170 - val_loss: 0.3208 - val_sparse_categorical_accuracy: 0.8870 - 481ms/epoch - 16ms/step
# Epoch 43/200
# 30/30 - 0s - loss: 0.2234 - sparse_categorical_accuracy: 0.9203 - val_loss: 0.3311 - val_sparse_categorical_accuracy: 0.8849 - 481ms/epoch - 16ms/step
# Epoch 44/200
# 30/30 - 0s - loss: 0.2145 - sparse_categorical_accuracy: 0.9242 - val_loss: 0.3305 - val_sparse_categorical_accuracy: 0.8813 - 482ms/epoch - 16ms/step
# Epoch 45/200
# 30/30 - 0s - loss: 0.2111 - sparse_categorical_accuracy: 0.9261 - val_loss: 0.3219 - val_sparse_categorical_accuracy: 0.8872 - 480ms/epoch - 16ms/step
# Epoch 46/200
# 30/30 - 0s - loss: 0.2086 - sparse_categorical_accuracy: 0.9258 - val_loss: 0.3202 - val_sparse_categorical_accuracy: 0.8890 - 487ms/epoch - 16ms/step
# Epoch 47/200
# 30/30 - 0s - loss: 0.2044 - sparse_categorical_accuracy: 0.9276 - val_loss: 0.3269 - val_sparse_categorical_accuracy: 0.8847 - 489ms/epoch - 16ms/step
# Epoch 48/200
# 30/30 - 0s - loss: 0.2060 - sparse_categorical_accuracy: 0.9269 - val_loss: 0.3218 - val_sparse_categorical_accuracy: 0.8885 - 482ms/epoch - 16ms/step
# Epoch 49/200
# 30/30 - 0s - loss: 0.2009 - sparse_categorical_accuracy: 0.9295 - val_loss: 0.3166 - val_sparse_categorical_accuracy: 0.8899 - 490ms/epoch - 16ms/step
# Epoch 50/200
# 30/30 - 0s - loss: 0.2046 - sparse_categorical_accuracy: 0.9266 - val_loss: 0.3228 - val_sparse_categorical_accuracy: 0.8880 - 494ms/epoch - 16ms/step
# Epoch 51/200
# 30/30 - 0s - loss: 0.1974 - sparse_categorical_accuracy: 0.9299 - val_loss: 0.3149 - val_sparse_categorical_accuracy: 0.8895 - 496ms/epoch - 17ms/step
# Epoch 52/200
# 30/30 - 1s - loss: 0.1924 - sparse_categorical_accuracy: 0.9330 - val_loss: 0.3165 - val_sparse_categorical_accuracy: 0.8899 - 502ms/epoch - 17ms/step
# Epoch 53/200
# 30/30 - 0s - loss: 0.1919 - sparse_categorical_accuracy: 0.9331 - val_loss: 0.3188 - val_sparse_categorical_accuracy: 0.8882 - 476ms/epoch - 16ms/step
# Epoch 54/200
# 30/30 - 0s - loss: 0.1936 - sparse_categorical_accuracy: 0.9316 - val_loss: 0.3272 - val_sparse_categorical_accuracy: 0.8841 - 482ms/epoch - 16ms/step
# Epoch 55/200
# 30/30 - 0s - loss: 0.1955 - sparse_categorical_accuracy: 0.9299 - val_loss: 0.3162 - val_sparse_categorical_accuracy: 0.8880 - 481ms/epoch - 16ms/step
# Epoch 56/200
# 30/30 - 0s - loss: 0.1927 - sparse_categorical_accuracy: 0.9315 - val_loss: 0.3144 - val_sparse_categorical_accuracy: 0.8908 - 478ms/epoch - 16ms/step
# Epoch 57/200
# 30/30 - 0s - loss: 0.1860 - sparse_categorical_accuracy: 0.9355 - val_loss: 0.3178 - val_sparse_categorical_accuracy: 0.8897 - 478ms/epoch - 16ms/step
# Epoch 58/200
# 30/30 - 0s - loss: 0.1839 - sparse_categorical_accuracy: 0.9359 - val_loss: 0.3134 - val_sparse_categorical_accuracy: 0.8912 - 484ms/epoch - 16ms/step
# Epoch 59/200
# 30/30 - 0s - loss: 0.1833 - sparse_categorical_accuracy: 0.9352 - val_loss: 0.3212 - val_sparse_categorical_accuracy: 0.8886 - 477ms/epoch - 16ms/step
# Epoch 60/200
# 30/30 - 0s - loss: 0.1798 - sparse_categorical_accuracy: 0.9373 - val_loss: 0.3226 - val_sparse_categorical_accuracy: 0.8870 - 479ms/epoch - 16ms/step
# Epoch 61/200
# 30/30 - 0s - loss: 0.1821 - sparse_categorical_accuracy: 0.9356 - val_loss: 0.3174 - val_sparse_categorical_accuracy: 0.8902 - 483ms/epoch - 16ms/step
# Epoch 62/200
# 30/30 - 0s - loss: 0.1768 - sparse_categorical_accuracy: 0.9379 - val_loss: 0.3175 - val_sparse_categorical_accuracy: 0.8876 - 479ms/epoch - 16ms/step
# Epoch 63/200
# 30/30 - 0s - loss: 0.1747 - sparse_categorical_accuracy: 0.9390 - val_loss: 0.3163 - val_sparse_categorical_accuracy: 0.8911 - 476ms/epoch - 16ms/step
# Epoch 64/200
# 30/30 - 0s - loss: 0.1749 - sparse_categorical_accuracy: 0.9387 - val_loss: 0.3209 - val_sparse_categorical_accuracy: 0.8880 - 486ms/epoch - 16ms/step
# Epoch 65/200
# 30/30 - 0s - loss: 0.1734 - sparse_categorical_accuracy: 0.9397 - val_loss: 0.3132 - val_sparse_categorical_accuracy: 0.8909 - 481ms/epoch - 16ms/step
# Epoch 66/200
# 30/30 - 0s - loss: 0.1710 - sparse_categorical_accuracy: 0.9402 - val_loss: 0.3157 - val_sparse_categorical_accuracy: 0.8924 - 476ms/epoch - 16ms/step
# Epoch 67/200
# 30/30 - 0s - loss: 0.1677 - sparse_categorical_accuracy: 0.9417 - val_loss: 0.3200 - val_sparse_categorical_accuracy: 0.8899 - 482ms/epoch - 16ms/step
# Epoch 68/200
# 30/30 - 0s - loss: 0.1664 - sparse_categorical_accuracy: 0.9420 - val_loss: 0.3126 - val_sparse_categorical_accuracy: 0.8923 - 479ms/epoch - 16ms/step
# Epoch 69/200
# 30/30 - 0s - loss: 0.1635 - sparse_categorical_accuracy: 0.9430 - val_loss: 0.3123 - val_sparse_categorical_accuracy: 0.8926 - 480ms/epoch - 16ms/step
# Epoch 70/200
# 30/30 - 0s - loss: 0.1652 - sparse_categorical_accuracy: 0.9423 - val_loss: 0.3198 - val_sparse_categorical_accuracy: 0.8902 - 480ms/epoch - 16ms/step
# Epoch 71/200
# 30/30 - 0s - loss: 0.1612 - sparse_categorical_accuracy: 0.9441 - val_loss: 0.3155 - val_sparse_categorical_accuracy: 0.8910 - 480ms/epoch - 16ms/step
# Epoch 72/200
# 30/30 - 0s - loss: 0.1598 - sparse_categorical_accuracy: 0.9457 - val_loss: 0.3162 - val_sparse_categorical_accuracy: 0.8910 - 476ms/epoch - 16ms/step
# Epoch 73/200
# 30/30 - 0s - loss: 0.1592 - sparse_categorical_accuracy: 0.9448 - val_loss: 0.3242 - val_sparse_categorical_accuracy: 0.8907 - 480ms/epoch - 16ms/step
# Epoch 74/200
# 30/30 - 0s - loss: 0.1590 - sparse_categorical_accuracy: 0.9453 - val_loss: 0.3230 - val_sparse_categorical_accuracy: 0.8889 - 474ms/epoch - 16ms/step
# Epoch 75/200
# 30/30 - 0s - loss: 0.1582 - sparse_categorical_accuracy: 0.9442 - val_loss: 0.3169 - val_sparse_categorical_accuracy: 0.8935 - 486ms/epoch - 16ms/step
# Epoch 76/200
# 30/30 - 0s - loss: 0.1526 - sparse_categorical_accuracy: 0.9483 - val_loss: 0.3146 - val_sparse_categorical_accuracy: 0.8932 - 491ms/epoch - 16ms/step
# Epoch 77/200
# 30/30 - 0s - loss: 0.1532 - sparse_categorical_accuracy: 0.9473 - val_loss: 0.3372 - val_sparse_categorical_accuracy: 0.8868 - 485ms/epoch - 16ms/step
# Epoch 78/200
# 30/30 - 0s - loss: 0.1539 - sparse_categorical_accuracy: 0.9463 - val_loss: 0.3195 - val_sparse_categorical_accuracy: 0.8953 - 494ms/epoch - 16ms/step
# Epoch 79/200
# 30/30 - 0s - loss: 0.1475 - sparse_categorical_accuracy: 0.9501 - val_loss: 0.3144 - val_sparse_categorical_accuracy: 0.8909 - 487ms/epoch - 16ms/step
# Epoch 80/200
# 30/30 - 0s - loss: 0.1458 - sparse_categorical_accuracy: 0.9506 - val_loss: 0.3205 - val_sparse_categorical_accuracy: 0.8904 - 489ms/epoch - 16ms/step
# Epoch 81/200
# 30/30 - 0s - loss: 0.1448 - sparse_categorical_accuracy: 0.9511 - val_loss: 0.3160 - val_sparse_categorical_accuracy: 0.8938 - 494ms/epoch - 16ms/step
# Epoch 82/200
# 30/30 - 0s - loss: 0.1458 - sparse_categorical_accuracy: 0.9506 - val_loss: 0.3236 - val_sparse_categorical_accuracy: 0.8921 - 495ms/epoch - 16ms/step
# Epoch 83/200
# 30/30 - 0s - loss: 0.1456 - sparse_categorical_accuracy: 0.9506 - val_loss: 0.3230 - val_sparse_categorical_accuracy: 0.8907 - 490ms/epoch - 16ms/step
# Epoch 84/200
# 30/30 - 0s - loss: 0.1426 - sparse_categorical_accuracy: 0.9521 - val_loss: 0.3204 - val_sparse_categorical_accuracy: 0.8946 - 484ms/epoch - 16ms/step
# Epoch 85/200
# 30/30 - 0s - loss: 0.1396 - sparse_categorical_accuracy: 0.9528 - val_loss: 0.3231 - val_sparse_categorical_accuracy: 0.8907 - 497ms/epoch - 17ms/step
# Epoch 86/200
# 30/30 - 1s - loss: 0.1404 - sparse_categorical_accuracy: 0.9529 - val_loss: 0.3220 - val_sparse_categorical_accuracy: 0.8936 - 507ms/epoch - 17ms/step
# Epoch 87/200
# 30/30 - 0s - loss: 0.1368 - sparse_categorical_accuracy: 0.9540 - val_loss: 0.3412 - val_sparse_categorical_accuracy: 0.8862 - 489ms/epoch - 16ms/step
# Epoch 88/200
# 30/30 - 0s - loss: 0.1420 - sparse_categorical_accuracy: 0.9516 - val_loss: 0.3200 - val_sparse_categorical_accuracy: 0.8939 - 497ms/epoch - 17ms/step
# Epoch 89/200
# 30/30 - 0s - loss: 0.1348 - sparse_categorical_accuracy: 0.9552 - val_loss: 0.3242 - val_sparse_categorical_accuracy: 0.8956 - 493ms/epoch - 16ms/step
# Epoch 90/200
# 30/30 - 0s - loss: 0.1361 - sparse_categorical_accuracy: 0.9545 - val_loss: 0.3319 - val_sparse_categorical_accuracy: 0.8899 - 497ms/epoch - 17ms/step
# Epoch 91/200
# 30/30 - 1s - loss: 0.1374 - sparse_categorical_accuracy: 0.9531 - val_loss: 0.3295 - val_sparse_categorical_accuracy: 0.8926 - 505ms/epoch - 17ms/step
# Epoch 92/200
# 30/30 - 0s - loss: 0.1318 - sparse_categorical_accuracy: 0.9557 - val_loss: 0.3267 - val_sparse_categorical_accuracy: 0.8923 - 499ms/epoch - 17ms/step
# Epoch 93/200
# 30/30 - 0s - loss: 0.1332 - sparse_categorical_accuracy: 0.9551 - val_loss: 0.3384 - val_sparse_categorical_accuracy: 0.8882 - 496ms/epoch - 17ms/step
# Epoch 94/200
# 30/30 - 1s - loss: 0.1354 - sparse_categorical_accuracy: 0.9539 - val_loss: 0.3280 - val_sparse_categorical_accuracy: 0.8912 - 504ms/epoch - 17ms/step
# Epoch 95/200
# 30/30 - 0s - loss: 0.1301 - sparse_categorical_accuracy: 0.9562 - val_loss: 0.3234 - val_sparse_categorical_accuracy: 0.8935 - 494ms/epoch - 16ms/step
# Epoch 96/200
# 30/30 - 1s - loss: 0.1268 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.3353 - val_sparse_categorical_accuracy: 0.8948 - 514ms/epoch - 17ms/step
# Epoch 97/200
# 30/30 - 0s - loss: 0.1287 - sparse_categorical_accuracy: 0.9567 - val_loss: 0.3239 - val_sparse_categorical_accuracy: 0.8956 - 494ms/epoch - 16ms/step
# Epoch 98/200
# 30/30 - 0s - loss: 0.1227 - sparse_categorical_accuracy: 0.9590 - val_loss: 0.3237 - val_sparse_categorical_accuracy: 0.8942 - 494ms/epoch - 16ms/step
# Epoch 99/200
# 30/30 - 0s - loss: 0.1234 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.3271 - val_sparse_categorical_accuracy: 0.8934 - 490ms/epoch - 16ms/step
# Epoch 100/200
# 30/30 - 0s - loss: 0.1236 - sparse_categorical_accuracy: 0.9589 - val_loss: 0.3314 - val_sparse_categorical_accuracy: 0.8896 - 496ms/epoch - 17ms/step
# Epoch 101/200
# 30/30 - 1s - loss: 0.1254 - sparse_categorical_accuracy: 0.9573 - val_loss: 0.3240 - val_sparse_categorical_accuracy: 0.8953 - 505ms/epoch - 17ms/step
# Epoch 102/200
# 30/30 - 1s - loss: 0.1188 - sparse_categorical_accuracy: 0.9606 - val_loss: 0.3304 - val_sparse_categorical_accuracy: 0.8922 - 503ms/epoch - 17ms/step
# Epoch 103/200
# 30/30 - 0s - loss: 0.1195 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.3513 - val_sparse_categorical_accuracy: 0.8868 - 495ms/epoch - 17ms/step
# Epoch 104/200
# 30/30 - 0s - loss: 0.1192 - sparse_categorical_accuracy: 0.9605 - val_loss: 0.3300 - val_sparse_categorical_accuracy: 0.8958 - 493ms/epoch - 16ms/step
# Epoch 105/200
# 30/30 - 1s - loss: 0.1185 - sparse_categorical_accuracy: 0.9613 - val_loss: 0.3393 - val_sparse_categorical_accuracy: 0.8917 - 504ms/epoch - 17ms/step
# Epoch 106/200
# 30/30 - 0s - loss: 0.1174 - sparse_categorical_accuracy: 0.9611 - val_loss: 0.3406 - val_sparse_categorical_accuracy: 0.8888 - 498ms/epoch - 17ms/step
# Epoch 107/200
# 30/30 - 0s - loss: 0.1164 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.3397 - val_sparse_categorical_accuracy: 0.8914 - 495ms/epoch - 16ms/step
# Epoch 108/200
# 30/30 - 0s - loss: 0.1193 - sparse_categorical_accuracy: 0.9603 - val_loss: 0.3618 - val_sparse_categorical_accuracy: 0.8856 - 497ms/epoch - 17ms/step
# Epoch 109/200
# 30/30 - 0s - loss: 0.1181 - sparse_categorical_accuracy: 0.9606 - val_loss: 0.3412 - val_sparse_categorical_accuracy: 0.8919 - 496ms/epoch - 17ms/step
# Epoch 110/200
# 30/30 - 1s - loss: 0.1126 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.3392 - val_sparse_categorical_accuracy: 0.8924 - 501ms/epoch - 17ms/step
# Epoch 111/200
# 30/30 - 0s - loss: 0.1120 - sparse_categorical_accuracy: 0.9631 - val_loss: 0.3650 - val_sparse_categorical_accuracy: 0.8865 - 499ms/epoch - 17ms/step
# Epoch 112/200
# 30/30 - 0s - loss: 0.1114 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.3371 - val_sparse_categorical_accuracy: 0.8925 - 494ms/epoch - 16ms/step
# Epoch 113/200
# 30/30 - 0s - loss: 0.1071 - sparse_categorical_accuracy: 0.9657 - val_loss: 0.3362 - val_sparse_categorical_accuracy: 0.8945 - 499ms/epoch - 17ms/step
# Epoch 114/200
# 30/30 - 1s - loss: 0.1078 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.3356 - val_sparse_categorical_accuracy: 0.8917 - 503ms/epoch - 17ms/step
# Epoch 115/200
# 30/30 - 0s - loss: 0.1035 - sparse_categorical_accuracy: 0.9675 - val_loss: 0.3480 - val_sparse_categorical_accuracy: 0.8917 - 496ms/epoch - 17ms/step
# Epoch 116/200
# 30/30 - 1s - loss: 0.1050 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.3403 - val_sparse_categorical_accuracy: 0.8940 - 510ms/epoch - 17ms/step
# Epoch 117/200
# 30/30 - 0s - loss: 0.1050 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.3433 - val_sparse_categorical_accuracy: 0.8943 - 499ms/epoch - 17ms/step
# Epoch 118/200
# 30/30 - 0s - loss: 0.1024 - sparse_categorical_accuracy: 0.9676 - val_loss: 0.3343 - val_sparse_categorical_accuracy: 0.8929 - 494ms/epoch - 16ms/step
# Epoch 119/200
# 30/30 - 0s - loss: 0.1034 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.3528 - val_sparse_categorical_accuracy: 0.8893 - 499ms/epoch - 17ms/step
# Epoch 120/200
# 30/30 - 1s - loss: 0.1067 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.3431 - val_sparse_categorical_accuracy: 0.8899 - 506ms/epoch - 17ms/step
# Epoch 121/200
# 30/30 - 1s - loss: 0.1003 - sparse_categorical_accuracy: 0.9682 - val_loss: 0.3435 - val_sparse_categorical_accuracy: 0.8934 - 501ms/epoch - 17ms/step
# Epoch 122/200
# 30/30 - 1s - loss: 0.0990 - sparse_categorical_accuracy: 0.9697 - val_loss: 0.3441 - val_sparse_categorical_accuracy: 0.8909 - 505ms/epoch - 17ms/step
# Epoch 123/200
# 30/30 - 1s - loss: 0.0986 - sparse_categorical_accuracy: 0.9688 - val_loss: 0.3482 - val_sparse_categorical_accuracy: 0.8938 - 501ms/epoch - 17ms/step
# Epoch 124/200
# 30/30 - 0s - loss: 0.0973 - sparse_categorical_accuracy: 0.9693 - val_loss: 0.3437 - val_sparse_categorical_accuracy: 0.8946 - 497ms/epoch - 17ms/step
# Epoch 125/200
# 30/30 - 1s - loss: 0.0981 - sparse_categorical_accuracy: 0.9693 - val_loss: 0.3473 - val_sparse_categorical_accuracy: 0.8925 - 500ms/epoch - 17ms/step
# Epoch 126/200
# 30/30 - 1s - loss: 0.0963 - sparse_categorical_accuracy: 0.9695 - val_loss: 0.3415 - val_sparse_categorical_accuracy: 0.8936 - 509ms/epoch - 17ms/step
# Epoch 127/200
# 30/30 - 0s - loss: 0.0969 - sparse_categorical_accuracy: 0.9699 - val_loss: 0.3542 - val_sparse_categorical_accuracy: 0.8918 - 499ms/epoch - 17ms/step
# Epoch 128/200
# 30/30 - 1s - loss: 0.0970 - sparse_categorical_accuracy: 0.9678 - val_loss: 0.3427 - val_sparse_categorical_accuracy: 0.8926 - 506ms/epoch - 17ms/step
# Epoch 129/200
# 30/30 - 1s - loss: 0.0939 - sparse_categorical_accuracy: 0.9709 - val_loss: 0.3582 - val_sparse_categorical_accuracy: 0.8929 - 502ms/epoch - 17ms/step
# Epoch 130/200
# 30/30 - 1s - loss: 0.0971 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.3506 - val_sparse_categorical_accuracy: 0.8943 - 502ms/epoch - 17ms/step
# Epoch 131/200
# 30/30 - 1s - loss: 0.0948 - sparse_categorical_accuracy: 0.9704 - val_loss: 0.3543 - val_sparse_categorical_accuracy: 0.8903 - 503ms/epoch - 17ms/step
# Epoch 132/200
# 30/30 - 1s - loss: 0.0968 - sparse_categorical_accuracy: 0.9690 - val_loss: 0.3715 - val_sparse_categorical_accuracy: 0.8925 - 507ms/epoch - 17ms/step
# Epoch 133/200
# 30/30 - 1s - loss: 0.0915 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.3604 - val_sparse_categorical_accuracy: 0.8921 - 506ms/epoch - 17ms/step
# Epoch 134/200
# 30/30 - 1s - loss: 0.0895 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.3500 - val_sparse_categorical_accuracy: 0.8930 - 506ms/epoch - 17ms/step
# Epoch 135/200
# 30/30 - 0s - loss: 0.0868 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.3663 - val_sparse_categorical_accuracy: 0.8915 - 499ms/epoch - 17ms/step
# Epoch 136/200
# 30/30 - 1s - loss: 0.0886 - sparse_categorical_accuracy: 0.9731 - val_loss: 0.3570 - val_sparse_categorical_accuracy: 0.8972 - 513ms/epoch - 17ms/step
# Epoch 137/200
# 30/30 - 1s - loss: 0.0861 - sparse_categorical_accuracy: 0.9737 - val_loss: 0.3568 - val_sparse_categorical_accuracy: 0.8926 - 505ms/epoch - 17ms/step
# Epoch 138/200
# 30/30 - 0s - loss: 0.0856 - sparse_categorical_accuracy: 0.9746 - val_loss: 0.3570 - val_sparse_categorical_accuracy: 0.8930 - 500ms/epoch - 17ms/step
# Epoch 139/200
# 30/30 - 1s - loss: 0.0859 - sparse_categorical_accuracy: 0.9732 - val_loss: 0.3643 - val_sparse_categorical_accuracy: 0.8918 - 509ms/epoch - 17ms/step
# Epoch 140/200
# 30/30 - 1s - loss: 0.0910 - sparse_categorical_accuracy: 0.9710 - val_loss: 0.3601 - val_sparse_categorical_accuracy: 0.8945 - 503ms/epoch - 17ms/step
# Epoch 141/200
# 30/30 - 1s - loss: 0.0841 - sparse_categorical_accuracy: 0.9742 - val_loss: 0.3633 - val_sparse_categorical_accuracy: 0.8945 - 502ms/epoch - 17ms/step
# Epoch 142/200
# 30/30 - 1s - loss: 0.0866 - sparse_categorical_accuracy: 0.9731 - val_loss: 0.3559 - val_sparse_categorical_accuracy: 0.8929 - 507ms/epoch - 17ms/step
# Epoch 143/200
# 30/30 - 1s - loss: 0.0812 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.3574 - val_sparse_categorical_accuracy: 0.8960 - 508ms/epoch - 17ms/step
# Epoch 144/200
# 30/30 - 1s - loss: 0.0782 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.3575 - val_sparse_categorical_accuracy: 0.8941 - 516ms/epoch - 17ms/step
# Epoch 145/200
# 30/30 - 0s - loss: 0.0796 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.3658 - val_sparse_categorical_accuracy: 0.8952 - 499ms/epoch - 17ms/step
# Epoch 146/200
# 30/30 - 1s - loss: 0.0824 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.3652 - val_sparse_categorical_accuracy: 0.8925 - 507ms/epoch - 17ms/step
# Epoch 147/200
# 30/30 - 1s - loss: 0.0792 - sparse_categorical_accuracy: 0.9765 - val_loss: 0.3636 - val_sparse_categorical_accuracy: 0.8954 - 511ms/epoch - 17ms/step
# Epoch 148/200
# 30/30 - 1s - loss: 0.0784 - sparse_categorical_accuracy: 0.9766 - val_loss: 0.3706 - val_sparse_categorical_accuracy: 0.8925 - 511ms/epoch - 17ms/step
# Epoch 149/200
# 30/30 - 1s - loss: 0.0796 - sparse_categorical_accuracy: 0.9756 - val_loss: 0.3889 - val_sparse_categorical_accuracy: 0.8879 - 506ms/epoch - 17ms/step
# Epoch 150/200
# 30/30 - 1s - loss: 0.0844 - sparse_categorical_accuracy: 0.9730 - val_loss: 0.3807 - val_sparse_categorical_accuracy: 0.8938 - 501ms/epoch - 17ms/step
# Epoch 151/200
# 30/30 - 1s - loss: 0.0845 - sparse_categorical_accuracy: 0.9728 - val_loss: 0.3764 - val_sparse_categorical_accuracy: 0.8918 - 511ms/epoch - 17ms/step
# Epoch 152/200
# 30/30 - 1s - loss: 0.0797 - sparse_categorical_accuracy: 0.9755 - val_loss: 0.3648 - val_sparse_categorical_accuracy: 0.8936 - 504ms/epoch - 17ms/step
# Epoch 153/200
# 30/30 - 1s - loss: 0.0761 - sparse_categorical_accuracy: 0.9765 - val_loss: 0.3697 - val_sparse_categorical_accuracy: 0.8957 - 507ms/epoch - 17ms/step
# Epoch 154/200
# 30/30 - 1s - loss: 0.0768 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.3751 - val_sparse_categorical_accuracy: 0.8938 - 507ms/epoch - 17ms/step
# Epoch 155/200
# 30/30 - 1s - loss: 0.0762 - sparse_categorical_accuracy: 0.9770 - val_loss: 0.3769 - val_sparse_categorical_accuracy: 0.8925 - 510ms/epoch - 17ms/step
# Epoch 156/200
# 30/30 - 1s - loss: 0.0754 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.3745 - val_sparse_categorical_accuracy: 0.8943 - 518ms/epoch - 17ms/step
# Epoch 157/200
# 30/30 - 1s - loss: 0.0731 - sparse_categorical_accuracy: 0.9787 - val_loss: 0.3806 - val_sparse_categorical_accuracy: 0.8936 - 508ms/epoch - 17ms/step
# Epoch 158/200
# 30/30 - 1s - loss: 0.0755 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.3739 - val_sparse_categorical_accuracy: 0.8950 - 501ms/epoch - 17ms/step
# Epoch 159/200
# 30/30 - 1s - loss: 0.0709 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.3798 - val_sparse_categorical_accuracy: 0.8932 - 505ms/epoch - 17ms/step
# Epoch 160/200
# 30/30 - 1s - loss: 0.0738 - sparse_categorical_accuracy: 0.9773 - val_loss: 0.3790 - val_sparse_categorical_accuracy: 0.8889 - 504ms/epoch - 17ms/step
# Epoch 161/200
# 30/30 - 1s - loss: 0.0738 - sparse_categorical_accuracy: 0.9777 - val_loss: 0.3818 - val_sparse_categorical_accuracy: 0.8950 - 509ms/epoch - 17ms/step
# Epoch 162/200
# 30/30 - 1s - loss: 0.0686 - sparse_categorical_accuracy: 0.9801 - val_loss: 0.3818 - val_sparse_categorical_accuracy: 0.8970 - 546ms/epoch - 18ms/step
# Epoch 163/200
# 30/30 - 1s - loss: 0.0691 - sparse_categorical_accuracy: 0.9797 - val_loss: 0.3795 - val_sparse_categorical_accuracy: 0.8937 - 506ms/epoch - 17ms/step
# Epoch 164/200
# 30/30 - 1s - loss: 0.0666 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.3810 - val_sparse_categorical_accuracy: 0.8925 - 507ms/epoch - 17ms/step
# Epoch 165/200
# 30/30 - 1s - loss: 0.0676 - sparse_categorical_accuracy: 0.9808 - val_loss: 0.3803 - val_sparse_categorical_accuracy: 0.8960 - 508ms/epoch - 17ms/step
# Epoch 166/200
# 30/30 - 1s - loss: 0.0683 - sparse_categorical_accuracy: 0.9800 - val_loss: 0.3885 - val_sparse_categorical_accuracy: 0.8932 - 516ms/epoch - 17ms/step
# Epoch 167/200
# 30/30 - 1s - loss: 0.0667 - sparse_categorical_accuracy: 0.9807 - val_loss: 0.3808 - val_sparse_categorical_accuracy: 0.8948 - 514ms/epoch - 17ms/step
# Epoch 168/200
# 30/30 - 1s - loss: 0.0641 - sparse_categorical_accuracy: 0.9821 - val_loss: 0.3909 - val_sparse_categorical_accuracy: 0.8900 - 509ms/epoch - 17ms/step
# Epoch 169/200
# 30/30 - 1s - loss: 0.0658 - sparse_categorical_accuracy: 0.9811 - val_loss: 0.3848 - val_sparse_categorical_accuracy: 0.8954 - 517ms/epoch - 17ms/step
# Epoch 170/200
# 30/30 - 1s - loss: 0.0633 - sparse_categorical_accuracy: 0.9825 - val_loss: 0.3868 - val_sparse_categorical_accuracy: 0.8921 - 511ms/epoch - 17ms/step
# Epoch 171/200
# 30/30 - 1s - loss: 0.0630 - sparse_categorical_accuracy: 0.9821 - val_loss: 0.3847 - val_sparse_categorical_accuracy: 0.8933 - 513ms/epoch - 17ms/step
# Epoch 172/200
# 30/30 - 1s - loss: 0.0617 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.3888 - val_sparse_categorical_accuracy: 0.8907 - 503ms/epoch - 17ms/step
# Epoch 173/200
# 30/30 - 1s - loss: 0.0639 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.3914 - val_sparse_categorical_accuracy: 0.8919 - 506ms/epoch - 17ms/step
# Epoch 174/200
# 30/30 - 1s - loss: 0.0631 - sparse_categorical_accuracy: 0.9822 - val_loss: 0.4173 - val_sparse_categorical_accuracy: 0.8891 - 509ms/epoch - 17ms/step
# Epoch 175/200
# 30/30 - 1s - loss: 0.0687 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.3921 - val_sparse_categorical_accuracy: 0.8954 - 510ms/epoch - 17ms/step
# Epoch 176/200
# 30/30 - 1s - loss: 0.0602 - sparse_categorical_accuracy: 0.9827 - val_loss: 0.4085 - val_sparse_categorical_accuracy: 0.8865 - 513ms/epoch - 17ms/step
# Epoch 177/200
# 30/30 - 1s - loss: 0.0653 - sparse_categorical_accuracy: 0.9808 - val_loss: 0.3969 - val_sparse_categorical_accuracy: 0.8897 - 505ms/epoch - 17ms/step
# Epoch 178/200
# 30/30 - 1s - loss: 0.0633 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.4271 - val_sparse_categorical_accuracy: 0.8875 - 550ms/epoch - 18ms/step
# Epoch 179/200
# 30/30 - 1s - loss: 0.0722 - sparse_categorical_accuracy: 0.9765 - val_loss: 0.4153 - val_sparse_categorical_accuracy: 0.8872 - 564ms/epoch - 19ms/step
# Epoch 180/200
# 30/30 - 1s - loss: 0.0673 - sparse_categorical_accuracy: 0.9794 - val_loss: 0.3979 - val_sparse_categorical_accuracy: 0.8900 - 534ms/epoch - 18ms/step
# Epoch 181/200
# 30/30 - 1s - loss: 0.0592 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.4035 - val_sparse_categorical_accuracy: 0.8884 - 515ms/epoch - 17ms/step
# Epoch 182/200
# 30/30 - 1s - loss: 0.0586 - sparse_categorical_accuracy: 0.9839 - val_loss: 0.3985 - val_sparse_categorical_accuracy: 0.8905 - 514ms/epoch - 17ms/step
# Epoch 183/200
# 30/30 - 1s - loss: 0.0609 - sparse_categorical_accuracy: 0.9824 - val_loss: 0.3984 - val_sparse_categorical_accuracy: 0.8915 - 510ms/epoch - 17ms/step
# Epoch 184/200
# 30/30 - 1s - loss: 0.0592 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.3984 - val_sparse_categorical_accuracy: 0.8954 - 522ms/epoch - 17ms/step
# Epoch 185/200
# 30/30 - 1s - loss: 0.0556 - sparse_categorical_accuracy: 0.9851 - val_loss: 0.4035 - val_sparse_categorical_accuracy: 0.8947 - 513ms/epoch - 17ms/step
# Epoch 186/200
# 30/30 - 1s - loss: 0.0549 - sparse_categorical_accuracy: 0.9855 - val_loss: 0.3992 - val_sparse_categorical_accuracy: 0.8945 - 515ms/epoch - 17ms/step
# Epoch 187/200
# 30/30 - 1s - loss: 0.0591 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.4089 - val_sparse_categorical_accuracy: 0.8918 - 517ms/epoch - 17ms/step
# Epoch 188/200
# 30/30 - 1s - loss: 0.0565 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.4091 - val_sparse_categorical_accuracy: 0.8930 - 517ms/epoch - 17ms/step
# Epoch 189/200
# 30/30 - 1s - loss: 0.0567 - sparse_categorical_accuracy: 0.9834 - val_loss: 0.4184 - val_sparse_categorical_accuracy: 0.8897 - 515ms/epoch - 17ms/step
# Epoch 190/200
# 30/30 - 1s - loss: 0.0546 - sparse_categorical_accuracy: 0.9851 - val_loss: 0.4141 - val_sparse_categorical_accuracy: 0.8923 - 512ms/epoch - 17ms/step
# Epoch 191/200
# 30/30 - 1s - loss: 0.0598 - sparse_categorical_accuracy: 0.9817 - val_loss: 0.4088 - val_sparse_categorical_accuracy: 0.8923 - 520ms/epoch - 17ms/step
# Epoch 192/200
# 30/30 - 1s - loss: 0.0536 - sparse_categorical_accuracy: 0.9855 - val_loss: 0.4052 - val_sparse_categorical_accuracy: 0.8946 - 517ms/epoch - 17ms/step
# Epoch 193/200
# 30/30 - 1s - loss: 0.0538 - sparse_categorical_accuracy: 0.9855 - val_loss: 0.4110 - val_sparse_categorical_accuracy: 0.8914 - 512ms/epoch - 17ms/step
# Epoch 194/200
# 30/30 - 1s - loss: 0.0527 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.4186 - val_sparse_categorical_accuracy: 0.8928 - 527ms/epoch - 18ms/step
# Epoch 195/200
# 30/30 - 1s - loss: 0.0521 - sparse_categorical_accuracy: 0.9859 - val_loss: 0.4169 - val_sparse_categorical_accuracy: 0.8959 - 518ms/epoch - 17ms/step
# Epoch 196/200
# 30/30 - 1s - loss: 0.0523 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.4172 - val_sparse_categorical_accuracy: 0.8929 - 518ms/epoch - 17ms/step
# Epoch 197/200
# 30/30 - 1s - loss: 0.0509 - sparse_categorical_accuracy: 0.9869 - val_loss: 0.4108 - val_sparse_categorical_accuracy: 0.8926 - 521ms/epoch - 17ms/step
# Epoch 198/200
# 30/30 - 1s - loss: 0.0501 - sparse_categorical_accuracy: 0.9869 - val_loss: 0.4136 - val_sparse_categorical_accuracy: 0.8935 - 516ms/epoch - 17ms/step
# Epoch 199/200
# 30/30 - 1s - loss: 0.0488 - sparse_categorical_accuracy: 0.9877 - val_loss: 0.4131 - val_sparse_categorical_accuracy: 0.8938 - 512ms/epoch - 17ms/step
# Epoch 200/200
# 30/30 - 1s - loss: 0.0482 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.4235 - val_sparse_categorical_accuracy: 0.8912 - 508ms/epoch - 17ms/step

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()
