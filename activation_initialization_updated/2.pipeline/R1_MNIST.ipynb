# %% [markdown]
# # training

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras import layers, losses
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Model

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')

x_train = tf.reshape(x_train, (-1, 28*28))
x_test  = tf.reshape(x_test, (-1, 28*28))

x_train = x_train/255.0
x_test  = x_test/255.0

print(x_train.shape)
print(x_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# (60000, 784)
# (10000, 784)
# (60000,)
# (10000,)

# %%
# create model
model = keras.Sequential()
model.add(keras.Input(shape=(784,)))
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimizer and loss
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['sparse_categorical_accuracy'])

# training
history = model.fit(x_train, y_train, 
                    validation_data=(x_test, y_test), 
                    batch_size=2048, epochs=200, verbose=2)
# Out:
# Epoch 1/200
# 30/30 - 1s - loss: 0.9471 - sparse_categorical_accuracy: 0.7581 - val_loss: 0.3909 - val_sparse_categorical_accuracy: 0.8955 - 893ms/epoch - 30ms/step
# Epoch 2/200
# 30/30 - 0s - loss: 0.3429 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.2841 - val_sparse_categorical_accuracy: 0.9205 - 481ms/epoch - 16ms/step
# Epoch 3/200
# 30/30 - 1s - loss: 0.2705 - sparse_categorical_accuracy: 0.9243 - val_loss: 0.2424 - val_sparse_categorical_accuracy: 0.9340 - 508ms/epoch - 17ms/step
# Epoch 4/200
# 30/30 - 0s - loss: 0.2316 - sparse_categorical_accuracy: 0.9359 - val_loss: 0.2125 - val_sparse_categorical_accuracy: 0.9399 - 482ms/epoch - 16ms/step
# Epoch 5/200
# 30/30 - 0s - loss: 0.2018 - sparse_categorical_accuracy: 0.9445 - val_loss: 0.1900 - val_sparse_categorical_accuracy: 0.9460 - 487ms/epoch - 16ms/step
# Epoch 6/200
# 30/30 - 0s - loss: 0.1792 - sparse_categorical_accuracy: 0.9504 - val_loss: 0.1711 - val_sparse_categorical_accuracy: 0.9510 - 492ms/epoch - 16ms/step
# Epoch 7/200
# 30/30 - 0s - loss: 0.1607 - sparse_categorical_accuracy: 0.9555 - val_loss: 0.1588 - val_sparse_categorical_accuracy: 0.9538 - 476ms/epoch - 16ms/step
# Epoch 8/200
# 30/30 - 0s - loss: 0.1455 - sparse_categorical_accuracy: 0.9596 - val_loss: 0.1436 - val_sparse_categorical_accuracy: 0.9584 - 478ms/epoch - 16ms/step
# Epoch 9/200
# 30/30 - 0s - loss: 0.1321 - sparse_categorical_accuracy: 0.9636 - val_loss: 0.1343 - val_sparse_categorical_accuracy: 0.9617 - 480ms/epoch - 16ms/step
# Epoch 10/200
# 30/30 - 0s - loss: 0.1204 - sparse_categorical_accuracy: 0.9669 - val_loss: 0.1255 - val_sparse_categorical_accuracy: 0.9642 - 493ms/epoch - 16ms/step
# Epoch 11/200
# 30/30 - 0s - loss: 0.1115 - sparse_categorical_accuracy: 0.9689 - val_loss: 0.1209 - val_sparse_categorical_accuracy: 0.9645 - 468ms/epoch - 16ms/step
# Epoch 12/200
# 30/30 - 1s - loss: 0.1024 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.1119 - val_sparse_categorical_accuracy: 0.9676 - 502ms/epoch - 17ms/step
# Epoch 13/200
# 30/30 - 0s - loss: 0.0951 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.1061 - val_sparse_categorical_accuracy: 0.9687 - 479ms/epoch - 16ms/step
# Epoch 14/200
# 30/30 - 0s - loss: 0.0881 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.1022 - val_sparse_categorical_accuracy: 0.9704 - 470ms/epoch - 16ms/step
# Epoch 15/200
# 30/30 - 0s - loss: 0.0818 - sparse_categorical_accuracy: 0.9783 - val_loss: 0.1007 - val_sparse_categorical_accuracy: 0.9702 - 469ms/epoch - 16ms/step
# Epoch 16/200
# 30/30 - 0s - loss: 0.0770 - sparse_categorical_accuracy: 0.9798 - val_loss: 0.0947 - val_sparse_categorical_accuracy: 0.9706 - 471ms/epoch - 16ms/step
# Epoch 17/200
# 30/30 - 0s - loss: 0.0719 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.0925 - val_sparse_categorical_accuracy: 0.9735 - 476ms/epoch - 16ms/step
# Epoch 18/200
# 30/30 - 0s - loss: 0.0673 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.0892 - val_sparse_categorical_accuracy: 0.9730 - 477ms/epoch - 16ms/step
# Epoch 19/200
# 30/30 - 0s - loss: 0.0633 - sparse_categorical_accuracy: 0.9836 - val_loss: 0.0885 - val_sparse_categorical_accuracy: 0.9731 - 481ms/epoch - 16ms/step
# Epoch 20/200
# 30/30 - 0s - loss: 0.0597 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.0845 - val_sparse_categorical_accuracy: 0.9742 - 485ms/epoch - 16ms/step
# Epoch 21/200
# 30/30 - 0s - loss: 0.0563 - sparse_categorical_accuracy: 0.9853 - val_loss: 0.0833 - val_sparse_categorical_accuracy: 0.9751 - 497ms/epoch - 17ms/step
# Epoch 22/200
# 30/30 - 1s - loss: 0.0528 - sparse_categorical_accuracy: 0.9862 - val_loss: 0.0841 - val_sparse_categorical_accuracy: 0.9746 - 502ms/epoch - 17ms/step
# Epoch 23/200
# 30/30 - 0s - loss: 0.0501 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.0799 - val_sparse_categorical_accuracy: 0.9773 - 498ms/epoch - 17ms/step
# Epoch 24/200
# 30/30 - 1s - loss: 0.0476 - sparse_categorical_accuracy: 0.9878 - val_loss: 0.0783 - val_sparse_categorical_accuracy: 0.9764 - 507ms/epoch - 17ms/step
# Epoch 25/200
# 30/30 - 1s - loss: 0.0445 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.0775 - val_sparse_categorical_accuracy: 0.9759 - 642ms/epoch - 21ms/step
# Epoch 26/200
# 30/30 - 1s - loss: 0.0423 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.0754 - val_sparse_categorical_accuracy: 0.9775 - 615ms/epoch - 21ms/step
# Epoch 27/200
# 30/30 - 0s - loss: 0.0402 - sparse_categorical_accuracy: 0.9899 - val_loss: 0.0743 - val_sparse_categorical_accuracy: 0.9778 - 486ms/epoch - 16ms/step
# Epoch 28/200
# 30/30 - 1s - loss: 0.0381 - sparse_categorical_accuracy: 0.9905 - val_loss: 0.0754 - val_sparse_categorical_accuracy: 0.9770 - 537ms/epoch - 18ms/step
# Epoch 29/200
# 30/30 - 1s - loss: 0.0361 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0728 - val_sparse_categorical_accuracy: 0.9780 - 563ms/epoch - 19ms/step
# Epoch 30/200
# 30/30 - 1s - loss: 0.0343 - sparse_categorical_accuracy: 0.9917 - val_loss: 0.0729 - val_sparse_categorical_accuracy: 0.9764 - 642ms/epoch - 21ms/step
# Epoch 31/200
# 30/30 - 1s - loss: 0.0324 - sparse_categorical_accuracy: 0.9926 - val_loss: 0.0713 - val_sparse_categorical_accuracy: 0.9773 - 536ms/epoch - 18ms/step
# Epoch 32/200
# 30/30 - 1s - loss: 0.0310 - sparse_categorical_accuracy: 0.9929 - val_loss: 0.0737 - val_sparse_categorical_accuracy: 0.9769 - 635ms/epoch - 21ms/step
# Epoch 33/200
# 30/30 - 1s - loss: 0.0295 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.0716 - val_sparse_categorical_accuracy: 0.9774 - 637ms/epoch - 21ms/step
# Epoch 34/200
# 30/30 - 1s - loss: 0.0277 - sparse_categorical_accuracy: 0.9942 - val_loss: 0.0710 - val_sparse_categorical_accuracy: 0.9781 - 604ms/epoch - 20ms/step
# Epoch 35/200
# 30/30 - 1s - loss: 0.0264 - sparse_categorical_accuracy: 0.9947 - val_loss: 0.0710 - val_sparse_categorical_accuracy: 0.9776 - 539ms/epoch - 18ms/step
# Epoch 36/200
# 30/30 - 1s - loss: 0.0254 - sparse_categorical_accuracy: 0.9948 - val_loss: 0.0688 - val_sparse_categorical_accuracy: 0.9778 - 592ms/epoch - 20ms/step
# Epoch 37/200
# 30/30 - 1s - loss: 0.0243 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.0691 - val_sparse_categorical_accuracy: 0.9782 - 571ms/epoch - 19ms/step
# Epoch 38/200
# 30/30 - 1s - loss: 0.0230 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0693 - val_sparse_categorical_accuracy: 0.9783 - 521ms/epoch - 17ms/step
# Epoch 39/200
# 30/30 - 1s - loss: 0.0216 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0691 - val_sparse_categorical_accuracy: 0.9783 - 556ms/epoch - 19ms/step
# Epoch 40/200
# 30/30 - 1s - loss: 0.0205 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0703 - val_sparse_categorical_accuracy: 0.9781 - 587ms/epoch - 20ms/step
# Epoch 41/200
# 30/30 - 1s - loss: 0.0197 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.0688 - val_sparse_categorical_accuracy: 0.9791 - 556ms/epoch - 19ms/step
# Epoch 42/200
# 30/30 - 1s - loss: 0.0188 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0676 - val_sparse_categorical_accuracy: 0.9788 - 565ms/epoch - 19ms/step
# Epoch 43/200
# 30/30 - 1s - loss: 0.0182 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0695 - val_sparse_categorical_accuracy: 0.9781 - 541ms/epoch - 18ms/step
# Epoch 44/200
# 30/30 - 1s - loss: 0.0172 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0676 - val_sparse_categorical_accuracy: 0.9785 - 535ms/epoch - 18ms/step
# Epoch 45/200
# 30/30 - 1s - loss: 0.0165 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0670 - val_sparse_categorical_accuracy: 0.9786 - 510ms/epoch - 17ms/step
# Epoch 46/200
# 30/30 - 1s - loss: 0.0157 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0687 - val_sparse_categorical_accuracy: 0.9779 - 638ms/epoch - 21ms/step
# Epoch 47/200
# 30/30 - 1s - loss: 0.0149 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0682 - val_sparse_categorical_accuracy: 0.9784 - 592ms/epoch - 20ms/step
# Epoch 48/200
# 30/30 - 1s - loss: 0.0141 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0677 - val_sparse_categorical_accuracy: 0.9787 - 558ms/epoch - 19ms/step
# Epoch 49/200
# 30/30 - 1s - loss: 0.0138 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0683 - val_sparse_categorical_accuracy: 0.9788 - 505ms/epoch - 17ms/step
# Epoch 50/200
# 30/30 - 1s - loss: 0.0131 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0687 - val_sparse_categorical_accuracy: 0.9785 - 529ms/epoch - 18ms/step
# Epoch 51/200
# 30/30 - 1s - loss: 0.0125 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0697 - val_sparse_categorical_accuracy: 0.9781 - 581ms/epoch - 19ms/step
# Epoch 52/200
# 30/30 - 1s - loss: 0.0121 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0679 - val_sparse_categorical_accuracy: 0.9793 - 539ms/epoch - 18ms/step
# Epoch 53/200
# 30/30 - 1s - loss: 0.0115 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0678 - val_sparse_categorical_accuracy: 0.9795 - 532ms/epoch - 18ms/step
# Epoch 54/200
# 30/30 - 1s - loss: 0.0111 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0688 - val_sparse_categorical_accuracy: 0.9789 - 553ms/epoch - 18ms/step
# Epoch 55/200
# 30/30 - 1s - loss: 0.0104 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0689 - val_sparse_categorical_accuracy: 0.9790 - 544ms/epoch - 18ms/step
# Epoch 56/200
# 30/30 - 1s - loss: 0.0102 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0691 - val_sparse_categorical_accuracy: 0.9788 - 557ms/epoch - 19ms/step
# Epoch 57/200
# 30/30 - 0s - loss: 0.0095 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0686 - val_sparse_categorical_accuracy: 0.9798 - 498ms/epoch - 17ms/step
# Epoch 58/200
# 30/30 - 1s - loss: 0.0093 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0695 - val_sparse_categorical_accuracy: 0.9792 - 508ms/epoch - 17ms/step
# Epoch 59/200
# 30/30 - 1s - loss: 0.0090 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0693 - val_sparse_categorical_accuracy: 0.9791 - 516ms/epoch - 17ms/step
# Epoch 60/200
# 30/30 - 1s - loss: 0.0085 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.0684 - val_sparse_categorical_accuracy: 0.9793 - 546ms/epoch - 18ms/step
# Epoch 61/200
# 30/30 - 0s - loss: 0.0080 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0696 - val_sparse_categorical_accuracy: 0.9794 - 487ms/epoch - 16ms/step
# Epoch 62/200
# 30/30 - 0s - loss: 0.0077 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0689 - val_sparse_categorical_accuracy: 0.9795 - 493ms/epoch - 16ms/step
# Epoch 63/200
# 30/30 - 0s - loss: 0.0076 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.0697 - val_sparse_categorical_accuracy: 0.9785 - 484ms/epoch - 16ms/step
# Epoch 64/200
# 30/30 - 0s - loss: 0.0073 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.0697 - val_sparse_categorical_accuracy: 0.9796 - 487ms/epoch - 16ms/step
# Epoch 65/200
# 30/30 - 0s - loss: 0.0072 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0702 - val_sparse_categorical_accuracy: 0.9788 - 493ms/epoch - 16ms/step
# Epoch 66/200
# 30/30 - 0s - loss: 0.0068 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0707 - val_sparse_categorical_accuracy: 0.9794 - 487ms/epoch - 16ms/step
# Epoch 67/200
# 30/30 - 0s - loss: 0.0064 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.0712 - val_sparse_categorical_accuracy: 0.9790 - 491ms/epoch - 16ms/step
# Epoch 68/200
# 30/30 - 0s - loss: 0.0062 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0702 - val_sparse_categorical_accuracy: 0.9791 - 492ms/epoch - 16ms/step
# Epoch 69/200
# 30/30 - 0s - loss: 0.0058 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0704 - val_sparse_categorical_accuracy: 0.9794 - 486ms/epoch - 16ms/step
# Epoch 70/200
# 30/30 - 0s - loss: 0.0058 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0709 - val_sparse_categorical_accuracy: 0.9794 - 489ms/epoch - 16ms/step
# Epoch 71/200
# 30/30 - 0s - loss: 0.0054 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0726 - val_sparse_categorical_accuracy: 0.9791 - 493ms/epoch - 16ms/step
# Epoch 72/200
# 30/30 - 0s - loss: 0.0053 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0706 - val_sparse_categorical_accuracy: 0.9791 - 490ms/epoch - 16ms/step
# Epoch 73/200
# 30/30 - 0s - loss: 0.0050 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0703 - val_sparse_categorical_accuracy: 0.9791 - 498ms/epoch - 17ms/step
# Epoch 74/200
# 30/30 - 1s - loss: 0.0048 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0717 - val_sparse_categorical_accuracy: 0.9788 - 520ms/epoch - 17ms/step
# Epoch 75/200
# 30/30 - 0s - loss: 0.0047 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0716 - val_sparse_categorical_accuracy: 0.9797 - 498ms/epoch - 17ms/step
# Epoch 76/200
# 30/30 - 1s - loss: 0.0045 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0722 - val_sparse_categorical_accuracy: 0.9784 - 601ms/epoch - 20ms/step
# Epoch 77/200
# 30/30 - 1s - loss: 0.0044 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0720 - val_sparse_categorical_accuracy: 0.9794 - 543ms/epoch - 18ms/step
# Epoch 78/200
# 30/30 - 1s - loss: 0.0042 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0729 - val_sparse_categorical_accuracy: 0.9795 - 551ms/epoch - 18ms/step
# Epoch 79/200
# 30/30 - 1s - loss: 0.0041 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0722 - val_sparse_categorical_accuracy: 0.9793 - 558ms/epoch - 19ms/step
# Epoch 80/200
# 30/30 - 1s - loss: 0.0039 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0732 - val_sparse_categorical_accuracy: 0.9795 - 514ms/epoch - 17ms/step
# Epoch 81/200
# 30/30 - 1s - loss: 0.0037 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0727 - val_sparse_categorical_accuracy: 0.9793 - 514ms/epoch - 17ms/step
# Epoch 82/200
# 30/30 - 1s - loss: 0.0036 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0724 - val_sparse_categorical_accuracy: 0.9791 - 626ms/epoch - 21ms/step
# Epoch 83/200
# 30/30 - 1s - loss: 0.0035 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0733 - val_sparse_categorical_accuracy: 0.9793 - 517ms/epoch - 17ms/step
# Epoch 84/200
# 30/30 - 0s - loss: 0.0034 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0735 - val_sparse_categorical_accuracy: 0.9788 - 497ms/epoch - 17ms/step
# Epoch 85/200
# 30/30 - 1s - loss: 0.0033 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0733 - val_sparse_categorical_accuracy: 0.9798 - 578ms/epoch - 19ms/step
# Epoch 86/200
# 30/30 - 1s - loss: 0.0031 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0735 - val_sparse_categorical_accuracy: 0.9794 - 564ms/epoch - 19ms/step
# Epoch 87/200
# 30/30 - 1s - loss: 0.0030 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0737 - val_sparse_categorical_accuracy: 0.9790 - 552ms/epoch - 18ms/step
# Epoch 88/200
# 30/30 - 1s - loss: 0.0029 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0742 - val_sparse_categorical_accuracy: 0.9789 - 540ms/epoch - 18ms/step
# Epoch 89/200
# 30/30 - 1s - loss: 0.0028 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0748 - val_sparse_categorical_accuracy: 0.9789 - 579ms/epoch - 19ms/step
# Epoch 90/200
# 30/30 - 1s - loss: 0.0028 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0739 - val_sparse_categorical_accuracy: 0.9795 - 574ms/epoch - 19ms/step
# Epoch 91/200
# 30/30 - 1s - loss: 0.0026 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0751 - val_sparse_categorical_accuracy: 0.9790 - 519ms/epoch - 17ms/step
# Epoch 92/200
# 30/30 - 1s - loss: 0.0025 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0753 - val_sparse_categorical_accuracy: 0.9791 - 581ms/epoch - 19ms/step
# Epoch 93/200
# 30/30 - 1s - loss: 0.0025 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0751 - val_sparse_categorical_accuracy: 0.9795 - 509ms/epoch - 17ms/step
# Epoch 94/200
# 30/30 - 1s - loss: 0.0024 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0761 - val_sparse_categorical_accuracy: 0.9790 - 579ms/epoch - 19ms/step
# Epoch 95/200
# 30/30 - 1s - loss: 0.0023 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0764 - val_sparse_categorical_accuracy: 0.9790 - 576ms/epoch - 19ms/step
# Epoch 96/200
# 30/30 - 1s - loss: 0.0023 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0753 - val_sparse_categorical_accuracy: 0.9795 - 544ms/epoch - 18ms/step
# Epoch 97/200
# 30/30 - 1s - loss: 0.0022 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0760 - val_sparse_categorical_accuracy: 0.9789 - 577ms/epoch - 19ms/step
# Epoch 98/200
# 30/30 - 1s - loss: 0.0022 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0767 - val_sparse_categorical_accuracy: 0.9795 - 572ms/epoch - 19ms/step
# Epoch 99/200
# 30/30 - 1s - loss: 0.0021 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0762 - val_sparse_categorical_accuracy: 0.9792 - 562ms/epoch - 19ms/step
# Epoch 100/200
# 30/30 - 1s - loss: 0.0020 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0766 - val_sparse_categorical_accuracy: 0.9795 - 567ms/epoch - 19ms/step
# Epoch 101/200
# 30/30 - 1s - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0768 - val_sparse_categorical_accuracy: 0.9795 - 524ms/epoch - 17ms/step
# Epoch 102/200
# 30/30 - 1s - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0764 - val_sparse_categorical_accuracy: 0.9798 - 563ms/epoch - 19ms/step
# Epoch 103/200
# 30/30 - 1s - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0774 - val_sparse_categorical_accuracy: 0.9798 - 552ms/epoch - 18ms/step
# Epoch 104/200
# 30/30 - 1s - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0779 - val_sparse_categorical_accuracy: 0.9789 - 517ms/epoch - 17ms/step
# Epoch 105/200
# 30/30 - 1s - loss: 0.0017 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0773 - val_sparse_categorical_accuracy: 0.9794 - 508ms/epoch - 17ms/step
# Epoch 106/200
# 30/30 - 1s - loss: 0.0017 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0786 - val_sparse_categorical_accuracy: 0.9793 - 502ms/epoch - 17ms/step
# Epoch 107/200
# 30/30 - 0s - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0781 - val_sparse_categorical_accuracy: 0.9796 - 499ms/epoch - 17ms/step
# Epoch 108/200
# 30/30 - 1s - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0784 - val_sparse_categorical_accuracy: 0.9794 - 504ms/epoch - 17ms/step
# Epoch 109/200
# 30/30 - 1s - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0785 - val_sparse_categorical_accuracy: 0.9797 - 541ms/epoch - 18ms/step
# Epoch 110/200
# 30/30 - 1s - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0787 - val_sparse_categorical_accuracy: 0.9796 - 528ms/epoch - 18ms/step
# Epoch 111/200
# 30/30 - 1s - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0786 - val_sparse_categorical_accuracy: 0.9797 - 518ms/epoch - 17ms/step
# Epoch 112/200
# 30/30 - 1s - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0795 - val_sparse_categorical_accuracy: 0.9792 - 536ms/epoch - 18ms/step
# Epoch 113/200
# 30/30 - 1s - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0791 - val_sparse_categorical_accuracy: 0.9793 - 508ms/epoch - 17ms/step
# Epoch 114/200
# 30/30 - 1s - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0787 - val_sparse_categorical_accuracy: 0.9795 - 500ms/epoch - 17ms/step
# Epoch 115/200
# 30/30 - 0s - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0791 - val_sparse_categorical_accuracy: 0.9796 - 500ms/epoch - 17ms/step
# Epoch 116/200
# 30/30 - 1s - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0798 - val_sparse_categorical_accuracy: 0.9792 - 519ms/epoch - 17ms/step
# Epoch 117/200
# 30/30 - 1s - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0800 - val_sparse_categorical_accuracy: 0.9795 - 501ms/epoch - 17ms/step
# Epoch 118/200
# 30/30 - 1s - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0802 - val_sparse_categorical_accuracy: 0.9797 - 520ms/epoch - 17ms/step
# Epoch 119/200
# 30/30 - 1s - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0809 - val_sparse_categorical_accuracy: 0.9793 - 553ms/epoch - 18ms/step
# Epoch 120/200
# 30/30 - 1s - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0810 - val_sparse_categorical_accuracy: 0.9792 - 539ms/epoch - 18ms/step
# Epoch 121/200
# 30/30 - 1s - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0812 - val_sparse_categorical_accuracy: 0.9797 - 523ms/epoch - 17ms/step
# Epoch 122/200
# 30/30 - 1s - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0810 - val_sparse_categorical_accuracy: 0.9798 - 503ms/epoch - 17ms/step
# Epoch 123/200
# 30/30 - 1s - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0812 - val_sparse_categorical_accuracy: 0.9800 - 514ms/epoch - 17ms/step
# Epoch 124/200
# 30/30 - 1s - loss: 0.0010 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0812 - val_sparse_categorical_accuracy: 0.9800 - 544ms/epoch - 18ms/step
# Epoch 125/200
# 30/30 - 1s - loss: 0.0010 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0822 - val_sparse_categorical_accuracy: 0.9796 - 546ms/epoch - 18ms/step
# Epoch 126/200
# 30/30 - 1s - loss: 0.0010 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0818 - val_sparse_categorical_accuracy: 0.9796 - 555ms/epoch - 18ms/step
# Epoch 127/200
# 30/30 - 1s - loss: 9.6947e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0822 - val_sparse_categorical_accuracy: 0.9795 - 532ms/epoch - 18ms/step
# Epoch 128/200
# 30/30 - 1s - loss: 9.4051e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0820 - val_sparse_categorical_accuracy: 0.9794 - 585ms/epoch - 20ms/step
# Epoch 129/200
# 30/30 - 1s - loss: 9.1778e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0818 - val_sparse_categorical_accuracy: 0.9798 - 576ms/epoch - 19ms/step
# Epoch 130/200
# 30/30 - 1s - loss: 8.9687e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0823 - val_sparse_categorical_accuracy: 0.9791 - 617ms/epoch - 21ms/step
# Epoch 131/200
# 30/30 - 1s - loss: 8.6605e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0831 - val_sparse_categorical_accuracy: 0.9798 - 649ms/epoch - 22ms/step
# Epoch 132/200
# 30/30 - 1s - loss: 8.4319e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0831 - val_sparse_categorical_accuracy: 0.9795 - 579ms/epoch - 19ms/step
# Epoch 133/200
# 30/30 - 1s - loss: 8.2914e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0831 - val_sparse_categorical_accuracy: 0.9796 - 552ms/epoch - 18ms/step
# Epoch 134/200
# 30/30 - 1s - loss: 7.9799e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0831 - val_sparse_categorical_accuracy: 0.9798 - 561ms/epoch - 19ms/step
# Epoch 135/200
# 30/30 - 1s - loss: 7.8070e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0833 - val_sparse_categorical_accuracy: 0.9794 - 557ms/epoch - 19ms/step
# Epoch 136/200
# 30/30 - 1s - loss: 7.6148e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0836 - val_sparse_categorical_accuracy: 0.9797 - 557ms/epoch - 19ms/step
# Epoch 137/200
# 30/30 - 1s - loss: 7.4814e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0836 - val_sparse_categorical_accuracy: 0.9795 - 566ms/epoch - 19ms/step
# Epoch 138/200
# 30/30 - 1s - loss: 7.3182e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0838 - val_sparse_categorical_accuracy: 0.9792 - 528ms/epoch - 18ms/step
# Epoch 139/200
# 30/30 - 1s - loss: 7.2137e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0845 - val_sparse_categorical_accuracy: 0.9798 - 518ms/epoch - 17ms/step
# Epoch 140/200
# 30/30 - 1s - loss: 6.9931e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0846 - val_sparse_categorical_accuracy: 0.9791 - 514ms/epoch - 17ms/step
# Epoch 141/200
# 30/30 - 1s - loss: 6.8157e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0851 - val_sparse_categorical_accuracy: 0.9800 - 522ms/epoch - 17ms/step
# Epoch 142/200
# 30/30 - 1s - loss: 6.6628e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0851 - val_sparse_categorical_accuracy: 0.9795 - 508ms/epoch - 17ms/step
# Epoch 143/200
# 30/30 - 1s - loss: 6.5691e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0854 - val_sparse_categorical_accuracy: 0.9796 - 508ms/epoch - 17ms/step
# Epoch 144/200
# 30/30 - 1s - loss: 6.3434e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0849 - val_sparse_categorical_accuracy: 0.9795 - 507ms/epoch - 17ms/step
# Epoch 145/200
# 30/30 - 1s - loss: 6.2400e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0855 - val_sparse_categorical_accuracy: 0.9793 - 521ms/epoch - 17ms/step
# Epoch 146/200
# 30/30 - 1s - loss: 6.0986e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0851 - val_sparse_categorical_accuracy: 0.9794 - 528ms/epoch - 18ms/step
# Epoch 147/200
# 30/30 - 1s - loss: 6.0154e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0857 - val_sparse_categorical_accuracy: 0.9800 - 535ms/epoch - 18ms/step
# Epoch 148/200
# 30/30 - 1s - loss: 5.8780e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0856 - val_sparse_categorical_accuracy: 0.9798 - 643ms/epoch - 21ms/step
# Epoch 149/200
# 30/30 - 1s - loss: 5.7322e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0861 - val_sparse_categorical_accuracy: 0.9799 - 601ms/epoch - 20ms/step
# Epoch 150/200
# 30/30 - 1s - loss: 5.5335e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0864 - val_sparse_categorical_accuracy: 0.9799 - 603ms/epoch - 20ms/step
# Epoch 151/200
# 30/30 - 1s - loss: 5.4905e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0862 - val_sparse_categorical_accuracy: 0.9797 - 705ms/epoch - 24ms/step
# Epoch 152/200
# 30/30 - 1s - loss: 5.3126e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0875 - val_sparse_categorical_accuracy: 0.9794 - 665ms/epoch - 22ms/step
# Epoch 153/200
# 30/30 - 1s - loss: 5.2276e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0865 - val_sparse_categorical_accuracy: 0.9795 - 681ms/epoch - 23ms/step
# Epoch 154/200
# 30/30 - 1s - loss: 5.0787e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0868 - val_sparse_categorical_accuracy: 0.9798 - 697ms/epoch - 23ms/step
# Epoch 155/200
# 30/30 - 1s - loss: 4.9596e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0869 - val_sparse_categorical_accuracy: 0.9799 - 631ms/epoch - 21ms/step
# Epoch 156/200
# 30/30 - 1s - loss: 4.8957e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0876 - val_sparse_categorical_accuracy: 0.9796 - 601ms/epoch - 20ms/step
# Epoch 157/200
# 30/30 - 1s - loss: 4.7854e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0872 - val_sparse_categorical_accuracy: 0.9795 - 580ms/epoch - 19ms/step
# Epoch 158/200
# 30/30 - 1s - loss: 4.6632e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0874 - val_sparse_categorical_accuracy: 0.9798 - 545ms/epoch - 18ms/step
# Epoch 159/200
# 30/30 - 1s - loss: 4.5637e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0887 - val_sparse_categorical_accuracy: 0.9795 - 544ms/epoch - 18ms/step
# Epoch 160/200
# 30/30 - 1s - loss: 4.5345e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0882 - val_sparse_categorical_accuracy: 0.9798 - 560ms/epoch - 19ms/step
# Epoch 161/200
# 30/30 - 1s - loss: 4.3510e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0881 - val_sparse_categorical_accuracy: 0.9801 - 538ms/epoch - 18ms/step
# Epoch 162/200
# 30/30 - 1s - loss: 4.3097e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0886 - val_sparse_categorical_accuracy: 0.9794 - 543ms/epoch - 18ms/step
# Epoch 163/200
# 30/30 - 1s - loss: 4.1789e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0886 - val_sparse_categorical_accuracy: 0.9799 - 558ms/epoch - 19ms/step
# Epoch 164/200
# 30/30 - 1s - loss: 4.1029e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0887 - val_sparse_categorical_accuracy: 0.9798 - 558ms/epoch - 19ms/step
# Epoch 165/200
# 30/30 - 1s - loss: 3.9765e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0890 - val_sparse_categorical_accuracy: 0.9799 - 552ms/epoch - 18ms/step
# Epoch 166/200
# 30/30 - 1s - loss: 3.9188e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0891 - val_sparse_categorical_accuracy: 0.9798 - 551ms/epoch - 18ms/step
# Epoch 167/200
# 30/30 - 1s - loss: 3.8496e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0890 - val_sparse_categorical_accuracy: 0.9800 - 540ms/epoch - 18ms/step
# Epoch 168/200
# 30/30 - 1s - loss: 3.7794e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0897 - val_sparse_categorical_accuracy: 0.9800 - 550ms/epoch - 18ms/step
# Epoch 169/200
# 30/30 - 1s - loss: 3.7227e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0897 - val_sparse_categorical_accuracy: 0.9800 - 540ms/epoch - 18ms/step
# Epoch 170/200
# 30/30 - 1s - loss: 3.6038e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0898 - val_sparse_categorical_accuracy: 0.9798 - 534ms/epoch - 18ms/step
# Epoch 171/200
# 30/30 - 1s - loss: 3.5155e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0898 - val_sparse_categorical_accuracy: 0.9797 - 548ms/epoch - 18ms/step
# Epoch 172/200
# 30/30 - 1s - loss: 3.4951e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0905 - val_sparse_categorical_accuracy: 0.9795 - 578ms/epoch - 19ms/step
# Epoch 173/200
# 30/30 - 1s - loss: 3.4123e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0904 - val_sparse_categorical_accuracy: 0.9797 - 623ms/epoch - 21ms/step
# Epoch 174/200
# 30/30 - 1s - loss: 3.3082e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0904 - val_sparse_categorical_accuracy: 0.9796 - 570ms/epoch - 19ms/step
# Epoch 175/200
# 30/30 - 1s - loss: 3.2312e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0907 - val_sparse_categorical_accuracy: 0.9799 - 571ms/epoch - 19ms/step
# Epoch 176/200
# 30/30 - 1s - loss: 3.1894e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0908 - val_sparse_categorical_accuracy: 0.9800 - 539ms/epoch - 18ms/step
# Epoch 177/200
# 30/30 - 1s - loss: 3.1168e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0912 - val_sparse_categorical_accuracy: 0.9798 - 548ms/epoch - 18ms/step
# Epoch 178/200
# 30/30 - 1s - loss: 3.0344e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0913 - val_sparse_categorical_accuracy: 0.9798 - 531ms/epoch - 18ms/step
# Epoch 179/200
# 30/30 - 1s - loss: 2.9727e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0912 - val_sparse_categorical_accuracy: 0.9795 - 542ms/epoch - 18ms/step
# Epoch 180/200
# 30/30 - 1s - loss: 2.9270e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0918 - val_sparse_categorical_accuracy: 0.9799 - 534ms/epoch - 18ms/step
# Epoch 181/200
# 30/30 - 1s - loss: 2.8479e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0916 - val_sparse_categorical_accuracy: 0.9801 - 539ms/epoch - 18ms/step
# Epoch 182/200
# 30/30 - 1s - loss: 2.7949e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0915 - val_sparse_categorical_accuracy: 0.9801 - 532ms/epoch - 18ms/step
# Epoch 183/200
# 30/30 - 1s - loss: 2.7660e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0926 - val_sparse_categorical_accuracy: 0.9797 - 530ms/epoch - 18ms/step
# Epoch 184/200
# 30/30 - 1s - loss: 2.7025e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0919 - val_sparse_categorical_accuracy: 0.9796 - 569ms/epoch - 19ms/step
# Epoch 185/200
# 30/30 - 1s - loss: 2.6631e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0924 - val_sparse_categorical_accuracy: 0.9797 - 567ms/epoch - 19ms/step
# Epoch 186/200
# 30/30 - 1s - loss: 2.6077e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0923 - val_sparse_categorical_accuracy: 0.9797 - 595ms/epoch - 20ms/step
# Epoch 187/200
# 30/30 - 1s - loss: 2.5474e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0927 - val_sparse_categorical_accuracy: 0.9802 - 579ms/epoch - 19ms/step
# Epoch 188/200
# 30/30 - 1s - loss: 2.5439e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0930 - val_sparse_categorical_accuracy: 0.9798 - 740ms/epoch - 25ms/step
# Epoch 189/200
# 30/30 - 1s - loss: 2.4374e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0936 - val_sparse_categorical_accuracy: 0.9798 - 561ms/epoch - 19ms/step
# Epoch 190/200
# 30/30 - 1s - loss: 2.4257e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0936 - val_sparse_categorical_accuracy: 0.9797 - 540ms/epoch - 18ms/step
# Epoch 191/200
# 30/30 - 1s - loss: 2.3668e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0932 - val_sparse_categorical_accuracy: 0.9798 - 536ms/epoch - 18ms/step
# Epoch 192/200
# 30/30 - 1s - loss: 2.2903e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0941 - val_sparse_categorical_accuracy: 0.9799 - 535ms/epoch - 18ms/step
# Epoch 193/200
# 30/30 - 1s - loss: 2.2675e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0939 - val_sparse_categorical_accuracy: 0.9798 - 554ms/epoch - 18ms/step
# Epoch 194/200
# 30/30 - 1s - loss: 2.2373e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0942 - val_sparse_categorical_accuracy: 0.9797 - 549ms/epoch - 18ms/step
# Epoch 195/200
# 30/30 - 1s - loss: 2.1495e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0943 - val_sparse_categorical_accuracy: 0.9799 - 561ms/epoch - 19ms/step
# Epoch 196/200
# 30/30 - 1s - loss: 2.1265e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0944 - val_sparse_categorical_accuracy: 0.9800 - 533ms/epoch - 18ms/step
# Epoch 197/200
# 30/30 - 1s - loss: 2.0895e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0951 - val_sparse_categorical_accuracy: 0.9796 - 541ms/epoch - 18ms/step
# Epoch 198/200
# 30/30 - 1s - loss: 2.0385e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0947 - val_sparse_categorical_accuracy: 0.9799 - 533ms/epoch - 18ms/step
# Epoch 199/200
# 30/30 - 1s - loss: 1.9905e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0950 - val_sparse_categorical_accuracy: 0.9799 - 534ms/epoch - 18ms/step
# Epoch 200/200
# 30/30 - 1s - loss: 1.9454e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0949 - val_sparse_categorical_accuracy: 0.9799 - 549ms/epoch - 18ms/step

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()
