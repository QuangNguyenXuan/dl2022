# %%
import torch
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import matplotlib.pyplot as plt

from torchvision.datasets import CIFAR10
from torch.utils.data import DataLoader 
from torch.optim import Adam

RANDOM_SEED = 1
torch.manual_seed(RANDOM_SEED)

# %%
class CNNModel(nn.Module):
    def __init__(self, n_classes=10):
        super(CNNModel, self).__init__()
        self.conv_layer1 = nn.Sequential(
            nn.Conv2d(3, 64, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.BatchNorm2d(64)
        )
        self.conv_layer2 = nn.Sequential(
            nn.Conv2d(64, 64, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.BatchNorm2d(64)
        )
        self.conv_layer3 = nn.Sequential(
            nn.Conv2d(64, 64, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2, 2)
        )
        
        self.conv_layer4 = nn.Sequential(
            nn.Conv2d(64, 128, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.BatchNorm2d(128)
        )
        self.conv_layer5 = nn.Sequential(
            nn.Conv2d(128, 128, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.BatchNorm2d(128)
        )
        self.conv_layer6 = nn.Sequential(
            nn.Conv2d(128, 128, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2, 2)
        )

        self.conv_layer7 = nn.Sequential(
            nn.Conv2d(128, 256, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.BatchNorm2d(256)
        )
        self.conv_layer8 = nn.Sequential(
            nn.Conv2d(256, 256, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.BatchNorm2d(256)
        )
        self.conv_layer9 = nn.Sequential(
            nn.Conv2d(256, 256, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2, 2)
        )

        self.conv_layer10 = nn.Sequential(
            nn.Conv2d(256, 512, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.BatchNorm2d(512)
        )
        self.conv_layer11 = nn.Sequential(
            nn.Conv2d(512, 512, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.BatchNorm2d(512)
        )
        self.conv_layer12 = nn.Sequential(
            nn.Conv2d(512, 512, 3, stride=1, padding='same'),
            nn.ReLU(),
            nn.BatchNorm2d(512),
            nn.MaxPool2d(2, 2)
        )

        self.flatten = nn.Flatten()

        self.fc_layer1 = nn.Sequential(
            nn.Linear(512 * 2 * 2, 512),
            nn.ReLU()
        )
        self.fc_layer2 = nn.Linear(512, n_classes)
    
    def forward(self, x):
        x = self.conv_layer1(x)
        x = self.conv_layer2(x)
        x = self.conv_layer3(x)
        x = self.conv_layer4(x)
        x = self.conv_layer5(x)
        x = self.conv_layer6(x)
        x = self.conv_layer7(x)
        x = self.conv_layer8(x)
        x = self.conv_layer9(x)
        x = self.conv_layer10(x)
        x = self.conv_layer11(x)
        x = self.conv_layer12(x)
        x = self.flatten(x)
        x = self.fc_layer1(x)
        out = self.fc_layer2(x)

        return out

# %%
n_classes = 10
n_epochs = 50
batch_size = 256
lr = 1e-4

# %%
transform = transforms.Compose(
    [
        transforms.ToTensor()
    ])

train_set = CIFAR10(
    root='./data', 
    train=True,
    download=True, 
    transform=transform
)

val_set = CIFAR10(
    root='./data', 
    train=False,
    download=True, 
    transform=transform
)

train_dataloader = DataLoader(
    train_set, 
    batch_size=batch_size,
    shuffle=True,
    num_workers=2
)

val_dataloader = DataLoader(
    val_set, 
    batch_size=batch_size,
    shuffle=False, 
    num_workers=2
)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = CNNModel(n_classes)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=lr)  

training_steps = len(train_dataloader)
val_steps = len(val_dataloader)

training_losses = []
val_losses = []

val_accs = []

print('Start Training...\n')
for epoch in range(n_epochs):
    total_training_loss = 0
    model.train()
    for idx, (X_train, y_train) in enumerate(train_dataloader):
        X_train = X_train.to(device)
        y_train = y_train.to(device)

        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)
        total_training_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    training_loss = total_training_loss / training_steps
    training_losses.append(training_loss)

    print(f'Epoch [{epoch+1}/{n_epochs}], Training Loss: {training_loss:.3f}')

    with torch.no_grad():
        model.eval()
        n_correct_preds = 0
        n_val_samples = 0
        total_val_loss = 0
        for idx, (X_val, y_val) in enumerate(val_dataloader):
            X_val = X_val.to(device)
            y_val = y_val.to(device)

            y_pred = model(X_val)
            loss = criterion(y_pred, y_val)
            total_val_loss += loss.item()

            y_pred_max, y_pred_max_idx = torch.max(y_pred, 1)
            n_val_samples += y_pred.size(0)
            n_correct_preds += (y_val == y_pred_max_idx).sum().item()

        val_acc = n_correct_preds / n_val_samples
        val_loss = total_val_loss / val_steps
        val_losses.append(val_loss)
        val_accs.append(val_acc)

        print(f'Val Loss: {val_loss:.3f}, Val Accuracy: {val_acc:.3f}\n')

print('Training Completed')
# Out:
# Start Training...
#
# Epoch [1/50], Training Loss: 1.300
# Val Loss: 1.025, Val Accuracy: 0.632
#
# Epoch [2/50], Training Loss: 0.829
# Val Loss: 0.899, Val Accuracy: 0.684
#
# Epoch [3/50], Training Loss: 0.572
# Val Loss: 0.812, Val Accuracy: 0.720
#
# Epoch [4/50], Training Loss: 0.372
# Val Loss: 0.809, Val Accuracy: 0.740
#
# Epoch [5/50], Training Loss: 0.213
# Val Loss: 0.976, Val Accuracy: 0.725
#
# Epoch [6/50], Training Loss: 0.139
# Val Loss: 0.970, Val Accuracy: 0.744
#
# Epoch [7/50], Training Loss: 0.112
# Val Loss: 1.039, Val Accuracy: 0.744
#
# Epoch [8/50], Training Loss: 0.096
# Val Loss: 1.054, Val Accuracy: 0.753
#
# Epoch [9/50], Training Loss: 0.084
# Val Loss: 1.111, Val Accuracy: 0.752
#
# Epoch [10/50], Training Loss: 0.067
# Val Loss: 1.102, Val Accuracy: 0.755
#
# Epoch [11/50], Training Loss: 0.058
# Val Loss: 1.111, Val Accuracy: 0.766
#
# Epoch [12/50], Training Loss: 0.064
# Val Loss: 1.238, Val Accuracy: 0.753
#
# Epoch [13/50], Training Loss: 0.069
# Val Loss: 1.171, Val Accuracy: 0.762
#
# Epoch [14/50], Training Loss: 0.045
# Val Loss: 1.203, Val Accuracy: 0.767
#
# Epoch [15/50], Training Loss: 0.038
# Val Loss: 1.231, Val Accuracy: 0.764
#
# Epoch [16/50], Training Loss: 0.054
# Val Loss: 1.206, Val Accuracy: 0.768
#
# Epoch [17/50], Training Loss: 0.059
# Val Loss: 1.146, Val Accuracy: 0.767
#
# Epoch [18/50], Training Loss: 0.038
# Val Loss: 1.142, Val Accuracy: 0.776
#
# Epoch [19/50], Training Loss: 0.035
# Val Loss: 1.226, Val Accuracy: 0.766
#
# Epoch [20/50], Training Loss: 0.040
# Val Loss: 1.180, Val Accuracy: 0.773
#
# Epoch [21/50], Training Loss: 0.053
# Val Loss: 1.198, Val Accuracy: 0.767
#
# Epoch [22/50], Training Loss: 0.036
# Val Loss: 1.191, Val Accuracy: 0.773
#
# Epoch [23/50], Training Loss: 0.025
# Val Loss: 1.203, Val Accuracy: 0.778
#
# Epoch [24/50], Training Loss: 0.030
# Val Loss: 1.327, Val Accuracy: 0.771
#
# Epoch [25/50], Training Loss: 0.043
# Val Loss: 1.205, Val Accuracy: 0.773
#
# Epoch [26/50], Training Loss: 0.028
# Val Loss: 1.209, Val Accuracy: 0.777
#
# Epoch [27/50], Training Loss: 0.045
# Val Loss: 1.239, Val Accuracy: 0.780
#
# Epoch [28/50], Training Loss: 0.039
# Val Loss: 1.208, Val Accuracy: 0.773
#
# Epoch [29/50], Training Loss: 0.018
# Val Loss: 1.173, Val Accuracy: 0.790
#
# Epoch [30/50], Training Loss: 0.020
# Val Loss: 1.212, Val Accuracy: 0.782
#
# Epoch [31/50], Training Loss: 0.030
# Val Loss: 1.225, Val Accuracy: 0.781
#
# Epoch [32/50], Training Loss: 0.040
# Val Loss: 1.171, Val Accuracy: 0.781
#
# Epoch [33/50], Training Loss: 0.029
# Val Loss: 1.163, Val Accuracy: 0.787
#
# Epoch [34/50], Training Loss: 0.022
# Val Loss: 1.170, Val Accuracy: 0.793
#
# Epoch [35/50], Training Loss: 0.026
# Val Loss: 1.247, Val Accuracy: 0.786
#
# Epoch [36/50], Training Loss: 0.026
# Val Loss: 1.246, Val Accuracy: 0.777
#
# Epoch [37/50], Training Loss: 0.030
# Val Loss: 1.211, Val Accuracy: 0.777
#
# Epoch [38/50], Training Loss: 0.027
# Val Loss: 1.182, Val Accuracy: 0.793
#
# Epoch [39/50], Training Loss: 0.020
# Val Loss: 1.203, Val Accuracy: 0.787
#
# Epoch [40/50], Training Loss: 0.021
# Val Loss: 1.238, Val Accuracy: 0.796
#
# Epoch [41/50], Training Loss: 0.023
# Val Loss: 1.152, Val Accuracy: 0.796
#
# Epoch [42/50], Training Loss: 0.027
# Val Loss: 1.154, Val Accuracy: 0.798
#
# Epoch [43/50], Training Loss: 0.016
# Val Loss: 1.233, Val Accuracy: 0.790
#
# Epoch [44/50], Training Loss: 0.021
# Val Loss: 1.258, Val Accuracy: 0.795
#
# Epoch [45/50], Training Loss: 0.028
# Val Loss: 1.249, Val Accuracy: 0.785
#
# Epoch [46/50], Training Loss: 0.022
# Val Loss: 1.155, Val Accuracy: 0.796
#
# Epoch [47/50], Training Loss: 0.013
# Val Loss: 1.243, Val Accuracy: 0.794
#
# Epoch [48/50], Training Loss: 0.016
# Val Loss: 1.367, Val Accuracy: 0.792
#
# Epoch [49/50], Training Loss: 0.031
# Val Loss: 1.280, Val Accuracy: 0.789
#
# Epoch [50/50], Training Loss: 0.022
# Val Loss: 1.233, Val Accuracy: 0.792
#
# Training Completed

# %%
plt.plot(training_losses, label = "train_loss")
plt.plot(val_losses, label = "val_loss")
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()
