# %% [markdown]
# # From Scratch

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf

from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
PATH = 'rebalanced_cats_and_dogs_over_2/'
train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')

BATCH_SIZE = 128
IMG_SIZE = (160, 160)
BUFFER_SIZE = BATCH_SIZE*5

train_dataset = image_dataset_from_directory(train_dir,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE)
# Out:
# Found 22000 files belonging to 2 classes.
# 2022-03-22 14:01:26.805418: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 14:01:26.814977: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 14:01:26.815696: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 14:01:26.816615: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-22 14:01:26.816988: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 14:01:26.817673: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 14:01:26.818413: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 14:01:27.072554: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 14:01:27.073231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 14:01:27.073864: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 14:01:27.074504: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21664 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
validation_dataset = image_dataset_from_directory(validation_dir,
                                                  shuffle=True,
                                                  batch_size=BATCH_SIZE,
                                                  image_size=IMG_SIZE)
# Out:
# Found 3000 files belonging to 2 classes.

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    print(labels[i])
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)

# %%
train_dataset = train_dataset.prefetch(buffer_size=BUFFER_SIZE)
validation_dataset = validation_dataset.prefetch(buffer_size=BUFFER_SIZE)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %%
preprocess_input = tf.keras.applications.vgg16.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)

# %%
print(IMG_SIZE)
IMG_SHAPE = IMG_SIZE + (3,)
print(IMG_SHAPE)
# Out:
# (160, 160)
# (160, 160, 3)

# %%
# Create the base model from the pre-trained model MobileNet V2
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights=None)

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# 2022-03-22 14:01:28.578542: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8100
# (128, 5, 5, 512)

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (128, 512)

# %%
prediction_layer = tf.keras.layers.Dense(1)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (128, 1)

# %%
inputs = tf.keras.Input(shape=(160, 160, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x)
x = global_average_layer(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
base_learning_rate = 0.0001
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.Adam(base_learning_rate),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  sequential (Sequential)     (None, 160, 160, 3)       0
#
#  tf.__operators__.getitem (S  (None, 160, 160, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 160, 160, 3)      0
#
#  vgg16 (Functional)          (None, 5, 5, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                 513
#
# =================================================================
# Total params: 14,715,201
# Trainable params: 14,715,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 28

# %%
history_fine = model.fit(train_dataset,
                         epochs=25,
                         validation_data=validation_dataset)
# Out:
# Epoch 1/25
# 2022-03-22 14:01:31.084122: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 172/172 [==============================] - 45s 245ms/step - loss: 0.6639 - accuracy: 0.5166 - val_loss: 0.6864 - val_accuracy: 0.5060
# Epoch 2/25
# 172/172 [==============================] - 39s 229ms/step - loss: 0.5964 - accuracy: 0.6293 - val_loss: 0.6564 - val_accuracy: 0.6727
# Epoch 3/25
# 172/172 [==============================] - 40s 229ms/step - loss: 0.5029 - accuracy: 0.7372 - val_loss: 0.6477 - val_accuracy: 0.6967
# Epoch 4/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.4312 - accuracy: 0.7893 - val_loss: 0.5038 - val_accuracy: 0.7570
# Epoch 5/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.3731 - accuracy: 0.8243 - val_loss: 0.5189 - val_accuracy: 0.7860
# Epoch 6/25
# 172/172 [==============================] - 40s 229ms/step - loss: 0.3359 - accuracy: 0.8479 - val_loss: 0.5507 - val_accuracy: 0.7663
# Epoch 7/25
# 172/172 [==============================] - 40s 232ms/step - loss: 0.2931 - accuracy: 0.8688 - val_loss: 0.6385 - val_accuracy: 0.7777
# Epoch 8/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.2800 - accuracy: 0.8765 - val_loss: 0.5200 - val_accuracy: 0.7807
# Epoch 9/25
# 172/172 [==============================] - 40s 229ms/step - loss: 0.2468 - accuracy: 0.8931 - val_loss: 0.5278 - val_accuracy: 0.8007
# Epoch 10/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.2476 - accuracy: 0.8940 - val_loss: 0.8749 - val_accuracy: 0.7440
# Epoch 11/25
# 172/172 [==============================] - 40s 229ms/step - loss: 0.2249 - accuracy: 0.9041 - val_loss: 0.4841 - val_accuracy: 0.8003
# Epoch 12/25
# 172/172 [==============================] - 40s 229ms/step - loss: 0.2112 - accuracy: 0.9106 - val_loss: 0.5680 - val_accuracy: 0.8083
# Epoch 13/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.2016 - accuracy: 0.9170 - val_loss: 0.4788 - val_accuracy: 0.7973
# Epoch 14/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.1839 - accuracy: 0.9240 - val_loss: 0.5836 - val_accuracy: 0.8083
# Epoch 15/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.1673 - accuracy: 0.9304 - val_loss: 0.7206 - val_accuracy: 0.8027
# Epoch 16/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.1636 - accuracy: 0.9332 - val_loss: 0.7494 - val_accuracy: 0.7820
# Epoch 17/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.1630 - accuracy: 0.9329 - val_loss: 0.6420 - val_accuracy: 0.7953
# Epoch 18/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.1455 - accuracy: 0.9417 - val_loss: 0.4808 - val_accuracy: 0.8227
# Epoch 19/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.1394 - accuracy: 0.9445 - val_loss: 0.4972 - val_accuracy: 0.8470
# Epoch 20/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.1323 - accuracy: 0.9459 - val_loss: 0.7394 - val_accuracy: 0.8060
# Epoch 21/25
# 172/172 [==============================] - 40s 229ms/step - loss: 0.1243 - accuracy: 0.9513 - val_loss: 0.7130 - val_accuracy: 0.8320
# Epoch 22/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.1192 - accuracy: 0.9521 - val_loss: 0.4265 - val_accuracy: 0.8487
# Epoch 23/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.1236 - accuracy: 0.9511 - val_loss: 0.9301 - val_accuracy: 0.7927
# Epoch 24/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.1106 - accuracy: 0.9560 - val_loss: 0.5695 - val_accuracy: 0.8363
# Epoch 25/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.1090 - accuracy: 0.9565 - val_loss: 0.5671 - val_accuracy: 0.8483

# %%
acc = history_fine.history['accuracy']
val_acc = history_fine.history['val_accuracy']

loss = history_fine.history['loss']
val_loss = history_fine.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
total_correct_cats = 0
total_correct_dogs = 0
total_correct = 0

for x,y in validation_dataset:    
    output = model.predict(x)
    
    prediction = output > 0.5   
    prediction = tf.dtypes.cast(prediction, tf.int32)
        
    correct_pre = prediction[:,0] == y
    correct_pre = tf.dtypes.cast(correct_pre, tf.int32)
    
    # accumulate
    total_correct = total_correct + tf.math.reduce_sum(correct_pre)
    total_correct_cats = total_correct_cats + tf.math.reduce_sum(correct_pre[y==0])
    total_correct_dogs = total_correct_dogs + tf.math.reduce_sum(correct_pre[y==1])
        
print('total_correct: ', total_correct)
print('total_correct_cats: ', total_correct_cats)
print('total_correct_dogs: ', total_correct_dogs)
# Out:
# total_correct:  tf.Tensor(2545, shape=(), dtype=int32)
# total_correct_cats:  tf.Tensor(1159, shape=(), dtype=int32)
# total_correct_dogs:  tf.Tensor(1386, shape=(), dtype=int32)
