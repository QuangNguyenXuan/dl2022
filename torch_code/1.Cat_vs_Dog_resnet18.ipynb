# %%
import torch
from torchvision import datasets, transforms
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import json
import matplotlib.pyplot as plt

from torchvision.datasets import CIFAR10
from torch.utils.data import DataLoader 
from torch.optim import Adam
import torchvision
import torchvision.models as models

torch.manual_seed(1)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ## Data

# %%
transform = transforms.Compose(
            [
                transforms.Resize((224, 224)),   # Resize images to a fixed size
                transforms.ToTensor(),           # Convert images to PyTorch tensors
                transforms.Normalize(mean=(0.5, 0.5, 0.5), 
                                     std=(0.5, 0.5, 0.5))    
            ])

# Load datasets
train_dataset = datasets.ImageFolder('imbalanced_data/train', transform=transform)
test_dataset = datasets.ImageFolder('imbalanced_data/validation', transform=transform)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=8)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=8)

# %%
print(f'Numbers of Cat images: {train_dataset.targets.count(0)}')
print(f'Numbers of Dog images: {train_dataset.targets.count(1)}')
# Out:
# Numbers of Cat images: 1000
# Numbers of Dog images: 11000

# %% [markdown]
# ## Model

# %%
from torchsummary import summary

# Load Resnet18 model
model = models.resnet18()
model.fc = nn.Linear(512, 2, bias=True)


model.to(device)
summary(model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#        BasicBlock-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
#              ReLU-14           [-1, 64, 56, 56]               0
#            Conv2d-15           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-16           [-1, 64, 56, 56]             128
#              ReLU-17           [-1, 64, 56, 56]               0
#        BasicBlock-18           [-1, 64, 56, 56]               0
#            Conv2d-19          [-1, 128, 28, 28]          73,728
#       BatchNorm2d-20          [-1, 128, 28, 28]             256
#              ReLU-21          [-1, 128, 28, 28]               0
#            Conv2d-22          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-23          [-1, 128, 28, 28]             256
#            Conv2d-24          [-1, 128, 28, 28]           8,192
#       BatchNorm2d-25          [-1, 128, 28, 28]             256
#              ReLU-26          [-1, 128, 28, 28]               0
#        BasicBlock-27          [-1, 128, 28, 28]               0
#            Conv2d-28          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-29          [-1, 128, 28, 28]             256
#              ReLU-30          [-1, 128, 28, 28]               0
#            Conv2d-31          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-32          [-1, 128, 28, 28]             256
#              ReLU-33          [-1, 128, 28, 28]               0
#        BasicBlock-34          [-1, 128, 28, 28]               0
#            Conv2d-35          [-1, 256, 14, 14]         294,912
#       BatchNorm2d-36          [-1, 256, 14, 14]             512
#              ReLU-37          [-1, 256, 14, 14]               0
#            Conv2d-38          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-39          [-1, 256, 14, 14]             512
#            Conv2d-40          [-1, 256, 14, 14]          32,768
#       BatchNorm2d-41          [-1, 256, 14, 14]             512
#              ReLU-42          [-1, 256, 14, 14]               0
#        BasicBlock-43          [-1, 256, 14, 14]               0
#            Conv2d-44          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-45          [-1, 256, 14, 14]             512
#              ReLU-46          [-1, 256, 14, 14]               0
#            Conv2d-47          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-48          [-1, 256, 14, 14]             512
#              ReLU-49          [-1, 256, 14, 14]               0
#        BasicBlock-50          [-1, 256, 14, 14]               0
#            Conv2d-51            [-1, 512, 7, 7]       1,179,648
#       BatchNorm2d-52            [-1, 512, 7, 7]           1,024
#              ReLU-53            [-1, 512, 7, 7]               0
#            Conv2d-54            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-55            [-1, 512, 7, 7]           1,024
#            Conv2d-56            [-1, 512, 7, 7]         131,072
#       BatchNorm2d-57            [-1, 512, 7, 7]           1,024
#              ReLU-58            [-1, 512, 7, 7]               0
#        BasicBlock-59            [-1, 512, 7, 7]               0
#            Conv2d-60            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-61            [-1, 512, 7, 7]           1,024
#              ReLU-62            [-1, 512, 7, 7]               0
#            Conv2d-63            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-64            [-1, 512, 7, 7]           1,024
#              ReLU-65            [-1, 512, 7, 7]               0
#        BasicBlock-66            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                    [-1, 2]           1,026
# ================================================================
# Total params: 11,177,538
# Trainable params: 11,177,538
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 62.79
# Params size (MB): 42.64
# Estimated Total Size (MB): 106.00
# ----------------------------------------------------------------

# %% [markdown]
# # Train

# %%
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=1e-4)  
max_epoch = 20

# %%
from sklearn.metrics import classification_report

target_names = ["Cat", "Dog"]

def cls_report(running_target, running_preds, target_names):
    targets = np.hstack(running_target[:-1])
    targets = np.concatenate((targets, running_target[-1]))
    
    predicts =  np.hstack(running_preds[:-1])
    predicts = np.concatenate((predicts, running_preds[-1]))

    report = classification_report(targets, predicts, 
                                   target_names=target_names, 
                                   zero_division=0.0, output_dict=True)
    del report['weighted avg']
    return report

# %%
# Function to compute loss and accuracy for test set
def evaluate(model, test_loader, criterion):
    model.eval()
    test_loss = 0.0
    running_target = []
    running_pred = []
    with torch.no_grad():
        for images, targets in test_loader:
            running_target.append(targets.numpy())
            
            # Move inputs and targets to the device
            images, targets = images.to(device), targets.to(device)

            outputs = model(images)
            loss = criterion(outputs, targets)
            test_loss += loss.item()
            _, pred = torch.max(outputs, 1)
            running_pred.append(pred.cpu().numpy())
            
    test_loss = test_loss / len(test_loader)
    test_rp = cls_report(running_target, running_pred, target_names)
    return test_loss, test_rp

# %%
# train
hist = {
        "train_loss": [],
        "train_accuracy": [],
        "val_loss": [],
        "val_accuracy": []
    }
for epoch in range(max_epoch):
    running_loss = 0.0
    running_target = []
    running_pred = []
    
    model.train()
    for i, (inputs, targets) in enumerate(train_loader, 0):
        running_target.append(targets.numpy())
        
        # Move inputs and targets to the device
        inputs, targets = inputs.to(device), targets.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        running_loss += loss.item()

        # Backward pass and optimization
        loss.backward()
        optimizer.step()  
    
        # Determine class predictions and track accuracy
        _, pred = torch.max(outputs, 1)
        running_pred.append(pred.cpu().numpy())


    epoch_loss = running_loss / len(train_loader)
    train_rp = cls_report(running_target, running_pred, target_names)
    val_loss, val_rp = evaluate(model, test_loader, criterion)

    print(f"Epoch [{epoch + 1}/{max_epoch}]")

    print(f"Train | loss: {epoch_loss:.4f}, accuracy: {train_rp['accuracy']:.4f}")
    print(f"\tAvg | precision: {train_rp['macro avg']['precision']:.4f}, recall: {train_rp['macro avg']['recall']:.4f}, F1: {train_rp['macro avg']['f1-score']:.4f}")
    print(f"\tCat | precision: {train_rp['Cat']['precision']:.4f}, recall: {train_rp['Cat']['recall']:.4f}, F1: {train_rp['Cat']['f1-score']:.4f}")
    print(f"\tDog | precision: {train_rp['Dog']['precision']:.4f}, recall: {train_rp['Dog']['recall']:.4f}, F1: {train_rp['Dog']['f1-score']:.4f}")
    
    print(f"Valid | loss: {val_loss:.4f}, accuracy: {val_rp['accuracy']:.4f}")
    print(f"\tAvg | precision: {val_rp['macro avg']['precision']:.4f}, recall: {val_rp['macro avg']['recall']:.4f}, F1: {val_rp['macro avg']['f1-score']:.4f}")
    print(f"\tCat | precision: {val_rp['Cat']['precision']:.4f}, recall: {val_rp['Cat']['recall']:.4f}, F1: {val_rp['Cat']['f1-score']:.4f}")
    print(f"\tDog | precision: {val_rp['Dog']['precision']:.4f}, recall: {val_rp['Dog']['recall']:.4f}, F1: {val_rp['Dog']['f1-score']:.4f}")
    
    print("*"*100)

    hist["train_loss"].append(epoch_loss)
    hist["train_accuracy"].append(train_rp['accuracy'])
    hist["val_loss"].append(val_loss)
    hist["val_accuracy"].append(val_rp['accuracy'])
# Out:
# Epoch [1/20]
# Train | loss: 0.2871, accuracy: 0.9044
# 	Avg | precision: 0.5120, recall: 0.5024, F1: 0.4917
# 	Cat | precision: 0.1070, recall: 0.0200, F1: 0.0337
# 	Dog | precision: 0.9170, recall: 0.9848, F1: 0.9497
# Valid | loss: 0.9302, accuracy: 0.5280
# 	Avg | precision: 0.6689, recall: 0.5280, F1: 0.4036
# 	Cat | precision: 0.8231, recall: 0.0713, F1: 0.1313
# 	Dog | precision: 0.5146, recall: 0.9847, F1: 0.6760
# ****************************************************************************************************
# Epoch [2/20]
# Train | loss: 0.2452, accuracy: 0.9163
# 	Avg | precision: 0.6943, recall: 0.5139, F1: 0.5072
# 	Cat | precision: 0.4697, recall: 0.0310, F1: 0.0582
# 	Dog | precision: 0.9188, recall: 0.9968, F1: 0.9562
# Valid | loss: 1.1905, accuracy: 0.5137
# 	Avg | precision: 0.7418, recall: 0.5137, F1: 0.3635
# 	Cat | precision: 0.9767, recall: 0.0280, F1: 0.0544
# 	Dog | precision: 0.5069, recall: 0.9993, F1: 0.6726
# ****************************************************************************************************
# Epoch [3/20]
# Train | loss: 0.2098, accuracy: 0.9226
# 	Avg | precision: 0.7855, recall: 0.5760, F1: 0.6077
# 	Cat | precision: 0.6426, recall: 0.1600, F1: 0.2562
# 	Dog | precision: 0.9285, recall: 0.9919, F1: 0.9592
# Valid | loss: 1.1351, accuracy: 0.5443
# 	Avg | precision: 0.7474, recall: 0.5443, F1: 0.4267
# 	Cat | precision: 0.9716, recall: 0.0913, F1: 0.1670
# 	Dog | precision: 0.5233, recall: 0.9973, F1: 0.6864
# ****************************************************************************************************
# Epoch [4/20]
# Train | loss: 0.1667, accuracy: 0.9367
# 	Avg | precision: 0.8330, recall: 0.6910, F1: 0.7384
# 	Cat | precision: 0.7187, recall: 0.3960, F1: 0.5106
# 	Dog | precision: 0.9472, recall: 0.9859, F1: 0.9662
# Valid | loss: 0.6361, accuracy: 0.6837
# 	Avg | precision: 0.7580, recall: 0.6837, F1: 0.6591
# 	Cat | precision: 0.8964, recall: 0.4153, F1: 0.5677
# 	Dog | precision: 0.6195, recall: 0.9520, F1: 0.7506
# ****************************************************************************************************
# Epoch [5/20]
# Train | loss: 0.1099, accuracy: 0.9585
# 	Avg | precision: 0.8972, recall: 0.8115, F1: 0.8480
# 	Cat | precision: 0.8268, recall: 0.6350, F1: 0.7183
# 	Dog | precision: 0.9675, recall: 0.9879, F1: 0.9776
# Valid | loss: 1.3138, accuracy: 0.6480
# 	Avg | precision: 0.7614, recall: 0.6480, F1: 0.6052
# 	Cat | precision: 0.9336, recall: 0.3187, F1: 0.4751
# 	Dog | precision: 0.5892, recall: 0.9773, F1: 0.7352
# ****************************************************************************************************
# Epoch [6/20]
# Train | loss: 0.0575, accuracy: 0.9792
# 	Avg | precision: 0.9481, recall: 0.9123, F1: 0.9293
# 	Cat | precision: 0.9113, recall: 0.8320, F1: 0.8698
# 	Dog | precision: 0.9848, recall: 0.9926, F1: 0.9887
# Valid | loss: 1.2892, accuracy: 0.6587
# 	Avg | precision: 0.7564, recall: 0.6587, F1: 0.6227
# 	Cat | precision: 0.9146, recall: 0.3500, F1: 0.5063
# 	Dog | precision: 0.5981, recall: 0.9673, F1: 0.7392
# ****************************************************************************************************
# Epoch [7/20]
# Train | loss: 0.0350, accuracy: 0.9866
# 	Avg | precision: 0.9646, recall: 0.9463, F1: 0.9552
# 	Cat | precision: 0.9383, recall: 0.8980, F1: 0.9177
# 	Dog | precision: 0.9908, recall: 0.9946, F1: 0.9927
# Valid | loss: 1.2795, accuracy: 0.6507
# 	Avg | precision: 0.7481, recall: 0.6507, F1: 0.6126
# 	Cat | precision: 0.9036, recall: 0.3373, F1: 0.4913
# 	Dog | precision: 0.5926, recall: 0.9640, F1: 0.7340
# ****************************************************************************************************
# Epoch [8/20]
# Train | loss: 0.0180, accuracy: 0.9938
# 	Avg | precision: 0.9827, recall: 0.9761, F1: 0.9794
# 	Cat | precision: 0.9695, recall: 0.9550, F1: 0.9622
# 	Dog | precision: 0.9959, recall: 0.9973, F1: 0.9966
# Valid | loss: 1.9247, accuracy: 0.6193
# 	Avg | precision: 0.7661, recall: 0.6193, F1: 0.5584
# 	Cat | precision: 0.9637, recall: 0.2480, F1: 0.3945
# 	Dog | precision: 0.5685, recall: 0.9907, F1: 0.7224
# ****************************************************************************************************
# Epoch [9/20]
# Train | loss: 0.0138, accuracy: 0.9960
# 	Avg | precision: 0.9882, recall: 0.9855, F1: 0.9869
# 	Cat | precision: 0.9789, recall: 0.9730, F1: 0.9759
# 	Dog | precision: 0.9975, recall: 0.9981, F1: 0.9978
# Valid | loss: 2.8986, accuracy: 0.5747
# 	Avg | precision: 0.7702, recall: 0.5747, F1: 0.4807
# 	Cat | precision: 1.0000, recall: 0.1493, F1: 0.2599
# 	Dog | precision: 0.5403, recall: 1.0000, F1: 0.7016
# ****************************************************************************************************
# Epoch [10/20]
# Train | loss: 0.0115, accuracy: 0.9972
# 	Avg | precision: 0.9929, recall: 0.9885, F1: 0.9907
# 	Cat | precision: 0.9879, recall: 0.9780, F1: 0.9829
# 	Dog | precision: 0.9980, recall: 0.9989, F1: 0.9985
# Valid | loss: 1.4724, accuracy: 0.6853
# 	Avg | precision: 0.7643, recall: 0.6853, F1: 0.6599
# 	Cat | precision: 0.9088, recall: 0.4120, F1: 0.5670
# 	Dog | precision: 0.6198, recall: 0.9587, F1: 0.7529
# ****************************************************************************************************
# Epoch [11/20]
# Train | loss: 0.0224, accuracy: 0.9921
# 	Avg | precision: 0.9772, recall: 0.9707, F1: 0.9739
# 	Cat | precision: 0.9594, recall: 0.9450, F1: 0.9521
# 	Dog | precision: 0.9950, recall: 0.9964, F1: 0.9957
# Valid | loss: 1.9022, accuracy: 0.6323
# 	Avg | precision: 0.7441, recall: 0.6323, F1: 0.5848
# 	Cat | precision: 0.9093, recall: 0.2940, F1: 0.4443
# 	Dog | precision: 0.5789, recall: 0.9707, F1: 0.7253
# ****************************************************************************************************
# Epoch [12/20]
# Train | loss: 0.0166, accuracy: 0.9943
# 	Avg | precision: 0.9836, recall: 0.9792, F1: 0.9814
# 	Cat | precision: 0.9707, recall: 0.9610, F1: 0.9658
# 	Dog | precision: 0.9965, recall: 0.9974, F1: 0.9969
# Valid | loss: 1.7386, accuracy: 0.6593
# 	Avg | precision: 0.7699, recall: 0.6593, F1: 0.6205
# 	Cat | precision: 0.9426, recall: 0.3393, F1: 0.4990
# 	Dog | precision: 0.5972, recall: 0.9793, F1: 0.7419
# ****************************************************************************************************
# Epoch [13/20]
# Train | loss: 0.0090, accuracy: 0.9978
# 	Avg | precision: 0.9929, recall: 0.9924, F1: 0.9926
# 	Cat | precision: 0.9870, recall: 0.9860, F1: 0.9865
# 	Dog | precision: 0.9987, recall: 0.9988, F1: 0.9988
# Valid | loss: 2.0144, accuracy: 0.6597
# 	Avg | precision: 0.7693, recall: 0.6597, F1: 0.6211
# 	Cat | precision: 0.9411, recall: 0.3407, F1: 0.5002
# 	Dog | precision: 0.5975, recall: 0.9787, F1: 0.7420
# ****************************************************************************************************
# Epoch [14/20]
# Train | loss: 0.0066, accuracy: 0.9974
# 	Avg | precision: 0.9922, recall: 0.9909, F1: 0.9915
# 	Cat | precision: 0.9860, recall: 0.9830, F1: 0.9845
# 	Dog | precision: 0.9985, recall: 0.9987, F1: 0.9986
# Valid | loss: 2.2764, accuracy: 0.6137
# 	Avg | precision: 0.7384, recall: 0.6137, F1: 0.5555
# 	Cat | precision: 0.9108, recall: 0.2520, F1: 0.3948
# 	Dog | precision: 0.5660, recall: 0.9753, F1: 0.7163
# ****************************************************************************************************
# Epoch [15/20]
# Train | loss: 0.0156, accuracy: 0.9942
# 	Avg | precision: 0.9830, recall: 0.9786, F1: 0.9808
# 	Cat | precision: 0.9697, recall: 0.9600, F1: 0.9648
# 	Dog | precision: 0.9964, recall: 0.9973, F1: 0.9968
# Valid | loss: 1.5320, accuracy: 0.6897
# 	Avg | precision: 0.7396, recall: 0.6897, F1: 0.6726
# 	Cat | precision: 0.8491, recall: 0.4613, F1: 0.5978
# 	Dog | precision: 0.6302, recall: 0.9180, F1: 0.7474
# ****************************************************************************************************
# Epoch [16/20]
# Train | loss: 0.0138, accuracy: 0.9946
# 	Avg | precision: 0.9859, recall: 0.9784, F1: 0.9821
# 	Cat | precision: 0.9756, recall: 0.9590, F1: 0.9672
# 	Dog | precision: 0.9963, recall: 0.9978, F1: 0.9970
# Valid | loss: 1.7010, accuracy: 0.6527
# 	Avg | precision: 0.7564, recall: 0.6527, F1: 0.6136
# 	Cat | precision: 0.9194, recall: 0.3347, F1: 0.4907
# 	Dog | precision: 0.5933, recall: 0.9707, F1: 0.7365
# ****************************************************************************************************
# Epoch [17/20]
# Train | loss: 0.0063, accuracy: 0.9982
# 	Avg | precision: 0.9953, recall: 0.9926, F1: 0.9940
# 	Cat | precision: 0.9920, recall: 0.9860, F1: 0.9890
# 	Dog | precision: 0.9987, recall: 0.9993, F1: 0.9990
# Valid | loss: 2.4744, accuracy: 0.6137
# 	Avg | precision: 0.7586, recall: 0.6137, F1: 0.5507
# 	Cat | precision: 0.9523, recall: 0.2393, F1: 0.3825
# 	Dog | precision: 0.5650, recall: 0.9880, F1: 0.7189
# ****************************************************************************************************
# Epoch [18/20]
# Train | loss: 0.0044, accuracy: 0.9989
# 	Avg | precision: 0.9962, recall: 0.9967, F1: 0.9965
# 	Cat | precision: 0.9930, recall: 0.9940, F1: 0.9935
# 	Dog | precision: 0.9995, recall: 0.9994, F1: 0.9994
# Valid | loss: 2.1682, accuracy: 0.6343
# 	Avg | precision: 0.7610, recall: 0.6343, F1: 0.5838
# 	Cat | precision: 0.9429, recall: 0.2860, F1: 0.4389
# 	Dog | precision: 0.5792, recall: 0.9827, F1: 0.7288
# ****************************************************************************************************
# Epoch [19/20]
# Train | loss: 0.0019, accuracy: 0.9997
# 	Avg | precision: 0.9998, recall: 0.9980, F1: 0.9989
# 	Cat | precision: 1.0000, recall: 0.9960, F1: 0.9980
# 	Dog | precision: 0.9996, recall: 1.0000, F1: 0.9998
# Valid | loss: 2.3407, accuracy: 0.6263
# 	Avg | precision: 0.7639, recall: 0.6263, F1: 0.5703
# 	Cat | precision: 0.9544, recall: 0.2653, F1: 0.4152
# 	Dog | precision: 0.5734, recall: 0.9873, F1: 0.7254
# ****************************************************************************************************
# Epoch [20/20]
# Train | loss: 0.0018, accuracy: 0.9995
# 	Avg | precision: 0.9988, recall: 0.9979, F1: 0.9984
# 	Cat | precision: 0.9980, recall: 0.9960, F1: 0.9970
# 	Dog | precision: 0.9996, recall: 0.9998, F1: 0.9997
# Valid | loss: 2.4688, accuracy: 0.6290
# 	Avg | precision: 0.7582, recall: 0.6290, F1: 0.5760
# 	Cat | precision: 0.9408, recall: 0.2753, F1: 0.4260
# 	Dog | precision: 0.5756, recall: 0.9827, F1: 0.7259
# ****************************************************************************************************

# %%
optimal_values = {
    "train_loss": min(hist["train_loss"]),
    "train_accuracy": max(hist["train_accuracy"]),
    "val_loss": min(hist["val_loss"]),
    "val_accuracy": max(hist["val_accuracy"])
}
optimal_values
# Out:
# {'train_loss': 0.0018231445843373373,
#  'train_accuracy': 0.9996666666666667,
#  'val_loss': 0.6361200500358927,
#  'val_accuracy': 0.6896666666666667}

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(hist["train_accuracy"], label='Training Accuracy')
plt.plot(hist["val_accuracy"], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(hist["train_loss"], label='Training Loss')
plt.plot(hist["val_loss"], label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Binary Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# classification_report example output
rp = {
    'Cat': {'precision': 0.1092896174863388, 'recall': 0.02, 'f1-score': 0.0338123415046492, 'support': 1000.0}, 
    'Dog': {'precision': 0.9170686299399171, 'recall': 0.9851818181818182, 'f1-score': 0.9499057720120963, 'support': 11000.0}, 
    'accuracy': 0.90475, 
    'macro avg': {'precision': 0.5131791237131279, 'recall': 0.5025909090909091, 'f1-score': 0.4918590567583727, 'support': 12000.0}, 
    'weighted avg': {'precision': 0.8497537122354522, 'recall': 0.90475, 'f1-score': 0.8735646528031422, 'support': 12000.0}
}

# %%
print(json.dumps(rp, indent = 4))
# Out:
# {
#     "Cat": {
#         "precision": 0.1092896174863388,
#         "recall": 0.02,
#         "f1-score": 0.0338123415046492,
#         "support": 1000.0
#     },
#     "Dog": {
#         "precision": 0.9170686299399171,
#         "recall": 0.9851818181818182,
#         "f1-score": 0.9499057720120963,
#         "support": 11000.0
#     },
#     "accuracy": 0.90475,
#     "macro avg": {
#         "precision": 0.5131791237131279,
#         "recall": 0.5025909090909091,
#         "f1-score": 0.4918590567583727,
#         "support": 12000.0
#     },
#     "weighted avg": {
#         "precision": 0.8497537122354522,
#         "recall": 0.90475,
#         "f1-score": 0.8735646528031422,
#         "support": 12000.0
#     }
# }
